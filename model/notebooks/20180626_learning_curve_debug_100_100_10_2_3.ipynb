# %%
# For debugging:
#   bin/gcloud-run --reuse=bubo-0 --container-exec 'jupyter console --existing=...'
from ipykernel import *; print(get_connection_file())
# Out:
# /root/.local/share/jupyter/runtime/kernel-fe786d9b-f2ad-48a5-8f13-a72b0f4a3cff.json

# %%
# FIXME -1 (log.char) is causing the 'IOStream.flush timed out' errors in remote kernels
from cache import memory
assert memory._verbose == 0

# %%
# Compare at parity with last local OOM run (168 hand-picked species x ≤100 recs)
com_names_168 = [
    "Mountain Quail",
    "Scaled Quail",
    "California Quail",
    "Montezuma Quail",
    "Sooty Grouse",
    "Wild Turkey",
    "Double-crested Cormorant",
    "Least Bittern",
    "Great Blue Heron",
    "Great Egret",
    "Snowy Egret",
    "Green Heron",
    "Black-crowned Night-Heron",
    "Turkey Vulture",
    "California Condor",
    "Osprey",
    "White-tailed Kite",
    "Golden Eagle",
    "Northern Harrier",
    "Sharp-shinned Hawk",
    "Cooper's Hawk",
    "Bald Eagle",
    "Red-shouldered Hawk",
    "Red-tailed Hawk",
    "Killdeer",
    "Rock Pigeon",
    "Band-tailed Pigeon",
    "Eurasian Collared-Dove",
    "Mourning Dove",
    "Western Screech-Owl",
    "Great Horned Owl",
    "Burrowing Owl",
    "Common Nighthawk",
    "Common Poorwill",
    "White-throated Swift",
    "Anna's Hummingbird",
    "Rufous Hummingbird",
    "Allen's Hummingbird",
    "Belted Kingfisher",
    "Acorn Woodpecker",
    "Red-breasted Sapsucker",
    "Nuttall's Woodpecker",
    "Downy Woodpecker",
    "Hairy Woodpecker",
    "Northern Flicker",
    "Pileated Woodpecker",
    "American Kestrel",
    "Merlin",
    "Peregrine Falcon",
    "Olive-sided Flycatcher",
    "Western Wood-Pewee",
    "Pacific-slope Flycatcher",
    "Black Phoebe",
    "Say's Phoebe",
    "Ash-throated Flycatcher",
    "Western Kingbird",
    "Hutton's Vireo",
    "Cassin's Vireo",
    "Warbling Vireo",
    "Steller's Jay",
    "California Scrub-Jay",
    "Black-billed Magpie",
    "Yellow-billed Magpie",
    "Clark's Nutcracker",
    "American Crow",
    "Common Raven",
    "Northern Rough-winged Swallow",
    "Purple Martin",
    "Tree Swallow",
    "Violet-green Swallow",
    "Barn Swallow",
    "Cliff Swallow",
    "Carolina Chickadee",
    "Black-capped Chickadee",
    "Mountain Chickadee",
    "Chestnut-backed Chickadee",
    "Boreal Chickadee",
    "Oak Titmouse",
    "Tufted Titmouse",
    "Black-crested Titmouse",
    "Bushtit",
    "Red-breasted Nuthatch",
    "White-breasted Nuthatch",
    "Pygmy Nuthatch",
    "Brown Creeper",
    "Rock Wren",
    "Canyon Wren",
    "House Wren",
    "Pacific Wren",
    "Winter Wren",
    "Sedge Wren",
    "Marsh Wren",
    "Carolina Wren",
    "Bewick's Wren",
    "Cactus Wren",
    "Blue-gray Gnatcatcher",
    "Golden-crowned Kinglet",
    "Ruby-crowned Kinglet",
    "Wrentit",
    "Western Bluebird",
    "Mountain Bluebird",
    "Swainson's Thrush",
    "Hermit Thrush",
    "Wood Thrush",
    "American Robin",
    "Varied Thrush",
    "California Thrasher",
    "Northern Mockingbird",
    "European Starling",
    "Cedar Waxwing",
    "Phainopepla",
    "Black-and-white Warbler",
    "Orange-crowned Warbler",
    "Nashville Warbler",
    "MacGillivray's Warbler",
    "Common Yellowthroat",
    "American Redstart",
    "Cape May Warbler",
    "Cerulean Warbler",
    "Magnolia Warbler",
    "Bay-breasted Warbler",
    "Yellow Warbler",
    "Black-throated Blue Warbler",
    "Yellow-rumped Warbler",
    "Yellow-throated Warbler",
    "Black-throated Gray Warbler",
    "Townsend's Warbler",
    "Hermit Warbler",
    "Golden-cheeked Warbler",
    "Black-throated Green Warbler",
    "Wilson's Warbler",
    "Chipping Sparrow",
    "Lark Sparrow",
    "Fox Sparrow",
    "Dark-eyed Junco",
    "White-crowned Sparrow",
    "Golden-crowned Sparrow",
    "Bell's Sparrow",
    "Savannah Sparrow",
    "Song Sparrow",
    "Lincoln's Sparrow",
    "Swamp Sparrow",
    "Canyon Towhee",
    "California Towhee",
    "Rufous-crowned Sparrow",
    "Spotted Towhee",
    "Summer Tanager",
    "Scarlet Tanager",
    "Western Tanager",
    "Northern Cardinal",
    "Black-headed Grosbeak",
    "Blue Grosbeak",
    "Lazuli Bunting",
    "Western Meadowlark",
    "Hooded Oriole",
    "Bullock's Oriole",
    "Red-winged Blackbird",
    "Tricolored Blackbird",
    "Brown-headed Cowbird",
    "Brewer's Blackbird",
    "Common Grackle",
    "Great-tailed Grackle",
    "Black Rosy-Finch",
    "House Finch",
    "Purple Finch",
    "Pine Siskin",
    "Lesser Goldfinch",
    "American Goldfinch",
    "House Sparrow",
]

# %%
from notebooks import *

# %%
load = Load()
# recs_all = recs_all if 'recs_all' in locals() else load.recs(
recs_all = load.recs(
    # limit=150,  # XXX Faster dev (need >100 to get >1 species, else things below break)
    datasets=[
        # 'peterson-field-guide',
        # 'recordings',
        'xc',
    ],
)
display(
    df_summary(recs_all).T,
    # df_summary(recs_all),
    recs_all[:5],
)
# Out:
#                                                                                                            min  \
#                  dtype    sizeof  len   count nunique mean         std
# dataset          object   4388754 86054 86054 1       NaN          NaN                                      xc
# species          category 4582743 86054 86054 3693    NaN          NaN                                    GRTI
# species_com_name category 5667529 86054 86054 3693    NaN          NaN                           Great Tinamou
# species_query    object   4582743 86054 86054 3693    NaN          NaN                                    ABBA
# duration_s       float64  2065296 86054 86054 42596   5.255254e+01 8.594005e+01                        0.20898
# samples_mb       float64  2065296 86054 86054 42592   2.229768e+00 3.649662e+00                     0.00878906
# samples_n        int64    2409512 86054 86054 42592   1.169041e+06 1.913474e+06                           4608
# basename         object   4646916 86054 86054 1       NaN          NaN                                   audio
# species_longhand category 6291788 86054 86054 3693    NaN          NaN                    Great Tinamou - GRTI
# id               object   6373543 86054 86054 86054   NaN          NaN               xc/data/ABBA/121054/audio
# path             object   6717759 86054 86054 86054   NaN          NaN           xc/data/ABBA/121054/audio.mp3
#
#                                                                                                             25%  \
#                  dtype    sizeof  len   count nunique mean         std
# dataset          object   4388754 86054 86054 1       NaN          NaN                                       xc
# species          category 4582743 86054 86054 3693    NaN          NaN                                     BHWO
# species_com_name category 5667529 86054 86054 3693    NaN          NaN                  Black-headed Woodpecker
# species_query    object   4582743 86054 86054 3693    NaN          NaN                                     CORA
# duration_s       float64  2065296 86054 86054 42596   5.255254e+01 8.594005e+01                          16.152
# samples_mb       float64  2065296 86054 86054 42592   2.229768e+00 3.649662e+00                        0.681324
# samples_n        int64    2409512 86054 86054 42592   1.169041e+06 1.913474e+06                          357210
# basename         object   4646916 86054 86054 1       NaN          NaN                                    audio
# species_longhand category 6291788 86054 86054 3693    NaN          NaN           Black-headed Woodpecker - BHWO
# id               object   6373543 86054 86054 86054   NaN          NaN                xc/data/CORA/192230/audio
# path             object   6717759 86054 86054 86054   NaN          NaN            xc/data/CORA/192230/audio.mp3
#
#                                                                                                            50%  \
#                  dtype    sizeof  len   count nunique mean         std
# dataset          object   4388754 86054 86054 1       NaN          NaN                                      xc
# species          category 4582743 86054 86054 3693    NaN          NaN                                    BUSH
# species_com_name category 5667529 86054 86054 3693    NaN          NaN                                 Bushtit
# species_query    object   4582743 86054 86054 3693    NaN          NaN                                    LIMP
# duration_s       float64  2065296 86054 86054 42596   5.255254e+01 8.594005e+01                        32.2306
# samples_mb       float64  2065296 86054 86054 42592   2.229768e+00 3.649662e+00                        1.36124
# samples_n        int64    2409512 86054 86054 42592   1.169041e+06 1.913474e+06                         713682
# basename         object   4646916 86054 86054 1       NaN          NaN                                   audio
# species_longhand category 6291788 86054 86054 3693    NaN          NaN                          Bushtit - BUSH
# id               object   6373543 86054 86054 86054   NaN          NaN               xc/data/LIMP/307639/audio
# path             object   6717759 86054 86054 86054   NaN          NaN           xc/data/LIMP/307639/audio.mp3
#
#                                                                                                           75%  \
#                  dtype    sizeof  len   count nunique mean         std
# dataset          object   4388754 86054 86054 1       NaN          NaN                                     xc
# species          category 4582743 86054 86054 3693    NaN          NaN                                   NAWA
# species_com_name category 5667529 86054 86054 3693    NaN          NaN                      Nashville Warbler
# species_query    object   4582743 86054 86054 3693    NaN          NaN                                   SOTF
# duration_s       float64  2065296 86054 86054 42596   5.255254e+01 8.594005e+01                        61.344
# samples_mb       float64  2065296 86054 86054 42592   2.229768e+00 3.649662e+00                       2.59717
# samples_n        int64    2409512 86054 86054 42592   1.169041e+06 1.913474e+06                       1361664
# basename         object   4646916 86054 86054 1       NaN          NaN                                  audio
# species_longhand category 6291788 86054 86054 3693    NaN          NaN               Nashville Warbler - NAWA
# id               object   6373543 86054 86054 86054   NaN          NaN               xc/data/SOTF/18965/audio
# path             object   6717759 86054 86054 86054   NaN          NaN           xc/data/SOTF/18965/audio.mp3
#
#                                                                                                               max
#                  dtype    sizeof  len   count nunique mean         std
# dataset          object   4388754 86054 86054 1       NaN          NaN                                         xc
# species          category 4582743 86054 86054 3693    NaN          NaN                                       PTWH
# species_com_name category 5667529 86054 86054 3693    NaN          NaN                          Pin-tailed Whydah
# species_query    object   4582743 86054 86054 3693    NaN          NaN                                    yethon3
# duration_s       float64  2065296 86054 86054 42596   5.255254e+01 8.594005e+01                           7370.71
# samples_mb       float64  2065296 86054 86054 42592   2.229768e+00 3.649662e+00                            309.99
# samples_n        int64    2409512 86054 86054 42592   1.169041e+06 1.913474e+06                         162524221
# basename         object   4646916 86054 86054 1       NaN          NaN                                      audio
# species_longhand category 6291788 86054 86054 3693    NaN          NaN                   Pin-tailed Whydah - PTWH
# id               object   6373543 86054 86054 86054   NaN          NaN               xc/data/yethon3/407670/audio
# path             object   6717759 86054 86054 86054   NaN          NaN           xc/data/yethon3/407670/audio.mp3
#   dataset species species_com_name species_query  duration_s  samples_mb  \
# 0      xc    GRTI    Great Tinamou          GRTI   11.040952    0.464350
# 1      xc    GRTI    Great Tinamou          GRTI    9.274286    0.390049
# 2      xc    GRTI    Great Tinamou          GRTI   13.116190    0.551628
# 3      xc    LITI   Little Tinamou          LITI   22.312018    0.938377
# 4      xc    LITI   Little Tinamou          LITI   52.715465    2.217056
#
#    samples_n basename       species_longhand                         id  \
# 0     243453    audio   Great Tinamou - GRTI  xc/data/GRTI/231248/audio
# 1     204498    audio   Great Tinamou - GRTI  xc/data/GRTI/231247/audio
# 2     289212    audio   Great Tinamou - GRTI  xc/data/GRTI/231243/audio
# 3     491980    audio  Little Tinamou - LITI  xc/data/LITI/221890/audio
# 4    1162376    audio  Little Tinamou - LITI  xc/data/LITI/221906/audio
#
#                             path
# 0  xc/data/GRTI/231248/audio.mp3
# 1  xc/data/GRTI/231247/audio.mp3
# 2  xc/data/GRTI/231243/audio.mp3
# 3  xc/data/LITI/221890/audio.mp3
# 4  xc/data/LITI/221906/audio.mp3

# %%
(recs_all
    .assign(species=lambda df: df.species_longhand)
    .assign(count=1)
    # 0-fill all (species, dataset) combinations to create empty placeholders for missing bars
    .pipe(lambda df: df.append(
        pd.DataFrame([
            dict(species=species, dataset=dataset, duration_s=0)
            for species in df.species.unique()
            for dataset in df.dataset.unique()
        ])
        .astype({'species': df.species.dtype})
    ))
    .groupby(['dataset', 'species'])[['count', 'duration_s']].sum().reset_index()
    .pipe(df_ordered_cat, species=lambda df: df.sort_values('count').species)  # Order species by count
    .pipe(pd.melt, id_vars=['dataset', 'species'], value_vars=['count', 'duration_s'])
    # .pipe(df_reverse_cat, 'species')  # Order species by taxo
    .pipe(ggplot, aes(x='species', y='value', fill='dataset', color='dataset'))
    + coord_flip()
    + geom_bar(stat='identity', position=position_dodge(), width=.8)
    + facet_wrap('variable', nrow=1, scales='free')
    + xlab('')
    + ylab('')
    + scale_fill_cmap_d(mpl.cm.tab10)
    + scale_color_cmap_d(mpl.cm.tab10)
    + theme(panel_spacing=2.5)
    + theme_figsize(width=18, aspect_ratio=4/1)
    + ggtitle(f'recs_all: Total (count, duration_s) per (species, dataset)')
)
# Out:
# [skip]

# %%
# Subset the data
#   - Runtime: reduce data volume
#   - Class imbalance: clip all classes at the same N (or smaller)
# recs_filter = lambda df: df.columns  # All recs
recs_filter = lambda df: df.species_com_name.isin(com_names_168)  # For parity with the last local OOM runs
# class_count = np.inf   # All species (168)
class_count = 100     # Faster dev
# class_count = 10     # Faster dev
# class_count = 2      # Faster dev
# class_size = np.inf  # recs[14k]  @ species[168]
# class_size = 200     # recs[12k]  @ species[168]
class_size = 100     # recs[10k]  @ species[168]
# class_size = 50      # recs[7.0k] @ species[168]
# class_size = 20      # recs[3.2k] @ species[168]
# class_size = 10      # recs[1.7k] @ species[168]
# class_size = 5       # recs[.84k] @ species[168]
# class_size = 2       # recs[.34k] @ species[168]
recs = (recs_all
    # Filter
    [recs_filter]
    # Drop empty cats else .groupby will fail on g.sample(n=0, ...)
    .pipe(df_remove_unused_categories)
    # Sample class_size per species
    .groupby('species').apply(lambda g: g.sample(n=min(len(g), class_size), random_state=0))
    # Drop classes with <2 instances, else StratifiedShuffleSplit complains (e.g. 'TUVU')
    [lambda df: df.species.isin(df.species.value_counts()[lambda s: s >= 2].index)]
    # Sample class_count of the species
    [lambda df: df.species.isin(df.species.sample(n=min(len(df.species), class_count), random_state=0))]
)
display(
    df_summary(recs_all).T,
    df_summary(recs).T,
)
# Out:
#                                                                                                            min  \
#                  dtype    sizeof  len   count nunique mean         std
# dataset          object   5421402 86054 86054 1       NaN          NaN                                      xc
# species          category 4582743 86054 86054 3693    NaN          NaN                                    GRTI
# species_com_name category 5667529 86054 86054 3693    NaN          NaN                           Great Tinamou
# species_query    object   4583155 86054 86054 3693    NaN          NaN                                    ABBA
# duration_s       float64  2065296 86054 86054 42596   5.255254e+01 8.594005e+01                        0.20898
# samples_mb       float64  2065296 86054 86054 42592   2.229768e+00 3.649662e+00                     0.00878906
# samples_n        int64    2409512 86054 86054 42592   1.169041e+06 1.913474e+06                           4608
# basename         object   4647372 86054 86054 1       NaN          NaN                                   audio
# species_longhand category 9065860 86054 86054 3693    NaN          NaN                    Great Tinamou - GRTI
# id               object   6375403 86054 86054 86054   NaN          NaN               xc/data/ABBA/121054/audio
# path             object   6719907 86054 86054 86054   NaN          NaN           xc/data/ABBA/121054/audio.mp3
#
#                                                                                                             25%  \
#                  dtype    sizeof  len   count nunique mean         std
# dataset          object   5421402 86054 86054 1       NaN          NaN                                       xc
# species          category 4582743 86054 86054 3693    NaN          NaN                                     BHWO
# species_com_name category 5667529 86054 86054 3693    NaN          NaN                  Black-headed Woodpecker
# species_query    object   4583155 86054 86054 3693    NaN          NaN                                     CORA
# duration_s       float64  2065296 86054 86054 42596   5.255254e+01 8.594005e+01                          16.152
# samples_mb       float64  2065296 86054 86054 42592   2.229768e+00 3.649662e+00                        0.681324
# samples_n        int64    2409512 86054 86054 42592   1.169041e+06 1.913474e+06                          357210
# basename         object   4647372 86054 86054 1       NaN          NaN                                    audio
# species_longhand category 9065860 86054 86054 3693    NaN          NaN           Black-headed Woodpecker - BHWO
# id               object   6375403 86054 86054 86054   NaN          NaN                xc/data/CORA/192230/audio
# path             object   6719907 86054 86054 86054   NaN          NaN            xc/data/CORA/192230/audio.mp3
#
#                                                                                                            50%  \
#                  dtype    sizeof  len   count nunique mean         std
# dataset          object   5421402 86054 86054 1       NaN          NaN                                      xc
# species          category 4582743 86054 86054 3693    NaN          NaN                                    BUSH
# species_com_name category 5667529 86054 86054 3693    NaN          NaN                                 Bushtit
# species_query    object   4583155 86054 86054 3693    NaN          NaN                                    LIMP
# duration_s       float64  2065296 86054 86054 42596   5.255254e+01 8.594005e+01                        32.2306
# samples_mb       float64  2065296 86054 86054 42592   2.229768e+00 3.649662e+00                        1.36124
# samples_n        int64    2409512 86054 86054 42592   1.169041e+06 1.913474e+06                         713682
# basename         object   4647372 86054 86054 1       NaN          NaN                                   audio
# species_longhand category 9065860 86054 86054 3693    NaN          NaN                          Bushtit - BUSH
# id               object   6375403 86054 86054 86054   NaN          NaN               xc/data/LIMP/307639/audio
# path             object   6719907 86054 86054 86054   NaN          NaN           xc/data/LIMP/307639/audio.mp3
#
#                                                                                                           75%  \
#                  dtype    sizeof  len   count nunique mean         std
# dataset          object   5421402 86054 86054 1       NaN          NaN                                     xc
# species          category 4582743 86054 86054 3693    NaN          NaN                                   NAWA
# species_com_name category 5667529 86054 86054 3693    NaN          NaN                      Nashville Warbler
# species_query    object   4583155 86054 86054 3693    NaN          NaN                                   SOTF
# duration_s       float64  2065296 86054 86054 42596   5.255254e+01 8.594005e+01                        61.344
# samples_mb       float64  2065296 86054 86054 42592   2.229768e+00 3.649662e+00                       2.59717
# samples_n        int64    2409512 86054 86054 42592   1.169041e+06 1.913474e+06                       1361664
# basename         object   4647372 86054 86054 1       NaN          NaN                                  audio
# species_longhand category 9065860 86054 86054 3693    NaN          NaN               Nashville Warbler - NAWA
# id               object   6375403 86054 86054 86054   NaN          NaN               xc/data/SOTF/18965/audio
# path             object   6719907 86054 86054 86054   NaN          NaN           xc/data/SOTF/18965/audio.mp3
#
#                                                                                                               max
#                  dtype    sizeof  len   count nunique mean         std
# dataset          object   5421402 86054 86054 1       NaN          NaN                                         xc
# species          category 4582743 86054 86054 3693    NaN          NaN                                       PTWH
# species_com_name category 5667529 86054 86054 3693    NaN          NaN                          Pin-tailed Whydah
# species_query    object   4583155 86054 86054 3693    NaN          NaN                                    yethon3
# duration_s       float64  2065296 86054 86054 42596   5.255254e+01 8.594005e+01                           7370.71
# samples_mb       float64  2065296 86054 86054 42592   2.229768e+00 3.649662e+00                            309.99
# samples_n        int64    2409512 86054 86054 42592   1.169041e+06 1.913474e+06                         162524221
# basename         object   4647372 86054 86054 1       NaN          NaN                                      audio
# species_longhand category 9065860 86054 86054 3693    NaN          NaN                   Pin-tailed Whydah - PTWH
# id               object   6375403 86054 86054 86054   NaN          NaN               xc/data/yethon3/407670/audio
# path             object   6719907 86054 86054 86054   NaN          NaN           xc/data/yethon3/407670/audio.mp3
#                                                                                                          min  \
#                  dtype    sizeof  len  count nunique mean         std
# dataset          object   418509  6643 6643  1       NaN          NaN                                     xc
# species          category 352079  6643 6643  71      NaN          NaN                                   GBHE
# species_com_name category 434440  6643 6643  71      NaN          NaN                       Great Blue Heron
# species_query    object   352319  6643 6643  71      NaN          NaN                                   AMCR
# duration_s       float64  159432  6643 6643  5505    5.294381e+01 6.943338e+01                      0.598458
# samples_mb       float64  159432  6643 6643  5511    2.249925e+00 2.966395e+00                     0.0251694
# samples_n        int64    186004  6643 6643  5511    1.179609e+06 1.555245e+06                         13196
# basename         object   359010  6643 6643  1       NaN          NaN                                  audio
# species_longhand category 1129249 6643 6643  71      NaN          NaN                Great Blue Heron - GBHE
# id               object   491437  6643 6643  6643    NaN          NaN               xc/data/AMCR/10197/audio
# path             object   518169  6643 6643  6643    NaN          NaN           xc/data/AMCR/10197/audio.mp3
#
#                                                                                                          25%  \
#                  dtype    sizeof  len  count nunique mean         std
# dataset          object   418509  6643 6643  1       NaN          NaN                                     xc
# species          category 352079  6643 6643  71      NaN          NaN                                   WEWP
# species_com_name category 434440  6643 6643  71      NaN          NaN                     Western Wood-Pewee
# species_query    object   352319  6643 6643  71      NaN          NaN                                   CAVI
# duration_s       float64  159432  6643 6643  5505    5.294381e+01 6.943338e+01                        15.569
# samples_mb       float64  159432  6643 6643  5511    2.249925e+00 2.966395e+00                      0.660622
# samples_n        int64    186004  6643 6643  5511    1.179609e+06 1.555245e+06                        346356
# basename         object   359010  6643 6643  1       NaN          NaN                                  audio
# species_longhand category 1129249 6643 6643  71      NaN          NaN              Western Wood-Pewee - WEWP
# id               object   491437  6643 6643  6643    NaN          NaN               xc/data/CAVI/21317/audio
# path             object   518169  6643 6643  6643    NaN          NaN           xc/data/CAVI/21317/audio.mp3
#
#                                                                                                           50%  \
#                  dtype    sizeof  len  count nunique mean         std
# dataset          object   418509  6643 6643  1       NaN          NaN                                      xc
# species          category 352079  6643 6643  71      NaN          NaN                                    PYNU
# species_com_name category 434440  6643 6643  71      NaN          NaN                          Pygmy Nuthatch
# species_query    object   352319  6643 6643  71      NaN          NaN                                    MOCH
# duration_s       float64  159432  6643 6643  5505    5.294381e+01 6.943338e+01                        32.6008
# samples_mb       float64  159432  6643 6643  5511    2.249925e+00 2.966395e+00                         1.3788
# samples_n        int64    186004  6643 6643  5511    1.179609e+06 1.555245e+06                         722887
# basename         object   359010  6643 6643  1       NaN          NaN                                   audio
# species_longhand category 1129249 6643 6643  71      NaN          NaN                   Pygmy Nuthatch - PYNU
# id               object   491437  6643 6643  6643    NaN          NaN               xc/data/MOCH/109936/audio
# path             object   518169  6643 6643  6643    NaN          NaN           xc/data/MOCH/109936/audio.mp3
#
#                                                                                                           75%  \
#                  dtype    sizeof  len  count nunique mean         std
# dataset          object   418509  6643 6643  1       NaN          NaN                                      xc
# species          category 352079  6643 6643  71      NaN          NaN                                    LASP
# species_com_name category 434440  6643 6643  71      NaN          NaN                            Lark Sparrow
# species_query    object   352319  6643 6643  71      NaN          NaN                                    SAPH
# duration_s       float64  159432  6643 6643  5505    5.294381e+01 6.943338e+01                        63.2686
# samples_mb       float64  159432  6643 6643  5511    2.249925e+00 2.966395e+00                        2.67737
# samples_n        int64    186004  6643 6643  5511    1.179609e+06 1.555245e+06                        1403712
# basename         object   359010  6643 6643  1       NaN          NaN                                   audio
# species_longhand category 1129249 6643 6643  71      NaN          NaN                     Lark Sparrow - LASP
# id               object   491437  6643 6643  6643    NaN          NaN               xc/data/SAPH/186698/audio
# path             object   518169  6643 6643  6643    NaN          NaN           xc/data/SAPH/186698/audio.mp3
#
#                                                                                                          max
#                  dtype    sizeof  len  count nunique mean         std
# dataset          object   418509  6643 6643  1       NaN          NaN                                     xc
# species          category 352079  6643 6643  71      NaN          NaN                                   HOSP
# species_com_name category 434440  6643 6643  71      NaN          NaN                          House Sparrow
# species_query    object   352319  6643 6643  71      NaN          NaN                                   YTWA
# duration_s       float64  159432  6643 6643  5505    5.294381e+01 6.943338e+01                       1011.33
# samples_mb       float64  159432  6643 6643  5511    2.249925e+00 2.966395e+00                       42.5336
# samples_n        int64    186004  6643 6643  5511    1.179609e+06 1.555245e+06                      22299840
# basename         object   359010  6643 6643  1       NaN          NaN                                  audio
# species_longhand category 1129249 6643 6643  71      NaN          NaN                   House Sparrow - HOSP
# id               object   491437  6643 6643  6643    NaN          NaN               xc/data/YTWA/81367/audio
# path             object   518169  6643 6643  6643    NaN          NaN           xc/data/YTWA/81367/audio.mp3

# %%
(recs
    .assign(species=lambda df: df.species_longhand)
    .assign(count=1)
    # 0-fill all (species, dataset) combinations to create empty placeholders for missing bars
    .pipe(lambda df: df.append(
        pd.DataFrame([
            dict(species=species, dataset=dataset, duration_s=0)
            for species in df.species.unique()
            for dataset in df.dataset.unique()
        ])
        .astype({'species': df.species.dtype})
    ))
    .groupby(['dataset', 'species'])[['count', 'duration_s']].sum().reset_index()
    .pipe(df_ordered_cat, species=lambda df: df.sort_values('count').species)  # Order species by count
    .pipe(pd.melt, id_vars=['dataset', 'species'], value_vars=['count', 'duration_s'])
    # .pipe(df_reverse_cat, 'species')  # Order species by taxo
    .pipe(df_remove_unused_categories)
    .pipe(ggplot, aes(x='species', y='value', fill='dataset', color='dataset'))
    + coord_flip()
    + geom_bar(stat='identity', position=position_dodge(), width=.8)
    + facet_wrap('variable', nrow=1, scales='free')
    + xlab('')
    + ylab('')
    + scale_fill_cmap_d(mpl.cm.tab10)
    + scale_color_cmap_d(mpl.cm.tab10)
    + theme(panel_spacing=2.5)
    + theme_figsize(width=18, aspect_ratio=4/1)
    + ggtitle(f'recs: Total (count, duration_s) per (species, dataset)')
)
# Out:
# /opt/conda/lib/python3.6/site-packages/plotnine/layer.py:452: UserWarning: geom_bar : Removed 194 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# <ggplot: (-9223363309682441875)>

# %%
# Load a saved projection model
projection = Projection.load('peterson-v0-26bae1c', features=Features(load=load))
# Out:
# [18:56:04.092] DEBUG  Projection.load
#   path: /app/data/models/projection/peterson-v0-26bae1c.pkl

# %%
# Add .feat
recs = projection.transform(recs)
# Out:
# [                                                                                                       ] | 0% Completed |  0.0s
# [                                                                                                       ] | 0% Completed |  0.1s
# [                                                                                                       ] | 0% Completed |  0.3s
# [                                                                                                       ] | 0% Completed |  0.6s
# [                                                                                                       ] | 0% Completed |  0.7s
# [                                                                                                       ] | 0% Completed |  0.8s
# [                                                                                                       ] | 0% Completed |  1.0s
# [                                                                                                       ] | 0% Completed |  1.1s
# [                                                                                                       ] | 0% Completed |  1.2s
# [                                                                                                       ] | 0% Completed |  1.4s
# [#                                                                                                      ] | 1% Completed |  1.5s
# [######                                                                                                 ] | 6% Completed |  1.6s
# [#########                                                                                              ] | 8% Completed |  1.7s
# [##########                                                                                             ] | 10% Completed |  1.9s
# [############                                                                                           ] | 11% Completed |  2.0s
# [##############                                                                                         ] | 13% Completed |  2.2s
# [###############                                                                                        ] | 15% Completed |  2.3s
# [#################                                                                                      ] | 16% Completed |  2.4s
# [###################                                                                                    ] | 19% Completed |  2.6s
# [########################                                                                               ] | 23% Completed |  2.7s
# [##########################                                                                             ] | 25% Completed |  2.9s
# [############################                                                                           ] | 27% Completed |  3.0s
# [#############################                                                                          ] | 28% Completed |  3.2s
# [################################                                                                       ] | 31% Completed |  3.3s
# [################################                                                                       ] | 31% Completed |  3.4s
# [##################################                                                                     ] | 33% Completed |  3.5s
# [####################################                                                                   ] | 35% Completed |  3.6s
# [#######################################                                                                ] | 38% Completed |  3.7s
# [#########################################                                                              ] | 40% Completed |  3.9s
# [###########################################                                                            ] | 42% Completed |  4.0s
# [##############################################                                                         ] | 45% Completed |  4.1s
# [##############################################                                                         ] | 45% Completed |  4.2s
# [#################################################                                                      ] | 48% Completed |  4.3s
# [##################################################                                                     ] | 49% Completed |  4.5s
# [#####################################################                                                  ] | 51% Completed |  4.6s
# [######################################################                                                 ] | 53% Completed |  4.8s
# [#########################################################                                              ] | 55% Completed |  4.9s
# [###########################################################                                            ] | 58% Completed |  5.1s
# [##############################################################                                         ] | 60% Completed |  5.2s
# [################################################################                                       ] | 62% Completed |  5.3s
# [##################################################################                                     ] | 65% Completed |  5.4s
# [###################################################################                                    ] | 65% Completed |  5.5s
# [#####################################################################                                  ] | 67% Completed |  5.7s
# [#######################################################################                                ] | 69% Completed |  5.8s
# [########################################################################                               ] | 70% Completed |  5.9s
# [##########################################################################                             ] | 72% Completed |  6.1s
# [#############################################################################                          ] | 75% Completed |  6.2s
# [###############################################################################                        ] | 76% Completed |  6.4s
# [#################################################################################                      ] | 78% Completed |  6.5s
# [##################################################################################                     ] | 80% Completed |  6.6s
# [#######################################################################################                ] | 85% Completed |  6.8s
# [################################################################################################       ] | 93% Completed |  6.9s
# [###################################################################################################    ] | 96% Completed |  7.0s
# [####################################################################################################   ] | 97% Completed |  7.1s
# [#####################################################################################################  ] | 98% Completed |  7.2s
# [#######################################################################################################] | 100% Completed |  7.3s

# %%
# GridSearchCV many models / model params
param_grid = dict(
    classifier=[

        # # KNN
        # #   - Bad for large k because we only have ~7-26 instances per class
        # #   - Bad for small k because KNN
        # # 'cls: knn, n_neighbors: 100',
        # 'cls: knn, n_neighbors: 50',
        # 'cls: knn, n_neighbors: 25',
        # # 'cls: knn, n_neighbors: 15',
        # 'cls: knn, n_neighbors: 10',
        # 'cls: knn, n_neighbors: 5',
        # 'cls: knn, n_neighbors: 3',
        # 'cls: knn, n_neighbors: 1',

        # # SVM(RBF)
        # #   - [SBF16] Uses these
        # 'cls: svm, random_state: 0, probability: true, kernel: rbf, C: 1',
        # 'cls: svm, random_state: 0, probability: true, kernel: rbf, C: 10',  # [SBF16]
        # 'cls: svm, random_state: 0, probability: true, kernel: rbf, C: 100',  # Same as C:10 [why?]
        # # 'cls: svm, random_state: 0, probability: true, kernel: rbf, C: 1000',  # Same as C:10 [why?]

        # # RandomForest(entropy)
        # #   - [SP14] uses entropy
        # # 'cls: rf, random_state: 0, criterion: entropy, n_estimators: 10',
        # 'cls: rf, random_state: 0, criterion: entropy, n_estimators: 50',
        # 'cls: rf, random_state: 0, criterion: entropy, n_estimators: 100',
        # 'cls: rf, random_state: 0, criterion: entropy, n_estimators: 200',  # [SP14]
        # 'cls: rf, random_state: 0, criterion: entropy, n_estimators: 400',
        # 'cls: rf, random_state: 0, criterion: entropy, n_estimators: 800',
        # 'cls: rf, random_state: 0, criterion: entropy, n_estimators: 1000',

        # # RandomForest(gini)
        # #   - sk uses gini by default
        # 'cls: rf, random_state: 0, criterion: gini, n_estimators: 1',  # Faster dev
        'cls: rf, random_state: 0, criterion: gini, n_estimators: 10',  # [sk default]
        # 'cls: rf, random_state: 0, criterion: gini, n_estimators: 50',
        # 'cls: rf, random_state: 0, criterion: gini, n_estimators: 100',
        # 'cls: rf, random_state: 0, criterion: gini, n_estimators: 200',
        # 'cls: rf, random_state: 0, criterion: gini, n_estimators: 400',
        # 'cls: rf, random_state: 0, criterion: gini, n_estimators: 600',
        # 'cls: rf, random_state: 0, criterion: gini, n_estimators: 800',
        # 'cls: rf, random_state: 0, criterion: gini, n_estimators: 1000',
        # WARNING These two are not very mem safe...
        #   - They finish, but they cause OSX to "Not responding" most/all of its apps at ~2-3 different times
        # 'cls: rf, random_state: 0, criterion: gini, n_estimators: 1500',
        # 'cls: rf, random_state: 0, criterion: gini, n_estimators: 2000',

    ],
    # Downsample for learning curves
    downsample_classes=[
        # .1, # Faster dev
        # .1, 1.0,  # Faster dev
        100, 50,  # Faster dev
        # 100, 75, 50, 25,  # Biggest first, to fail fast
    ],
    # TODO agg_funs
)

# TODO Increase cv to decrease variance in eval metrics (this made Alex extremely squirmy)
cv = GridSearchCVCached(
    estimator=Search(projection=projection),
    param_grid=param_grid,
    refit=False,  # Don't spend time fitting cv.best_estimator_ at the end (default: True)
    # cv=3,  # [SP14] uses two-/three-fold CV [why?]
    # Stratified ensures that all classes have >0 instances in each split, which is statistically maybe fishy but avoids
    # breaking various code that merges the split results back together and assumes all splits' classes are the same
    cv=sk.model_selection.StratifiedShuffleSplit(
        # n_splits=1,  # [for ~18/20 miss: ~19m, ~16g disk cache]
        n_splits=3,
        # n_splits=5,
        # n_splits=10,
        # n_splits=20,  # Known good [>51m uncached, >25g disk cache]
        # n_splits=100,  # [?m runtime, ?g disk cache]
        test_size=.2,
        random_state=0,
    ),
    return_train_score=True,
    extra_metrics=dict(
        # [How to specify SearchEvals here without creating caching headaches?]
        #   - e.g. defs don't bust cache on code edit
        #   - And avoid thrashing cache every time we refactor SearchEvals
        test_i='i_test',
        test_y='y_test',
        test_classes='estimator.classes_',
        test_predict_proba='estimator.classifier_.predict_proba(X_test)',
    ),
    # return_estimator=True,  # Verrrry heavy, use extra_metrics instead
    # verbose=100,
    # verbose=10,  # O(models * n_splits) lines of outputs
    verbose=1,  # O(1) lines of outputs
    # n_jobs=1,  # For %prun
    # n_jobs=6,  # Doesn't peg all 8 hyperthreads
    # n_jobs=8,
    n_jobs=16,  # Not mem safe on laptop (16x rf classifiers)
)
with contextlib.ExitStack() as stack:
    # stack.enter_context(cache_control(refresh=True))  # Disk unsafe...
    stack.enter_context(cache_control(enabled=False))  # Disk safe
    # stack.enter_context(joblib.parallel_backend('threading'))  # Default: 'multiprocessing'
    # stack.enter_context(joblib.parallel_backend('sequential'))  # For %prun [FIXME Has no effect; why?]
    stack.enter_context(log.context(level='info'))
    X, y = Search.Xy(recs)
    cv.fit(X, y)
# Out:
# Fitting 3 folds for each of 2 candidates, totalling 6 fits
# [18:56:15.917] INFO   _fit_and_score... split_i[0], train[5314], test[1329], classes[71], estimator[Search(downsample_classes=100, classifier='cls: rf, random_state: 0, criterion: gini, n_estimators: 10', random_state=0)]
# [18:56:16.070] INFO   _fit_and_score... split_i[1], train[5314], test[1329], classes[71], estimator[Search(downsample_classes=100, classifier='cls: rf, random_state: 0, criterion: gini, n_estimators: 10', random_state=0)]
# [18:56:16.222] INFO   _fit_and_score... split_i[2], train[5314], test[1329], classes[71], estimator[Search(downsample_classes=100, classifier='cls: rf, random_state: 0, criterion: gini, n_estimators: 10', random_state=0)]
# [18:56:16.371] INFO   _fit_and_score... split_i[0], train[5314], test[1329], classes[71], estimator[Search(downsample_classes=50, classifier='cls: rf, random_state: 0, criterion: gini, n_estimators: 10', random_state=0)]
# [18:56:16.522] INFO   _fit_and_score... split_i[1], train[5314], test[1329], classes[71], estimator[Search(downsample_classes=50, classifier='cls: rf, random_state: 0, criterion: gini, n_estimators: 10', random_state=0)]
# [18:56:16.673] INFO   _fit_and_score... split_i[2], train[5314], test[1329], classes[71], estimator[Search(downsample_classes=50, classifier='cls: rf, random_state: 0, criterion: gini, n_estimators: 10', random_state=0)]
# [18:56:24.529] INFO   _fit_and_score[8.154s]: split_i[0], train[5314], test[1329], classes[71], estimator[Search(downsample_classes=50, classifier='cls: rf, random_state: 0, criterion: gini, n_estimators: 10', random_state=0)]
# [18:56:24.717] INFO   _fit_and_score[8.191s]: split_i[1], train[5314], test[1329], classes[71], estimator[Search(downsample_classes=50, classifier='cls: rf, random_state: 0, criterion: gini, n_estimators: 10', random_state=0)]
# [18:56:25.087] INFO   _fit_and_score[8.410s]: split_i[2], train[5314], test[1329], classes[71], estimator[Search(downsample_classes=50, classifier='cls: rf, random_state: 0, criterion: gini, n_estimators: 10', random_state=0)]
# [Parallel(n_jobs=16)]: Done   3 out of   6 | elapsed:    9.8s remaining:    9.8s
# [18:56:26.686] INFO   _fit_and_score[10.459s]: split_i[2], train[5314], test[1329], classes[71], estimator[Search(downsample_classes=100, classifier='cls: rf, random_state: 0, criterion: gini, n_estimators: 10', random_state=0)]
# [18:56:26.848] INFO   _fit_and_score[10.926s]: split_i[0], train[5314], test[1329], classes[71], estimator[Search(downsample_classes=100, classifier='cls: rf, random_state: 0, criterion: gini, n_estimators: 10', random_state=0)]
# [18:56:26.867] INFO   _fit_and_score[10.793s]: split_i[1], train[5314], test[1329], classes[71], estimator[Search(downsample_classes=100, classifier='cls: rf, random_state: 0, criterion: gini, n_estimators: 10', random_state=0)]
# [Parallel(n_jobs=16)]: Done   6 out of   6 | elapsed:   11.6s finished

# %%
# Precompute eval metrics + dims for the plots below
#   - Grain: models
#   - Metrics: train_score, test_score, ...
#   - Dims: model_id, classifier_type, fold, ...
cv_models = (cv_results_splits_df(cv.cv_results_)
    # Slow yaml parsing, compute up front
    .assign(params_dict=lambda df: df.apply(axis=1, func=lambda row: {
        **{strip_startswith(k, 'param_'): row[k] for k in df if k.startswith('param_')},
        'classifier': yaml.safe_load('{%s}' % row.param_classifier),
    }))
    [lambda df: [c for c in df if not c.startswith('param_')]]
    # Dims from params
    .assign(
        # Useful for validation curves (vary params by classifier type)
        # classifier_type=lambda df: df.params_dict.str['classifier'].apply(lambda x: (
        #     '%s-%s' % (x['cls'], x['criterion']) if x['cls'] == 'rf' else
        #     x['cls']
        # )),
        # Useful for learning curves (vary downsample_classes per classifier)
        classifier_type=lambda df: df.params_dict.apply(lambda d: ', '.join(
            '%s[%s]' % (k, v) for k, v in d.items() if k not in ['downsample_classes']
        )),
    )
    # .eval
    .assign(test_evals=lambda df: np.vectorize(SearchEvals)(
        i=df.pop('test_i'),
        y=df.pop('test_y'),
        classes=df.pop('test_classes'),
        y_scores=df.pop('test_predict_proba'),
    ))
    # Reorder
    .pipe(df_reorder_cols, first=[
        'model_id', 'params', 'params_dict', 'classifier_type',
    ])
)
param_list = list(cv_models.params.unique())
display(
    df_summary(cv_models).T,
    # cv_models[:5],
    cv_models,
    param_list,
)
# Out:
#                                                                                                           min  \
#                 dtype   sizeof  len count nunique mean std
# model_id        object  921     6   6     6.0     NaN  NaN  classifier[cls: rf, random_state: 0, criterion...
# params          object  867     6   6     2.0     NaN  NaN  classifier[cls: rf, random_state: 0, criterion...
# params_dict     object  1440    6   6     NaN     NaN  NaN                                                NaN
# classifier_type object  804     6   6     1.0     NaN  NaN  classifier[{'cls': 'rf', 'random_state': 0, 'c...
# fold            int64   160     6   6     3.0     NaN  NaN                                                  0
# train_score     float64 144     6   6     1.0     NaN  NaN                                                 -1
# test_score      float64 144     6   6     2.0     NaN  NaN                                                -10
# test_evals      object  4731198 6   6     NaN     NaN  NaN                                                NaN
#
#                                                                                                           25%  \
#                 dtype   sizeof  len count nunique mean std
# model_id        object  921     6   6     6.0     NaN  NaN  classifier[cls: rf, random_state: 0, criterion...
# params          object  867     6   6     2.0     NaN  NaN  classifier[cls: rf, random_state: 0, criterion...
# params_dict     object  1440    6   6     NaN     NaN  NaN                                                NaN
# classifier_type object  804     6   6     1.0     NaN  NaN  classifier[{'cls': 'rf', 'random_state': 0, 'c...
# fold            int64   160     6   6     3.0     NaN  NaN                                                  0
# train_score     float64 144     6   6     1.0     NaN  NaN                                                 -1
# test_score      float64 144     6   6     2.0     NaN  NaN                                                -10
# test_evals      object  4731198 6   6     NaN     NaN  NaN                                                NaN
#
#                                                                                                           50%  \
#                 dtype   sizeof  len count nunique mean std
# model_id        object  921     6   6     6.0     NaN  NaN  classifier[cls: rf, random_state: 0, criterion...
# params          object  867     6   6     2.0     NaN  NaN  classifier[cls: rf, random_state: 0, criterion...
# params_dict     object  1440    6   6     NaN     NaN  NaN                                                NaN
# classifier_type object  804     6   6     1.0     NaN  NaN  classifier[{'cls': 'rf', 'random_state': 0, 'c...
# fold            int64   160     6   6     3.0     NaN  NaN                                                  1
# train_score     float64 144     6   6     1.0     NaN  NaN                                                 -1
# test_score      float64 144     6   6     2.0     NaN  NaN                                                -10
# test_evals      object  4731198 6   6     NaN     NaN  NaN                                                NaN
#
#                                                                                                           75%  \
#                 dtype   sizeof  len count nunique mean std
# model_id        object  921     6   6     6.0     NaN  NaN  classifier[cls: rf, random_state: 0, criterion...
# params          object  867     6   6     2.0     NaN  NaN  classifier[cls: rf, random_state: 0, criterion...
# params_dict     object  1440    6   6     NaN     NaN  NaN                                                NaN
# classifier_type object  804     6   6     1.0     NaN  NaN  classifier[{'cls': 'rf', 'random_state': 0, 'c...
# fold            int64   160     6   6     3.0     NaN  NaN                                                  1
# train_score     float64 144     6   6     1.0     NaN  NaN                                                 -1
# test_score      float64 144     6   6     2.0     NaN  NaN                                                 -9
# test_evals      object  4731198 6   6     NaN     NaN  NaN                                                NaN
#
#                                                                                                           max
#                 dtype   sizeof  len count nunique mean std
# model_id        object  921     6   6     6.0     NaN  NaN  classifier[cls: rf, random_state: 0, criterion...
# params          object  867     6   6     2.0     NaN  NaN  classifier[cls: rf, random_state: 0, criterion...
# params_dict     object  1440    6   6     NaN     NaN  NaN                                                NaN
# classifier_type object  804     6   6     1.0     NaN  NaN  classifier[{'cls': 'rf', 'random_state': 0, 'c...
# fold            int64   160     6   6     3.0     NaN  NaN                                                  2
# train_score     float64 144     6   6     1.0     NaN  NaN                                                 -1
# test_score      float64 144     6   6     2.0     NaN  NaN                                                 -9
# test_evals      object  4731198 6   6     NaN     NaN  NaN                                                NaN
#                                             model_id  \
# 0  classifier[cls: rf, random_state: 0, criterion...
# 1  classifier[cls: rf, random_state: 0, criterion...
# 2  classifier[cls: rf, random_state: 0, criterion...
# 3  classifier[cls: rf, random_state: 0, criterion...
# 4  classifier[cls: rf, random_state: 0, criterion...
# 5  classifier[cls: rf, random_state: 0, criterion...
#
#                                               params  \
# 0  classifier[cls: rf, random_state: 0, criterion...
# 1  classifier[cls: rf, random_state: 0, criterion...
# 2  classifier[cls: rf, random_state: 0, criterion...
# 3  classifier[cls: rf, random_state: 0, criterion...
# 4  classifier[cls: rf, random_state: 0, criterion...
# 5  classifier[cls: rf, random_state: 0, criterion...
#
#                                          params_dict  \
# 0  {'classifier': {'cls': 'rf', 'random_state': 0...
# 1  {'classifier': {'cls': 'rf', 'random_state': 0...
# 2  {'classifier': {'cls': 'rf', 'random_state': 0...
# 3  {'classifier': {'cls': 'rf', 'random_state': 0...
# 4  {'classifier': {'cls': 'rf', 'random_state': 0...
# 5  {'classifier': {'cls': 'rf', 'random_state': 0...
#
#                                      classifier_type  fold  train_score  \
# 0  classifier[{'cls': 'rf', 'random_state': 0, 'c...     0         -1.0
# 1  classifier[{'cls': 'rf', 'random_state': 0, 'c...     1         -1.0
# 2  classifier[{'cls': 'rf', 'random_state': 0, 'c...     2         -1.0
# 3  classifier[{'cls': 'rf', 'random_state': 0, 'c...     0         -1.0
# 4  classifier[{'cls': 'rf', 'random_state': 0, 'c...     1         -1.0
# 5  classifier[{'cls': 'rf', 'random_state': 0, 'c...     2         -1.0
#
#    test_score                                         test_evals
# 0        -9.0  SearchEvals(i[(1329,)], y[(1329,)], classes[(7...
# 1        -9.0  SearchEvals(i[(1329,)], y[(1329,)], classes[(7...
# 2        -9.0  SearchEvals(i[(1329,)], y[(1329,)], classes[(7...
# 3       -10.0  SearchEvals(i[(1329,)], y[(1329,)], classes[(7...
# 4       -10.0  SearchEvals(i[(1329,)], y[(1329,)], classes[(7...
# 5       -10.0  SearchEvals(i[(1329,)], y[(1329,)], classes[(7...
# [
#     'classifier[cls: rf, random_state: 0, criterion: gini, n_estimators: '
#         '10], downsample_classes[100]',
#     'classifier[cls: rf, random_state: 0, criterion: gini, n_estimators: '
#         '10], downsample_classes[50]'
# ]

# %%
# Train/test scores
#   - Grain: models x {train,test}
#   - Metrics: score
#   - Dims: group, params
(cv_models
    .pipe(lambda df: pd.melt(
        df,
        id_vars=['classifier_type', 'params', 'fold'],
        value_vars=['train_score', 'test_score'],
        var_name='split',
        value_name='score'),
    )
    .assign(
        split=lambda df: df.split.str.replace('_score', ''),
        group=lambda df: df.apply(axis=1, func=lambda row: row.classifier_type + '/' + row.split),
    )
    .pipe(df_ordered_cat, params=lambda df: param_list)
    .pipe(ggplot, aes(x='params', y='score', color='group'))
    + geom_hline(yintercept=0, color='grey')
    + geom_jitter(alpha=.5, width=.05, height=1e-9)
    # + geom_point(alpha=.5)
    + geom_line(aes(group='group + str(fold)'), alpha=.2)
    + stat_summary(aes(group='group'), fun_data='mean_cl_boot', random_state=0, geom='errorbar')
    + stat_summary(aes(group='group'), fun_data='mean_cl_boot', random_state=0, geom='line', size=1)
    + scale_color_cmap_d(mpl.cm.tab10)
    + theme(axis_text_x=element_text(angle=90, hjust=.5))
    + theme_figsize(width=12, aspect_ratio=1/2)
    # + coord_cartesian(ylim=(-35, 0))
    + ylab('score (-coverage_error)')
    + ggtitle('Train/test scores')
)
# Out:
# <ggplot: (8727172595818)>

# %% [markdown]
# # Model diagnostics: all models, all folds

# %%
print('models:')
print('  params[*/%s]' % len(param_list))
print('  fold[*/%s]' % cv.cv.n_splits)
# Out:
# models:
#   params[*/2]
#   fold[*/3]

# %%
# TODO Cache
# Coverage errors: all models, all folds
#   - Subset: all models
#   - Grain: sum(recs[model.test_i] for model)
#   - Dims: model_id, params, fold, y_true, rec_id
#   - Metrics: coverage_error
coverage_errors_all_all = (cv_models
    # .sample(n=5, random_state=0)  # For faster dev
    .pipe(lambda df: DF(
        OrderedDict(
            # **row[['model_id', 'params', 'fold']],  # Slow (in this inner loop), unpack manually instead
            model_id=row.model_id,
            params=row.params,
            classifier_type=row.classifier_type,
            fold=row.fold,
            i=i,
            y_true=y_true,
            coverage_error=coverage_error,
        )
        for row in iter_progress(df_rows(df), n=len(df))
        for i, y_true, coverage_error in zip(
            row.test_evals.i,
            row.test_evals.y,
            row.test_evals.coverage_errors(),
        )
    ))
)
display(
    df_summary(coverage_errors_all_all).T,
    coverage_errors_all_all[:10],
)
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
#  17%|█▋        | 1/6 [00:00<00:02,  1.74it/s]
#  33%|███▎      | 2/6 [00:01<00:02,  1.75it/s]
#  50%|█████     | 3/6 [00:01<00:01,  1.74it/s]
#  67%|██████▋   | 4/6 [00:02<00:01,  1.74it/s]
#  83%|████████▎ | 5/6 [00:02<00:00,  1.74it/s]
# 100%|██████████| 6/6 [00:03<00:00,  1.74it/s]
#                                                                                                            min  \
#                 dtype   sizeof  len  count nunique mean std
# model_id        object  4030857 7974 7974  6       NaN  NaN  classifier[cls: rf, random_state: 0, criterion...
# params          object  3719871 7974 7974  2       NaN  NaN  classifier[cls: rf, random_state: 0, criterion...
# classifier_type object  3354396 7974 7974  1       NaN  NaN  classifier[{'cls': 'rf', 'random_state': 0, 'c...
# fold            int64   212640  7974 7974  3       NaN  NaN                                                  0
# i               int64   223272  7974 7974  3190    NaN  NaN                                                  1
# y_true          object  677790  7974 7974  71      NaN  NaN                                               AMCR
# coverage_error  float64 191376  7974 7974  11      NaN  NaN                                                  1
#
#                                                                                                            25%  \
#                 dtype   sizeof  len  count nunique mean std
# model_id        object  4030857 7974 7974  6       NaN  NaN  classifier[cls: rf, random_state: 0, criterion...
# params          object  3719871 7974 7974  2       NaN  NaN  classifier[cls: rf, random_state: 0, criterion...
# classifier_type object  3354396 7974 7974  1       NaN  NaN  classifier[{'cls': 'rf', 'random_state': 0, 'c...
# fold            int64   212640  7974 7974  3       NaN  NaN                                                  0
# i               int64   223272  7974 7974  3190    NaN  NaN                                               1661
# y_true          object  677790  7974 7974  71      NaN  NaN                                               CAVI
# coverage_error  float64 191376  7974 7974  11      NaN  NaN                                                  2
#
#                                                                                                            50%  \
#                 dtype   sizeof  len  count nunique mean std
# model_id        object  4030857 7974 7974  6       NaN  NaN  classifier[cls: rf, random_state: 0, criterion...
# params          object  3719871 7974 7974  2       NaN  NaN  classifier[cls: rf, random_state: 0, criterion...
# classifier_type object  3354396 7974 7974  1       NaN  NaN  classifier[{'cls': 'rf', 'random_state': 0, 'c...
# fold            int64   212640  7974 7974  3       NaN  NaN                                                  1
# i               int64   223272  7974 7974  3190    NaN  NaN                                               3322
# y_true          object  677790  7974 7974  71      NaN  NaN                                               MOCH
# coverage_error  float64 191376  7974 7974  11      NaN  NaN                                                 10
#
#                                                                                                            75%  \
#                 dtype   sizeof  len  count nunique mean std
# model_id        object  4030857 7974 7974  6       NaN  NaN  classifier[cls: rf, random_state: 0, criterion...
# params          object  3719871 7974 7974  2       NaN  NaN  classifier[cls: rf, random_state: 0, criterion...
# classifier_type object  3354396 7974 7974  1       NaN  NaN  classifier[{'cls': 'rf', 'random_state': 0, 'c...
# fold            int64   212640  7974 7974  3       NaN  NaN                                                  2
# i               int64   223272  7974 7974  3190    NaN  NaN                                               4979
# y_true          object  677790  7974 7974  71      NaN  NaN                                               SAPH
# coverage_error  float64 191376  7974 7974  11      NaN  NaN                                                 71
#
#                                                                                                            max
#                 dtype   sizeof  len  count nunique mean std
# model_id        object  4030857 7974 7974  6       NaN  NaN  classifier[cls: rf, random_state: 0, criterion...
# params          object  3719871 7974 7974  2       NaN  NaN  classifier[cls: rf, random_state: 0, criterion...
# classifier_type object  3354396 7974 7974  1       NaN  NaN  classifier[{'cls': 'rf', 'random_state': 0, 'c...
# fold            int64   212640  7974 7974  3       NaN  NaN                                                  2
# i               int64   223272  7974 7974  3190    NaN  NaN                                               6640
# y_true          object  677790  7974 7974  71      NaN  NaN                                               YTWA
# coverage_error  float64 191376  7974 7974  11      NaN  NaN                                                 71
#                                             model_id  \
# 0  classifier[cls: rf, random_state: 0, criterion...
# 1  classifier[cls: rf, random_state: 0, criterion...
# 2  classifier[cls: rf, random_state: 0, criterion...
# 3  classifier[cls: rf, random_state: 0, criterion...
# 4  classifier[cls: rf, random_state: 0, criterion...
# 5  classifier[cls: rf, random_state: 0, criterion...
# 6  classifier[cls: rf, random_state: 0, criterion...
# 7  classifier[cls: rf, random_state: 0, criterion...
# 8  classifier[cls: rf, random_state: 0, criterion...
# 9  classifier[cls: rf, random_state: 0, criterion...
#
#                                               params  \
# 0  classifier[cls: rf, random_state: 0, criterion...
# 1  classifier[cls: rf, random_state: 0, criterion...
# 2  classifier[cls: rf, random_state: 0, criterion...
# 3  classifier[cls: rf, random_state: 0, criterion...
# 4  classifier[cls: rf, random_state: 0, criterion...
# 5  classifier[cls: rf, random_state: 0, criterion...
# 6  classifier[cls: rf, random_state: 0, criterion...
# 7  classifier[cls: rf, random_state: 0, criterion...
# 8  classifier[cls: rf, random_state: 0, criterion...
# 9  classifier[cls: rf, random_state: 0, criterion...
#
#                                      classifier_type  fold     i y_true  \
# 0  classifier[{'cls': 'rf', 'random_state': 0, 'c...     0  1449   NOFL
# 1  classifier[{'cls': 'rf', 'random_state': 0, 'c...     0  3102   TUTI
# 2  classifier[{'cls': 'rf', 'random_state': 0, 'c...     0  5285   SWSP
# 3  classifier[{'cls': 'rf', 'random_state': 0, 'c...     0  4504   CERW
# 4  classifier[{'cls': 'rf', 'random_state': 0, 'c...     0  6089   BHCO
# 5  classifier[{'cls': 'rf', 'random_state': 0, 'c...     0  3531   CARW
# 6  classifier[{'cls': 'rf', 'random_state': 0, 'c...     0  3044   OATI
# 7  classifier[{'cls': 'rf', 'random_state': 0, 'c...     0   902   BUOW
# 8  classifier[{'cls': 'rf', 'random_state': 0, 'c...     0  1607   PIWO
# 9  classifier[{'cls': 'rf', 'random_state': 0, 'c...     0  5819   WETA
#
#    coverage_error
# 0             2.0
# 1            10.0
# 2             8.0
# 3             1.0
# 4            71.0
# 5            10.0
# 6             7.0
# 7             3.0
# 8             9.0
# 9            71.0

# %%
# Facet by classifier_type, order by median(coverage_error)
#   - Subset: all models
#   - Grain: sum(recs[model.test_i].groupby(params, y_true) for model)
#       - Over: fold, rec_id
#   - Dims: params, y_true
#   - Metrics: coverage_error.median
# in: coverage_errors_all_all, recs
(coverage_errors_all_all
    # Sort species by median(coverage_error) (across all models)
    .pipe(df_ordered_cat, y_true=lambda df: (
        df.groupby('y_true').agg({'coverage_error': np.median}).reset_index().sort_values('coverage_error').y_true
    ))
    .pipe(ggplot, aes(x='y_true', y='coverage_error', color='params'))
    + facet_wrap('classifier_type')
    + geom_line(aes(group='params'), stat='summary', fun_y=np.median)
    + coord_flip(ylim=(0, min(30, len(np.unique(y)))))
    + geom_hline(yintercept=recs.species.nunique(), color='grey')
    + scale_color_cmap_d(mpl.cm.tab20)
    + theme_figsize('square')
    # + theme_figsize('full')
    # + theme_figsize('full_dense')
    + ggtitle(rf'Coverage error over fold$\times$instance, by params')
)
# Out:
# <ggplot: (-9223363309682694631)>

# %%
# TODO Slow, bad for notebook dev loop -- move lower, or disable by default?
# Facet by species
#   - Subset: all models
#   - Grain: sum(recs[model.test_i].groupby(params, y_true) for model)
#       - Over: fold, rec_id
#   - Dims: params, y_true
#   - Metrics: coverage_error.median
# in: coverage_errors_all_all, recs
(coverage_errors_all_all
    # .sample(200, random_state=0)  # Faster dev
    .astype({'y_true': metadata.species.df.shorthand.dtype})
    .pipe(df_ordered_cat, params=lambda df: reversed(param_list))
    .pipe(ggplot, aes(x='params', y='coverage_error', color='classifier_type'))
    + facet_wrap('y_true')
    + geom_hline(yintercept=1, color='grey')
    + geom_hline(yintercept=recs.species.nunique(), color='grey')

    # Percentiles (faster, no overplot)
    # + geom_point(stat='summary', fun_y=np.median)
    # + geom_linerange(stat='summary', fun_ymin=partial(np.percentile, q=25), fun_ymax=partial(np.percentile, q=75))

    # Violin (slow, no overplot)
    # + geom_violin()

    # Boxplot (very slow, no overplot)
    # + geom_boxplot()

    # Points (medium cost, high overplot)
    #   - n (count) instead of prop (proportion)
    #   - scale_size_area() instead of default scale_size(), because it's a count [I don't grok this but it looks good]
    + geom_count(aes(size='..n..'), alpha=.5)
    + scale_size_area()
    + geom_point(stat='summary', fun_y=np.median, alpha=1, color='black', shape='|', size=3, stroke=1)

    + coord_flip()
    + scale_color_cmap_d(mpl.cm.tab20)
    + theme(axis_text_y=element_text(size=6))
    + theme_figsize('square')  # Faster
    # + theme_figsize('half')
    # + theme_figsize('full')
    # + theme_figsize('full_dense')
    + ggtitle(rf'Coverage error over fold$\times$instance, by params')
)
# Out:
# <ggplot: (-9223363309685336660)>

# %% [markdown]
# # Model diagnostics: one model, all folds

# %%
params_i = -1
params = param_list[params_i]
print("param_list:\n%s" % '\n'.join('  %s: %r' % (i, x) for i, x in enumerate(param_list)))
print()
print('models:')
print('  params[%s/%s]: %r' % (params_i, len(param_list), params))
print('  fold[*/%s]' % cv.cv.n_splits)
# Out:
# param_list:
#   0: 'classifier[cls: rf, random_state: 0, criterion: gini, n_estimators: 10], downsample_classes[100]'
#   1: 'classifier[cls: rf, random_state: 0, criterion: gini, n_estimators: 10], downsample_classes[50]'
#
# models:
#   params[-1/2]: 'classifier[cls: rf, random_state: 0, criterion: gini, n_estimators: 10], downsample_classes[50]'
#   fold[*/3]

# %%
# Coverage errors: one model, all folds
#   - Subset: models.params == params
#   - Grain: sum(recs[model.test_i] for model)
#   - Dims: model_id, params, fold, y_true, rec_id
#   - Metrics: coverage_error
coverage_errors_one_all = (coverage_errors_all_all
    [lambda df: df.params == params]  # One model, all folds
)
display(
    df_summary(coverage_errors_one_all).T,
    coverage_errors_one_all[:10],
)
# Out:
#                                                                                                            min  \
#                 dtype   sizeof  len  count nunique mean std
# model_id        object  2284551 3987 3987  3       NaN  NaN  classifier[cls: rf, random_state: 0, criterion...
# params          object  1594800 3987 3987  1       NaN  NaN  classifier[cls: rf, random_state: 0, criterion...
# classifier_type object  1905786 3987 3987  1       NaN  NaN  classifier[{'cls': 'rf', 'random_state': 0, 'c...
# fold            int64   106320  3987 3987  3       NaN  NaN                                                  0
# i               int64   111636  3987 3987  3190    NaN  NaN                                                  1
# y_true          object  338995  3987 3987  71      NaN  NaN                                               AMCR
# coverage_error  float64 95688   3987 3987  11      NaN  NaN                                                  1
#
#                                                                                                            25%  \
#                 dtype   sizeof  len  count nunique mean std
# model_id        object  2284551 3987 3987  3       NaN  NaN  classifier[cls: rf, random_state: 0, criterion...
# params          object  1594800 3987 3987  1       NaN  NaN  classifier[cls: rf, random_state: 0, criterion...
# classifier_type object  1905786 3987 3987  1       NaN  NaN  classifier[{'cls': 'rf', 'random_state': 0, 'c...
# fold            int64   106320  3987 3987  3       NaN  NaN                                                  0
# i               int64   111636  3987 3987  3190    NaN  NaN                                               1661
# y_true          object  338995  3987 3987  71      NaN  NaN                                               CAVI
# coverage_error  float64 95688   3987 3987  11      NaN  NaN                                                  3
#
#                                                                                                            50%  \
#                 dtype   sizeof  len  count nunique mean std
# model_id        object  2284551 3987 3987  3       NaN  NaN  classifier[cls: rf, random_state: 0, criterion...
# params          object  1594800 3987 3987  1       NaN  NaN  classifier[cls: rf, random_state: 0, criterion...
# classifier_type object  1905786 3987 3987  1       NaN  NaN  classifier[{'cls': 'rf', 'random_state': 0, 'c...
# fold            int64   106320  3987 3987  3       NaN  NaN                                                  1
# i               int64   111636  3987 3987  3190    NaN  NaN                                               3322
# y_true          object  338995  3987 3987  71      NaN  NaN                                               MOCH
# coverage_error  float64 95688   3987 3987  11      NaN  NaN                                                 10
#
#                                                                                                            75%  \
#                 dtype   sizeof  len  count nunique mean std
# model_id        object  2284551 3987 3987  3       NaN  NaN  classifier[cls: rf, random_state: 0, criterion...
# params          object  1594800 3987 3987  1       NaN  NaN  classifier[cls: rf, random_state: 0, criterion...
# classifier_type object  1905786 3987 3987  1       NaN  NaN  classifier[{'cls': 'rf', 'random_state': 0, 'c...
# fold            int64   106320  3987 3987  3       NaN  NaN                                                  2
# i               int64   111636  3987 3987  3190    NaN  NaN                                               4979
# y_true          object  338995  3987 3987  71      NaN  NaN                                               SAPH
# coverage_error  float64 95688   3987 3987  11      NaN  NaN                                                 71
#
#                                                                                                            max
#                 dtype   sizeof  len  count nunique mean std
# model_id        object  2284551 3987 3987  3       NaN  NaN  classifier[cls: rf, random_state: 0, criterion...
# params          object  1594800 3987 3987  1       NaN  NaN  classifier[cls: rf, random_state: 0, criterion...
# classifier_type object  1905786 3987 3987  1       NaN  NaN  classifier[{'cls': 'rf', 'random_state': 0, 'c...
# fold            int64   106320  3987 3987  3       NaN  NaN                                                  2
# i               int64   111636  3987 3987  3190    NaN  NaN                                               6640
# y_true          object  338995  3987 3987  71      NaN  NaN                                               YTWA
# coverage_error  float64 95688   3987 3987  11      NaN  NaN                                                 71
#                                                model_id  \
# 3987  classifier[cls: rf, random_state: 0, criterion...
# 3988  classifier[cls: rf, random_state: 0, criterion...
# 3989  classifier[cls: rf, random_state: 0, criterion...
# 3990  classifier[cls: rf, random_state: 0, criterion...
# 3991  classifier[cls: rf, random_state: 0, criterion...
# 3992  classifier[cls: rf, random_state: 0, criterion...
# 3993  classifier[cls: rf, random_state: 0, criterion...
# 3994  classifier[cls: rf, random_state: 0, criterion...
# 3995  classifier[cls: rf, random_state: 0, criterion...
# 3996  classifier[cls: rf, random_state: 0, criterion...
#
#                                                  params  \
# 3987  classifier[cls: rf, random_state: 0, criterion...
# 3988  classifier[cls: rf, random_state: 0, criterion...
# 3989  classifier[cls: rf, random_state: 0, criterion...
# 3990  classifier[cls: rf, random_state: 0, criterion...
# 3991  classifier[cls: rf, random_state: 0, criterion...
# 3992  classifier[cls: rf, random_state: 0, criterion...
# 3993  classifier[cls: rf, random_state: 0, criterion...
# 3994  classifier[cls: rf, random_state: 0, criterion...
# 3995  classifier[cls: rf, random_state: 0, criterion...
# 3996  classifier[cls: rf, random_state: 0, criterion...
#
#                                         classifier_type  fold     i y_true  \
# 3987  classifier[{'cls': 'rf', 'random_state': 0, 'c...     0  1449   NOFL
# 3988  classifier[{'cls': 'rf', 'random_state': 0, 'c...     0  3102   TUTI
# 3989  classifier[{'cls': 'rf', 'random_state': 0, 'c...     0  5285   SWSP
# 3990  classifier[{'cls': 'rf', 'random_state': 0, 'c...     0  4504   CERW
# 3991  classifier[{'cls': 'rf', 'random_state': 0, 'c...     0  6089   BHCO
# 3992  classifier[{'cls': 'rf', 'random_state': 0, 'c...     0  3531   CARW
# 3993  classifier[{'cls': 'rf', 'random_state': 0, 'c...     0  3044   OATI
# 3994  classifier[{'cls': 'rf', 'random_state': 0, 'c...     0   902   BUOW
# 3995  classifier[{'cls': 'rf', 'random_state': 0, 'c...     0  1607   PIWO
# 3996  classifier[{'cls': 'rf', 'random_state': 0, 'c...     0  5819   WETA
#
#       coverage_error
# 3987             9.0
# 3988             7.0
# 3989            71.0
# 3990            10.0
# 3991            71.0
# 3992            71.0
# 3993            10.0
# 3994            71.0
# 3995            71.0
# 3996            10.0

# %%
#   - Subset: models.params == params
#   - Grain: sum(recs[model.test_i].groupby(y_true) for model)
#       - Over: fold, rec_id
#   - Dims: y_true
#   - Metrics: count, coverage_error.percentiles
# in: coverage_errors_one_all, recs
(coverage_errors_one_all
    .astype({'y_true': metadata.species.df.shorthand.dtype})
    .pipe(df_reverse_cat, 'y_true')
    .pipe(ggplot, aes(x='y_true', y='coverage_error'))
    + geom_hline(yintercept=1, color='grey')
    + geom_hline(yintercept=recs.species.nunique(), color='grey')
    + geom_count(aes(size='..n..'), alpha=1)  # n (count) instead of prop (proportion)
    + scale_size_area()  # Instead of default scale_size(), because it's a count [I don't grok this but it looks good]
    + geom_point(stat='summary', fun_y=np.median, alpha=1, color='red', shape='|', size=6, stroke=2)
    + coord_flip()
    # + theme_figsize('inline')
    # + theme_figsize('square')
    # + theme_figsize('half')
    + theme_figsize('half_dense')
    # + theme_figsize('full')
    # + theme_figsize('full_dense')
    + ggtitle(rf'Coverage error over fold$\times$instance ({params})')
)
# Out:
# <ggplot: (8727172397397)>

# %%
# One-model/all-folds confusion matrix
with figsize(
    # 'square',
    # 'full',
    'full_dense',
):
    (cv_models
        [lambda df: df.params == params]
        .pipe(lambda df: plot_confusion_matrix(
            classes=df.iloc[0].test_evals.classes,
            M=np.array([
                row.test_evals.confusion_matrix_prob()
                for row in df_rows(df)
            ]).sum(axis=0),
            # normalize=False,  # For counts
            raw=True, scale=10,  # Faster dev
            format=None,  # Omit numbers, too dense
        ))
    )
# Out:
# <PIL.Image.Image image mode=RGBA size=710x710 at 0x7EFF310A7588>

# %% [markdown]
# # Model diagnostics: one model, one fold

# %%
fold = 0
# params_i = ...  # Comment out to reuse from above
params = param_list[params_i]
[(_, model)] = list(cv_models[lambda df: (df.params == params) & (df.fold == fold)].iterrows())
print("param_list:\n%s" % '\n'.join('  %s: %r' % (i, x) for i, x in enumerate(param_list)))
print()
print('model:')
print('  params[%s/%s]: %r' % (params_i, len(param_list), model.params))
print('  fold[%s/%s]' % (model.fold, cv.cv.n_splits))
print()
print(model)
# Out:
# param_list:
#   0: 'classifier[cls: rf, random_state: 0, criterion: gini, n_estimators: 10], downsample_classes[100]'
#   1: 'classifier[cls: rf, random_state: 0, criterion: gini, n_estimators: 10], downsample_classes[50]'
#
# model:
#   params[-1/2]: 'classifier[cls: rf, random_state: 0, criterion: gini, n_estimators: 10], downsample_classes[50]'
#   fold[0/3]
#
# model_id           classifier[cls: rf, random_state: 0, criterion...
# params             classifier[cls: rf, random_state: 0, criterion...
# params_dict        {'classifier': {'cls': 'rf', 'random_state': 0...
# classifier_type    classifier[{'cls': 'rf', 'random_state': 0, 'c...
# fold                                                               0
# train_score                                                       -1
# test_score                                                       -10
# test_evals         SearchEvals(i[(1329,)], y[(1329,)], classes[(7...
# Name: 3, dtype: object

# %%
# in: model
model_id = model.model_id
params = model.params
fold = model.fold
# train_evals = model.train_evals
test_evals = model.test_evals

# in: model, recs
# train_recs = recs.iloc[train_evals.i]
# train_X = Search.X(recs)[train_evals.i]
# train_y = Search.y(recs)[train_evals.i]
test_recs = recs.iloc[test_evals.i]
test_X = Search.X(recs)[test_evals.i]
test_y = Search.y(recs)[test_evals.i]  # (Don't need to store cv_models.test_evals.y if we have recs -- which sometimes we don't?)

display(
    # len(train_recs),
    len(test_recs),
)
# Out:
# [skip]

# %%
# TODO TODO Restore this plot like 'Coverage error over ...' above, so we can see _one_ model instead of aggregating over n_splits models
# # TODO Update [kill the .merge, then species -> y_true]
# (search.coverage_error_by(test_recs, 'id')
#     [:5]
#     # .merge(test_recs[['id', 'species']], on='id', how='left')
#     # .pipe(ggplot, aes(x='species', y='coverage_error'))
#     # + geom_count(aes(size='..n..'))
#     # + stat_summary(fun_y=np.median, geom='point', color='red', alpha=.5, shape='|', size=6, stroke=1)
#     # + stat_summary(
#     #     fun_ymin=partial(np.percentile, q=25), fun_ymax=partial(np.percentile, q=75),
#     #     geom='linerange', color='red', alpha=.5, size=1,
#     # )
#     # + coord_flip()
#     # + geom_hline(yintercept=len(search.classes_), color='grey')
#     # + scale_x_discrete(limits=list(reversed(test_recs.species.cat.categories)))
#     # + theme_figsize('square')
#     # + ggtitle(rf'Coverage error over instance ({model_id})')
# )
# Out:
# [skip]

# %%
# One-model/one-fold confusion matrix
with figsize(
    'square',
    # 'full',
    # 'full_dense',
):
    plot_confusion_matrix_df(
        confusion_matrix_prob_df(model.test_evals.y, model.test_evals.y_scores, model.test_evals.classes),
        title=model.model_id,
        # normalize=False,  # For counts
        raw=True, scale=10,  # Faster dev
    )
# Out:
# [skip]
