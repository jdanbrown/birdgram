# %%
from notebooks import *
print_sys_info()
# Out:
# platform:
#   machine: x86_64
#   node: Dan-B.local
#   processor: i386
#   release: 15.6.0
#   system: Darwin
#   version: 'Darwin Kernel Version 15.6.0: Thu Jun 23 18:25:34 PDT 2016; root:xnu-3248.60.10~1/RELEASE_X86_64'
# cpu: 8
# mem: 16g
# swap: 19g

# %%
# Load models
load = Load()
projection = Projection.load('peterson-v0-26bae1c', features=Features(load=load))
# Out:
# [23:59:39.556] DEBUG  Projection.load
#   path: /Users/danb/hack/bubo/features/data/models/projection/peterson-v0-26bae1c.pkl

# %%
# Select recs
#   1. countries: Filter recs to these countries
#   2. com_names: Filter recs to these species
#   3. recs_at_least: Filter species to those with at least this many recs
#   4. num_species: Sample this many of the species
#   5. num_recs: Sample this many recs per species
get_recs_stats = lambda df: dict(sp=df.species.nunique(), recs=len(df))
puts_stats = lambda desc: partial(tap, f=lambda df: print('%-15s %12s (sp/recs)' % (desc, '%(sp)s/%(recs)s' % get_recs_stats(df))))
countries, com_names = countries_na, com_names_us  # 400k/9.4k -> 60k/1.1k -> 53k/774
# countries, com_names = countries_na, com_names_ca  # 400k/9.4k -> 60k/1.1k -> 35k/334
# recs_at_least, num_species, num_recs = 100, 100, 100  # ca[334/35k -> 127/25k -> 100/21k -> 100/10k   -> 100/10k]
# recs_at_least, num_species, num_recs =  50, 100, 100  # ca[334/35k -> 224/32k -> 100/16k -> 100/ 9.0k -> 100/ 9.0k]
# recs_at_least, num_species, num_recs =   0, 100, 100  # ca[334/35k -> 334/35k -> 100/12k -> 100/ 6.8k ->  99/ 6.8k]
# recs_at_least, num_species, num_recs =   0, 168, 100  # ca[334/34k -> 334/34k -> 168/18k -> 168/11k   -> 167/11k]    # (old 'all')
# recs_at_least, num_species, num_recs =   0, 168,  20  # ca[334/34k -> 334/35k -> 168/18k -> 168/ 3.2k -> 167/ 3.2k]  # (old 'recs')
recs_at_least, num_species, num_recs =  20, 168,  20  # ca[334/35k -> 296/35k -> 168/20k -> 168/ 3.4k -> 168/ 3.4k]  # Familiar set
# recs_at_least, num_species, num_recs =  20, 336,  20  # us[774/53k -> 528/51k -> 336/33k -> 336/ 6.7k -> 336/ 6.7k]  # Scale species
# recs_at_least, num_species, num_recs =  10, 168,  20  # ca[334/35k ->                                             ]  # Class imbalance
# recs_at_least, num_species, num_recs =   0, 168,  20  # ca[334/35k ->                                             ]  # Class imbalance
# recs_at_least, num_species, num_recs =  20, 50,  100  # Faster dev
# recs_at_least, num_species, num_recs =  20, 50,   50  # Faster dev
# recs_at_least, num_species, num_recs =  20, 50,   20  # Faster dev
# recs_at_least, num_species, num_recs =  20, 50,   10  # Faster dev
# recs_at_least, num_species, num_recs =  20, 50,    5  # Faster dev
xcs = (xc.metadata
    .pipe(puts_stats('all'))
    # 1. countries: Filter recs to these countries
    [lambda df: df.country.isin(countries)]
    .pipe(puts_stats('countries'))
    # 2. com_names: Filter recs to these species
    [lambda df: df.com_name.isin(com_names)]
    .pipe(puts_stats('com_names'))
    # Omit not-downloaded recs (should be few within the selected countries)
    [lambda df: df.downloaded]
    .pipe(puts_stats('(downloaded)'))
    # Remove empty cats for perf
    .pipe(df_remove_unused_categories)
    # 3. recs_at_least: Filter species to those with at least this many recs
    [lambda df: df.species.isin(df.species.value_counts()[lambda s: s >= recs_at_least].index)]
    .pipe(puts_stats('recs_at_least'))
    # 4. num_species: Sample this many of the species
    [lambda df: df.species.isin(df.species.drop_duplicates().pipe(lambda s: s.sample(n=min(len(s), num_species), random_state=0)))]
    .pipe(puts_stats('num_species'))
    # 5. num_recs: Sample this many recs per species
    #   - Remove empty cats else .groupby fails on empty groups
    .pipe(df_remove_unused_categories)
    .groupby('species').apply(lambda g: g.sample(n=min(len(g), num_recs), random_state=0))
    .pipe(puts_stats('num_recs'))
    # Drop species with <2 recs, else StratifiedShuffleSplit complains (e.g. 'TUVU')
    [lambda df: df.species.isin(df.species.value_counts()[lambda s: s >= 2].index)]
    .pipe(puts_stats('recs ≥ 2'))
    # Clean up for downstream
    .pipe(df_remove_unused_categories)
)
_recs_stats = get_recs_stats(xcs)
recs_stats = ', '.join(['%s[%s]' % (k, v) for k, v in _recs_stats.items()])
display(
    recs_stats,
    df_summary(xcs).T,
    xcs.sample(n=10, random_state=0).sort_values('species'),
)
# Out:
# all              9442/399859 (sp/recs)
# countries         1148/59713 (sp/recs)
# com_names          774/52707 (sp/recs)
# (downloaded)       774/52702 (sp/recs)
# recs_at_least      528/50784 (sp/recs)
# num_species        168/16658 (sp/recs)
# num_recs            168/3360 (sp/recs)
# recs ≥ 2            168/3360 (sp/recs)
# 'sp[168], recs[3360]'
#                                                                                                                          min                                           25%                                           50%                                           75%                                                          max
#                dtype          sizeof len  count nunique mean        std
# downloaded     bool           94080  3360 3360  1       NaN         NaN                                                 True                                          True                                          True                                          True                                                         True
# species        category       178080 3360 3360  168     NaN         NaN                                                 SNGO                                          WILL                                          SAPH                                          CONW                                                         LAGO
# id             int64          94080  3360 3360  3360     203634.821 106129.642                                           624                                        130689                                        182956                                        296799                                                       417459
# sci_name       category       224900 3360 3360  168     NaN         NaN                                    Chen caerulescens                            Tringa semipalmata                                 Sayornis saya                              Oporornis agilis                                             Spinus lawrencei
# com_name       category       220580 3360 3360  168     NaN         NaN                                           Snow Goose                                        Willet                                  Say's Phoebe                           Connecticut Warbler                                         Lawrence's Goldfinch
# subspecies     object         180989 3360 3360  168     NaN         NaN                                                                                                                                                                                                                                                  yumanensis
# recordist      object         211871 3360 3360  275     NaN         NaN                                                ASJ26                                    Eric Hough                                   Mike Nelson                                 Peter Boesman                                                     tetiaroa
# country        object         203623 3360 3360  3       NaN         NaN                                               Canada                                 United States                                 United States                                 United States                                                United States
# locality       object         321083 3360 3360  1643    NaN         NaN                Bahía la Ventosa, Salina Cruz, Oaxaca                             Durango, Colorado                     Marathon, Monroe, Florida        Rustler Park, Chiricahua Mtns, Arizona  west end of Pound Road, Niland, Imperial County, California
# lat            float64        80640  3360 3313  1648     36.766     10.994                                              15.6                                          30.1                                          34.3                                          42.4                                                         71.4
# lng            float64        80640  3360 3313  1651    -105.956    22.843                                              -177                                          -116                                          -107                                         -89.8                                                        -56.9
# type           object         193682 3360 3360  341     NaN         NaN                           "Slow-flap" flight display                                          call                             call, flight call                                          song                                                    wingbeats
# quality        category       194767 3360 3360  6       NaN         NaN                                                    A                                             A                                             B                                             B                                                     no score
# date           datetime64[ns] 430056 3360 3359  1565    NaN         NaN                                  1976-05-15 00:00:00                           2011-06-26 00:00:00                           2013-07-11 00:00:00                           2015-06-02 00:00:00                                          2018-05-21 00:00:00
# time           object         181046 3360 3360  895     NaN         NaN                                                00:00                                         07:52                                         10:00                                         14:30                                                           am
# license_type   category       191406 3360 3360  3       NaN         NaN                                             by-nc-nd                                      by-nc-nd                                      by-nc-sa                                      by-nc-sa                                                        by-sa
# license_detail category       174720 3360 3360  3       NaN         NaN                                                  2.5                                           3.0                                           4.0                                           4.0                                                          4.0
# license        object         313254 3360 3360  7       NaN         NaN         //creativecommons.org/licenses/by-nc-nd/2.5/  //creativecommons.org/licenses/by-nc-nd/4.0/  //creativecommons.org/licenses/by-nc-sa/3.0/  //creativecommons.org/licenses/by-nc-sa/4.0/                    //creativecommons.org/licenses/by-sa/4.0/
# url            object         275669 3360 3360  3360    NaN         NaN                    https://www.xeno-canto.org/100134             https://www.xeno-canto.org/156193             https://www.xeno-canto.org/227091             https://www.xeno-canto.org/332208                             https://www.xeno-canto.org/99811
# download       object         285809 3360 3360  3360    NaN         NaN                 //www.xeno-canto.org/100134/download          //www.xeno-canto.org/156193/download          //www.xeno-canto.org/227091/download          //www.xeno-canto.org/332208/download                          //www.xeno-canto.org/99811/download
#                 downloaded species      id                 sci_name                 com_name  subspecies           recordist        country                                             locality     lat      lng                                                  type quality       date   time license_type license_detail                                       license                                url                              download
# species
# SNEG    266575        True    SNEG  143594            Egretta thula              Snowy Egret                     Paul Marvin  United States                              Viera Wetlands, Florida  28.227  -80.764                                                  call       B 2013-07-11  08:50     by-nc-sa            3.0  //creativecommons.org/licenses/by-nc-sa/3.0/  https://www.xeno-canto.org/143594  //www.xeno-canto.org/143594/download
# LETE    220072        True    LETE  191773      Sternula antillarum               Least Tern  antillarum       Daniel Parker  United States           West End, Jones Beach State Park, New York     NaN      NaN                                     call, flight call       C 2014-08-19  17:15     by-nc-sa            4.0  //creativecommons.org/licenses/by-nc-sa/4.0/  https://www.xeno-canto.org/191773  //www.xeno-canto.org/191773/download
# LEOW    269213        True    LEOW  140797                Asio otus           Long-eared Owl                    Ed MacKerrow  United States                       Santa Fe, Santa Fe, New Mexico  35.893 -105.983  alarm call, bullfrog, call, crickets, juvenile, male       A 2013-06-27  21:30     by-nc-sa            3.0  //creativecommons.org/licenses/by-nc-sa/3.0/  https://www.xeno-canto.org/140797  //www.xeno-canto.org/140797/download
# ANHU    54270         True    ANHU  362401             Calypte anna       Anna's Hummingbird                     Paul Marvin  United States            Nestor Park, San Diego County, California  32.572 -117.081                                           flight call       A 2017-02-01  09:58     by-nc-sa            4.0  //creativecommons.org/licenses/by-nc-sa/4.0/  https://www.xeno-canto.org/362401  //www.xeno-canto.org/362401/download
# LEWO    159503        True    LEWO  254617         Melanerpes lewis       Lewis's Woodpecker                Jonathon Jongsma  United States   Four Mile Draw Rd, Custer State Park, South Dakota  43.671 -103.451                                                  call       C 2015-06-25  11:00        by-sa            4.0     //creativecommons.org/licenses/by-sa/4.0/  https://www.xeno-canto.org/254617  //www.xeno-canto.org/254617/download
# COFL    89569         True    COFL  326468   Empidonax occidentalis   Cordilleran Flycatcher                Manuel Grosselet         Mexico               Mex DF entrance Desierto de los Leones  19.320  -99.304                                   call, stream  in BG       C 2016-07-09  10:00     by-nc-sa            4.0  //creativecommons.org/licenses/by-nc-sa/4.0/  https://www.xeno-canto.org/326468  //www.xeno-canto.org/326468/download
# BLPW    93087         True    BLPW  322816        Setophaga striata        Blackpoll Warbler                   Peter Boesman  United States                          Kougarok road, Nome, Alaska  64.630 -165.305                                                  song       A 2016-05-31  16:00     by-nc-nd            4.0  //creativecommons.org/licenses/by-nc-nd/4.0/  https://www.xeno-canto.org/322816  //www.xeno-canto.org/322816/download
# HCRE    264631        True    HCRE  145607         Manucerthia mana           Hawaii Creeper                 Eric VanderWerf  United States      Hakalau Forest NWR Maulua tract, Hawaii, Hawaii  19.874 -155.320                                                  song       B 1996-03-25  09:30     by-nc-sa            3.0  //creativecommons.org/licenses/by-nc-sa/3.0/  https://www.xeno-canto.org/145607  //www.xeno-canto.org/145607/download
# GCRF    266236        True    GCRF  143947  Leucosticte tephrocotis  Grey-crowned Rosy Finch     umbrina      Andrew Spencer  United States      St. Paul Island Quarry, St. Paul Island, Alaska  57.153 -170.273                                                  call       B 2013-05-29  08:40     by-nc-sa            3.0  //creativecommons.org/licenses/by-nc-sa/3.0/  https://www.xeno-canto.org/143947  //www.xeno-canto.org/143947/download
# LAGO    108267        True    LAGO  307104         Spinus lawrencei     Lawrence's Goldfinch              Lance A. M. Benner  United States  Castaic Lagoon park, Los Angeles County, California  34.506 -118.614                                            call, male       B 2016-03-12  10:20     by-nc-sa            4.0  //creativecommons.org/licenses/by-nc-sa/4.0/  https://www.xeno-canto.org/307104  //www.xeno-canto.org/307104/download

# %%
xcs_paths = [
    ('xc', f'{data_dir}/xc/data/{row.species}/{row.id}/audio.mp3')
    for row in df_rows(xcs)
]
joblib.dump(xcs_paths, '/tmp/xcs_paths')  # In case you want to run load.recs in a terminal (it's long and verbose)
display(
    f"{len(xcs_paths)}/{len(xcs)}",
    # xcs_paths[:2],
)
# Out:
# '3360/3360'

# %%
# TODO Restore once:true after debug [but think carefully how once:true interacts with the once:false params above]
recs = load.recs(paths=xcs_paths)
display(
    df_summary(recs).T,
    recs[:5],
)
# Out:
#                                                                                                    min                           25%                            50%                           75%                           max
#                  dtype    sizeof len  count nunique mean      std
# dataset          object   171360 3360 3360  1       NaN       NaN                                   xc                            xc                             xc                            xc                            xc
# species          category 178080 3360 3360  168     NaN       NaN                                 SNGO                          WILL                           SAPH                          CONW                          LAGO
# species_com_name category 220320 3360 3360  168     NaN       NaN                           Snow Goose                        Willet                   Say's Phoebe           Connecticut Warbler          Lawrence's Goldfinch
# species_query    object   178080 3360 3360  168     NaN       NaN                                 ABTO                          CACG                           HAFL                          RNSA                          YRWA
# duration_s       float64  80640  3360 3360  3041    6.052e+01 1.585e+02                          0.788                          14.1                           31.7                          66.4                      5.85e+03
# samples_mb       float64  80640  3360 3360  3043    2.553e+00 6.678e+00                         0.0332                         0.591                           1.34                           2.8                           246
# samples_n        int64    94080  3360 3360  3043    1.339e+06 3.501e+06                          17384                        309888                         700132                       1466496                     129029566
# basename         object   181440 3360 3360  1       NaN       NaN                                audio                         audio                          audio                         audio                         audio
# species_longhand category 243840 3360 3360  168     NaN       NaN                    Snow Goose - SNGO                 Willet - WILL            Say's Phoebe - SAPH    Connecticut Warbler - CONW   Lawrence's Goldfinch - LAGO
# id               object   248113 3360 3360  3360    NaN       NaN            xc/data/ABTO/110755/audio      xc/data/CACG/92018/audio      xc/data/HAFL/407011/audio      xc/data/RNSA/91210/audio      xc/data/YRWA/78150/audio
# path             object   261553 3360 3360  3360    NaN       NaN        xc/data/ABTO/110755/audio.mp3  xc/data/CACG/92018/audio.mp3  xc/data/HAFL/407011/audio.mp3  xc/data/RNSA/91210/audio.mp3  xc/data/YRWA/78150/audio.mp3
#   dataset species species_com_name species_query  duration_s  samples_mb  samples_n basename   species_longhand                         id                           path
# 0      xc    SNGO       Snow Goose          SNGO      28.320       1.191     624456    audio  Snow Goose - SNGO  xc/data/SNGO/143620/audio  xc/data/SNGO/143620/audio.mp3
# 1      xc    SNGO       Snow Goose          SNGO      49.128       2.066    1083272    audio  Snow Goose - SNGO  xc/data/SNGO/143618/audio  xc/data/SNGO/143618/audio.mp3
# 2      xc    SNGO       Snow Goose          SNGO      34.964       1.470     770954    audio  Snow Goose - SNGO  xc/data/SNGO/121403/audio  xc/data/SNGO/121403/audio.mp3
# 3      xc    SNGO       Snow Goose          SNGO      82.272       3.460    1814098    audio  Snow Goose - SNGO  xc/data/SNGO/160495/audio  xc/data/SNGO/160495/audio.mp3
# 4      xc    SNGO       Snow Goose          SNGO     165.937       6.979    3658910    audio  Snow Goose - SNGO  xc/data/SNGO/362121/audio  xc/data/SNGO/362121/audio.mp3

# %%
# Fast-and-cheap version (<1s) of the plots below (~7s)
(recs
    .species_longhand.value_counts().sort_index()
    .reset_index().rename(columns={'index': 'species_longhand', 'species_longhand': 'num_recs'})
    .assign(num_recs=lambda df: df.num_recs.map(lambda n: '%s /%s' % ('•' * int(n / df.num_recs.max() * 60), df.num_recs.max())))
)
# Out:
#                          species_longhand                                                          num_recs
# 0                       Snow Goose - SNGO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 1      Greater White-fronted Goose - GWFG  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 2                            Brant - BRAN  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 3                   Cackling Goose - CACG  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 4                      Tundra Swan - TUSW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 5                        Wood Duck - WODU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 6                 Hooded Merganser - HOME  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 7                 Plain Chachalaca - PLCH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 8                Northern Bobwhite - NOBO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 9                     Scaled Quail - SCQU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 10                  Gambel's Quail - GAQU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 11                 Montezuma Quail - MONQ  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 12                   Ruffed Grouse - RUGR  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 13                Willow Ptarmigan - WIPT  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 14          White-tailed Ptarmigan - WTPT  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 15             Sharp-tailed Grouse - STGR  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 16                     Common Loon - COLO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 17                Red-necked Grebe - RNGR  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 18                Laysan Albatross - LAAL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 19          Black-footed Albatross - BFAL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 20                    Bonin Petrel - BOPE  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 21                Great Blue Heron - GBHE  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 22                     Great Egret - GREG  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 23                     Snowy Egret - SNEG  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 24               Little Blue Heron - LBHE  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 25                    Cattle Egret - CAEG  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 26                     Green Heron - GRHE  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 27                White-faced Ibis - WFIB  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 28                Northern Harrier - NOHA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 29               Common Black Hawk - COBH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 30               Broad-winged Hawk - BWHA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 31                  Ridgway's Rail - RIRA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 32                Purple Gallinule - PUGA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 33                         Limpkin - LIMP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 34            Black-bellied Plover - BBPL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 35          American Golden-Plover - AMGP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 36             Semipalmated Plover - SEPL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 37                        Killdeer - KILL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 38                  Rock Sandpiper - ROSA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 39               Baird's Sandpiper - BASA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 40          Semipalmated Sandpiper - SESA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 41                          Willet - WILL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 42                 Franklin's Gull - FRGU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 43                        Mew Gull - MEGU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 44                    Western Gull - WEGU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 45                   Glaucous Gull - GLGU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 46                      Least Tern - LETE  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 47                      Black Tern - BLTE  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 48                    Roseate Tern - ROST  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 49                   Black Skimmer - BLSK  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 50                       Inca Dove - INDO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 51              Greater Roadrunner - GRRO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 52            Yellow-billed Cuckoo - YBCU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 53           Whiskered Screech-Owl - WHSO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 54                Great Horned Owl - GHOW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 55                   Burrowing Owl - BUOW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 56                  Long-eared Owl - LEOW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 57                      Boreal Owl - BOOW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 58           Northern Saw-whet Owl - NSWO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 59          Eastern Whip-poor-will - EWPW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 60            White-throated Swift - WTSW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 61            Rivoli's Hummingbird - RIHU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 62       Blue-throated Hummingbird - BTHH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 63       Ruby-throated Hummingbird - RTHU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 64       Black-chinned Hummingbird - BCHU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 65              Anna's Hummingbird - ANHU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 66        Broad-tailed Hummingbird - BTAH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 67        Buff-bellied Hummingbird - BBEH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 68              Lewis's Woodpecker - LEWO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 69        Yellow-bellied Sapsucker - YBSA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 70             Red-naped Sapsucker - RNSA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 71          Red-breasted Sapsucker - RBSA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 72            Nuttall's Woodpecker - NUWO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 73              Arizona Woodpecker - ARWO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 74                American Kestrel - AMKE  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 75   Northern Beardless-Tyrannulet - NOBT  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 76          Olive-sided Flycatcher - OSFL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 77                   Greater Pewee - GRPE  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 78              Eastern Wood-Pewee - EAWP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 79              Acadian Flycatcher - ACFL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 80            Hammond's Flycatcher - HAFL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 81          Cordilleran Flycatcher - COFL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 82        Buff-breasted Flycatcher - BBFL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 83                    Say's Phoebe - SAPH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 84         Dusky-capped Flycatcher - DCFL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 85        Great Crested Flycatcher - GCFL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 86        Brown-crested Flycatcher - BCFL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 87                  Great Kiskadee - GKIS  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 88               Tropical Kingbird - TRKI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 89               Cassin's Kingbird - CAKI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 90                Eastern Kingbird - EAKI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 91                   Gray Kingbird - GRAK  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 92            Rose-throated Becard - RTBE  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 93              Black-capped Vireo - BCVI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 94               Blue-headed Vireo - BHVI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 95              Philadelphia Vireo - PHVI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 96                  Warbling Vireo - WAVI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 97                  Red-eyed Vireo - REVI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 98       Black-throated Magpie-Jay - BTMJ  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 99                      Pinyon Jay - PIJA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 100              Florida Scrub-Jay - FLSJ  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 101          Woodhouse's Scrub-Jay - WOSJ  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 102                      Fish Crow - FICR  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 103                   Common Raven - CORA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 104                   Barn Swallow - BARS  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 105         Black-capped Chickadee - BCCH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 106              Mexican Chickadee - MECH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 107      Chestnut-backed Chickadee - CBCH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 108                Tufted Titmouse - TUTI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 109         Black-crested Titmouse - BCTI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 110          Red-breasted Nuthatch - RBNU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 111        White-breasted Nuthatch - WBNU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 112                     House Wren - HOWR  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 113                   Pacific Wren - PAWR  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 114                   Sinaloa Wren - SIWR  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 115                        Wrentit - WREN  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 116              Swainson's Thrush - SWTH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 117                Sprague's Pipit - SPPI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 118                  Cedar Waxwing - CEDW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 119                   Snow Bunting - SNBU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 120            Blue-winged Warbler - BWWA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 121        Black-and-white Warbler - BAWW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 122              Tennessee Warbler - TEWA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 123                 Colima Warbler - COLW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 124             Virginia's Warbler - VIWA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 125            Connecticut Warbler - CONW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 126      Gray-crowned Yellowthroat - GCYE  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 127               Kentucky Warbler - KEWA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 128                Northern Parula - NOPA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 129              Blackpoll Warbler - BLPW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 130    Black-throated Blue Warbler - BTBW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 131          Yellow-rumped Warbler - YRWA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 132                Prairie Warbler - PRAW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 133    Black-throated Gray Warbler - BTYW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 134         Golden-cheeked Warbler - GCWA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 135                 Canada Warbler - CAWA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 136               Painted Redstart - PARE  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 137          Rufous-winged Sparrow - RWSP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 138              Botteri's Sparrow - BOSP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 139               Cassin's Sparrow - CASP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 140            Grasshopper Sparrow - GRSP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 141                Baird's Sparrow - BAIS  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 142               Chipping Sparrow - CHSP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 143           Clay-colored Sparrow - CCSP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 144                   Lark Bunting - LARB  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 145                Dark-eyed Junco - DEJU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 146                 Bell's Sparrow - BESP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 147                   Song Sparrow - SOSP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 148                 Abert's Towhee - ABTO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 149              California Towhee - CALT  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 150            Green-tailed Towhee - GTTO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 151                Scarlet Tanager - SCTA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 152                  Blue Grosbeak - BLGR  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 153                     Dickcissel - DICK  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 154        Yellow-headed Blackbird - YHBL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 155             Western Meadowlark - WEME  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 156            Black-vented Oriole - BVOR  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 157           Red-winged Blackbird - RWBL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 158             Brewer's Blackbird - BRBL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 159            Boat-tailed Grackle - BTGR  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 160                        Apapane - APAP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 161                           Iiwi - IIWI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 162                 Hawaii Creeper - HCRE  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 163        Gray-crowned Rosy-Finch - GCRF  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 164                    House Finch - HOFI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 165                   Purple Finch - PUFI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 166                  Red Crossbill - RECR  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 167           Lawrence's Goldfinch - LAGO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20

# %%
# Num recs loaded for training + total num available [slow: ~7s]
(recs
    .pipe(df_reverse_cat, 'species_longhand')
    .assign(recs_n=1).groupby(['species', 'species_longhand'])['recs_n'].sum().reset_index()
    .set_index('species')
    # [:100]
    .join(how='left', other=(xc.metadata
        .assign(total_n=1).groupby('species')['total_n'].sum().reset_index()
        .set_index('species')
    ))
    .reset_index()
    .pipe(ggplot)
    + aes(x='species_longhand')
    + geom_col(aes(y='total_n'), fill='darkgray')
    + geom_col(aes(y='recs_n'), fill=scale_color_cmap(mpl.cm.tab10).palette(0))
    # + geom_point(aes(y='total_n'), color='darkgray')
    # + geom_point(aes(y='recs_n'), color=scale_color_cmap(mpl.cm.tab10).palette(0))
    + expand_limits(y=0)
    + coord_flip()
    + theme(axis_text_y=element_text(size=4))
    + theme_figsize(width=18, aspect_ratio=3/2)
    + ggtitle('Num recs loaded for training + total num available')
)
# Out:
# [skip]

# %%
# Plot recs with duration [slow: ~7s]
(recs
    .assign(species=lambda df: df.species_longhand)
    .assign(count=1)
    # 0-fill all (species, dataset) combinations to create empty placeholders for missing bars
    .pipe(lambda df: df.append(
        pd.DataFrame([
            dict(species=species, dataset=dataset, duration_s=0)
            for species in df.species.unique()
            for dataset in df.dataset.unique()
        ])
        .astype({'species': df.species.dtype})
    ))
    .groupby(['dataset', 'species'])[['count', 'duration_s']].sum().reset_index()
    # Order by species by taxo
    .pipe(df_reverse_cat, 'species')
    # Order by species by count
    # .pipe(df_ordered_cat, species=lambda df: df.sort_values('count').species)
    .pipe(pd.melt, id_vars=['dataset', 'species'], value_vars=['count', 'duration_s'])
    .pipe(df_remove_unused_categories)
    .pipe(ggplot, aes(x='species', y='value', fill='dataset', color='dataset'))
    + coord_flip()
    + geom_bar(stat='identity', position=position_dodge(), width=.8)
    + facet_wrap('variable', nrow=1, scales='free')
    + xlab('')
    + ylab('')
    + scale_fill_cmap_d(mpl_cmap_concat('tab20', 'tab20b', 'tab20c'))
    + scale_color_cmap_d(mpl_cmap_concat('tab20', 'tab20b', 'tab20c'))
    + theme(panel_spacing=2.5)
    + theme_figsize(width=18, aspect_ratio=4/1)
    + ggtitle(f'recs: Total (count, duration_s) per (species, dataset)')
)
# Out:
# [skip]

# %%
# Add .feat
recs = projection.transform(recs)

# %%
# GridSearchCV many models / model params
#   - Order these roughly from most to least expensive, so that training runs fail fast (e.g. oom at the start, not the end)
param_grid = list(unique_everseen([
    dict(
        classifier=[classifier],
        n_species=[n_species if isinstance(n_species, int) else int(n_species * _recs_stats['sp'])],
        n_recs=[
            # n_recs if isinstance(n_recs, int) else int(n_recs * _recs_stats['recs']),
            # TODO Figure out how to represent this as an n instead of a frac again [TODO interaction with test_size=.2 ...]
            #   - TODO Also make clear in the plot descs when e.g. (recs[3360], n_species[33], n_recs[1.0]) -> n_recs[33*20 < 3360]
            n_recs,
        ],
    )
    for (n_species, n_recs) in [
        # Subset for learning curves
        #   - Biggest first, to fail fast

        # (None, None),

        # Scale data
        (1.00, 1.00),
        (1.00, 0.75),
        (1.00, 0.50),
        (1.00, 0.25),

        # Scale species
        (1.00, 1.00),
        (0.75, 1.00),
        (0.50, 1.00),
        (0.25, 1.00),

        # (1.00, 1.00),
        # (1.00, 0.50),
        # (0.50, 1.00),

        # Faster dev
        # (0.10, 0.10),

    ]
    # model_size ~ forest_depth
    for rf_mean_depth_at_168_sp in [
        93.5,
    ]
    for rf_max_depth in [
        'null',
        int(rf_mean_depth_at_168_sp * n_species * 1),
        int(rf_mean_depth_at_168_sp * n_species * 3/4),
        int(rf_mean_depth_at_168_sp * n_species * 1/2),
        int(rf_mean_depth_at_168_sp * n_species * 1/3),
        int(rf_mean_depth_at_168_sp * n_species * 1/4),
        int(rf_mean_depth_at_168_sp * n_species * 1/8),
        5,
        4,
        3,
        2,
        1,
    ]
    # for ovr_rf_max_depth in [int(rf_max_depth / 10) if rf_max_depth != 'null' else 'null']
    # for xgb_rf_max_depth in [lambda x: x if x != 'null' else 100]
    for ovr_rf_max_depth in [
        # 'null',
        # 46,
        # 35,
        # 5,
        # 4,
        3,
        2,
        1,
    ]
    for xgb_rf_max_depth_f in [lambda x: x if x != 'null' else 100]
    for xgb_rf_max_depth in [
        # xgb_rf_max_depth_f(rf_max_depth),
        xgb_rf_max_depth_f(ovr_rf_max_depth),
    ]
    for rf_n_estimators in [
        # 2000, 1500,  # WARNING Not mem safe on laptop
        100,
        # 50, 25,  # TODO Train
    ]
    for xgb_rf_n_estimators in [
        # 1600, 400,
        100,
        # 50, 25,
    ]
    for ovr_rf_n_estimators in [
        100,
        # 50, 25,
    ]
    for logreg_cls, logreg_solver in [
        # ('logreg_multi', 'newton-cg'),  # Similar acc to ('logreg_ovr', 'liblinear') but ~2-10x slower to train
        ('logreg_ovr', 'liblinear'),
        # ('ovr-logreg_ovr', 'liblinear'),
        # ('logreg_ovr', 'saga'),
        # ('logreg_multi', 'saga'),
    ]
    for logreg_max_iter in (
        [None] if logreg_solver not in ['saga'] else [
            # 100,
            # 200,
            # 400,
            # 800,
            # 1600,
            3200,
            # 6400,
            # 12800,
        ]
    )
    for logreg_C in [
        # 1/reg_strength: C=inf is no regularization, smaller C is more regularization (default: 1)
        # Default: 1; inf is no regular
        # 1,
        .01, .1, 1,
        # .001, .005, .01, .05, .1, 1, 10, 100,
    ]
    for logreg_class_weight in [
        None,
        # 'balanced',  # No (visually) significant effect with class sizes 0-20 (see class_imbalance notebooks)
    ]
    for classifier in [

        # RF
        # f'cls: rf, n_estimators: {rf_n_estimators}, max_depth: {rf_max_depth}',
        # f'cls: ovr-rf, n_estimators: {ovr_rf_n_estimators}, max_depth: {ovr_rf_max_depth}',
        # f'cls: xgb_rf, n_estimators: {xgb_rf_n_estimators}, max_depth: {xgb_rf_max_depth}',

        # Logistic regression
        # ','.join(x for x in [
        #     f'cls: {logreg_cls}',
        #     f'solver: {logreg_solver}',
        #     '' if logreg_max_iter is None else f'max_iter: {logreg_max_iter}',
        #     f'C: {logreg_C}',
        #     '' if logreg_class_weight is None else f'class_weight: {logreg_class_weight}',
        # ] if x),

        # Naive Bayes
        'cls: nb',

    ]
]))

# TODO Increase cv to decrease variance in eval metrics (this made Alex extremely squirmy)
cv = GridSearchCVCached(
    estimator=Search(projection=projection),
    param_grid=param_grid,
    refit=False,  # Don't spend time fitting cv.best_estimator_ at the end (default: True)
    # cv=3,  # [SP14] uses two-/three-fold CV [why?]
    # Stratified ensures that all classes have >0 instances in each split, which is statistically maybe fishy but avoids
    # breaking various code that merges the split results back together and assumes all splits' classes are the same
    cv=sk.model_selection.StratifiedShuffleSplit(
        n_splits=3,  # [for ~18/20 miss: ~19m, ~16g disk cache]
        # n_splits=2,
        # n_splits=3,
        # n_splits=5,
        # n_splits=10,
        # n_splits=20,  # Known good [>51m uncached, >25g disk cache]
        # n_splits=100,  # [?m runtime, ?g disk cache]
        test_size=.2,
        random_state=0,
    ),
    return_train_score=True,
    # return_estimator=True,  # Verrrry heavy, use extra_metrics instead
    # recompute_extra_metrics=True,  # Loads estimator.pkl (fast) but doesn't return it (huge)
    extra_metrics=dict(
        # [How to specify SearchEvals here without creating caching headaches?]
        #   - e.g. defs don't bust cache on code edit
        #   - And avoid thrashing cache every time we refactor SearchEvals
        classes='estimator.classes_',
        train_i='train',
        train_y='y_train',
        train_predict_proba='estimator.classifier_.predict_proba(X_train)',
        test_i='test',
        test_y='y_test',
        test_predict_proba='estimator.classifier_.predict_proba(X_test)',
        model_size='len(joblib_dumps(estimator))',
        model_stats='model_stats(estimator)',
        proc_stats='proc_stats',
    ),
    # verbose=10,  # O(models * n_splits) lines of outputs
    verbose=1,  # O(1) lines of outputs
    # Use n_jobs=1
    #   - All classifiers can parallelize .fit/.predict
    #   - Avoid memory contention
    # n_jobs=-1,
    # n_jobs=1,  # For %prun, and way faster for 100% loads
    # n_jobs=2,
    n_jobs=4,
    # n_jobs=6,  # For exactly 6 models
    # n_jobs=8,  # For slow ovr serdes [why?]
    # n_jobs=16,  # For recomputing model_stats
    artifacts=dict(
        dir=f'{data_dir}/artifacts',  # TODO Iron out syncing across local/gs/remote
        save=True,
        reuse='20180709-211727-fd34af5-ovr_try_2',
        # skip_compute_if_missing=True,  # TODO Tricky to implement: _fit_and_score_cached needs to be able to return nothing
    ),
)
with contextlib.ExitStack() as stack:
    # stack.enter_context(cache_control(refresh=True))  # Disk unsafe...
    stack.enter_context(cache_control(enabled=False))  # Disk safe
    # stack.enter_context(joblib.parallel_backend('threading'))  # Default: 'multiprocessing'
    # stack.enter_context(joblib.parallel_backend('sequential'))  # For %prun [FIXME Has no effect; why?]
    stack.enter_context(log.context(level='info'))
    # stack.enter_context(log.context(level='debug'))
    X, y = Search.Xy(recs)
    cv.fit(X, y)
# Out:
# Fitting 3 folds for each of 7 candidates, totalling 21 fits
# [23:59:42.468] INFO   artifacts
#   dir: /Users/danb/hack/bubo/features/data/artifacts
#   save: true
#   reuse: 20180709-211727-fd34af5-ovr_try_2
#   experiment_id: 20180709-211727-fd34af5-ovr_try_2
# [23:59:42.770] INFO   _fit_and_score: n[2/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=nb',random_state=0)]: fit...
# [23:59:42.779] INFO   _fit_and_score: n[1/21], model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=nb',random_state=0)]: reuse.load[0.019s, 4.6 MB]: ret
# [23:59:42.797] INFO   _fit_and_score: n[3/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=nb',random_state=0)]: fit...
# [23:59:42.846] INFO   _fit_and_score: n[4/21], model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.75,classifier='cls=nb',random_state=0)]: fit...
# [23:59:42.971] INFO   _fit_and_score: n[5/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.75,classifier='cls=nb',random_state=0)]: fit...
# [23:59:54.293] INFO   _fit_and_score: n[2/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=nb',random_state=0)]: fit[11.079s]
# [23:59:54.325] INFO   _fit_and_score: n[3/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=nb',random_state=0)]: fit[11.087s]
# [23:59:54.342] INFO   _fit_and_score: n[2/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=nb',random_state=0)]: extra_metrics... ['classes', 'train_i', 'train_y', 'train_predict_proba', 'test_i', 'test_y', 'test_predict_proba', 'model_size', 'model_stats', 'proc_stats']
# [23:59:54.375] INFO   _fit_and_score: n[4/21], model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.75,classifier='cls=nb',random_state=0)]: fit[11.083s]
# [23:59:54.427] INFO   _fit_and_score: n[4/21], model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.75,classifier='cls=nb',random_state=0)]: extra_metrics... ['classes', 'train_i', 'train_y', 'train_predict_proba', 'test_i', 'test_y', 'test_predict_proba', 'model_size', 'model_stats', 'proc_stats']
# [23:59:54.566] INFO   _fit_and_score: n[5/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.75,classifier='cls=nb',random_state=0)]: fit[11.210s]
# [23:59:55.365] INFO   _fit_and_score: n[3/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=nb',random_state=0)]: extra_metrics... ['classes', 'train_i', 'train_y', 'train_predict_proba', 'test_i', 'test_y', 'test_predict_proba', 'model_size', 'model_stats', 'proc_stats']
# [23:59:55.498] INFO   _fit_and_score: n[5/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.75,classifier='cls=nb',random_state=0)]: extra_metrics... ['classes', 'train_i', 'train_y', 'train_predict_proba', 'test_i', 'test_y', 'test_predict_proba', 'model_size', 'model_stats', 'proc_stats']
# [00:00:04.883] INFO   _fit_and_score: n[2/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=nb',random_state=0)]: extra_metrics[10.529s, 4.6 MB]: ['classes', 'train_i', 'train_y', 'train_predict_proba', 'test_i', 'test_y', 'test_predict_proba', 'model_size', 'model_stats', 'proc_stats']
# [00:00:04.887] INFO   _fit_and_score: n[2/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=nb',random_state=0)]: save: ret...
# [00:00:04.915] INFO   _fit_and_score: n[2/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=nb',random_state=0)]: save[0.026s, 4.6 MB]: ret
# [00:00:04.919] INFO   _fit_and_score: n[2/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=nb',random_state=0)]: save: estimator...
# [00:00:04.979] INFO   _fit_and_score: n[2/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=nb',random_state=0)]: save[0.057s, 20.2 MB]: estimator
# [00:00:04.990] INFO   _fit_and_score: n[4/21], model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.75,classifier='cls=nb',random_state=0)]: extra_metrics[10.544s, 4.6 MB]: ['classes', 'train_i', 'train_y', 'train_predict_proba', 'test_i', 'test_y', 'test_predict_proba', 'model_size', 'model_stats', 'proc_stats']
# [00:00:04.993] INFO   _fit_and_score: n[4/21], model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.75,classifier='cls=nb',random_state=0)]: save: ret...
# [00:00:05.018] INFO   _fit_and_score: n[4/21], model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.75,classifier='cls=nb',random_state=0)]: save[0.023s, 4.6 MB]: ret
# [00:00:05.022] INFO   _fit_and_score: n[4/21], model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.75,classifier='cls=nb',random_state=0)]: save: estimator...
# [00:00:05.066] INFO   _fit_and_score: n[4/21], model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.75,classifier='cls=nb',random_state=0)]: save[0.042s, 16.2 MB]: estimator
# [00:00:05.150] INFO   _fit_and_score: n[6/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.75,classifier='cls=nb',random_state=0)]: fit...
# [00:00:05.227] INFO   _fit_and_score: n[7/21], model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.5,classifier='cls=nb',random_state=0)]: reuse.load[0.013s, 4.6 MB]: ret
# [00:00:05.304] INFO   _fit_and_score: n[8/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.5,classifier='cls=nb',random_state=0)]: fit...
# [00:00:06.128] INFO   _fit_and_score: n[3/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=nb',random_state=0)]: extra_metrics[10.751s, 4.6 MB]: ['classes', 'train_i', 'train_y', 'train_predict_proba', 'test_i', 'test_y', 'test_predict_proba', 'model_size', 'model_stats', 'proc_stats']
# [00:00:06.130] INFO   _fit_and_score: n[3/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=nb',random_state=0)]: save: ret...
# [00:00:06.151] INFO   _fit_and_score: n[3/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=nb',random_state=0)]: save[0.018s, 4.6 MB]: ret
# [00:00:06.157] INFO   _fit_and_score: n[3/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=nb',random_state=0)]: save: estimator...
# [00:00:06.213] INFO   _fit_and_score: n[3/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=nb',random_state=0)]: save[0.053s, 20.2 MB]: estimator
# [00:00:06.294] INFO   _fit_and_score: n[5/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.75,classifier='cls=nb',random_state=0)]: extra_metrics[10.785s, 4.6 MB]: ['classes', 'train_i', 'train_y', 'train_predict_proba', 'test_i', 'test_y', 'test_predict_proba', 'model_size', 'model_stats', 'proc_stats']
# [00:00:06.297] INFO   _fit_and_score: n[5/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.75,classifier='cls=nb',random_state=0)]: save: ret...
# [00:00:06.327] INFO   _fit_and_score: n[5/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.75,classifier='cls=nb',random_state=0)]: save[0.026s, 4.6 MB]: ret
# [00:00:06.330] INFO   _fit_and_score: n[5/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.75,classifier='cls=nb',random_state=0)]: save: estimator...
# [00:00:06.376] INFO   _fit_and_score: n[5/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.75,classifier='cls=nb',random_state=0)]: save[0.043s, 16.2 MB]: estimator
# [00:00:06.427] INFO   _fit_and_score: n[9/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.5,classifier='cls=nb',random_state=0)]: fit...
# [00:00:06.561] INFO   _fit_and_score: n[10/21], model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.25,classifier='cls=nb',random_state=0)]: fit...
# [00:00:16.718] INFO   _fit_and_score: n[6/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.75,classifier='cls=nb',random_state=0)]: fit[11.284s]
# [00:00:16.935] INFO   _fit_and_score: n[8/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.5,classifier='cls=nb',random_state=0)]: fit[11.407s]
# [00:00:17.598] INFO   _fit_and_score: n[6/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.75,classifier='cls=nb',random_state=0)]: extra_metrics... ['classes', 'train_i', 'train_y', 'train_predict_proba', 'test_i', 'test_y', 'test_predict_proba', 'model_size', 'model_stats', 'proc_stats']
# [00:00:17.686] INFO   _fit_and_score: n[8/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.5,classifier='cls=nb',random_state=0)]: extra_metrics... ['classes', 'train_i', 'train_y', 'train_predict_proba', 'test_i', 'test_y', 'test_predict_proba', 'model_size', 'model_stats', 'proc_stats']
# [00:00:17.749] INFO   _fit_and_score: n[10/21], model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.25,classifier='cls=nb',random_state=0)]: fit[10.971s]
# [00:00:17.938] INFO   _fit_and_score: n[10/21], model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.25,classifier='cls=nb',random_state=0)]: extra_metrics... ['classes', 'train_i', 'train_y', 'train_predict_proba', 'test_i', 'test_y', 'test_predict_proba', 'model_size', 'model_stats', 'proc_stats']
# [00:00:18.026] INFO   _fit_and_score: n[9/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.5,classifier='cls=nb',random_state=0)]: fit[11.347s]
# [00:00:18.878] INFO   _fit_and_score: n[9/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.5,classifier='cls=nb',random_state=0)]: extra_metrics... ['classes', 'train_i', 'train_y', 'train_predict_proba', 'test_i', 'test_y', 'test_predict_proba', 'model_size', 'model_stats', 'proc_stats']
# [00:00:29.914] INFO   _fit_and_score: n[10/21], model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.25,classifier='cls=nb',random_state=0)]: extra_metrics[11.966s, 4.6 MB]: ['classes', 'train_i', 'train_y', 'train_predict_proba', 'test_i', 'test_y', 'test_predict_proba', 'model_size', 'model_stats', 'proc_stats']
# [00:00:29.916] INFO   _fit_and_score: n[10/21], model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.25,classifier='cls=nb',random_state=0)]: save: ret...
# [00:00:29.954] INFO   _fit_and_score: n[10/21], model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.25,classifier='cls=nb',random_state=0)]: save[0.035s, 4.6 MB]: ret
# [00:00:29.958] INFO   _fit_and_score: n[10/21], model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.25,classifier='cls=nb',random_state=0)]: save: estimator...
# [00:00:29.979] INFO   _fit_and_score: n[6/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.75,classifier='cls=nb',random_state=0)]: extra_metrics[12.365s, 4.6 MB]: ['classes', 'train_i', 'train_y', 'train_predict_proba', 'test_i', 'test_y', 'test_predict_proba', 'model_size', 'model_stats', 'proc_stats']
# [00:00:29.980] INFO   _fit_and_score: n[10/21], model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.25,classifier='cls=nb',random_state=0)]: save[0.019s, 8.1 MB]: estimator
# [00:00:29.982] INFO   _fit_and_score: n[6/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.75,classifier='cls=nb',random_state=0)]: save: ret...
# [00:00:30.013] INFO   _fit_and_score: n[6/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.75,classifier='cls=nb',random_state=0)]: save[0.028s, 4.6 MB]: ret
# [00:00:30.020] INFO   _fit_and_score: n[6/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.75,classifier='cls=nb',random_state=0)]: save: estimator...
# [00:00:30.068] INFO   _fit_and_score: n[6/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.75,classifier='cls=nb',random_state=0)]: save[0.044s, 16.2 MB]: estimator
# [00:00:30.084] INFO   _fit_and_score: n[8/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.5,classifier='cls=nb',random_state=0)]: extra_metrics[12.366s, 4.6 MB]: ['classes', 'train_i', 'train_y', 'train_predict_proba', 'test_i', 'test_y', 'test_predict_proba', 'model_size', 'model_stats', 'proc_stats']
# [00:00:30.089] INFO   _fit_and_score: n[8/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.5,classifier='cls=nb',random_state=0)]: save: ret...
# [00:00:30.134] INFO   _fit_and_score: n[8/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.5,classifier='cls=nb',random_state=0)]: save[0.039s, 4.6 MB]: ret
# [00:00:30.138] INFO   _fit_and_score: n[8/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.5,classifier='cls=nb',random_state=0)]: save: estimator...
# [00:00:30.160] INFO   _fit_and_score: n[11/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.25,classifier='cls=nb',random_state=0)]: fit...
# [00:00:30.177] INFO   _fit_and_score: n[8/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.5,classifier='cls=nb',random_state=0)]: save[0.036s, 12.1 MB]: estimator
# [00:00:30.242] INFO   _fit_and_score: n[12/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.25,classifier='cls=nb',random_state=0)]: fit...
# [00:00:30.376] INFO   _fit_and_score: n[13/21], model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=126,n_recs=1.0,classifier='cls=nb',random_state=0)]: fit...
# [00:00:30.890] INFO   _fit_and_score: n[9/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.5,classifier='cls=nb',random_state=0)]: extra_metrics[11.997s, 4.6 MB]: ['classes', 'train_i', 'train_y', 'train_predict_proba', 'test_i', 'test_y', 'test_predict_proba', 'model_size', 'model_stats', 'proc_stats']
# [00:00:30.893] INFO   _fit_and_score: n[9/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.5,classifier='cls=nb',random_state=0)]: save: ret...
# [00:00:30.915] INFO   _fit_and_score: n[9/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.5,classifier='cls=nb',random_state=0)]: save[0.020s, 4.6 MB]: ret
# [00:00:30.918] INFO   _fit_and_score: n[9/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.5,classifier='cls=nb',random_state=0)]: save: estimator...
# [00:00:30.960] INFO   _fit_and_score: n[9/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.5,classifier='cls=nb',random_state=0)]: save[0.038s, 12.1 MB]: estimator
# [00:00:31.130] INFO   _fit_and_score: n[14/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=126,n_recs=1.0,classifier='cls=nb',random_state=0)]: fit...
# [00:00:39.118] INFO   _fit_and_score: n[13/21], model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=126,n_recs=1.0,classifier='cls=nb',random_state=0)]: fit[8.492s]
# [00:00:39.743] INFO   _fit_and_score: n[13/21], model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=126,n_recs=1.0,classifier='cls=nb',random_state=0)]: extra_metrics... ['classes', 'train_i', 'train_y', 'train_predict_proba', 'test_i', 'test_y', 'test_predict_proba', 'model_size', 'model_stats', 'proc_stats']
# [00:00:40.197] INFO   _fit_and_score: n[14/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=126,n_recs=1.0,classifier='cls=nb',random_state=0)]: fit[8.806s]
# [00:00:40.520] INFO   _fit_and_score: n[14/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=126,n_recs=1.0,classifier='cls=nb',random_state=0)]: extra_metrics... ['classes', 'train_i', 'train_y', 'train_predict_proba', 'test_i', 'test_y', 'test_predict_proba', 'model_size', 'model_stats', 'proc_stats']
# [00:00:41.714] INFO   _fit_and_score: n[11/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.25,classifier='cls=nb',random_state=0)]: fit[11.255s]
# [00:00:42.203] INFO   _fit_and_score: n[12/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.25,classifier='cls=nb',random_state=0)]: fit[11.645s]
# [00:00:42.608] INFO   _fit_and_score: n[11/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.25,classifier='cls=nb',random_state=0)]: extra_metrics... ['classes', 'train_i', 'train_y', 'train_predict_proba', 'test_i', 'test_y', 'test_predict_proba', 'model_size', 'model_stats', 'proc_stats']
# [00:00:42.716] INFO   _fit_and_score: n[12/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.25,classifier='cls=nb',random_state=0)]: extra_metrics... ['classes', 'train_i', 'train_y', 'train_predict_proba', 'test_i', 'test_y', 'test_predict_proba', 'model_size', 'model_stats', 'proc_stats']
# [00:00:47.748] INFO   _fit_and_score: n[13/21], model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=126,n_recs=1.0,classifier='cls=nb',random_state=0)]: extra_metrics[7.997s, 3.5 MB]: ['classes', 'train_i', 'train_y', 'train_predict_proba', 'test_i', 'test_y', 'test_predict_proba', 'model_size', 'model_stats', 'proc_stats']
# [00:00:47.751] INFO   _fit_and_score: n[13/21], model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=126,n_recs=1.0,classifier='cls=nb',random_state=0)]: save: ret...
# [00:00:47.776] INFO   _fit_and_score: n[13/21], model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=126,n_recs=1.0,classifier='cls=nb',random_state=0)]: save[0.024s, 3.5 MB]: ret
# [00:00:47.781] INFO   _fit_and_score: n[13/21], model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=126,n_recs=1.0,classifier='cls=nb',random_state=0)]: save: estimator...
# [00:00:47.822] INFO   _fit_and_score: n[13/21], model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=126,n_recs=1.0,classifier='cls=nb',random_state=0)]: save[0.038s, 15.2 MB]: estimator
# [00:00:47.954] INFO   _fit_and_score: n[15/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=126,n_recs=1.0,classifier='cls=nb',random_state=0)]: fit...
# [00:00:48.443] INFO   _fit_and_score: n[14/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=126,n_recs=1.0,classifier='cls=nb',random_state=0)]: extra_metrics[7.913s, 3.5 MB]: ['classes', 'train_i', 'train_y', 'train_predict_proba', 'test_i', 'test_y', 'test_predict_proba', 'model_size', 'model_stats', 'proc_stats']
# [00:00:48.449] INFO   _fit_and_score: n[14/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=126,n_recs=1.0,classifier='cls=nb',random_state=0)]: save: ret...
# [00:00:48.481] INFO   _fit_and_score: n[14/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=126,n_recs=1.0,classifier='cls=nb',random_state=0)]: save[0.028s, 3.5 MB]: ret
# [00:00:48.484] INFO   _fit_and_score: n[14/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=126,n_recs=1.0,classifier='cls=nb',random_state=0)]: save: estimator...
# [00:00:48.531] INFO   _fit_and_score: n[14/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=126,n_recs=1.0,classifier='cls=nb',random_state=0)]: save[0.044s, 15.2 MB]: estimator
# [00:00:48.656] INFO   _fit_and_score: n[16/21], model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=nb',random_state=0)]: reuse.load[0.013s, 2.3 MB]: ret
# [00:00:48.757] INFO   _fit_and_score: n[17/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=nb',random_state=0)]: fit...
# [00:00:52.647] INFO   _fit_and_score: n[11/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.25,classifier='cls=nb',random_state=0)]: extra_metrics[10.028s, 4.6 MB]: ['classes', 'train_i', 'train_y', 'train_predict_proba', 'test_i', 'test_y', 'test_predict_proba', 'model_size', 'model_stats', 'proc_stats']
# [00:00:52.650] INFO   _fit_and_score: n[11/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.25,classifier='cls=nb',random_state=0)]: save: ret...
# [00:00:52.670] INFO   _fit_and_score: n[11/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.25,classifier='cls=nb',random_state=0)]: save[0.017s, 4.6 MB]: ret
# [00:00:52.673] INFO   _fit_and_score: n[11/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.25,classifier='cls=nb',random_state=0)]: save: estimator...
# [00:00:52.698] INFO   _fit_and_score: n[11/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.25,classifier='cls=nb',random_state=0)]: save[0.021s, 8.1 MB]: estimator
# [00:00:52.868] INFO   _fit_and_score: n[18/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=nb',random_state=0)]: fit...
# [00:00:53.195] INFO   _fit_and_score: n[12/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.25,classifier='cls=nb',random_state=0)]: extra_metrics[10.466s, 4.6 MB]: ['classes', 'train_i', 'train_y', 'train_predict_proba', 'test_i', 'test_y', 'test_predict_proba', 'model_size', 'model_stats', 'proc_stats']
# [00:00:53.198] INFO   _fit_and_score: n[12/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.25,classifier='cls=nb',random_state=0)]: save: ret...
# [00:00:53.220] INFO   _fit_and_score: n[12/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.25,classifier='cls=nb',random_state=0)]: save[0.020s, 4.6 MB]: ret
# [00:00:53.223] INFO   _fit_and_score: n[12/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.25,classifier='cls=nb',random_state=0)]: save: estimator...
# [00:00:53.254] INFO   _fit_and_score: n[12/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.25,classifier='cls=nb',random_state=0)]: save[0.029s, 8.1 MB]: estimator
# [00:00:53.410] INFO   _fit_and_score: n[19/21], model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=42,n_recs=1.0,classifier='cls=nb',random_state=0)]: fit...
# [00:00:54.212] INFO   _fit_and_score: n[17/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=nb',random_state=0)]: fit[5.191s]
# [00:00:55.107] INFO   _fit_and_score: n[17/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=nb',random_state=0)]: extra_metrics... ['classes', 'train_i', 'train_y', 'train_predict_proba', 'test_i', 'test_y', 'test_predict_proba', 'model_size', 'model_stats', 'proc_stats']
# [00:00:56.264] INFO   _fit_and_score: n[15/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=126,n_recs=1.0,classifier='cls=nb',random_state=0)]: fit[8.047s]
# [00:00:56.343] INFO   _fit_and_score: n[15/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=126,n_recs=1.0,classifier='cls=nb',random_state=0)]: extra_metrics... ['classes', 'train_i', 'train_y', 'train_predict_proba', 'test_i', 'test_y', 'test_predict_proba', 'model_size', 'model_stats', 'proc_stats']
# [00:00:56.650] INFO   _fit_and_score: n[19/21], model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=42,n_recs=1.0,classifier='cls=nb',random_state=0)]: fit[2.849s]
# [00:00:56.857] INFO   _fit_and_score: n[19/21], model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=42,n_recs=1.0,classifier='cls=nb',random_state=0)]: extra_metrics... ['classes', 'train_i', 'train_y', 'train_predict_proba', 'test_i', 'test_y', 'test_predict_proba', 'model_size', 'model_stats', 'proc_stats']
# [00:00:59.308] INFO   _fit_and_score: n[18/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=nb',random_state=0)]: fit[6.090s]
# [00:00:59.668] INFO   _fit_and_score: n[19/21], model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=42,n_recs=1.0,classifier='cls=nb',random_state=0)]: extra_metrics[2.804s, 1.2 MB]: ['classes', 'train_i', 'train_y', 'train_predict_proba', 'test_i', 'test_y', 'test_predict_proba', 'model_size', 'model_stats', 'proc_stats']
# [00:00:59.670] INFO   _fit_and_score: n[19/21], model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=42,n_recs=1.0,classifier='cls=nb',random_state=0)]: save: ret...
# [00:00:59.686] INFO   _fit_and_score: n[19/21], model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=42,n_recs=1.0,classifier='cls=nb',random_state=0)]: save[0.014s, 1.2 MB]: ret
# [00:00:59.689] INFO   _fit_and_score: n[19/21], model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=42,n_recs=1.0,classifier='cls=nb',random_state=0)]: save: estimator...
# [00:00:59.709] INFO   _fit_and_score: n[19/21], model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=42,n_recs=1.0,classifier='cls=nb',random_state=0)]: save[0.016s, 5.1 MB]: estimator
# [00:00:59.786] INFO   _fit_and_score: n[20/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=42,n_recs=1.0,classifier='cls=nb',random_state=0)]: fit...
# [00:01:00.319] INFO   _fit_and_score: n[18/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=nb',random_state=0)]: extra_metrics... ['classes', 'train_i', 'train_y', 'train_predict_proba', 'test_i', 'test_y', 'test_predict_proba', 'model_size', 'model_stats', 'proc_stats']
# [00:01:00.619] INFO   _fit_and_score: n[17/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=nb',random_state=0)]: extra_metrics[5.497s, 2.3 MB]: ['classes', 'train_i', 'train_y', 'train_predict_proba', 'test_i', 'test_y', 'test_predict_proba', 'model_size', 'model_stats', 'proc_stats']
# [00:01:00.622] INFO   _fit_and_score: n[17/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=nb',random_state=0)]: save: ret...
# [00:01:00.648] INFO   _fit_and_score: n[17/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=nb',random_state=0)]: save[0.020s, 2.3 MB]: ret
# [00:01:00.656] INFO   _fit_and_score: n[17/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=nb',random_state=0)]: save: estimator...
# [00:01:00.692] INFO   _fit_and_score: n[17/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=nb',random_state=0)]: save[0.028s, 10.1 MB]: estimator
# [00:01:00.791] INFO   _fit_and_score: n[21/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=42,n_recs=1.0,classifier='cls=nb',random_state=0)]: fit...
# [00:01:02.752] INFO   _fit_and_score: n[20/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=42,n_recs=1.0,classifier='cls=nb',random_state=0)]: fit[2.744s]
# [00:01:03.070] INFO   _fit_and_score: n[20/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=42,n_recs=1.0,classifier='cls=nb',random_state=0)]: extra_metrics... ['classes', 'train_i', 'train_y', 'train_predict_proba', 'test_i', 'test_y', 'test_predict_proba', 'model_size', 'model_stats', 'proc_stats']
# [00:01:03.808] INFO   _fit_and_score: n[21/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=42,n_recs=1.0,classifier='cls=nb',random_state=0)]: fit[2.748s]
# [00:01:04.117] INFO   _fit_and_score: n[21/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=42,n_recs=1.0,classifier='cls=nb',random_state=0)]: extra_metrics... ['classes', 'train_i', 'train_y', 'train_predict_proba', 'test_i', 'test_y', 'test_predict_proba', 'model_size', 'model_stats', 'proc_stats']
# [00:01:04.327] INFO   _fit_and_score: n[15/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=126,n_recs=1.0,classifier='cls=nb',random_state=0)]: extra_metrics[7.973s, 3.5 MB]: ['classes', 'train_i', 'train_y', 'train_predict_proba', 'test_i', 'test_y', 'test_predict_proba', 'model_size', 'model_stats', 'proc_stats']
# [00:01:04.330] INFO   _fit_and_score: n[15/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=126,n_recs=1.0,classifier='cls=nb',random_state=0)]: save: ret...
# [00:01:04.353] INFO   _fit_and_score: n[15/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=126,n_recs=1.0,classifier='cls=nb',random_state=0)]: save[0.021s, 3.5 MB]: ret
# [00:01:04.358] INFO   _fit_and_score: n[15/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=126,n_recs=1.0,classifier='cls=nb',random_state=0)]: save: estimator...
# [00:01:04.411] INFO   _fit_and_score: n[15/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=126,n_recs=1.0,classifier='cls=nb',random_state=0)]: save[0.050s, 15.2 MB]: estimator
# [00:01:05.275] INFO   _fit_and_score: n[18/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=nb',random_state=0)]: extra_metrics[4.946s, 2.3 MB]: ['classes', 'train_i', 'train_y', 'train_predict_proba', 'test_i', 'test_y', 'test_predict_proba', 'model_size', 'model_stats', 'proc_stats']
# [00:01:05.278] INFO   _fit_and_score: n[18/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=nb',random_state=0)]: save: ret...
# [00:01:05.292] INFO   _fit_and_score: n[18/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=nb',random_state=0)]: save[0.011s, 2.3 MB]: ret
# [00:01:05.294] INFO   _fit_and_score: n[18/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=nb',random_state=0)]: save: estimator...
# [00:01:05.307] INFO   _fit_and_score: n[20/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=42,n_recs=1.0,classifier='cls=nb',random_state=0)]: extra_metrics[2.229s, 1.2 MB]: ['classes', 'train_i', 'train_y', 'train_predict_proba', 'test_i', 'test_y', 'test_predict_proba', 'model_size', 'model_stats', 'proc_stats']
# [00:01:05.310] INFO   _fit_and_score: n[20/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=42,n_recs=1.0,classifier='cls=nb',random_state=0)]: save: ret...
# [00:01:05.313] INFO   _fit_and_score: n[18/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=nb',random_state=0)]: save[0.017s, 10.1 MB]: estimator
# [00:01:05.325] INFO   _fit_and_score: n[20/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=42,n_recs=1.0,classifier='cls=nb',random_state=0)]: save[0.011s, 1.2 MB]: ret
# [00:01:05.328] INFO   _fit_and_score: n[20/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=42,n_recs=1.0,classifier='cls=nb',random_state=0)]: save: estimator...
# [00:01:05.342] INFO   _fit_and_score: n[20/21], model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=42,n_recs=1.0,classifier='cls=nb',random_state=0)]: save[0.011s, 5.1 MB]: estimator
# [00:01:06.160] INFO   _fit_and_score: n[21/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=42,n_recs=1.0,classifier='cls=nb',random_state=0)]: extra_metrics[2.035s, 1.2 MB]: ['classes', 'train_i', 'train_y', 'train_predict_proba', 'test_i', 'test_y', 'test_predict_proba', 'model_size', 'model_stats', 'proc_stats']
# [00:01:06.163] INFO   _fit_and_score: n[21/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=42,n_recs=1.0,classifier='cls=nb',random_state=0)]: save: ret...
# [00:01:06.173] INFO   _fit_and_score: n[21/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=42,n_recs=1.0,classifier='cls=nb',random_state=0)]: save[0.008s, 1.2 MB]: ret
# [00:01:06.175] INFO   _fit_and_score: n[21/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=42,n_recs=1.0,classifier='cls=nb',random_state=0)]: save: estimator...
# [00:01:06.188] INFO   _fit_and_score: n[21/21], model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=42,n_recs=1.0,classifier='cls=nb',random_state=0)]: save[0.012s, 5.1 MB]: estimator
# [Parallel(n_jobs=4)]: Done  21 out of  21 | elapsed:  1.4min finished

# %%
# Precompute eval metrics + dims for the plots below
#   - Grain: models
#   - Metrics: train_score, test_score, ...
#   - Dims: model_id, fold, params_data, params_complexity, params_model, ...
facet = (
    # facet_wrap('params_data_and_model')
    # facet_grid('params_data ~ params_model')
    # facet_grid('params_model ~ params_data')
    facet_grid('n_recs ~ n_species', labeller='label_both')
)
ks_params_data = [
    'n_species',
    'n_recs',
]
ks_params_complexity = [
    # 'c_n_estimators',
    'c_max_depth',
    'c_C',
    # 'c_class_weight',
]
# params_model = ...  # Everything else
# log.debug('Start')
cv_models = (cv_results_splits_df(cv.cv_results_)
    # Slow yaml parsing, compute up front
    .assign(params_dict=lambda df: df.apply(axis=1, func=lambda row: dict(
        **{strip_startswith(k, 'param_'): row[k] for k in df if k.startswith('param_') and k not in ['param_classifier']},
        # HACK 'classifier.foo' -> 'c_foo'
        #   - TODO Refactor Search.classifier to get rid of the yaml strs ('c_cls', 'c_n_estimators', ...)
        **{'c_' + k: v for k, v in yaml.safe_load('{%s}' % row.param_classifier).items()},
        # 'classifier': yaml.safe_load('{%s}' % row.param_classifier),
    )))
    [lambda df: [c for c in df if not c.startswith('param_')]]
    # Dims from params (for validation curves, learning curves, etc.)
    .assign(
        n_species=lambda df: df.params_dict.apply(lambda d: d['n_species']),
        n_recs=lambda df: df.params_dict.apply(lambda d: d['n_recs']),
        params_data=lambda df: df.params_dict.apply(lambda d: ', '.join(
            '%s[%s]' % (k, d[k]) for k in ks_params_data if k in d
        )),
        params_complexity=lambda df: df.params_dict.apply(lambda d: ', '.join(
            '%s[%s]' % (k, d[k]) for k in ks_params_complexity if k in d
        )),
        params_model=lambda df: df.params_dict.apply(lambda d: ', '.join(
            '%s[%s]' % (k, d[k]) for k in d if k not in ks_params_data + ks_params_complexity
        )),
        params_data_and_model=lambda df: df.apply(axis=1, func=lambda row: (
            '\n'.join([row.params_data, row.params_model])
        )),
        params_model_and_complexity=lambda df: df.apply(axis=1, func=lambda row: (
            '\n'.join([row.params_model, row.params_complexity])
        )),
    )
    # HACK Convert yaml strs ('x: y') to bracket style ('x[y]'), for visual consistency
    #   - TODO Refactor Search.classifier to get rid of the yaml strs ('c_cls', 'c_n_estimators', ...)
    .applymap(lambda x: x if not isinstance(x, str) else (
        re.sub(r'([^][:, ]+):\s+([^][:,]+)(, )?', r'c_\1[\2]\3',
            re.sub(r'classifier\[([^]]+)\]', r'\1',
                x,
            ),
        )
    ))
    #   - Restore the cats we just destroyed [copied from cv_results_splits_df]
    .pipe(df_ordered_cat,
        model_id=lambda df: df.model_id.unique(),
        params=lambda df: df.params.unique(),
        params_data=lambda df: df.params_data.unique(),
        # Order params_complexity like c_max_depth
        params_complexity=lambda df: sorted(
            df.params_complexity.unique(),
            reverse=True,  # Match how the normal .unique() would come out (not clear why, and don't care)
            key=lambda s: one(
                (x['name'], or_else(-np.inf, lambda: float({'None': 'inf'}.get(x['value'], x['value']))))
                for x in [
                    parse.search('{name}[{value}]', s) or  # Parses first match, ignores rest
                    {'name': 'unk', 'value': None}
                ]
            ),
        ),
        params_model=lambda df: df.params_model.unique(),
    )
    .pipe(df_ordered_cat,
        params_data_and_model=lambda df: (df
            .sort_values(['params_data', 'params_model']).params_data_and_model.unique()
        ),
        params_model_and_complexity=lambda df: (df
            .sort_values(['params_model', 'params_complexity']).params_model_and_complexity.unique()
        ),
    )
    # .eval
    .assign(
        train_evals=lambda df: np.vectorize(SearchEvals)(
            i=df.pop('train_i'),
            y=df.pop('train_y'),
            classes=df['classes'],
            y_scores=df.pop('train_predict_proba'),
            drop_missing_classes_for_n_species=True,  # HACK Migrate to sk Pipeline to avoid this
        ),
        test_evals=lambda df: np.vectorize(SearchEvals)(
            i=df.pop('test_i'),
            y=df.pop('test_y'),
            classes=df['classes'],
            y_scores=df.pop('test_predict_proba'),
            drop_missing_classes_for_n_species=True,  # HACK Migrate to sk Pipeline to avoid this
        ),
    )
    # .pipe(tap, f=lambda df: log.debug('SearchEvals.score'))
    .assign(
        # HACK Recompute (train_score, test_score) using SearchEvals.score so it can drop_missing_classes_for_n_species
        #   - Else you'll get scores that are too low (bad) because they include some -np.inf's in the median
        train_score=lambda df: df.train_evals.map(lambda x: x.score()),
        test_score=lambda df: df.test_evals.map(lambda x: x.score()),  # (= 50p)
        test_75p_score=lambda df: df.test_evals.map(lambda x: x.score(agg=partial(np.percentile, q=75))),
        test_95p_score=lambda df: df.test_evals.map(lambda x: x.score(agg=partial(np.percentile, q=95))),
        # train_score=lambda df: map_progress(lambda x: x.score(), df.train_evals, use='dask', scheduler='threads'),
        # test_score=lambda df: map_progress(lambda x: x.score(), df.test_evals, use='dask', scheduler='threads'),
    )
    .drop(columns=[
        'classes',
    ])
    # proc_stats
    # .pipe(tap, f=lambda df: log.debug('proc_stats'))
    .pipe(lambda df: df.join(df
        .apply(axis=1, func=lambda row: (row.proc_stats.stats
            .groupby('pid')[['cpu_user', 'cpu_system', 'mem_rss', 'mem_vms']].agg(lambda g: g.max() - g.min())
            .sum(axis=0)
        ))
        .rename(columns={
            'cpu_user': 'cpu_user_time',
            'cpu_system': 'cpu_system_time',
            'mem_rss': 'mem_rss_delta',
            'mem_vms': 'mem_vms_delta',
        })
    ))
    .assign(
        cpu_time=lambda df: df.cpu_user_time + df.cpu_system_time,
        cpu_time_m=lambda df: df.cpu_time / 60,  # s -> m
    )
    # For xgb_rf, rf, ovr-rf
    .assign(
        c_multiclass=lambda df: df.params_dict.str.get('c_multiclass'),
        c_max_depth=lambda df: df.params_dict.str.get('c_max_depth'),
        # c_rf_max_depth=lambda df: df.apply(axis=1, func=lambda row: (
        #     row['c_max_depth'] * (10 if row['c_multiclass'] == 'ovr' else 1)  # HACK Undo rf_max_depth -> ovr_rf_max_depth
        # )),
    )
    # model_stats
    .assign(
        logreg_n_iter=lambda df: df.model_stats.map(lambda stats: or_else(None, lambda: stats.n_iter)),
        forest_depth_mean=lambda df: df.model_stats.map(lambda stats: or_else(None, lambda: stats.depth.mean())),
        forest_depth_std=lambda df: df.model_stats.map(lambda stats: or_else(None, lambda: stats.depth.std())),
    )
    # Reorder
    .pipe(df_reorder_cols,
        first=['model_id', 'params', 'params_dict', 'params_data', 'params_complexity', 'params_model'],
        last=['train_evals', 'test_evals', 'proc_stats', 'model_stats', 'model'],
    )
    # .pipe(tap, f=lambda df: log.debug('display'))
    .pipe(tap, f=lambda df: display(
        # df_summary(df).T,
        # df,
        len(df),
        df[:5],
    ))
    # .pipe(tap, f=lambda df: log.debug('Done'))
)
# Out:
# 21
#                                            model_id                                   params                                        params_dict                   params_data params_complexity params_model  fold  train_score  test_score  fit_time  score_time  model_size  n_species  n_recs                    params_data_and_model params_model_and_complexity  test_75p_score  test_95p_score  cpu_user_time  cpu_system_time  mem_rss_delta  mem_vms_delta  cpu_time  cpu_time_m c_multiclass c_max_depth logreg_n_iter forest_depth_mean forest_depth_std                                                                  train_evals                                                                test_evals                          proc_stats                                                model_stats  model
# 0   n_species[168], n_recs[1.0], c_cls[nb], fold[0]   n_species[168], n_recs[1.0], c_cls[nb]   {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'nb'}   n_species[168], n_recs[1.0]                      c_cls[nb]     0         -2.0       -15.0     0.637       0.922    20212559        168    1.00   n_species[168], n_recs[1.0]\nc_cls[nb]                 c_cls[nb]\n          -168.0          -168.0          4.625            1.421      2.022e+08      1.987e+08     6.046       0.101         None        None          None              None             None  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])   ProcStats(interval=1.0, stats[7])                          type
# 0  search/unknown:GaussianNB    NaN
# 1   n_species[168], n_recs[1.0], c_cls[nb], fold[1]   n_species[168], n_recs[1.0], c_cls[nb]   {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'nb'}   n_species[168], n_recs[1.0]                      c_cls[nb]     1         -2.0       -15.0     0.284       1.464    20212559        168    1.00   n_species[168], n_recs[1.0]\nc_cls[nb]                 c_cls[nb]\n          -168.0          -168.0          7.565            2.451      1.717e+08      1.385e+08    10.016       0.167         None        None          None              None             None  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])  ProcStats(interval=1.0, stats[11])                          type
# 0  search/unknown:GaussianNB    NaN
# 2   n_species[168], n_recs[1.0], c_cls[nb], fold[2]   n_species[168], n_recs[1.0], c_cls[nb]   {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'nb'}   n_species[168], n_recs[1.0]                      c_cls[nb]     2         -2.0       -18.0     0.269       1.459    20212559        168    1.00   n_species[168], n_recs[1.0]\nc_cls[nb]                 c_cls[nb]\n          -168.0          -168.0          8.313            2.671      1.834e+08      1.448e+08    10.984       0.183         None        None          None              None             None  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])  ProcStats(interval=1.0, stats[12])                          type
# 0  search/unknown:GaussianNB    NaN
# 3  n_species[168], n_recs[0.75], c_cls[nb], fold[0]  n_species[168], n_recs[0.75], c_cls[nb]  {'n_recs': 0.75, 'n_species': 168, 'c_cls': 'nb'}  n_species[168], n_recs[0.75]                      c_cls[nb]     0         -3.0       -18.0     0.271       1.464    16169807        168    0.75  n_species[168], n_recs[0.75]\nc_cls[nb]                 c_cls[nb]\n          -168.0          -168.0          7.609            2.406      1.674e+08      1.340e+08    10.015       0.167         None        None          None              None             None  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])  ProcStats(interval=1.0, stats[11])                          type
# 0  search/unknown:GaussianNB    NaN
# 4  n_species[168], n_recs[0.75], c_cls[nb], fold[1]  n_species[168], n_recs[0.75], c_cls[nb]  {'n_recs': 0.75, 'n_species': 168, 'c_cls': 'nb'}  n_species[168], n_recs[0.75]                      c_cls[nb]     1         -2.0       -15.0     0.256       1.494    16169807        168    0.75  n_species[168], n_recs[0.75]\nc_cls[nb]                 c_cls[nb]\n          -168.0          -168.0          8.270            2.728      1.569e+08      1.275e+08    10.999       0.183         None        None          None              None             None  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])  ProcStats(interval=1.0, stats[12])                          type
# 0  search/unknown:GaussianNB    NaN

# %%
# Tune logreg n_iter
(cv_models
    .merge(how='left', on='model_id', right=df_flatmap(cv_models, lambda row: (
        dict(model_id=row.model_id, n_iter=n_iter)
        for n_iter in coalesce(row.logreg_n_iter, [0])
    )))
    # Manually compute y.mean() per group
    # .groupby('params').apply(lambda g: g.assign(cpu_time_m_mean=lambda df: df.cpu_time_m.mean()))
    .pipe(df_reverse_cat, 'params_complexity')
    .pipe(ggplot)
    + aes(x='params_complexity')
    + facet
    + geom_count(aes(y='n_iter', size='..n..')) + scale_size_area()
    + expand_limits(y=0)
    + coord_flip()
    + theme_figsize(width=12*1, aspect_ratio=1/1.5)
    + ggtitle(f'Logreg: n_iter ({recs_stats})')
)
# Out:
# <ggplot: (-9223372036535945177)>

# %%
# Train time ~ n_species
(cv_models
    .pipe(df_reverse_cat, 'params_complexity')
    .pipe(ggplot)
    + aes(x='n_species', y='cpu_time_m', color='params_complexity')
    + facet_wrap('params_model', nrow=1)
    + geom_point()
    + geom_line()
    + theme_figsize(width=12*1, aspect_ratio=1/1.5)
    + ggtitle(f'Train time ~ n_species ({recs_stats})')
)
# Out:
# <ggplot: (324028992)>

# %%
# Train time ~ n_recs
(cv_models
    .pipe(df_reverse_cat, 'params_complexity')
    .pipe(ggplot)
    + aes(x='n_recs', y='cpu_time_m', color='params_complexity')
    + facet_wrap('params_model', nrow=1)
    + geom_point()
    + geom_line()
    + theme_figsize(width=12*1, aspect_ratio=1/1.5)
    + ggtitle(f'Train time ~ n_recs ({recs_stats})')
)
# Out:
# <ggplot: (-9223372036538204377)>

# %%
(cv_models
    # Manually compute y.mean() per group
    .groupby('params').apply(lambda g: g.assign(cpu_time_m_mean=lambda df: df.cpu_time_m.mean()))
    .pipe(df_reverse_cat, 'params_complexity')
    .pipe(ggplot)
    + aes(x='params_complexity')
    + facet
    + geom_col(aes(y='cpu_time_m_mean'), fill='darkgray', position=position_dodge())
    + geom_point(aes(y='cpu_time_m'), color='black', fill='none', size=2)
    + coord_flip()
    + theme_figsize(width=12*1, aspect_ratio=1/1.5)
    + ggtitle(f'Train + score times ({recs_stats})')
)
# Out:
# <ggplot: (-9223372036535490346)>

# %%
(cv_models
    # Manually compute y.mean() per group
    .groupby('params').apply(lambda g: g.assign(model_size_mean=lambda df: df.model_size.mean()))
    .pipe(df_reverse_cat, 'params_complexity')
    .pipe(ggplot)
    + aes(x='params_complexity')
    + facet
    + geom_col(aes(y='model_size_mean'), fill='darkgray', position=position_dodge()) # Summary per fold
    + geom_point(aes(y='model_size'), color='black', fill='none', size=2) # Distribution of folds
    + scale_y_continuous(labels=labels_bytes(), breaks=breaks_bytes())
    + coord_flip()
    + ylab('model_size')
    + theme_figsize(width=12*1, aspect_ratio=1/1.5)
    + ggtitle(f'Model size ({recs_stats})')
)
# Out:
# <ggplot: (-9223372036532775010)>

# %%
# TODO Make not barf on non-tree models (blocks rest of notebook)
(cv_models
    # Manually compute boxplot stats, else it's _really_ slow (or you have to downsample, which misses outliers)
    #   - Based on stat_boxplot.compute_group
    .merge(how='left', on='params', right=cv_models.groupby('params').apply(lambda g: one(
        pd.Series(dict(
            params=g.name,
            ymin=boxplot['whislo'],
            lower=boxplot['q1'],
            middle=boxplot['med'],
            upper=boxplot['q3'],
            ymax=boxplot['whishi'],
            outliers=np.unique(boxplot['fliers']),  # np.unique else really slow, because lots of repeated (int) points
        ))
        for [boxplot] in [mpl.cbook.boxplot_stats(  # [boxplot] is 1 elem because X.ndim = 1
            X=np.concatenate([[] if x is None else x.depth for x in g.model_stats]),
            whis=1.5,
        )]
    )))
    .pipe(df_reverse_cat, 'params_complexity')
    .pipe(ggplot)
    + aes(x='params_complexity')
    + facet
    + geom_boxplot(
        stat='identity',
        outlier_size=.5,
        mapping=aes(ymin='ymin', ymax='ymax', upper='upper', lower='lower', middle='middle', outliers='outliers',
            width=.8,  # Close enough to geom_boxplot defaults [TODO Maybe should compute based on num categorical x's?]
        ),
    )
    + ylab('tree_depth')
    + coord_flip()
    + theme_figsize(width=12*2, aspect_ratio=1/1.5)
    + ggtitle(f'Tree depth ({recs_stats})')
)
# Out:
# [skip]

# %%
# Train/test scores
#   - Grain: models x {train,test}
#   - Metrics: score
#   - Dims: group, params
(cv_models
    .pipe(df_reverse_cat, 'params_complexity')
    .pipe(lambda df: pd.melt(df,
        id_vars=[
            'params', 'params_data', 'params_model', 'params_complexity',
            'params_data_and_model', 'params_model_and_complexity',
            'n_species', 'n_recs',
            'fold',
        ],
        value_vars=[
            # 'train_score',  # Boring
            'test_score',
            'test_75p_score',
            'test_95p_score',
        ],
        var_name='metric',
        value_name='score'),
    )
    .assign(
        metric=lambda df: df.metric.str.replace('_score', ''),
        group=lambda df: df.params_complexity.str.cat(df.metric, '/'),
    )
    .pipe(df_ordered_cat,
        group=lambda df: reversed(df.group.unique()),
    )
    .pipe(ggplot)
    + aes(x='params_complexity')
    + aes(y='score')
    + aes(color='metric')
    # + facet_grid('params_data ~ params_model')
    + facet
    + geom_hline(yintercept=-1, color='lightgrey')  # -1 is the max score (1 is the min coverage_error)
    + geom_point(alpha=.5)
    # + geom_jitter(fill='none', size=3, height=1e-9, width=.05)
    # + geom_count(aes(size='..n..')) + scale_size_area()
    # + stat_summary(aes(group='group'), fun_data='mean_cl_boot', random_state=0, geom='errorbar')
    + coord_flip(
        # ylim=(-40, 0),
    )
    # + scale_color_cmap_d('tab10')
    + scale_color_cmap_d('Set1')
    + theme_figsize(width=12*1, aspect_ratio=1/1.5)
    + ylab('score (-coverage_error)')
    + ggtitle(f'Train/test scores ({recs_stats})')
)
# Out:
# <ggplot: (-9223372036534314815)>

# %%
(cv_models
    .pipe(ggplot)
    + aes(x='cpu_time_m', y='test_score')
    + aes(color='params_complexity')
    + facet
    + geom_point()
    + geom_hline(yintercept=0, color='grey')
    + expand_limits(x=0)
    # + ylim(-30, 0)
    + scale_color_cmap_d(mpl_cmap_concat('tab20', 'tab20b', 'tab20c'))
    + guides(color=guide_legend(ncol=1)) + theme(legend_position='right', legend_box_spacing=.4, legend_key_height=8)
    + theme_figsize(width=12*1, aspect_ratio=1/1.5)
    + ggtitle('test_score ~ cpu_time_m')
)
# Out:
# <ggplot: (348395468)>

# %%
(cv_models
    .pipe(ggplot)
    + aes(x='model_size', y='test_score')
    + aes(color='params_complexity')
    + facet
    + geom_point()
    + geom_hline(yintercept=0, color='grey')
    + scale_x_continuous(labels=labels_bytes(), breaks=breaks_bytes())
    + expand_limits(x=0)
    # + ylim(-30, 0)
    + scale_color_cmap_d(mpl_cmap_concat('tab20', 'tab20b', 'tab20c'))
    + guides(color=guide_legend(ncol=1)) + theme(legend_position='right', legend_box_spacing=.4, legend_key_height=8)
    + theme_figsize(width=12*1, aspect_ratio=1/1.5)
    + ggtitle('test_score ~ model_size')
)
# Out:
# <ggplot: (-9223372036528289911)>

# %%
SLOW_PLOTS_NEXT
# Out:
# Traceback (most recent call last):
#
#   File "<ipython-input-58-cf9919437dad>", line 1, in <module>
#     SLOW_PLOTS_NEXT
#
# NameError: name 'SLOW_PLOTS_NEXT' is not defined

# %% [markdown]
# # Model diagnostics: all models, all folds

# %%
print('models:')
print('  params[*/%s]' % len(cv_models.params.cat.categories))
print('  fold[*/%s]' % cv.cv.n_splits)
# Out:
# models:
#   params[*/7]
#   fold[*/3]

# %%
# TODO Cache
# Coverage errors: all models, all folds
#   - Subset: all models
#   - Grain: sum(recs[model.test_i] for model)
#   - Dims: model_id, params, fold, y_true, rec_id
#   - Metrics: coverage_error
coverage_errors_all_all = (cv_models
    # .sample(n=5, random_state=0)  # For faster dev
    .pipe(lambda df: DF(
        OrderedDict(
            # **row[['model_id', 'params', 'fold']],  # Slow (in this inner loop), unpack manually instead
            model_id=row.model_id,
            params=row.params,
            params_data=row.params_data,
            params_model=row.params_model,
            params_complexity=row.params_complexity,
            params_data_and_model=row.params_data_and_model,
            params_model_and_complexity=row.params_model_and_complexity,
            fold=row.fold,
            i=i,
            y_true=y_true,
            coverage_error=coverage_error,
        )
        for row in iter_progress(df_rows(df), n=len(df))
        for i, y_true, coverage_error in zip(
            row.test_evals.i,
            row.test_evals.y,
            row.test_evals.coverage_errors(),
        )
    ))
    .astype(dict(
        model_id=cv_models.model_id.dtype,
        params=cv_models.params.dtype,
        params_data=cv_models.params_data.dtype,
        params_model=cv_models.params_model.dtype,
        params_complexity=cv_models.params_complexity.dtype,
        params_data_and_model=cv_models.params_data_and_model.dtype,
        params_model_and_complexity=cv_models.params_model_and_complexity.dtype,
    ))
    .pipe(tap, lambda df: display(
        df_summary(df).T,
        df[:10],
    ))
)
# Out:
#   0%|                                                                                           | 0/21 [00:00<?, ?it/s]
#  10%|███████▉                                                                           | 2/21 [00:00<00:01, 14.91it/s]
#  19%|███████████████▊                                                                   | 4/21 [00:00<00:01, 15.54it/s]
#  29%|███████████████████████▋                                                           | 6/21 [00:00<00:00, 15.82it/s]
#  38%|███████████████████████████████▌                                                   | 8/21 [00:00<00:00, 15.92it/s]
#  48%|███████████████████████████████████████                                           | 10/21 [00:00<00:00, 15.70it/s]
#  57%|██████████████████████████████████████████████▊                                   | 12/21 [00:00<00:00, 15.58it/s]
#  71%|██████████████████████████████████████████████████████████▌                       | 15/21 [00:00<00:00, 16.45it/s]
#  90%|██████████████████████████████████████████████████████████████████████████▏       | 19/21 [00:01<00:00, 18.66it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 21/21 [00:01<00:00, 19.96it/s]
#                                                                                                                                min                                               25%                                              50%                                              75%                                             max
#                             dtype    sizeof  len   count nunique mean     std
# model_id                    category 1066968 11088 11088 21      NaN      NaN      n_species[168], n_recs[1.0], c_cls[nb], fold[0]  n_species[168], n_recs[0.75], c_cls[nb], fold[1]  n_species[168], n_recs[0.5], c_cls[nb], fold[2]  n_species[126], n_recs[1.0], c_cls[nb], fold[0]  n_species[42], n_recs[1.0], c_cls[nb], fold[2]
# params                      category 967176  11088 11088 7       NaN      NaN               n_species[168], n_recs[1.0], c_cls[nb]           n_species[168], n_recs[0.75], c_cls[nb]           n_species[168], n_recs[0.5], c_cls[nb]           n_species[126], n_recs[1.0], c_cls[nb]           n_species[42], n_recs[1.0], c_cls[nb]
# params_data                 category 845208  11088 11088 7       NaN      NaN                          n_species[168], n_recs[1.0]                      n_species[168], n_recs[0.75]                      n_species[168], n_recs[0.5]                      n_species[126], n_recs[1.0]                      n_species[42], n_recs[1.0]
# params_model                category 1086624 11088 11088 1       NaN      NaN                                            c_cls[nb]                                         c_cls[nb]                                        c_cls[nb]                                        c_cls[nb]                                       c_cls[nb]
# params_complexity           category 587664  11088 11088 1       NaN      NaN
# params_data_and_model       category 956088  11088 11088 7       NaN      NaN               n_species[168], n_recs[1.0]\nc_cls[nb]           n_species[168], n_recs[0.75]\nc_cls[nb]           n_species[168], n_recs[0.5]\nc_cls[nb]           n_species[126], n_recs[1.0]\nc_cls[nb]           n_species[42], n_recs[1.0]\nc_cls[nb]
# params_model_and_complexity category 654192  11088 11088 1       NaN      NaN                                          c_cls[nb]\n                                       c_cls[nb]\n                                      c_cls[nb]\n                                      c_cls[nb]\n                                     c_cls[nb]\n
# fold                        int64    295680  11088 11088 3       1.000    0.817                                                  0                                                 0                                                1                                                2                                               2
# i                           int64    310464  11088 11088 1638    1687.776 966.441                                                2                                               856                                             1681                                             2527                                            3359
# y_true                      object   942480  11088 11088 168     NaN      NaN                                                 ABTO                                              CAKI                                             HOFI                                             ROSA                                            YRWA
# coverage_error              float64  266112  11088 11088 106     64.636   73.071                                                 1                                                 3                                               18                                              168                                             168
#                                           model_id                                  params                  params_data params_model params_complexity                   params_data_and_model params_model_and_complexity  fold     i y_true  coverage_error
# 0  n_species[168], n_recs[1.0], c_cls[nb], fold[0]  n_species[168], n_recs[1.0], c_cls[nb]  n_species[168], n_recs[1.0]    c_cls[nb]                    n_species[168], n_recs[1.0]\nc_cls[nb]                 c_cls[nb]\n     0  1325   BTAH           168.0
# 1  n_species[168], n_recs[1.0], c_cls[nb], fold[0]  n_species[168], n_recs[1.0], c_cls[nb]  n_species[168], n_recs[1.0]    c_cls[nb]                    n_species[168], n_recs[1.0]\nc_cls[nb]                 c_cls[nb]\n     0  2331   SWTH            23.0
# 2  n_species[168], n_recs[1.0], c_cls[nb], fold[0]  n_species[168], n_recs[1.0], c_cls[nb]  n_species[168], n_recs[1.0]    c_cls[nb]                    n_species[168], n_recs[1.0]\nc_cls[nb]                 c_cls[nb]\n     0  3347   LAGO           117.0
# 3  n_species[168], n_recs[1.0], c_cls[nb], fold[0]  n_species[168], n_recs[1.0], c_cls[nb]  n_species[168], n_recs[1.0]    c_cls[nb]                    n_species[168], n_recs[1.0]\nc_cls[nb]                 c_cls[nb]\n     0  3258   HCRE            53.0
# 4  n_species[168], n_recs[1.0], c_cls[nb], fold[0]  n_species[168], n_recs[1.0], c_cls[nb]  n_species[168], n_recs[1.0]    c_cls[nb]                    n_species[168], n_recs[1.0]\nc_cls[nb]                 c_cls[nb]\n     0  1864   BCVI           168.0
# 5  n_species[168], n_recs[1.0], c_cls[nb], fold[0]  n_species[168], n_recs[1.0], c_cls[nb]  n_species[168], n_recs[1.0]    c_cls[nb]                    n_species[168], n_recs[1.0]\nc_cls[nb]                 c_cls[nb]\n     0   389   BFAL            63.0
# 6  n_species[168], n_recs[1.0], c_cls[nb], fold[0]  n_species[168], n_recs[1.0], c_cls[nb]  n_species[168], n_recs[1.0]    c_cls[nb]                    n_species[168], n_recs[1.0]\nc_cls[nb]                 c_cls[nb]\n     0  1352   BBEH             1.0
# 7  n_species[168], n_recs[1.0], c_cls[nb], fold[0]  n_species[168], n_recs[1.0], c_cls[nb]  n_species[168], n_recs[1.0]    c_cls[nb]                    n_species[168], n_recs[1.0]\nc_cls[nb]                 c_cls[nb]\n     0  2494   VIWA            20.0
# 8  n_species[168], n_recs[1.0], c_cls[nb], fold[0]  n_species[168], n_recs[1.0], c_cls[nb]  n_species[168], n_recs[1.0]    c_cls[nb]                    n_species[168], n_recs[1.0]\nc_cls[nb]                 c_cls[nb]\n     0  1004   INDO             1.0
# 9  n_species[168], n_recs[1.0], c_cls[nb], fold[0]  n_species[168], n_recs[1.0], c_cls[nb]  n_species[168], n_recs[1.0]    c_cls[nb]                    n_species[168], n_recs[1.0]\nc_cls[nb]                 c_cls[nb]\n     0  1655   BBFL           168.0

# %%
[print(x) for x in coverage_errors_all_all.params_data.unique()];
params_data = (
    'n_species[168], n_recs[1.0]'
    # 'n_species[336], n_recs[1.0]'
    # 'n_species[159], n_recs[1.0]'
)
n_species = parse.search('n_species[{n_species:d}], n_recs[{n_recs:f}]', params_data)['n_species']
# Out:
# n_species[168], n_recs[1.0]
# n_species[168], n_recs[0.75]
# n_species[168], n_recs[0.5]
# n_species[168], n_recs[0.25]
# n_species[126], n_recs[1.0]
# n_species[84], n_recs[1.0]
# n_species[42], n_recs[1.0]

# %%
# TODO Class imbalance
#   1. Is class imbalance causing a problem? [-> maybe]
#   2. Is class_weight solving it? [-> maybe a little bit]
#   - TODO Try again with larger class imbalance
(coverage_errors_all_all
    [lambda df: df.params_data == params_data]
    # .sample(100, random_state=0)  # Faster dev
    .merge(how='left', on='y_true', right=(recs
        .assign(n_recs=1).groupby('species')['n_recs'].sum().reset_index()
        .rename(columns={'species': 'y_true'})
    ))
    # .pipe(puts, f=lambda df: df[:3])  # XXX Debug
    .pipe(ggplot)
    # + facet_grid('params_complexity ~ params_model')
    + facet_wrap('params_model_and_complexity')
    + aes(x='n_recs', y='coverage_error')
    + geom_count(aes(size='..n..')) + scale_size_area()
    + expand_limits(x=0, y=0)
    + coord_flip()
    + theme_figsize(width=12*1, aspect_ratio=1/1)
    + ggtitle(rf'Coverage error by n_recs per species ({recs_stats}) [{params_data}]')
)
# Out:
# <ggplot: (319281728)>

# %%
# Facet by params_no_ns, order by median(coverage_error)
#   - Subset: all models
#   - Grain: sum(recs[model.test_i].groupby(params, y_true) for model)
#       - Over: fold, rec_id
#   - Dims: params, y_true
#   - Metrics: coverage_error.median
# in: coverage_errors_all_all, recs
(coverage_errors_all_all
    [lambda df: df.params_data == params_data]
    # .sample(100, random_state=0)  # Faster dev
    # .pipe(df_reverse_cat, 'params', 'params_no_ns', 'ns')
    .pipe(df_ordered_cat,
        y_true=lambda df: (
            # Sort species by median(coverage_error) (across all models)
            df.groupby('y_true').agg({'coverage_error': np.median}).reset_index().sort_values('coverage_error').y_true
            # Sort species by taxo (hard to compare across models, unless they're pretty low noise)
            # reversed(recs.species.cat.categories)
        ),
    )
    .pipe(ggplot)
    + aes(x='y_true', y='coverage_error')
    + aes(color='y_true')
    # + facet_grid('params_complexity ~ params_model')
    + facet_wrap('params_model_and_complexity', dir='v',
        nrow=coverage_errors_all_all.params_model.nunique(),  # Bug: nrow instead of ncol [https://github.com/has2k1/plotnine/issues/163]
    )
    # + geom_line(aes(group='params'), stat='summary', fun_y=np.median)  # TODO Bad interpolation with n_species
    + geom_point(aes(group='params'), stat='summary', fun_y=np.median)
    + coord_flip()
    # + geom_hline(yintercept=recs.species.nunique(), color='grey')
    + scale_color_cmap_d(mpl_cmap_repeat(10, 'tab20', 'tab20b', 'tab20c'))
    + theme_minimal()  # Before other theme()
    + guides(color=guide_legend(nrow=70))
    + theme(legend_position='right', legend_box_spacing=.4, legend_key_height=8, legend_text=element_text(size=8))
    + theme(axis_text_y=element_blank())
    + theme_figsize(width=12*1, aspect_ratio=1/2)
    + ggtitle(rf'Coverage error over fold $\times$ instance ({recs_stats}) [{params_data}]')
)
# Out:
# <ggplot: (-9223372036538046092)>

# %%
# TODO Slow, bad for notebook dev loop -- move lower, or disable by default?
# Facet by species
#   - Subset: all models
#   - Grain: sum(recs[model.test_i].groupby(params, y_true) for model)
#       - Over: fold, rec_id
#   - Dims: params, y_true
#   - Metrics: coverage_error.median
# in: coverage_errors_all_all, recs
[print(x) for x in coverage_errors_all_all.params_model.unique()];
params_model = [
    # 'c_cls[rf], c_n_estimators[100]',
    # 'c_cls[logreg_multi], c_solver[newton-cg]',
    # 'c_cls[logreg_ovr], c_solver[liblinear]',
    # 'c_cls[xgb_rf], c_n_estimators[100]',
    # 'c_cls[logreg_ovr], c_solver[liblinear], c_C[0.1]',
    'c_cls[nb]',
]
(coverage_errors_all_all
    [lambda df: df.params_data == params_data]
    [lambda df: df.params_model.isin(params_model)]
    # .sample(200, random_state=0)  # Faster dev
    # [lambda df: df.y_true.isin(df.y_true.drop_duplicates().sample(n=3, random_state=0))]  # Faster dev
    .astype({'y_true': metadata.species.df.shorthand.dtype})
    # .pipe(df_reverse_cat, 'params_complexity')
    .pipe(ggplot)
    + aes(x='params_complexity', y='coverage_error')
    + aes(color='params_complexity')
    + facet_wrap('y_true',
        ncol=int((n_species * 1/(2/3)) ** .5),
    )
    + geom_hline(yintercept=1, color='grey')
    # + geom_hline(yintercept=recs.species.nunique(), color='grey')
    # Percentiles (faster, no overplot)
    # + geom_point(stat='summary', fun_y=np.median)
    # + geom_linerange(stat='summary', fun_ymin=partial(np.percentile, q=25), fun_ymax=partial(np.percentile, q=75))
    # Violin (slow, no overplot)
    # + geom_violin()
    # Boxplot (very slow, no overplot)
    # + geom_boxplot()
    # Points (medium cost, high overplot)
    #   - n (count) instead of prop (proportion)
    #   - scale_size_area() instead of default scale_size(), because it's a count [I don't grok this but it looks good]
    + geom_count(aes(size='..n..'), color='lightgray')
    + scale_size_area()
    # + geom_point(stat='summary', fun_y=np.median, shape='|', size=5, stroke=2)
    + geom_point(stat='summary', fun_y=np.median, size=5)
    + coord_flip(
        # ylim=(0, 40),
    )
    # + scale_color_cmap_d(mpl_cmap_repeat(10, 'tab10'))  # Strong
    + scale_color_cmap_d(mpl_cmap_repeat(1, 'tab20', 'tab20b', 'tab20c'))  # FIXME repeat(10) makes lots of blue/gray
    + guides(color=guide_legend(reverse=True))
    + theme(axis_text_y=element_text(size=6))
    + theme_minimal()  # [TODO Before other theme()]
    + theme_figsize(width=12*2, aspect_ratio=1/1)
    + ggtitle(rf'Coverage error over fold $\times$ instance, by params_complexity ({recs_stats}) [{params_data}, {params_model}]')
)
# Out:
# c_cls[nb]
# <ggplot: (325731739)>

# %%
# TODO Slow, bad for notebook dev loop -- move lower, or disable by default?
# Facet by species
#   - Subset: all models
#   - Grain: sum(recs[model.test_i].groupby(params, y_true) for model)
#       - Over: fold, rec_id
#   - Dims: params, y_true
#   - Metrics: coverage_error.median
# in: coverage_errors_all_all, recs
[print(x) for x in coverage_errors_all_all.params_complexity.unique()];
params_complexity = [
    # 'c_max_depth[46]',
    # 'c_max_depth[1]',
    # 'c_C[0.01]',
    # 'c_class_weight[balanced]',
    '',
]
(coverage_errors_all_all
    [lambda df: df.params_data == params_data]
    [lambda df: df.params_complexity.isin(params_complexity)]
    # [lambda df: df.params.astype(str).str.contains(r'c_n_estimators\[100\]')]  # XXX Subset models
    # .sample(200, random_state=0)  # Faster dev
    # [lambda df: df.y_true.isin(df.y_true.drop_duplicates().sample(n=3, random_state=0))]  # Faster dev
    .astype({'y_true': metadata.species.df.shorthand.dtype})
    # .pipe(df_reverse_cat, 'params_model')
    .pipe(ggplot)
    + aes(x='params_model', y='coverage_error')
    + aes(color='params_model')
    + facet_wrap('y_true',
        ncol=int((n_species * 1/(2/3)) ** .5),
    )
    + geom_hline(yintercept=1, color='grey')
    # + geom_hline(yintercept=recs.species.nunique(), color='grey')
    # Percentiles (faster, no overplot)
    # + geom_point(stat='summary', fun_y=np.median)
    # + geom_linerange(stat='summary', fun_ymin=partial(np.percentile, q=25), fun_ymax=partial(np.percentile, q=75))
    # Violin (slow, no overplot)
    # + geom_violin()
    # Boxplot (very slow, no overplot)
    # + geom_boxplot()
    # Points (medium cost, high overplot)
    #   - n (count) instead of prop (proportion)
    #   - scale_size_area() instead of default scale_size(), because it's a count [I don't grok this but it looks good]
    + geom_count(aes(size='..n..'), color='lightgray')
    + scale_size_area()
    # + geom_point(stat='summary', fun_y=np.median, shape='|', size=5, stroke=2)
    + geom_point(stat='summary', fun_y=np.median, size=5)
    + coord_flip(
        ylim=(0, 40),
    )
    + scale_color_cmap_d(mpl_cmap_repeat(1, 'tab20', 'tab20b', 'tab20c'))  # FIXME repeat(10) makes lots of blue/gray
    + guides(color=guide_legend(reverse=True))
    + theme(axis_text_y=element_text(size=6))
    + theme_minimal()  # [TODO Before other theme()]
    + theme_figsize(width=12*2, aspect_ratio=1/1)
    + ggtitle(rf'Coverage error over fold $\times$ instance, by params_model ({recs_stats}) [{params_data}, {params_complexity}]')
)
# Out:
# <ggplot: (-9223372036528929227)>

# %%
ONE_MODEL_PLOTS_NEXT
# Out:
# Traceback (most recent call last):
#
#   File "<ipython-input-66-1d9a201e1df1>", line 1, in <module>
#     ONE_MODEL_PLOTS_NEXT
#
# NameError: name 'ONE_MODEL_PLOTS_NEXT' is not defined

# %% [markdown]
# # Model diagnostics: one model, all folds

# %%
params_i = 0
params = cv_models.params.cat.categories[params_i]
print("params:\n%s" % '\n'.join('  %s: %r' % (i, x) for i, x in enumerate(cv_models.params.cat.categories)))
print()
print('models:')
print('  params[%s/%s]: %r' % (params_i, len(cv_models.params.cat.categories), params))
print('  fold[*/%s]' % cv.cv.n_splits)
# Out:
# params:
#   0: 'n_species[168], n_recs[1.0], c_cls[nb]'
#   1: 'n_species[168], n_recs[0.75], c_cls[nb]'
#   2: 'n_species[168], n_recs[0.5], c_cls[nb]'
#   3: 'n_species[168], n_recs[0.25], c_cls[nb]'
#   4: 'n_species[126], n_recs[1.0], c_cls[nb]'
#   5: 'n_species[84], n_recs[1.0], c_cls[nb]'
#   6: 'n_species[42], n_recs[1.0], c_cls[nb]'
#
# models:
#   params[0/7]: 'n_species[168], n_recs[1.0], c_cls[nb]'
#   fold[*/3]

# %%
# Coverage errors: one model, all folds
#   - Subset: models.params == params
#   - Grain: sum(recs[model.test_i] for model)
#   - Dims: model_id, params, fold, y_true, rec_id
#   - Metrics: coverage_error
coverage_errors_one_all = (coverage_errors_all_all
    [lambda df: df.params == params]  # One model, all folds
)
display(
    df_summary(coverage_errors_one_all).T,
    coverage_errors_one_all[:5],
)
# Out:
#                                                                                                                              min                                              25%                                              50%                                              75%                                              max
#                             dtype    sizeof len  count nunique mean     std
# model_id                    category 193536 2016 2016  3       NaN      NaN      n_species[168], n_recs[1.0], c_cls[nb], fold[0]  n_species[168], n_recs[1.0], c_cls[nb], fold[0]  n_species[168], n_recs[1.0], c_cls[nb], fold[1]  n_species[168], n_recs[1.0], c_cls[nb], fold[2]  n_species[168], n_recs[1.0], c_cls[nb], fold[2]
# params                      category 175392 2016 2016  1       NaN      NaN               n_species[168], n_recs[1.0], c_cls[nb]           n_species[168], n_recs[1.0], c_cls[nb]           n_species[168], n_recs[1.0], c_cls[nb]           n_species[168], n_recs[1.0], c_cls[nb]           n_species[168], n_recs[1.0], c_cls[nb]
# params_data                 category 153216 2016 2016  1       NaN      NaN                          n_species[168], n_recs[1.0]                      n_species[168], n_recs[1.0]                      n_species[168], n_recs[1.0]                      n_species[168], n_recs[1.0]                      n_species[168], n_recs[1.0]
# params_model                category 197568 2016 2016  1       NaN      NaN                                            c_cls[nb]                                        c_cls[nb]                                        c_cls[nb]                                        c_cls[nb]                                        c_cls[nb]
# params_complexity           category 106848 2016 2016  1       NaN      NaN
# params_data_and_model       category 173376 2016 2016  1       NaN      NaN               n_species[168], n_recs[1.0]\nc_cls[nb]           n_species[168], n_recs[1.0]\nc_cls[nb]           n_species[168], n_recs[1.0]\nc_cls[nb]           n_species[168], n_recs[1.0]\nc_cls[nb]           n_species[168], n_recs[1.0]\nc_cls[nb]
# params_model_and_complexity category 118944 2016 2016  1       NaN      NaN                                          c_cls[nb]\n                                      c_cls[nb]\n                                      c_cls[nb]\n                                      c_cls[nb]\n                                      c_cls[nb]\n
# fold                        int64    53760  2016 2016  3       1.000    0.817                                                  0                                                0                                                1                                                2                                                2
# i                           int64    56448  2016 2016  1638    1679.539 970.159                                                2                                              836                                             1679                                             2518                                             3359
# y_true                      object   174720 2016 2016  168     NaN      NaN                                                 ABTO                                             CACG                                             HAFL                                             RNSA                                             YRWA
# coverage_error              float64  48384  2016 2016  96      56.533   70.043                                                 1                                                2                                               16                                              168                                              168
#                                           model_id                                  params                  params_data params_model params_complexity                   params_data_and_model params_model_and_complexity  fold     i y_true  coverage_error
# 0  n_species[168], n_recs[1.0], c_cls[nb], fold[0]  n_species[168], n_recs[1.0], c_cls[nb]  n_species[168], n_recs[1.0]    c_cls[nb]                    n_species[168], n_recs[1.0]\nc_cls[nb]                 c_cls[nb]\n     0  1325   BTAH           168.0
# 1  n_species[168], n_recs[1.0], c_cls[nb], fold[0]  n_species[168], n_recs[1.0], c_cls[nb]  n_species[168], n_recs[1.0]    c_cls[nb]                    n_species[168], n_recs[1.0]\nc_cls[nb]                 c_cls[nb]\n     0  2331   SWTH            23.0
# 2  n_species[168], n_recs[1.0], c_cls[nb], fold[0]  n_species[168], n_recs[1.0], c_cls[nb]  n_species[168], n_recs[1.0]    c_cls[nb]                    n_species[168], n_recs[1.0]\nc_cls[nb]                 c_cls[nb]\n     0  3347   LAGO           117.0
# 3  n_species[168], n_recs[1.0], c_cls[nb], fold[0]  n_species[168], n_recs[1.0], c_cls[nb]  n_species[168], n_recs[1.0]    c_cls[nb]                    n_species[168], n_recs[1.0]\nc_cls[nb]                 c_cls[nb]\n     0  3258   HCRE            53.0
# 4  n_species[168], n_recs[1.0], c_cls[nb], fold[0]  n_species[168], n_recs[1.0], c_cls[nb]  n_species[168], n_recs[1.0]    c_cls[nb]                    n_species[168], n_recs[1.0]\nc_cls[nb]                 c_cls[nb]\n     0  1864   BCVI           168.0

# %%
#   - Subset: models.params == params
#   - Grain: sum(recs[model.test_i].groupby(y_true) for model)
#       - Over: fold, rec_id
#   - Dims: y_true
#   - Metrics: count, coverage_error.percentiles
# in: coverage_errors_one_all, recs
(coverage_errors_one_all
    .astype({'y_true': metadata.species.df.shorthand.dtype})
    .pipe(df_reverse_cat, 'y_true')
    .pipe(ggplot, aes(x='y_true', y='coverage_error'))
    + geom_hline(yintercept=1, color='grey')
    + geom_hline(yintercept=10, color='grey')
    + geom_hline(yintercept=recs.species.nunique(), color='grey')
    + geom_count(aes(size='..n..'), alpha=1)  # n (count) instead of prop (proportion)
    + scale_size_area()  # Instead of default scale_size(), because it's a count [I don't grok this but it looks good]
    + geom_point(stat='summary', fun_y=np.median, alpha=1, color='red', shape='|', size=6, stroke=2)
    + coord_flip()
    # + theme_figsize('inline')
    # + theme_figsize('square')
    # + theme_figsize('half')
    + theme_figsize('half_dense')
    # + theme_figsize('full')
    # + theme_figsize('full_dense')
    + ggtitle(rf'Coverage error over fold $\times$ instance ({params}) ({recs_stats})')
)
# Out:
# <ggplot: (316524948)>

# %%
# One-model/all-folds confusion matrix
with figsize(
    # 'square',
    # 'full',
    'full_dense',
):
    (cv_models
        [lambda df: df.params == params]
        .pipe(lambda df: plot_confusion_matrix(
            classes=df.iloc[0].test_evals.classes,
            M=np.array([
                row.test_evals.confusion_matrix_prob()
                for row in df_rows(df)
            ]).sum(axis=0),
            # normalize=False,  # For counts
            raw=True, scale=10,  # Faster dev
            format=None,  # Omit numbers, too dense
            title=f'({recs_stats})',
        ))
    )
# Out:
# <PIL.Image.Image image mode=RGBA size=1680x1680 at 0x1300F8080>

# %% [markdown]
# # Model diagnostics: one model, one fold

# %%
fold = 0
# params_i = ...  # Comment out to reuse from above
params = cv_models.params.cat.categories[params_i]
[(_, model)] = list(cv_models[lambda df: (df.params == params) & (df.fold == fold)].iterrows())
print("params:\n%s" % '\n'.join('  %s: %r' % (i, x) for i, x in enumerate(cv_models.params.cat.categories)))
print()
print('model:')
print('  params[%s/%s]: %r' % (params_i, len(cv_models.params.cat.categories), model.params))
print('  fold[%s/%s]' % (model.fold, cv.cv.n_splits))
print()
print(model)
# Out:
# [skip]

# %%
# in: model
model_id = model.model_id
params = model.params
fold = model.fold
# train_evals = model.train_evals
test_evals = model.test_evals

# in: model, recs
# train_recs = recs.iloc[train_evals.i]
# train_X = Search.X(recs)[train_evals.i]
# train_y = Search.y(recs)[train_evals.i]
test_recs = recs.iloc[test_evals.i]
test_X = Search.X(recs)[test_evals.i]
test_y = Search.y(recs)[test_evals.i]  # (Don't need to store cv_models.test_evals.y if we have recs -- which sometimes we don't?)

display(
    # len(train_recs),
    len(test_recs),
)
# Out:
# [skip]

# %%
# TODO Restore this plot like 'Coverage error over ...' above, so we can see _one_ model instead of aggregating over n_splits models
# # TODO Update [kill the .merge, then species -> y_true]
# (search.coverage_error_by(test_recs, 'id')
#     [:5]
#     # .merge(test_recs[['id', 'species']], on='id', how='left')
#     # .pipe(ggplot, aes(x='species', y='coverage_error'))
#     # + geom_count(aes(size='..n..'))
#     # + stat_summary(fun_y=np.median, geom='point', color='red', alpha=.5, shape='|', size=6, stroke=1)
#     # + stat_summary(
#     #     fun_ymin=partial(np.percentile, q=25), fun_ymax=partial(np.percentile, q=75),
#     #     geom='linerange', color='red', alpha=.5, size=1,
#     # )
#     # + coord_flip()
#     # + geom_hline(yintercept=len(search.classes_), color='grey')
#     # + scale_x_discrete(limits=list(reversed(test_recs.species.cat.categories)))
#     # + theme_figsize('square')
#     # + ggtitle(rf'Coverage error over instance ({model_id}) ({recs_stats})')
# )
# Out:
# [skip]

# %%
# One-model/one-fold confusion matrix
with figsize(
    'square',
    # 'full',
    # 'full_dense',
):
    plot_confusion_matrix_df(
        confusion_matrix_prob_df(model.test_evals.y, model.test_evals.y_scores, model.test_evals.classes),
        title=model.model_id,
        # normalize=False,  # For counts
        raw=True, scale=10,  # Faster dev
        title=f'({recs_stats})',
    )
# Out:
# [skip]

# %%
DEBUG_PLOTS_NEXT
# Out:
# Traceback (most recent call last):
#
#   File "<ipython-input-73-54fa6794c706>", line 1, in <module>
#     DEBUG_PLOTS_NEXT
#
# NameError: name 'DEBUG_PLOTS_NEXT' is not defined

# %% [markdown]
# # Debug plots, ignored by default

# %% [markdown]
# ## Debug: resource usage

# %%
(cv_models
    .pipe(df_reverse_cat, 'params', 'params_no_ns', 'ns')
    # Manually compute y.mean() per group
    .groupby('params').apply(lambda g: g.assign(mem_rss_delta_mean=lambda df: df.mem_rss_delta.mean()))
    .pipe(ggplot, aes(x='ns', group='params_no_ns'))
    + geom_col(aes(y='mem_rss_delta_mean', fill='params_no_ns'), position=position_dodge()) # Summary per fold
    + geom_point(aes(y='mem_rss_delta'), fill='none', size=2, position=position_dodge(width=.9)) # Distribution of folds
    + coord_flip()
    + scale_fill_cmap_d(mpl_cmap_concat('tab20', 'tab20b', 'tab20c'))
    + scale_y_continuous(labels=labels_bytes(), breaks=breaks_bytes())
    + guides(fill=guide_legend(reverse=True))
    + theme(legend_position='bottom', legend_direction='vertical', legend_box_spacing=.4, legend_key_height=8)
    + theme_figsize(aspect_ratio=1/3*2)
    + ggtitle(f'Mem rss spread ($max-min$) ({recs_stats})')
)

# %%
# TODO Very slow with ~200 models
cv_models_proc_stats = (cv_models
    # Enable these as needed (at the cost of mem usage)
    [[
        'model_id',
        'params',
        # 'params_dict',
        'params_data',
        'params_complexity',
        'params_model',
        'fold',
        # 'train_score',
        # 'test_score',
        # 'fit_time',
        # 'score_time',
        'mem_rss_delta',
        # 'mem_vms_delta',
        # 'train_evals',
        # 'test_evals',
        'proc_stats',
    ]]
    # TODO Faster way to do this? (.merge is >2x slower)
    .pipe(df_flatmap, lambda row: [
        row.append(pd.Series(dict(**stats)))
        for stats in row.proc_stats.stats
    ])
    # .pipe(lambda df: (df
    #     .merge(how='left',
    #         right=DF(
    #             OrderedDict(model_id=row.model_id, **stats)
    #             for row in df_rows(df)
    #             for stats in row.proc_stats.stats
    #         )
    #     )
    # ))
    # HACK Restore the cats that the df_flatmap just destroyed [copied from cv_results_splits_df]
    .pipe(df_ordered_cat,
        model_id=lambda df: df.model_id.unique(),
        params=lambda df: df.params.unique(),
    )
    .assign(
        cpu_user=lambda df: df.cpu_user.diff() * 100,
        cpu_system=lambda df: df.cpu_system.diff() * 100,
    )
    .pipe(tap, f=lambda df: display(
        df_summary(df).T,
        df[:5],
    ))
)

# %%
# TODO Might need to stack/geom_area for overlapping runs
(cv_models_proc_stats
    .pipe(ggplot)
    + aes(x='time', color='model_id')
    + geom_line(aes(y='cpu_system'), linetype='dashed', size=.5)
    + geom_line(aes(y='cpu_system + cpu_user'), linetype='solid', size=.5)
    + expand_limits(y=0)
    + ylab('cpu')
    + scale_x_datetime(date_labels='%H:%M:%S')
    + scale_y_continuous(labels=lambda labels: ['%.3g%%' % x for x in labels])
    + theme(legend_position='bottom', legend_direction='vertical', legend_box_spacing=.4, legend_key_height=8)
    + theme_figsize('inline_short')
    + ggtitle('cpu over time (system + user)')
)

# %%
(cv_models_proc_stats
    .pipe(ggplot)
    + aes(x='time', color='model_id')
    + geom_line(aes(y='mem_rss'), linetype='solid', size=.5)
    + geom_line(aes(y='mem_vms'), linetype='dashed', size=.5)
    + expand_limits(y=0)
    + ylab('mem')
    + scale_x_datetime(date_labels='%H:%M:%S')
    + scale_y_continuous(labels=labels_bytes(), breaks=breaks_bytes(pow=3))
    + theme(legend_position='bottom', legend_direction='vertical', legend_box_spacing=.4, legend_key_height=8)
    + theme_figsize('inline_short')
    + ggtitle('Mem over time (rss, vms)')
)

# %% [markdown]
# ## Debug: RF tuning

# %%
# TODO Revive if insightful
(cv_models
    .pipe(df_reverse_cat, 'params_no_ns')
    .assign(n_species=lambda df: df.params_dict.str['n_species'])
    .pipe(ggplot, aes(x='n_species', y='forest_depth_mean', color='params_no_ns'))
    # + facet_wrap('params_no_ns', ncol=2)
    + geom_point()
    + geom_pointrange(aes(ymin='forest_depth_mean - 2*forest_depth_std', ymax='forest_depth_mean + 2*forest_depth_std'))
    + geom_smooth(method='lm', se=False)  # Disable se because it only knows forest_depth_mean, no measure of spread
    + expand_limits(x=0)
    + scale_color_cmap_d(mpl_cmap_concat('tab20', 'tab20b', 'tab20c'))
    + guides(color=guide_legend(reverse=True))
    + theme(legend_position='bottom', legend_direction='vertical', legend_box_spacing=.4, legend_key_height=8)
    # + theme_figsize(aspect_ratio=1/3)
    + theme_figsize(aspect_ratio=1/3)
    + ggtitle(f'RF depth vs. n_species ({recs_stats})')
)
