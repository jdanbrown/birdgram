# %%
from notebooks import *
print_sys_info()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The potoo.default_magic_magic extension is already loaded. To reload it, use:
#   %reload_ext potoo.default_magic_magic
# platform:
#   machine: x86_64
#   node: Dan-B.local
#   processor: i386
#   release: 15.6.0
#   system: Darwin
#   version: 'Darwin Kernel Version 15.6.0: Thu Jun 23 18:25:34 PDT 2016; root:xnu-3248.60.10~1/RELEASE_X86_64'
# cpu: 8
# mem: 16g
# swap: 20g

# %%
# Load models
load = Load()
projection = Projection.load('peterson-v0-26bae1c', features=Features(load=load))
# Out:
# [21:11:37.462] DEBUG  Projection.load
#   path: /Users/danb/hack/bubo/features/data/models/projection/peterson-v0-26bae1c.pkl

# %%
# Select recs
#   1. countries: Filter recs to these countries
#   2. com_names: Filter recs to these species
#   3. recs_at_least: Filter species to those with at least this many recs
#   4. num_species: Sample this many of the species
#   5. num_recs: Sample this many recs per species
get_recs_stats = lambda df: dict(sp=df.species.nunique(), recs=len(df))
puts_stats = lambda desc: partial(tap, f=lambda df: print('%-15s %12s (sp/recs)' % (desc, '%(sp)s/%(recs)s' % get_recs_stats(df))))
countries, com_names = countries_na, com_names_ca  # 400k/9.4k -> 60k/1.1k -> 35k/334
# recs_at_least, num_species, num_recs = 100, 100, 100  # ca[334/35k -> 127/25k -> 100/21k -> 100/10k   -> 100/10k]
# recs_at_least, num_species, num_recs =  50, 100, 100  # ca[334/35k -> 224/32k -> 100/16k -> 100/ 9.0k -> 100/ 9.0k]
# recs_at_least, num_species, num_recs =   0, 100, 100  # ca[334/35k -> 334/35k -> 100/12k -> 100/ 6.8k ->  99/ 6.8k]
# recs_at_least, num_species, num_recs =   0, 168, 100  # ca[334/34k -> 334/34k -> 168/18k -> 168/11k   -> 167/11k]    # (old 'all')
# recs_at_least, num_species, num_recs =   0, 168,  20  # ca[334/34k -> 334/35k -> 168/18k -> 168/ 3.2k -> 167/ 3.2k]  # (old 'recs')
recs_at_least, num_species, num_recs =  20, 168,  20    # ca[334/35k -> 296/35k -> 168/20k -> 168/ 3.4k -> 168/ 3.4k]  # (old 'recs')
# recs_at_least, num_species, num_recs =  20, 50,  100  # Faster dev
# recs_at_least, num_species, num_recs =  20, 50,  50   # Faster dev
# recs_at_least, num_species, num_recs =  20, 50,  20   # Faster dev
# recs_at_least, num_species, num_recs =  20, 50,  10   # Faster dev
# recs_at_least, num_species, num_recs =  20, 50,  5    # Faster dev
xcs = (xc.metadata
    .pipe(puts_stats('all'))
    # 1. countries: Filter recs to these countries
    [lambda df: df.country.isin(countries)]
    .pipe(puts_stats('countries'))
    # 2. com_names: Filter recs to these species
    [lambda df: df.com_name.isin(com_names)]
    .pipe(puts_stats('com_names'))
    # Omit not-downloaded recs (should be few within the selected countries)
    [lambda df: df.downloaded]
    .pipe(puts_stats('(downloaded)'))
    # Remove empty cats for perf
    .pipe(df_remove_unused_categories)
    # 3. recs_at_least: Filter species to those with at least this many recs
    [lambda df: df.species.isin(df.species.value_counts()[lambda s: s >= recs_at_least].index)]
    .pipe(puts_stats('recs_at_least'))
    # 4. num_species: Sample this many of the species
    [lambda df: df.species.isin(df.species.drop_duplicates().pipe(lambda s: s.sample(n=min(len(s), num_species), random_state=0)))]
    .pipe(puts_stats('num_species'))
    # 5. num_recs: Sample this many recs per species
    #   - Remove empty cats else .groupby fails on empty groups
    .pipe(df_remove_unused_categories)
    .groupby('species').apply(lambda g: g.sample(n=min(len(g), num_recs), random_state=0))
    .pipe(puts_stats('num_recs'))
    # Drop species with <2 recs, else StratifiedShuffleSplit complains (e.g. 'TUVU')
    [lambda df: df.species.isin(df.species.value_counts()[lambda s: s >= 2].index)]
    .pipe(puts_stats('recs ≥ 2'))
    # Clean up for downstream
    .pipe(df_remove_unused_categories)
)
_recs_stats = get_recs_stats(xcs)
recs_stats = ', '.join(['%s[%s]' % (k, v) for k, v in _recs_stats.items()])
display(
    recs_stats,
    df_summary(xcs).T,
    xcs.sample(n=10, random_state=0).sort_values('species'),
)
# Out:
# all              9442/399859 (sp/recs)
# countries         1148/59713 (sp/recs)
# com_names          334/35236 (sp/recs)
# (downloaded)       334/35232 (sp/recs)
# recs_at_least      296/34846 (sp/recs)
# num_species        168/19640 (sp/recs)
# num_recs            168/3360 (sp/recs)
# recs ≥ 2            168/3360 (sp/recs)
# 'sp[168], recs[3360]'
#                                                                                                                          min                                               25%                                           50%                                                  75%                                        max
#                dtype          sizeof len  count nunique mean        std
# downloaded     bool           94080  3360 3360  1       NaN         NaN                                                 True                                              True                                          True                                                 True                                       True
# species        category       178080 3360 3360  168     NaN         NaN                                                 GWFG                                              GBTE                                          REVI                                                 NOWA                                       AMGO
# id             int64          94080  3360 3360  3360     213283.439 108055.964                                          1133                                            138144                                        193564                                               308285                                     416744
# sci_name       category       227200 3360 3360  168     NaN         NaN                                      Anser albifrons                             Gelochelidon nilotica                               Vireo olivaceus                              Parkesia noveboracensis                             Spinus tristis
# com_name       category       220320 3360 3360  168     NaN         NaN                          Greater White-fronted Goose                                  Gull-billed Tern                                Red-eyed Vireo                                 Northern Waterthrush                         American Goldfinch
# subspecies     object         169603 3360 3360  205     NaN         NaN                                                                                                                                                                                                                                              zaboria
# recordist      object         211728 3360 3360  291     NaN         NaN                                              AJ Knue                                     Frank Lambert                          Matthias Feuersenger                                        Peter Boesman                                   tetiaroa
# country        object         203063 3360 3360  3       NaN         NaN                                               Canada                                     United States                                 United States                                        United States                              United States
# locality       object         316516 3360 3360  1740    NaN         NaN                Bahía la Ventosa, Salina Cruz, Oaxaca  Desert Beeline Highway, Maricopa County, Arizona             May Lake, Yosemite NP, California  Sabine Nature Trail loop, Cameron Parish, Louisiana                          west of Thorp, WA
# lat            float64        80640  3360 3308  1768     37.885     9.895                                               15.6                                              31.9                                          35.8                                                 43.8                                       71.3
# lng            float64        80640  3360 3308  1782    -107.691    19.351                                              -177                                              -118                                          -110                                                  -95                                        -54
# type           object         191561 3360 3360  339     NaN         NaN                                   "chekurrrrrr" call                                              call                                    call, male                                                 song                                   wipe-out
# quality        category       194711 3360 3360  6       NaN         NaN                                                    A                                                 A                                             B                                                    B                                   no score
# date           datetime64[ns] 430080 3360 3360  1569    NaN         NaN                                  1985-06-25 00:00:00                               2011-09-28 00:00:00                           2013-09-18 00:00:00                                  2015-06-12 00:00:00                        2018-05-23 00:00:00
# time           object         180924 3360 3360  896     NaN         NaN                                                    ?                                              0820                                       10:00am                                                 1513                                         am
# license_type   category       191388 3360 3360  3       NaN         NaN                                             by-nc-nd                                          by-nc-nd                                      by-nc-sa                                             by-nc-sa                                      by-sa
# license_detail category       174720 3360 3360  3       NaN         NaN                                                  2.5                                               3.0                                           4.0                                                  4.0                                        4.0
# license        object         312348 3360 3360  7       NaN         NaN         //creativecommons.org/licenses/by-nc-nd/2.5/      //creativecommons.org/licenses/by-nc-nd/4.0/  //creativecommons.org/licenses/by-nc-sa/4.0/         //creativecommons.org/licenses/by-nc-sa/4.0/  //creativecommons.org/licenses/by-sa/4.0/
# url            object         275034 3360 3360  3360    NaN         NaN                    https://www.xeno-canto.org/100121                 https://www.xeno-canto.org/160005             https://www.xeno-canto.org/236694                     https://www.xeno-canto.org/34583           https://www.xeno-canto.org/99812
# download       object         285114 3360 3360  3360    NaN         NaN                 //www.xeno-canto.org/100121/download              //www.xeno-canto.org/160005/download          //www.xeno-canto.org/236694/download                  //www.xeno-canto.org/34583/download        //www.xeno-canto.org/99812/download
#                 downloaded species      id               sci_name                 com_name    subspecies           recordist        country                                                                    locality     lat      lng                           type   quality       date   time license_type license_detail                                       license                                url                              download
# species
# COGA    205189        True    COGA  207451      Gallinula galeata         Common Gallinule  sandvicensis       Ross Gallardy  United States                                             Kailua, Honolulu County, Hawaii  21.391 -157.743                           call         B 2014-12-21  07:30     by-nc-sa            4.0  //creativecommons.org/licenses/by-nc-sa/4.0/  https://www.xeno-canto.org/207451  //www.xeno-canto.org/207451/download
# INDO    18832         True    INDO  398616         Columbina inca                Inca Dove                  Manuel Grosselet         Mexico                                 Lomas de Bezares Miguel Hidalgo Mexico city  19.391  -99.244                           song         B 2018-01-07  08:00     by-nc-sa            4.0  //creativecommons.org/licenses/by-nc-sa/4.0/  https://www.xeno-canto.org/398616  //www.xeno-canto.org/398616/download
# EWPW    223194        True    EWPW  188611  Antrostomus vociferus   Eastern Whip-poor-will                 David Jonas Weber  United States                                 Gravelly Hill Rd., Salem County, New Jersey  39.495  -75.355                           song         C 2014-07-25  05:30     by-nc-sa            4.0  //creativecommons.org/licenses/by-nc-sa/4.0/  https://www.xeno-canto.org/188611  //www.xeno-canto.org/188611/download
# NUWO    113835        True    NUWO  301366     Picoides nuttallii     Nuttall's Woodpecker                      Denise Wight  United States                                     Moraga, Contra Costa County, California  37.832 -122.134  Hawk mobbing call, alarm call         C 2016-01-25  10:00     by-nc-sa            4.0  //creativecommons.org/licenses/by-nc-sa/4.0/  https://www.xeno-canto.org/301366  //www.xeno-canto.org/301366/download
# BBWO    80808         True    BBWO  335436      Picoides arcticus  Black-backed Woodpecker                Lance A. M. Benner  United States                              Blackrock Trailhead, Tulare County, California  36.175 -118.270                 drumming, male  no score 2016-09-17  16:41     by-nc-sa            4.0  //creativecommons.org/licenses/by-nc-sa/4.0/  https://www.xeno-canto.org/335436  //www.xeno-canto.org/335436/download
# HUVI    117936        True    HUVI  297126          Vireo huttoni           Hutton's Vireo                       Paul Marvin  United States                            Kickapoo Cavern State Park, Brackettville, Texas  29.618 -100.451                           song         C 2012-04-08  07:58     by-nc-sa            4.0  //creativecommons.org/licenses/by-nc-sa/4.0/  https://www.xeno-canto.org/297126  //www.xeno-canto.org/297126/download
# MGWA    89731         True    MGWA  326299     Geothlypis tolmiei   MacGillivray's Warbler                Lance A. M. Benner  United States  Buckhorn Campground, San Gabriel Mountains, Los Angeles County, California  34.346 -117.915                     male, song  no score 2016-06-28  10:49     by-nc-sa            4.0  //creativecommons.org/licenses/by-nc-sa/4.0/  https://www.xeno-canto.org/326299  //www.xeno-canto.org/326299/download
# PUFI    159786        True    PUFI  254326   Haemorhous purpureus             Purple Finch                              Iain         Canada                             Algonquin Highlands, Haliburton County, Ontario  45.306  -78.809                           song         C 2015-06-27  11:00     by-nc-sa            4.0  //creativecommons.org/licenses/by-nc-sa/4.0/  https://www.xeno-canto.org/254326  //www.xeno-canto.org/254326/download
# CAFI    46804         True    CAFI  369971    Haemorhous cassinii           Cassin's Finch                      Eric DeFonso  United States          Dunton Rd area, San Juan National Forest, Dolores County, Colorado  37.780 -108.040                           song         A 2016-06-28  15:00     by-nc-sa            4.0  //creativecommons.org/licenses/by-nc-sa/4.0/  https://www.xeno-canto.org/369971  //www.xeno-canto.org/369971/download
# AMGO    256886        True    AMGO  153552         Spinus tristis       American Goldfinch                  Mike Schanbacher  United States                                         Falmouth, Barnstable, Massachusetts  41.522  -70.668                     call, male         B 2013-05-01  12:00     by-nc-sa            3.0  //creativecommons.org/licenses/by-nc-sa/3.0/  https://www.xeno-canto.org/153552  //www.xeno-canto.org/153552/download

# %%
xcs_paths = [
    ('xc', f'{data_dir}/xc/data/{row.species}/{row.id}/audio.mp3')
    for row in df_rows(xcs)
]
joblib.dump(xcs_paths, '/tmp/xcs_paths')  # In case you want to run load.recs in a terminal (it's long and verbose)
display(
    len(xcs_paths),
    # xcs_paths[:2],
)
# Out:
# 3360

# %%
# TODO Restore once:true after debug [but think carefully how once:true interacts with the once:false params above]
recs = load.recs(paths=xcs_paths)
display(
    df_summary(recs).T,
    recs[:5],
)
# Out:
#                                                                                                         min                           25%                           50%                            75%                           max
#                  dtype    sizeof len  count nunique mean      std
# dataset          object   171360 3360 3360  1       NaN       NaN                                        xc                            xc                            xc                             xc                            xc
# species          category 178080 3360 3360  168     NaN       NaN                                      GWFG                          GBTE                          REVI                           NOWA                          AMGO
# species_com_name category 219160 3360 3360  168     NaN       NaN               Greater White-fronted Goose              Gull-billed Tern                Red-eyed Vireo           Northern Waterthrush            American Goldfinch
# species_query    object   178080 3360 3360  168     NaN       NaN                                      ACWO                          CONI                          LASP                           RIRA                          YRWA
# duration_s       float64  80640  3360 3360  3054    5.430e+01 7.031e+01                               0.697                          14.4                          31.8                           65.4                           940
# samples_mb       float64  80640  3360 3360  3055    2.286e+00 2.958e+00                              0.0293                         0.604                          1.34                           2.76                          39.5
# samples_n        int64    94080  3360 3360  3055    1.198e+06 1.551e+06                               15368                        316510                        701190                        1444435                      20731931
# basename         object   181440 3360 3360  1       NaN       NaN                                     audio                         audio                         audio                          audio                         audio
# species_longhand category 242680 3360 3360  168     NaN       NaN        Greater White-fronted Goose - GWFG       Gull-billed Tern - GBTE         Red-eyed Vireo - REVI    Northern Waterthrush - NOWA     American Goldfinch - AMGO
# id               object   248154 3360 3360  3360    NaN       NaN                 xc/data/ACWO/153315/audio      xc/data/CONI/77526/audio      xc/data/LASP/72200/audio      xc/data/RIRA/408562/audio      xc/data/YRWA/78150/audio
# path             object   261594 3360 3360  3360    NaN       NaN             xc/data/ACWO/153315/audio.mp3  xc/data/CONI/77526/audio.mp3  xc/data/LASP/72200/audio.mp3  xc/data/RIRA/408562/audio.mp3  xc/data/YRWA/78150/audio.mp3
#   dataset species             species_com_name species_query  duration_s  samples_mb  samples_n basename                    species_longhand                         id                           path
# 0      xc    GWFG  Greater White-fronted Goose          GWFG      23.712       0.997     522850    audio  Greater White-fronted Goose - GWFG  xc/data/GWFG/149379/audio  xc/data/GWFG/149379/audio.mp3
# 1      xc    GWFG  Greater White-fronted Goose          GWFG      18.312       0.770     403780    audio  Greater White-fronted Goose - GWFG  xc/data/GWFG/276918/audio  xc/data/GWFG/276918/audio.mp3
# 2      xc    GWFG  Greater White-fronted Goose          GWFG      44.957       1.891     991296    audio  Greater White-fronted Goose - GWFG  xc/data/GWFG/210100/audio  xc/data/GWFG/210100/audio.mp3
# 3      xc    GWFG  Greater White-fronted Goose          GWFG      17.554       0.738     387072    audio  Greater White-fronted Goose - GWFG  xc/data/GWFG/323113/audio  xc/data/GWFG/323113/audio.mp3
# 4      xc    GWFG  Greater White-fronted Goose          GWFG      23.952       1.007     528142    audio  Greater White-fronted Goose - GWFG  xc/data/GWFG/276919/audio  xc/data/GWFG/276919/audio.mp3

# %%
# Fast-and-cheap version (<1s) of the plot below (7s)
(recs
    .species_longhand.value_counts().sort_index()
    .reset_index().rename(columns={'index': 'species_longhand', 'species_longhand': 'num_recs'})
    .assign(num_recs=lambda df: df.num_recs.map(lambda n: '%s /%s' % ('•' * int(n / df.num_recs.max() * 60), df.num_recs.max())))
)
# Out:
#                          species_longhand                                                          num_recs
# 0      Greater White-fronted Goose - GWFG  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 1                          Gadwall - GADW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 2                  American Wigeon - AMWI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 3                          Mallard - MALL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 4                Green-winged Teal - GWTE  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 5                 California Quail - CAQU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 6                   Gambel's Quail - GAQU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 7                     Sooty Grouse - SOGR  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 8                      Wild Turkey - WITU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 9                      Common Loon - COLO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 10                Red-necked Grebe - RNGR  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 11          Black-footed Albatross - BFAL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 12        Double-crested Cormorant - DCCO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 13                American Bittern - AMBI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 14                   Least Bittern - LEBI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 15                Great Blue Heron - GBHE  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 16                     Great Egret - GREG  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 17                     Snowy Egret - SNEG  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 18                          Osprey - OSPR  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 19                 Swainson's Hawk - SWHA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 20                 Red-tailed Hawk - RTHA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 21                      Black Rail - BLRA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 22                  Ridgway's Rail - RIRA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 23                Common Gallinule - COGA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 24              Black-necked Stilt - BNST  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 25             Black Oystercatcher - BLOY  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 26             Semipalmated Plover - SEPL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 27                        Whimbrel - WHIM  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 28              Long-billed Curlew - LBCU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 29                  Rock Sandpiper - ROSA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 30                 Least Sandpiper - LESA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 31           Long-billed Dowitcher - LBDO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 32            Red-necked Phalarope - RNPH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 33              Greater Yellowlegs - GRYE  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 34                Bonaparte's Gull - BOGU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 35                   Laughing Gull - LAGU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 36                 Heermann's Gull - HEEG  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 37                Ring-billed Gull - RBGU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 38                    Western Gull - WEGU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 39                 California Gull - CAGU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 40            Glaucous-winged Gull - GWGU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 41                Gull-billed Tern - GBTE  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 42                    Caspian Tern - CATE  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 43                      Black Tern - BLTE  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 44                      Royal Tern - ROYT  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 45              Band-tailed Pigeon - BTPI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 46                       Inca Dove - INDO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 47              Common Ground-Dove - COGD  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 48            Yellow-billed Cuckoo - YBCU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 49                        Barn Owl - BANO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 50                Great Horned Owl - GHOW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 51                         Elf Owl - ELOW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 52                     Spotted Owl - SPOW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 53                Lesser Nighthawk - LENI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 54                Common Nighthawk - CONI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 55                 Common Poorwill - COPO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 56          Eastern Whip-poor-will - EWPW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 57          Mexican Whip-poor-will - MWPW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 58            White-throated Swift - WTSW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 59       Black-chinned Hummingbird - BCHU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 60        Broad-tailed Hummingbird - BTAH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 61                Acorn Woodpecker - ACWO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 62          Williamson's Sapsucker - WISA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 63          Red-breasted Sapsucker - RBSA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 64        Ladder-backed Woodpecker - LBWO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 65            Nuttall's Woodpecker - NUWO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 66                Hairy Woodpecker - HAWO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 67         White-headed Woodpecker - WHWO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 68         Black-backed Woodpecker - BBWO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 69                Northern Flicker - NOFL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 70              Western Wood-Pewee - WEWP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 71                Least Flycatcher - LEFL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 72                 Gray Flycatcher - GRFL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 73                Dusky Flycatcher - DUFL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 74        Pacific-slope Flycatcher - PSFL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 75                  Eastern Phoebe - EAPH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 76                    Say's Phoebe - SAPH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 77            Vermilion Flycatcher - VEFL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 78         Dusky-capped Flycatcher - DCFL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 79               Tropical Kingbird - TRKI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 80                Couch's Kingbird - COKI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 81                  Hutton's Vireo - HUVI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 82                  Warbling Vireo - WAVI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 83                  Red-eyed Vireo - REVI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 84              Yellow-green Vireo - YGVI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 85                        Gray Jay - GRAJ  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 86                      Pinyon Jay - PIJA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 87                   Steller's Jay - STJA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 88            California Scrub-Jay - CASJ  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 89           Woodhouse's Scrub-Jay - WOSJ  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 90              Clark's Nutcracker - CLNU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 91                    Common Raven - CORA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 92   Northern Rough-winged Swallow - NRWS  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 93                   Purple Martin - PUMA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 94            Violet-green Swallow - VGSW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 95                   Cliff Swallow - CLSW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 96              Mountain Chickadee - MOCH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 97       Chestnut-backed Chickadee - CBCH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 98                          Verdin - VERD  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 99                         Bushtit - BUSH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 100          Red-breasted Nuthatch - RBNU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 101                      Rock Wren - ROWR  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 102                    Canyon Wren - CANW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 103                    Winter Wren - WIWR  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 104                     Marsh Wren - MAWR  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 105                  Bewick's Wren - BEWR  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 106                    Cactus Wren - CACW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 107         California Gnatcatcher - CAGN  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 108       Black-tailed Gnatcatcher - BTGN  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 109                American Dipper - AMDI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 110           Ruby-crowned Kinglet - RCKI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 111               Western Bluebird - WEBL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 112              Mountain Bluebird - MOBL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 113           Townsend's Solitaire - TOSO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 114              Swainson's Thrush - SWTH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 115                  Hermit Thrush - HETH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 116                 American Robin - AMRO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 117                   Gray Catbird - GRCA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 118             Bendire's Thrasher - BETH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 119             LeConte's Thrasher - LCTH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 120               Crissal Thrasher - CRTH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 121              European Starling - EUST  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 122                 American Pipit - AMPI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 123                    Phainopepla - PHAI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 124               Lapland Longspur - LALO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 125           Northern Waterthrush - NOWA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 126         Orange-crowned Warbler - OCWA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 127                 Lucy's Warbler - LUWA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 128              Nashville Warbler - NAWA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 129         MacGillivray's Warbler - MGWA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 130            Common Yellowthroat - COYE  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 131                 Hooded Warbler - HOWA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 132                Northern Parula - NOPA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 133         Chestnut-sided Warbler - CSWA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 134          Yellow-rumped Warbler - YRWA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 135                Prairie Warbler - PRAW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 136                Grace's Warbler - GRWA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 137                 Hermit Warbler - HEWA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 138               Cassin's Sparrow - CASP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 139          Black-chinned Sparrow - BCSP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 140         Black-throated Sparrow - BTSP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 141                   Lark Sparrow - LASP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 142                    Fox Sparrow - FOSP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 143          White-crowned Sparrow - WCSP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 144         Golden-crowned Sparrow - GCSP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 145         White-throated Sparrow - WTSP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 146                 Vesper Sparrow - VESP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 147                   Song Sparrow - SOSP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 148              Lincoln's Sparrow - LISP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 149         Rufous-crowned Sparrow - RCSP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 150           Yellow-breasted Chat - YBCH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 151                Western Tanager - WETA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 152              Northern Cardinal - NOCA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 153         Rose-breasted Grosbeak - RBGR  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 154                 Indigo Bunting - INBU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 155        Yellow-headed Blackbird - YHBL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 156                 Scott's Oriole - SCOR  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 157           Red-winged Blackbird - RWBL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 158             Brewer's Blackbird - BRBL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 159           Great-tailed Grackle - GTGR  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 160                  Pine Grosbeak - PIGR  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 161                    House Finch - HOFI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 162                   Purple Finch - PUFI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 163                 Cassin's Finch - CAFI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 164                    Pine Siskin - PISI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 165               Lesser Goldfinch - LEGO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 166           Lawrence's Goldfinch - LAGO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 167             American Goldfinch - AMGO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20

# %%
(recs
    .assign(species=lambda df: df.species_longhand)
    .assign(count=1)
    # 0-fill all (species, dataset) combinations to create empty placeholders for missing bars
    .pipe(lambda df: df.append(
        pd.DataFrame([
            dict(species=species, dataset=dataset, duration_s=0)
            for species in df.species.unique()
            for dataset in df.dataset.unique()
        ])
        .astype({'species': df.species.dtype})
    ))
    .groupby(['dataset', 'species'])[['count', 'duration_s']].sum().reset_index()
    # Order by species by taxo
    .pipe(df_reverse_cat, 'species')
    # Order by species by count
    # .pipe(df_ordered_cat, species=lambda df: df.sort_values('count').species)
    .pipe(pd.melt, id_vars=['dataset', 'species'], value_vars=['count', 'duration_s'])
    .pipe(df_remove_unused_categories)
    .pipe(ggplot, aes(x='species', y='value', fill='dataset', color='dataset'))
    + coord_flip()
    + geom_bar(stat='identity', position=position_dodge(), width=.8)
    + facet_wrap('variable', nrow=1, scales='free')
    + xlab('')
    + ylab('')
    + scale_fill_cmap_d(mpl_cmap_concat('tab20', 'tab20b', 'tab20c'))
    + scale_color_cmap_d(mpl_cmap_concat('tab20', 'tab20b', 'tab20c'))
    + theme(panel_spacing=2.5)
    + theme_figsize(width=18, aspect_ratio=4/1)
    + ggtitle(f'recs: Total (count, duration_s) per (species, dataset)')
)
# Out:
# [skip]

# %%
# Add .feat
recs = projection.transform(recs)

# %%
# GridSearchCV many models / model params
#   - Order these roughly from most to least expensive, so that training runs fail fast (e.g. oom at the start, not the end)
param_grid = list(unique_everseen([
    dict(
        classifier=[classifier],
        n_species=[n_species if isinstance(n_species, int) else int(n_species * _recs_stats['sp'])],
        n_recs=[
            # n_recs if isinstance(n_recs, int) else int(n_recs * _recs_stats['recs']),
            # TODO Figure out how to represent this as an n instead of a frac again [TODO interaction with test_size=.2 ...]
            #   - TODO Also make clear in the plot descs when e.g. (recs[3360], n_species[33], n_recs[1.0]) -> n_recs[33*20 < 3360]
            n_recs,
        ],
    )
    for (n_species, n_recs) in [
        # Subset for learning curves
        #   - Biggest first, to fail fast

        # (None, None),

        (1.00, 1.00),
        (1.00, 0.50),
        # (0.75, 1.00),
        # (0.75, 0.50),
        (0.50, 1.00),
        # (0.50, 0.50),
        # (0.25, 1.00),
        # (0.25, 0.50),

        # (1.00, 1.00),
        # (1.00, 0.80),
        # (1.00, 0.60),
        # (1.00, 0.40),
        # (1.00, 0.20),

    ]
    # model_size ~ forest_depth
    for rf_mean_depth_at_168_sp in [93.5]
    for rf_max_depth in [
        'null',
        int(rf_mean_depth_at_168_sp * n_species * 1),
        int(rf_mean_depth_at_168_sp * n_species * 3/4),
        int(rf_mean_depth_at_168_sp * n_species * 1/2),
        int(rf_mean_depth_at_168_sp * n_species * 1/3),
        int(rf_mean_depth_at_168_sp * n_species * 1/4),
        int(rf_mean_depth_at_168_sp * n_species * 1/8),
        # int(rf_mean_depth_at_168_sp * n_species * 1/16),
    ]
    for ovr_rf_max_depth in [
        rf_max_depth / 10 if rf_max_depth != 'null' else 'null'
    ]
    for classifier in [

        # RandomForest(entropy)
        #   - 'gini' tends has better accuracy
        # 'cls: rf, criterion: entropy, n_estimators: 200',  # [SP14]

        # RandomForest(gini)
        #
        # WARNING These two are not very mem safe...
        #   - They finish, but they cause OSX to "Not responding" most/all of its apps at ~2-3 different times
        # 'cls: rf, criterion: gini, n_estimators: 2000',
        # 'cls: rf, criterion: gini, n_estimators: 1500',
        #
        # 'cls: rf, criterion: gini, n_estimators: 1000',
        # 'cls: rf, criterion: gini, n_estimators: 800',
        # 'cls: rf, criterion: gini, n_estimators: 600',
        # 'cls: rf, criterion: gini, n_estimators: 400',
        # f'cls: rf, criterion: gini, n_estimators: 200, max_depth: {max_depth}',
        # f'cls: rf, criterion: gini, n_estimators: 100, max_depth: {max_depth}',
        # 'cls: rf, criterion: gini, n_estimators: 50',
        # 'cls: rf, criterion: gini, n_estimators: 10',
        # 'cls: rf, criterion: gini, n_estimators: 1',

        f'cls: rf, criterion: gini, n_estimators: 100, max_depth: {rf_max_depth}',
        f'cls: rf, criterion: gini, n_estimators: 20, multiclass: ovr, max_depth: {ovr_rf_max_depth}',
        f'cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: {ovr_rf_max_depth}',
        # f'cls: rf, criterion: gini, n_estimators: 40, multiclass: ovr, max_depth: 4.6',
        # f'cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 4.6',

    ]
]))

# TODO Increase cv to decrease variance in eval metrics (this made Alex extremely squirmy)
cv = GridSearchCVCached(
    estimator=Search(projection=projection),
    param_grid=param_grid,
    refit=False,  # Don't spend time fitting cv.best_estimator_ at the end (default: True)
    # cv=3,  # [SP14] uses two-/three-fold CV [why?]
    # Stratified ensures that all classes have >0 instances in each split, which is statistically maybe fishy but avoids
    # breaking various code that merges the split results back together and assumes all splits' classes are the same
    cv=sk.model_selection.StratifiedShuffleSplit(
        # n_splits=1,  # [for ~18/20 miss: ~19m, ~16g disk cache]
        # n_splits=2,
        n_splits=3,
        # n_splits=5,
        # n_splits=10,
        # n_splits=20,  # Known good [>51m uncached, >25g disk cache]
        # n_splits=100,  # [?m runtime, ?g disk cache]
        test_size=.2,
        random_state=0,
    ),
    return_train_score=True,
    extra_metrics=dict(
        # [How to specify SearchEvals here without creating caching headaches?]
        #   - e.g. defs don't bust cache on code edit
        #   - And avoid thrashing cache every time we refactor SearchEvals
        classes='estimator.classes_',
        train_i='train',
        train_y='y_train',
        train_predict_proba='estimator.classifier_.predict_proba(X_train)',
        test_i='test',
        test_y='y_test',
        test_predict_proba='estimator.classifier_.predict_proba(X_test)',
        model_size='len(joblib_dumps(estimator))',
        model_stats='model_stats(estimator)',
        proc_stats='proc_stats',
    ),
    # return_estimator=True,  # Verrrry heavy, use extra_metrics instead
    # verbose=100,
    # verbose=10,  # O(models * n_splits) lines of outputs
    verbose=1,  # O(1) lines of outputs
    # Use n_jobs=1
    #   - All classifiers can parallelize .fit/.predict
    #   - Avoid memory contention
    # n_jobs=1,  # Required for %prun
    n_jobs=8,  # HACK for slow ovr serdes
    artifacts=dict(
        dir=f'{data_dir}/artifacts',  # TODO Iron out syncing across local/gs/remote
        extra=dict(estimator='estimator'),
        save=True,
        reuse='20180709-211727-fd34af5-ovr_try_2',
    ),
)
with contextlib.ExitStack() as stack:
    # stack.enter_context(cache_control(refresh=True))  # Disk unsafe...
    stack.enter_context(cache_control(enabled=False))  # Disk safe
    # stack.enter_context(joblib.parallel_backend('threading'))  # Default: 'multiprocessing'
    # stack.enter_context(joblib.parallel_backend('sequential'))  # For %prun [FIXME Has no effect; why?]
    stack.enter_context(log.context(level='info'))
    # stack.enter_context(log.context(level='debug'))
    X, y = Search.Xy(recs)
    cv.fit(X, y)
# Out:
# Fitting 3 folds for each of 63 candidates, totalling 189 fits
# [05:12:53.580] INFO   artifacts
#   dir: /Users/danb/hack/bubo/features/data/artifacts
#   extra: {estimator: estimator}
#   save: true
#   reuse: 20180709-211727-fd34af5-ovr_try_2
#   experiment_id: 20180709-211727-fd34af5-ovr_try_2
# [05:12:54.618] INFO   _fit_and_score[1/189].reuse.ret[0.034s, 4.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=null',random_state=0)/ret.pkl
# [05:12:54.622] INFO   _fit_and_score[2/189].reuse.ret[0.020s, 4.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=null',random_state=0)/ret.pkl
# [05:12:54.655] INFO   _fit_and_score[3/189].reuse.ret[0.023s, 4.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=null',random_state=0)/ret.pkl
# [05:12:54.729] INFO   _fit_and_score[4/189].reuse.ret[0.056s, 5.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=20,multiclass=ovr,max_depth=null',random_state=0)/ret.pkl
# [05:12:54.767] INFO   _fit_and_score[5/189].reuse.ret[0.048s, 5.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=20,multiclass=ovr,max_depth=null',random_state=0)/ret.pkl
# [05:12:54.789] INFO   _fit_and_score[7/189].compute... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: null', random_state=0)]
# [05:12:54.807] INFO   _fit_and_score[6/189].reuse.ret[0.050s, 5.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=20,multiclass=ovr,max_depth=null',random_state=0)/ret.pkl
# [05:12:54.824] INFO   _fit_and_score[8/189].compute... split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: null', random_state=0)]
# [05:12:54.860] INFO   _fit_and_score[9/189].compute... split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: null', random_state=0)]
# [05:12:54.970] INFO   _fit_and_score[10/189].reuse.ret[0.021s, 4.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=93',random_state=0)/ret.pkl
# [05:12:55.047] INFO   _fit_and_score[11/189].reuse.ret[0.027s, 4.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=93',random_state=0)/ret.pkl
# [05:12:55.225] INFO   _fit_and_score[12/189].reuse.ret[0.025s, 4.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=93',random_state=0)/ret.pkl
# [05:12:55.376] INFO   _fit_and_score[13/189].reuse.ret[0.043s, 5.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=20,multiclass=ovr,max_depth=9.3',random_state=0)/ret.pkl
# [05:12:55.566] INFO   _fit_and_score[14/189].reuse.ret[0.047s, 5.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=20,multiclass=ovr,max_depth=9.3',random_state=0)/ret.pkl
# [05:12:55.668] INFO   _fit_and_score[15/189].reuse.ret[0.040s, 5.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=20,multiclass=ovr,max_depth=9.3',random_state=0)/ret.pkl
# [05:12:55.736] INFO   _fit_and_score[16/189].compute... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 9.3', random_state=0)]
# [05:12:55.822] INFO   _fit_and_score[17/189].compute... split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 9.3', random_state=0)]
# [05:12:55.936] INFO   _fit_and_score[18/189].compute... split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 9.3', random_state=0)]
# [05:12:56.177] INFO   _fit_and_score[19/189].reuse.ret[0.030s, 4.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=70',random_state=0)/ret.pkl
# [05:12:56.344] INFO   _fit_and_score[20/189].reuse.ret[0.021s, 4.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=70',random_state=0)/ret.pkl
# [05:12:56.451] INFO   _fit_and_score[21/189].reuse.ret[0.020s, 4.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=70',random_state=0)/ret.pkl
# [05:12:56.589] INFO   _fit_and_score[22/189].reuse.ret[0.030s, 4.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=20,multiclass=ovr,max_depth=7.0',random_state=0)/ret.pkl
# [05:12:56.715] INFO   _fit_and_score[23/189].reuse.ret[0.029s, 4.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=20,multiclass=ovr,max_depth=7.0',random_state=0)/ret.pkl
# [05:12:56.830] INFO   _fit_and_score[24/189].reuse.ret[0.032s, 4.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=20,multiclass=ovr,max_depth=7.0',random_state=0)/ret.pkl
# [05:12:56.891] INFO   _fit_and_score[25/189].compute... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 7.0', random_state=0)]
# [05:12:57.010] INFO   _fit_and_score[26/189].compute... split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 7.0', random_state=0)]
# /Users/danb/miniconda3/envs/bubo-features/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /Users/danb/miniconda3/envs/bubo-features/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /Users/danb/miniconda3/envs/bubo-features/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /Users/danb/miniconda3/envs/bubo-features/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /Users/danb/miniconda3/envs/bubo-features/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /Users/danb/miniconda3/envs/bubo-features/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /Users/danb/miniconda3/envs/bubo-features/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /Users/danb/miniconda3/envs/bubo-features/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# [05:25:22.034] INFO   _fit_and_score[26/189].compute[741.182s]: split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 7.0', random_state=0)]
# [05:25:22.345] INFO   _fit_and_score[8/189].compute[744.707s]: split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: null', random_state=0)]
# [05:25:24.211] INFO   _fit_and_score[17/189].compute[746.014s]: split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 9.3', random_state=0)]
# [05:25:24.803] INFO   _fit_and_score[25/189].compute[744.156s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 7.0', random_state=0)]
# [05:25:26.153] INFO   _fit_and_score[16/189].compute[748.023s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 9.3', random_state=0)]
# [05:25:26.513] INFO   _fit_and_score[7/189].compute[748.882s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: null', random_state=0)]
# [05:25:26.690] INFO   _fit_and_score[9/189].compute[749.055s]: split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: null', random_state=0)]
# [05:25:26.932] INFO   _fit_and_score[18/189].compute[748.343s]: split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 9.3', random_state=0)]
# [05:26:10.555] INFO   _fit_and_score[26/189].save... model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=7.0',random_state=0)]
# [05:26:10.861] INFO   _fit_and_score[8/189].save... model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=null',random_state=0)]
# [05:26:14.071] INFO   _fit_and_score[17/189].save... model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=9.3',random_state=0)]
# [05:26:15.025] INFO   _fit_and_score[25/189].save... model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=7.0',random_state=0)]
# [05:26:16.608] INFO   _fit_and_score[16/189].save... model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=9.3',random_state=0)]
# [05:26:17.236] INFO   _fit_and_score[7/189].save... model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=null',random_state=0)]
# [05:26:17.360] INFO   _fit_and_score[9/189].save... model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=null',random_state=0)]
# [05:26:17.392] INFO   _fit_and_score[18/189].save... model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=9.3',random_state=0)]
# [05:26:25.346] INFO   _fit_and_score[26/189].save[14.787s, 56.3 MB]: model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=7.0',random_state=0)]
# [05:26:25.500] INFO   _fit_and_score[8/189].save[14.626s, 59.5 MB]: model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=null',random_state=0)]
# [05:26:25.520] INFO   _fit_and_score[27/189].compute... split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 7.0', random_state=0)]
# [05:26:25.770] INFO   _fit_and_score[28/189].reuse.ret[0.033s, 4.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=46',random_state=0)/ret.pkl
# [05:26:25.946] INFO   _fit_and_score[29/189].reuse.ret[0.018s, 4.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=46',random_state=0)/ret.pkl
# [05:26:26.084] INFO   _fit_and_score[30/189].reuse.ret[0.019s, 4.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=46',random_state=0)/ret.pkl
# [05:26:26.248] INFO   _fit_and_score[31/189].reuse.ret[0.033s, 5.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=20,multiclass=ovr,max_depth=4.6',random_state=0)/ret.pkl
# [05:26:26.417] INFO   _fit_and_score[32/189].reuse.ret[0.034s, 5.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=20,multiclass=ovr,max_depth=4.6',random_state=0)/ret.pkl
# [05:26:26.590] INFO   _fit_and_score[33/189].reuse.ret[0.034s, 5.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=20,multiclass=ovr,max_depth=4.6',random_state=0)/ret.pkl
# [05:26:26.806] INFO   _fit_and_score[34/189].reuse.ret[0.083s, 4.7 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=4.6',random_state=0)/ret.pkl
# [05:26:27.015] INFO   _fit_and_score[35/189].reuse.ret[0.085s, 4.7 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=4.6',random_state=0)/ret.pkl
# [05:26:27.256] INFO   _fit_and_score[36/189].reuse.ret[0.090s, 4.7 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=4.6',random_state=0)/ret.pkl
# [05:26:27.399] INFO   _fit_and_score[37/189].reuse.ret[0.017s, 4.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=31',random_state=0)/ret.pkl
# [05:26:27.546] INFO   _fit_and_score[38/189].reuse.ret[0.019s, 4.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=31',random_state=0)/ret.pkl
# [05:26:27.687] INFO   _fit_and_score[39/189].reuse.ret[0.019s, 4.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=31',random_state=0)/ret.pkl
# /Users/danb/miniconda3/envs/bubo-features/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# [05:26:27.862] INFO   _fit_and_score[40/189].reuse.ret[0.041s, 5.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=20,multiclass=ovr,max_depth=3.1',random_state=0)/ret.pkl
# [05:26:28.161] INFO   _fit_and_score[41/189].reuse.ret[0.037s, 5.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=20,multiclass=ovr,max_depth=3.1',random_state=0)/ret.pkl
# [05:26:28.328] INFO   _fit_and_score[42/189].reuse.ret[0.034s, 5.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=20,multiclass=ovr,max_depth=3.1',random_state=0)/ret.pkl
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed: 13.6min
# [05:26:28.500] INFO   _fit_and_score[43/189].compute... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 3.1', random_state=0)]
# [05:26:29.458] INFO   _fit_and_score[17/189].save[15.379s, 59.0 MB]: model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=9.3',random_state=0)]
# [05:26:29.641] INFO   _fit_and_score[44/189].compute... split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 3.1', random_state=0)]
# [05:26:31.416] INFO   _fit_and_score[25/189].save[16.370s, 56.2 MB]: model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=7.0',random_state=0)]
# [05:26:31.584] INFO   _fit_and_score[45/189].compute... split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 3.1', random_state=0)]
# /Users/danb/miniconda3/envs/bubo-features/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /Users/danb/miniconda3/envs/bubo-features/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# [05:26:36.294] INFO   _fit_and_score[16/189].save[19.672s, 59.1 MB]: model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=9.3',random_state=0)]
# [05:26:36.680] INFO   _fit_and_score[46/189].reuse.ret[0.021s, 4.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=23',random_state=0)/ret.pkl
# [05:26:36.857] INFO   _fit_and_score[47/189].reuse.ret[0.015s, 4.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=23',random_state=0)/ret.pkl
# /Users/danb/miniconda3/envs/bubo-features/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# [05:26:37.092] INFO   _fit_and_score[48/189].reuse.ret[0.018s, 4.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=23',random_state=0)/ret.pkl
# [05:26:37.400] INFO   _fit_and_score[49/189].reuse.ret[0.056s, 5.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=20,multiclass=ovr,max_depth=2.3',random_state=0)/ret.pkl
# [05:26:37.608] INFO   _fit_and_score[50/189].reuse.ret[0.030s, 5.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=20,multiclass=ovr,max_depth=2.3',random_state=0)/ret.pkl
# [05:26:38.048] INFO   _fit_and_score[51/189].reuse.ret[0.184s, 5.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=20,multiclass=ovr,max_depth=2.3',random_state=0)/ret.pkl
# [05:26:38.374] INFO   _fit_and_score[52/189].compute... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 2.3', random_state=0)]
# [05:26:38.716] INFO   _fit_and_score[7/189].save[21.477s, 59.5 MB]: model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=null',random_state=0)]
# [05:26:39.051] INFO   _fit_and_score[53/189].compute... split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 2.3', random_state=0)]
# [05:26:39.558] INFO   _fit_and_score[18/189].save[22.153s, 59.1 MB]: model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=9.3',random_state=0)]
# [05:26:39.650] INFO   _fit_and_score[9/189].save[22.285s, 59.6 MB]: model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=null',random_state=0)]
# [05:26:39.884] INFO   _fit_and_score[54/189].compute... split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 2.3', random_state=0)]
# [05:26:40.100] INFO   _fit_and_score[55/189].reuse.ret[0.015s, 4.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=11',random_state=0)/ret.pkl
# [05:26:40.384] INFO   _fit_and_score[56/189].reuse.ret[0.015s, 4.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=11',random_state=0)/ret.pkl
# [05:26:40.753] INFO   _fit_and_score[57/189].reuse.ret[0.017s, 4.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=11',random_state=0)/ret.pkl
# [05:26:40.909] INFO   _fit_and_score[58/189].reuse.ret[0.030s, 5.5 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=20,multiclass=ovr,max_depth=1.1',random_state=0)/ret.pkl
# [05:26:41.204] INFO   _fit_and_score[59/189].reuse.ret[0.029s, 5.5 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=20,multiclass=ovr,max_depth=1.1',random_state=0)/ret.pkl
# [05:26:41.599] INFO   _fit_and_score[60/189].reuse.ret[0.040s, 5.5 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=20,multiclass=ovr,max_depth=1.1',random_state=0)/ret.pkl
# [05:26:41.860] INFO   _fit_and_score[61/189].compute... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 1.1', random_state=0)]
# /Users/danb/miniconda3/envs/bubo-features/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /Users/danb/miniconda3/envs/bubo-features/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /Users/danb/miniconda3/envs/bubo-features/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /Users/danb/miniconda3/envs/bubo-features/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# [05:31:55.925] INFO   _fit_and_score[61/189].compute[308.307s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 1.1', random_state=0)]
# [05:33:13.152] INFO   _fit_and_score[52/189].compute[389.101s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 2.3', random_state=0)]
# [05:33:14.169] INFO   _fit_and_score[53/189].compute[389.761s]: split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 2.3', random_state=0)]
# [05:33:15.798] INFO   _fit_and_score[54/189].compute[390.262s]: split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 2.3', random_state=0)]
# [05:33:22.936] INFO   _fit_and_score[61/189].save... model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=1.1',random_state=0)]
# [05:33:51.409] INFO   _fit_and_score[61/189].save[28.470s, 29.0 MB]: model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=1.1',random_state=0)]
# [05:33:51.573] INFO   _fit_and_score[62/189].compute... split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 1.1', random_state=0)]
# [05:33:52.921] INFO   _fit_and_score[44/189].compute[440.450s]: split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 3.1', random_state=0)]
# [05:33:52.993] INFO   _fit_and_score[43/189].compute[441.995s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 3.1', random_state=0)]
# /Users/danb/miniconda3/envs/bubo-features/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# [05:33:56.998] INFO   _fit_and_score[45/189].compute[441.298s]: split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 3.1', random_state=0)]
# [05:34:18.689] INFO   _fit_and_score[52/189].save... model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=2.3',random_state=0)]
# [05:34:18.982] INFO   _fit_and_score[53/189].save... model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=2.3',random_state=0)]
# [05:34:20.467] INFO   _fit_and_score[54/189].save... model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=2.3',random_state=0)]
# [05:34:36.716] INFO   _fit_and_score[27/189].compute[489.433s]: split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 7.0', random_state=0)]
# [05:34:37.967] INFO   _fit_and_score[52/189].save[19.271s, 32.6 MB]: model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=2.3',random_state=0)]
# [05:34:38.023] INFO   _fit_and_score[53/189].save[19.038s, 32.6 MB]: model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=2.3',random_state=0)]
# [05:34:38.103] INFO   _fit_and_score[63/189].compute... split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 1.1', random_state=0)]
# [05:34:38.350] INFO   _fit_and_score[64/189].reuse.ret[0.021s, 4.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.5,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=null',random_state=0)/ret.pkl
# [05:34:38.490] INFO   _fit_and_score[65/189].reuse.ret[0.014s, 4.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.5,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=null',random_state=0)/ret.pkl
# [05:34:38.712] INFO   _fit_and_score[66/189].reuse.ret[0.011s, 4.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.5,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=null',random_state=0)/ret.pkl
# [05:34:38.875] INFO   _fit_and_score[67/189].reuse.ret[0.042s, 5.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.5,classifier='cls=rf,criterion=gini,n_estimators=20,multiclass=ovr,max_depth=null',random_state=0)/ret.pkl
# [05:34:39.150] INFO   _fit_and_score[68/189].reuse.ret[0.031s, 5.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.5,classifier='cls=rf,criterion=gini,n_estimators=20,multiclass=ovr,max_depth=null',random_state=0)/ret.pkl
# [05:34:39.440] INFO   _fit_and_score[69/189].reuse.ret[0.033s, 5.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.5,classifier='cls=rf,criterion=gini,n_estimators=20,multiclass=ovr,max_depth=null',random_state=0)/ret.pkl
# [05:34:39.637] INFO   _fit_and_score[70/189].compute... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: null', random_state=0)]
# [05:34:40.135] INFO   _fit_and_score[54/189].save[19.665s, 32.6 MB]: model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=2.3',random_state=0)]
# [05:34:40.288] INFO   _fit_and_score[71/189].compute... split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: null', random_state=0)]
# /Users/danb/miniconda3/envs/bubo-features/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /Users/danb/miniconda3/envs/bubo-features/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /Users/danb/miniconda3/envs/bubo-features/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# [05:35:09.317] INFO   _fit_and_score[44/189].save... model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=3.1',random_state=0)]
# [05:35:10.417] INFO   _fit_and_score[43/189].save... model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=3.1',random_state=0)]
# [05:35:20.267] INFO   _fit_and_score[45/189].save... model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=3.1',random_state=0)]
# [05:35:54.445] INFO   _fit_and_score[44/189].save[45.120s, 37.5 MB]: model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=3.1',random_state=0)]
# [05:35:54.737] INFO   _fit_and_score[72/189].compute... split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: null', random_state=0)]
# [05:35:55.676] INFO   _fit_and_score[43/189].save[45.236s, 37.4 MB]: model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=3.1',random_state=0)]
# [05:35:55.979] INFO   _fit_and_score[73/189].reuse.ret[0.015s, 4.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.5,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=93',random_state=0)/ret.pkl
# [05:35:56.319] INFO   _fit_and_score[74/189].reuse.ret[0.013s, 4.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.5,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=93',random_state=0)/ret.pkl
# [05:35:56.486] INFO   _fit_and_score[75/189].reuse.ret[0.014s, 4.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.5,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=93',random_state=0)/ret.pkl
# [05:35:56.772] INFO   _fit_and_score[76/189].reuse.ret[0.032s, 5.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.5,classifier='cls=rf,criterion=gini,n_estimators=20,multiclass=ovr,max_depth=9.3',random_state=0)/ret.pkl
# [05:35:57.151] INFO   _fit_and_score[77/189].reuse.ret[0.038s, 5.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.5,classifier='cls=rf,criterion=gini,n_estimators=20,multiclass=ovr,max_depth=9.3',random_state=0)/ret.pkl
# [05:35:57.380] INFO   _fit_and_score[78/189].reuse.ret[0.050s, 5.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.5,classifier='cls=rf,criterion=gini,n_estimators=20,multiclass=ovr,max_depth=9.3',random_state=0)/ret.pkl
# [05:35:57.589] INFO   _fit_and_score[79/189].compute... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 9.3', random_state=0)]
# [05:35:58.253] INFO   _fit_and_score[62/189].compute[125.067s]: split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 1.1', random_state=0)]
# /Users/danb/miniconda3/envs/bubo-features/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /Users/danb/miniconda3/envs/bubo-features/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# [05:36:06.114] INFO   _fit_and_score[45/189].save[45.836s, 37.5 MB]: model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=3.1',random_state=0)]
# [05:36:06.415] INFO   _fit_and_score[80/189].compute... split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 9.3', random_state=0)]
# /Users/danb/miniconda3/envs/bubo-features/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# [05:36:24.354] INFO   _fit_and_score[27/189].save... model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=7.0',random_state=0)]
# [05:37:22.728] INFO   _fit_and_score[27/189].save[58.344s, 56.3 MB]: model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=7.0',random_state=0)]
# [05:37:23.000] INFO   _fit_and_score[81/189].compute... split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 9.3', random_state=0)]
# /Users/danb/miniconda3/envs/bubo-features/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# [05:37:43.816] INFO   _fit_and_score[63/189].compute[183.079s]: split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 1.1', random_state=0)]
# [05:37:49.071] INFO   _fit_and_score[62/189].save... model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=1.1',random_state=0)]
# /Users/danb/miniconda3/envs/bubo-features/lib/python3.6/site-packages/sklearn/multiclass.py:352: RuntimeWarning: invalid value encountered in true_divide
#   Y /= np.sum(Y, axis=1)[:, np.newaxis]
# [05:38:13.168] INFO   _fit_and_score[70/189].compute[211.248s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: null', random_state=0)]
# [05:38:15.016] INFO   _fit_and_score[71/189].compute[212.245s]: split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: null', random_state=0)]
# [05:38:43.061] INFO   _fit_and_score[62/189].save[53.969s, 28.9 MB]: model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=1.1',random_state=0)]
# [05:38:43.360] INFO   _fit_and_score[82/189].reuse.ret[0.037s, 4.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.5,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=70',random_state=0)/ret.pkl
# [05:38:43.656] INFO   _fit_and_score[83/189].reuse.ret[0.049s, 4.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.5,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=70',random_state=0)/ret.pkl
# [05:38:43.821] INFO   _fit_and_score[84/189].reuse.ret[0.028s, 4.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.5,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=70',random_state=0)/ret.pkl
# [05:38:44.098] INFO   _fit_and_score[85/189].reuse.ret[0.029s, 4.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.5,classifier='cls=rf,criterion=gini,n_estimators=20,multiclass=ovr,max_depth=7.0',random_state=0)/ret.pkl
# [05:38:44.439] INFO   _fit_and_score[86/189].reuse.ret[0.044s, 4.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.5,classifier='cls=rf,criterion=gini,n_estimators=20,multiclass=ovr,max_depth=7.0',random_state=0)/ret.pkl
# [05:38:44.689] INFO   _fit_and_score[87/189].reuse.ret[0.026s, 4.6 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.5,classifier='cls=rf,criterion=gini,n_estimators=20,multiclass=ovr,max_depth=7.0',random_state=0)/ret.pkl
# [05:38:44.924] INFO   _fit_and_score[88/189].compute... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 7.0', random_state=0)]
# /Users/danb/miniconda3/envs/bubo-features/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# [05:39:18.346] INFO   _fit_and_score[63/189].save... model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=1.1',random_state=0)]
# /Users/danb/miniconda3/envs/bubo-features/lib/python3.6/site-packages/sklearn/multiclass.py:352: RuntimeWarning: invalid value encountered in true_divide
#   Y /= np.sum(Y, axis=1)[:, np.newaxis]
# /Users/danb/miniconda3/envs/bubo-features/lib/python3.6/site-packages/sklearn/multiclass.py:352: RuntimeWarning: invalid value encountered in true_divide
#   Y /= np.sum(Y, axis=1)[:, np.newaxis]
# [05:39:34.055] INFO   _fit_and_score[72/189].compute[215.004s]: split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: null', random_state=0)]
# [05:39:36.501] INFO   _fit_and_score[79/189].compute[214.252s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 9.3', random_state=0)]
# [05:39:38.110] INFO   _fit_and_score[70/189].save... model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.5,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=null',random_state=0)]
# [05:39:39.175] INFO   _fit_and_score[71/189].save... model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.5,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=null',random_state=0)]
# [05:39:41.108] INFO   _fit_and_score[80/189].compute[209.089s]: split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 9.3', random_state=0)]
# [05:39:45.390] INFO   _fit_and_score[63/189].save[27.003s, 28.9 MB]: model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=1.1',random_state=0)]
# [05:39:45.610] INFO   _fit_and_score[89/189].compute... split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 7.0', random_state=0)]
# /Users/danb/miniconda3/envs/bubo-features/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# [05:40:07.775] INFO   _fit_and_score[70/189].save[29.656s, 35.8 MB]: model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.5,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=null',random_state=0)]
# [05:40:08.064] INFO   _fit_and_score[90/189].compute... split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 7.0', random_state=0)]
# [05:40:09.156] INFO   _fit_and_score[71/189].save[29.966s, 36.0 MB]: model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0.5,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=null',random_state=0)]
# ...
# [05:49:50.678] INFO   _fit_and_score[173/189].reuse.ret[0.022s, 2.4 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=11',random_state=0)/ret.pkl
# [05:49:50.790] INFO   _fit_and_score[174/189].reuse.ret[0.010s, 2.4 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=11',random_state=0)/ret.pkl
# [05:49:50.889] INFO   _fit_and_score[175/189].reuse.ret[0.018s, 2.8 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=20,multiclass=ovr,max_depth=1.1',random_state=0)/ret.pkl
# [05:49:50.991] INFO   _fit_and_score[176/189].reuse.ret[0.018s, 2.8 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=20,multiclass=ovr,max_depth=1.1',random_state=0)/ret.pkl
# [05:49:51.204] INFO   _fit_and_score[177/189].reuse.ret[0.031s, 2.8 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=20,multiclass=ovr,max_depth=1.1',random_state=0)/ret.pkl
# [05:49:51.276] INFO   _fit_and_score[178/189].compute... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 1.1', random_state=0)]
# /Users/danb/miniconda3/envs/bubo-features/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# [05:49:56.055] INFO   _fit_and_score[160/189].compute[78.337s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 2.3', random_state=0)]
# [05:49:56.596] INFO   _fit_and_score[161/189].compute[78.112s]: split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 2.3', random_state=0)]
# [05:49:57.783] INFO   _fit_and_score[169/189].compute[74.381s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 1.5', random_state=0)]
# [05:49:58.524] INFO   _fit_and_score[162/189].compute[78.103s]: split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 2.3', random_state=0)]
# [05:50:01.532] INFO   _fit_and_score[170/189].compute[69.662s]: split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 1.5', random_state=0)]
# [05:50:05.556] INFO   _fit_and_score[153/189].save... model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=3.5',random_state=0)]
# [05:50:14.943] INFO   _fit_and_score[153/189].save[9.383s, 18.6 MB]: model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=3.5',random_state=0)]
# [05:50:15.034] INFO   _fit_and_score[179/189].compute... split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 1.1', random_state=0)]
# /Users/danb/miniconda3/envs/bubo-features/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# [05:50:18.717] INFO   _fit_and_score[171/189].compute[41.391s]: split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 1.5', random_state=0)]
# [05:50:21.378] INFO   _fit_and_score[160/189].save... model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=2.3',random_state=0)]
# [05:50:22.517] INFO   _fit_and_score[161/189].save... model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=2.3',random_state=0)]
# [05:50:23.486] INFO   _fit_and_score[169/189].save... model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=1.5',random_state=0)]
# [05:50:24.953] INFO   _fit_and_score[162/189].save... model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=2.3',random_state=0)]
# [05:50:27.674] INFO   _fit_and_score[170/189].save... model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=1.5',random_state=0)]
# [05:50:30.463] INFO   _fit_and_score[160/189].save[9.082s, 16.2 MB]: model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=2.3',random_state=0)]
# [05:50:30.632] INFO   _fit_and_score[180/189].compute... split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 1.1', random_state=0)]
# [05:50:31.360] INFO   _fit_and_score[161/189].save[8.831s, 16.2 MB]: model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=2.3',random_state=0)]
# [05:50:31.564] INFO   _fit_and_score[181/189].reuse.ret[0.011s, 2.4 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=5',random_state=0)/ret.pkl
# [05:50:31.632] INFO   _fit_and_score[182/189].reuse.ret[0.011s, 2.4 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=5',random_state=0)/ret.pkl
# [05:50:31.836] INFO   _fit_and_score[183/189].reuse.ret[0.009s, 2.4 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=5',random_state=0)/ret.pkl
# [05:50:31.911] INFO   _fit_and_score[184/189].reuse.ret[0.018s, 2.8 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=20,multiclass=ovr,max_depth=0.5',random_state=0)/ret.pkl
# [05:50:32.071] INFO   _fit_and_score[185/189].reuse.ret[0.013s, 2.8 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=20,multiclass=ovr,max_depth=0.5',random_state=0)/ret.pkl
# [05:50:32.172] INFO   _fit_and_score[186/189].reuse.ret[0.016s, 2.8 MB]: 20180709-211727-fd34af5-ovr_try_2/split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=20,multiclass=ovr,max_depth=0.5',random_state=0)/ret.pkl
# [05:50:32.324] INFO   _fit_and_score[187/189].compute... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 0.5', random_state=0)]
# [05:50:32.498] INFO   _fit_and_score[169/189].save[9.008s, 14.5 MB]: model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=1.5',random_state=0)]
# [05:50:32.599] INFO   _fit_and_score[188/189].compute... split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 0.5', random_state=0)]
# /Users/danb/miniconda3/envs/bubo-features/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# [05:50:34.458] INFO   _fit_and_score[162/189].save[9.500s, 16.2 MB]: model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=2.3',random_state=0)]
# [05:50:34.596] INFO   _fit_and_score[189/189].compute... split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 0.5', random_state=0)]
# /Users/danb/miniconda3/envs/bubo-features/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /Users/danb/miniconda3/envs/bubo-features/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# [05:50:37.038] INFO   _fit_and_score[178/189].compute[43.540s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 1.1', random_state=0)]
# /Users/danb/miniconda3/envs/bubo-features/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# [05:50:38.550] INFO   _fit_and_score[170/189].save[10.872s, 14.5 MB]: model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=1.5',random_state=0)]
# [05:50:49.849] INFO   _fit_and_score[171/189].save... model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=1.5',random_state=0)]
# [05:50:57.310] INFO   _fit_and_score[171/189].save[7.457s, 14.5 MB]: model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=1.5',random_state=0)]
# [05:50:58.579] INFO   _fit_and_score[179/189].compute[42.424s]: split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 1.1', random_state=0)]
# [05:51:00.086] INFO   _fit_and_score[178/189].save... model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=1.1',random_state=0)]
# [05:51:03.959] INFO   _fit_and_score[178/189].save[3.870s, 14.5 MB]: model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=1.1',random_state=0)]
# [05:51:13.739] INFO   _fit_and_score[180/189].compute[41.326s]: split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 1.1', random_state=0)]
# [05:51:15.391] INFO   _fit_and_score[188/189].compute[40.779s]: split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 0.5', random_state=0)]
# [05:51:15.493] INFO   _fit_and_score[187/189].compute[41.234s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 0.5', random_state=0)]
# [05:51:17.165] INFO   _fit_and_score[189/189].compute[40.083s]: split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 80, multiclass: ovr, max_depth: 0.5', random_state=0)]
# [05:51:19.533] INFO   _fit_and_score[179/189].save... model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=1.1',random_state=0)]
# [05:51:22.952] INFO   _fit_and_score[179/189].save[3.416s, 14.5 MB]: model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=1.1',random_state=0)]
# [05:51:34.565] INFO   _fit_and_score[180/189].save... model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=1.1',random_state=0)]
# [05:51:36.660] INFO   _fit_and_score[187/189].save... model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=0.5',random_state=0)]
# [05:51:37.028] INFO   _fit_and_score[188/189].save... model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=0.5',random_state=0)]
# [05:51:38.197] INFO   _fit_and_score[180/189].save[3.629s, 14.5 MB]: model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=1.1',random_state=0)]
# [05:51:38.678] INFO   _fit_and_score[189/189].save... model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=0.5',random_state=0)]
# [05:51:40.127] INFO   _fit_and_score[187/189].save[3.464s, 13.5 MB]: model_id[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=0.5',random_state=0)]
# [05:51:40.421] INFO   _fit_and_score[188/189].save[3.389s, 13.5 MB]: model_id[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=0.5',random_state=0)]
# [05:51:41.746] INFO   _fit_and_score[189/189].save[3.064s, 13.5 MB]: model_id[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1.0,classifier='cls=rf,criterion=gini,n_estimators=80,multiclass=ovr,max_depth=0.5',random_state=0)]
# [Parallel(n_jobs=8)]: Done 189 out of 189 | elapsed: 38.8min finished
# /Users/danb/hack/bubo/features/sk_hack.py:415: RuntimeWarning: invalid value encountered in subtract
#   array_means[:, np.newaxis]) ** 2,

# %%
# Precompute eval metrics + dims for the plots below
#   - Grain: models
#   - Metrics: train_score, test_score, ...
#   - Dims: model_id, params_no_ns, fold, ...
ns = [
    'n_species',
    'n_recs',
    # TODO TODO Figure out the params_no_ns ordering shit
    # 'c_n_estimators',  # Pivot plots for model_size ~ max_depth
    'c_n_estimators',  'c_multiclass',  # Pivot plots for model_size ~ max_depth
]
cv_models = (cv_results_splits_df(cv.cv_results_)
    # Slow yaml parsing, compute up front
    .assign(params_dict=lambda df: df.apply(axis=1, func=lambda row: dict(
        **{strip_startswith(k, 'param_'): row[k] for k in df if k.startswith('param_') and k not in ['param_classifier']},
        # HACK 'classifier.foo' -> 'c_foo'
        #   - TODO Refactor Search.classifier to get rid of the yaml strs ('c_cls', 'c_n_estimators', ...)
        **{'c_' + k: v for k, v in yaml.safe_load('{%s}' % row.param_classifier).items()},
        # 'classifier': yaml.safe_load('{%s}' % row.param_classifier),
    )))
    [lambda df: [c for c in df if not c.startswith('param_')]]
    # Dims from params
    .assign(
        # Useful for validation curves (vary params by classifier type)
        # params_no_ns=lambda df: df.params_dict.str['classifier'].apply(lambda x: (
        #     '%s-%s' % (x['cls'], x['criterion']) if x['cls'] == 'rf' else
        #     x['cls']
        # )),
        # Useful for learning curves (vary n_species/n_recs per classifier)
        params_no_ns=lambda df: df.params_dict.apply(lambda d: ', '.join(
            '%s[%s]' % (k, d[k]) for k in d if k not in ns
        )),
        ns=lambda df: df.params_dict.apply(lambda d: ', '.join(
            '%s[%s]' % (k, d.get(k)) for k in ns
        )),
    )
    # HACK Convert yaml strs ('x: y') to bracket style ('x[y]'), for visual consistency
    #   - TODO Refactor Search.classifier to get rid of the yaml strs ('c_cls', 'c_n_estimators', ...)
    .applymap(lambda x: x if not isinstance(x, str) else (
        re.sub(r'([^][:, ]+):\s+([^][:,]+)(, )?', r'c_\1[\2]\3',
            re.sub(r'classifier\[([^]]+)\]', r'\1',
                x,
            ),
        )
    ))
    #   - Restore the cats we just destroyed [copied from cv_results_splits_df]
    .pipe(df_ordered_cat,
        model_id=lambda df: df.model_id.unique(),
        params=lambda df: df.params.unique(),
        params_no_ns=lambda df: df.params_no_ns.unique(),
        ns=lambda df: df.ns.unique(),
    )
    # .eval
    .assign(
        train_evals=lambda df: np.vectorize(SearchEvals)(
            i=df.pop('train_i'),
            y=df.pop('train_y'),
            classes=df['classes'],
            y_scores=df.pop('train_predict_proba'),
            drop_missing_classes_for_n_species=True,  # HACK Migrate to sk Pipeline to avoid this
        ),
        test_evals=lambda df: np.vectorize(SearchEvals)(
            i=df.pop('test_i'),
            y=df.pop('test_y'),
            classes=df['classes'],
            y_scores=df.pop('test_predict_proba'),
            drop_missing_classes_for_n_species=True,  # HACK Migrate to sk Pipeline to avoid this
        ),
        # HACK Recompute (train_score, test_score) using SearchEvals.score so it can drop_missing_classes_for_n_species
        #   - Else you'll get scores that are too low (bad) because they include some -np.inf's in the median
        train_score=lambda df: df.train_evals.map(lambda x: x.score()),
        test_score=lambda df: df.test_evals.map(lambda x: x.score()),
    )
    .drop(columns=[
        'classes',
    ])
    # proc_stats
    .assign(
        mem_rss_spread=lambda df: df.proc_stats.map(lambda p: p.df.mem_rss.pipe(lambda s: s.max() - s.min())),
        mem_vms_spread=lambda df: df.proc_stats.map(lambda p: p.df.mem_vms.pipe(lambda s: s.max() - s.min())),
    )
    # Reorder
    .pipe(df_reorder_cols,
        first=['model_id', 'params', 'params_dict', 'params_no_ns', 'ns'],
        last=['train_evals', 'test_evals', 'proc_stats', 'model_stats', 'model'],
    )
    .pipe(tap, f=lambda df: display(
        # df_summary(df).T,
        # df,
        len(df),
        df[:5],
    ))
)
# Out:
# 189
#                                                                                                                        model_id                                                                                                               params                                                                                                                                params_dict                                     params_no_ns                                                                    ns  fold  train_score  test_score  fit_time  score_time  model_size  mem_rss_spread  mem_vms_spread                                                                  train_evals                                                                test_evals                           proc_stats                                                                                                                                                                                              model_stats  model
# 0                    n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[null], fold[0]                    n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[null]                        {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 100, 'c_max_depth': None}  c_cls[rf], c_criterion[gini], c_max_depth[None]  n_species[168], n_recs[1.0], c_n_estimators[100], c_multiclass[None]     0         -1.0       -10.0    86.999       1.597   357092405       716984320       667213824  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])   ProcStats(interval=1.0, stats[94])                    type  n_trees  tree_i  leaf_count  fork_count  depth  max_depth  node_count  capacity  max_n_classes  n_features  n_outputs
# 0   search/forest/tree      100       0        1228   ...    NaN
# 1                    n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[null], fold[1]                    n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[null]                        {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 100, 'c_max_depth': None}  c_cls[rf], c_criterion[gini], c_max_depth[None]  n_species[168], n_recs[1.0], c_n_estimators[100], c_multiclass[None]     1         -1.0       -10.5    87.009       1.558   356456805       716087296       647254016  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])   ProcStats(interval=1.0, stats[94])                    type  n_trees  tree_i  leaf_count  fork_count  depth  max_depth  node_count  capacity  max_n_classes  n_features  n_outputs
# 0   search/forest/tree      100       0        1246   ...    NaN
# 2                    n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[null], fold[2]                    n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[null]                        {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 100, 'c_max_depth': None}  c_cls[rf], c_criterion[gini], c_max_depth[None]  n_species[168], n_recs[1.0], c_n_estimators[100], c_multiclass[None]     2         -1.0        -8.0    88.216       1.708   357761605       717230080       708104192  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])   ProcStats(interval=1.0, stats[96])                    type  n_trees  tree_i  leaf_count  fork_count  depth  max_depth  node_count  capacity  max_n_classes  n_features  n_outputs
# 0   search/forest/tree      100       0        1238   ...    NaN
# 3  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[20], c_multiclass[ovr], c_max_depth[null], fold[0]  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[20], c_multiclass[ovr], c_max_depth[null]  {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 20, 'c_multiclass': 'ovr', 'c_max_depth': None}  c_cls[rf], c_criterion[gini], c_max_depth[None]    n_species[168], n_recs[1.0], c_n_estimators[20], c_multiclass[ovr]     0         -1.0      -168.0   181.158      32.663    25849619       157704192       153829376  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])  ProcStats(interval=1.0, stats[249])                          type  n_classes class_  n_trees  tree_i  leaf_count  fork_count  depth  max_depth  node_count  capacity  max_n_classes  n_features  n_outputs
# 0     search/ovr/forest/tree  ...    NaN
# 4  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[20], c_multiclass[ovr], c_max_depth[null], fold[1]  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[20], c_multiclass[ovr], c_max_depth[null]  {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 20, 'c_multiclass': 'ovr', 'c_max_depth': None}  c_cls[rf], c_criterion[gini], c_max_depth[None]    n_species[168], n_recs[1.0], c_n_estimators[20], c_multiclass[ovr]     1         -1.0      -168.0   180.944      32.177    25824419       157700096       153853952  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])  ProcStats(interval=1.0, stats[249])                          type  n_classes class_  n_trees  tree_i  leaf_count  fork_count  depth  max_depth  node_count  capacity  max_n_classes  n_features  n_outputs
# 0     search/ovr/forest/tree  ...    NaN

# %%
# For rf / ovr
cv_models = (cv_models
    .assign(
        c_multiclass=lambda df: df.params_dict.str.get('c_multiclass'),
        c_max_depth=lambda df: df.params_dict.str.get('c_max_depth'),
        c_rf_max_depth=lambda df: df.apply(axis=1, func=lambda row: (
            row['c_max_depth'] * (10 if row['c_multiclass'] == 'ovr' else 1)  # HACK Undo rf_max_depth -> ovr_rf_max_depth
        )),
    )
)

# %%
cv_models_proc_stats = (cv_models
    # Enable these as needed (at the cost of mem usage)
    [[
        'model_id',
        'params',
        # 'params_dict',
        'params_no_ns',
        'ns',
        'fold',
        # 'train_score',
        # 'test_score',
        # 'fit_time',
        # 'score_time',
        'mem_rss_spread',
        # 'mem_vms_spread',
        # 'train_evals',
        # 'test_evals',
        'proc_stats',
    ]]
    .pipe(df_flatmap, lambda row: [
        row.append(pd.Series(dict(**stats)))
        for stats in row.proc_stats.stats
    ])
    # Restore the cats we just destroyed [copied from cv_results_splits_df]
    .pipe(df_ordered_cat,
        model_id=lambda df: df.model_id.unique(),
        params=lambda df: df.params.unique(),
    )
    .assign(
        cpu_user=lambda df: df.cpu_user.diff() * 100,
        cpu_system=lambda df: df.cpu_system.diff() * 100,
    )
    .pipe(tap, f=lambda df: display(
        # df_summary(df).T,
        # df[:5],
    ))
)

# %%
(cv_models
    # Manually compute y.mean() per group
    .groupby('params').apply(lambda g: g.assign(
        fit_time_mean=lambda df: df.fit_time.mean(),
        score_time_mean=lambda df: df.score_time.mean(),
    ))
    .pipe(df_reverse_cat, 'params_no_ns')
    .fillna({'c_rf_max_depth': np.inf})
    .pipe(ggplot)
    # + aes(x='params_no_ns', color='params_no_ns')
    + aes(x='factor(c_rf_max_depth)', color='params_no_ns')
    + facet_wrap('ns', ncol=3)
    # Summary per fold
    + geom_col(aes(y='fit_time_mean + score_time_mean', fill='params_no_ns'), color='black', size=.2, position=position_dodge())
    + geom_col(aes(y='fit_time_mean', fill='params_no_ns'), color='black', size=.2, position=position_dodge())
    # Distribution of folds
    + geom_point(aes(y='fit_time'), size=2, color='gray', fill='none')
    + geom_point(aes(y='fit_time + score_time'), size=2, color='black', fill='none')
    + scale_fill_cmap_d(mpl_cmap_concat('tab20', 'tab20b', 'tab20c'))
    + coord_flip()
    + guides(fill=guide_legend(reverse=True, ncol=2, byrow=True))
    # + theme(axis_title_y=element_blank(), axis_text_y=element_blank(), axis_ticks_major_y=element_blank())
    + theme(legend_position='bottom', legend_direction='vertical', legend_box_spacing=.4, legend_key_height=8)
    + theme_figsize(width=24, aspect_ratio=1/2)
    + ylab('fit_time + score_time')
    + ggtitle(f'Train + score times ({recs_stats})')
)
# Out:
# <ggplot: (477263901)>

# %%
(cv_models
    # Manually compute y.mean() per group
    .groupby('params').apply(lambda g: g.assign(model_size_mean=lambda df: df.model_size.mean()))
    .pipe(df_reverse_cat, 'params_no_ns')
    .fillna({'c_rf_max_depth': np.inf})
    .pipe(ggplot)
    # + aes(x='params_no_ns', group='params_no_ns')
    + aes(x='factor(c_rf_max_depth)', group='params_no_ns')
    + facet_wrap('ns', ncol=3)
    + geom_col(aes(y='model_size_mean', fill='params_no_ns'), position=position_dodge()) # Summary per fold
    + geom_point(aes(y='model_size'), fill='none', size=2) # Distribution of folds
    + scale_fill_cmap_d(mpl_cmap_concat('tab20', 'tab20b', 'tab20c'))
    + scale_y_continuous(labels=labels_bytes(), breaks=breaks_bytes())
    + coord_flip()
    + guides(fill=guide_legend(reverse=True, ncol=2, byrow=True))
    # + theme(axis_title_y=element_blank(), axis_text_y=element_blank(), axis_ticks_major_y=element_blank())
    + theme(legend_position='bottom', legend_direction='vertical', legend_box_spacing=.4, legend_key_height=8)
    + theme_figsize(width=24, aspect_ratio=1/2)
    + ggtitle(f'Model size ({recs_stats})')
)
# Out:
# <ggplot: (-9223372036516759166)>

# %%
# TODO TODO Fix forest_depth for c_multiclass[ovr], c_n_estimators[80]
# Forest depth stats so we can tune max_depth, model_size
cv_models = (cv_models
    .assign(
        # TODO Generalize this for models other than rf
        forest_depth_mean=lambda df: df.model_stats.map(lambda stats: or_else(None, lambda: stats.depth.mean())),
        forest_depth_std=lambda df: df.model_stats.map(lambda stats: or_else(None, lambda: stats.depth.std())),
    )
)
(cv_models
    [['model_id', 'forest_depth_mean', 'forest_depth_std']]
    [:10]
)
# Out:
#                                                                                                                        model_id  forest_depth_mean  forest_depth_std
# 0                    n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[null], fold[0]             93.430            11.615
# 1                    n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[null], fold[1]             92.690            13.149
# 2                    n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[null], fold[2]             94.990            13.390
# 3  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[20], c_multiclass[ovr], c_max_depth[null], fold[0]              7.822             1.636
# 4  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[20], c_multiclass[ovr], c_max_depth[null], fold[1]              7.756             1.639
# 5  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[20], c_multiclass[ovr], c_max_depth[null], fold[2]              7.829             1.624
# 6  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[80], c_multiclass[ovr], c_max_depth[null], fold[0]                NaN               NaN
# 7  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[80], c_multiclass[ovr], c_max_depth[null], fold[1]                NaN               NaN
# 8  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[80], c_multiclass[ovr], c_max_depth[null], fold[2]                NaN               NaN
# 9                      n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[93], fold[0]             88.670             6.442

# %%
# TODO TODO Fix forest_depth for c_multiclass[ovr], c_n_estimators[80]
(cv_models
    # Manually compute y.mean() per group
    .groupby('params').apply(lambda g: g.assign(forest_depth_mean_mean=lambda df: df.forest_depth_mean.mean()))
    .pipe(df_reverse_cat, 'params_no_ns')
    .fillna({'c_rf_max_depth': np.inf})
    .pipe(ggplot)
    # + aes(x='params_no_ns', group='params_no_ns')
    + aes(x='factor(c_rf_max_depth)', group='params_no_ns')
    + facet_wrap('ns', ncol=3)
    + geom_col(aes(y='forest_depth_mean_mean', fill='params_no_ns'), position=position_dodge()) # Summary per fold
    + geom_point(aes(y='forest_depth_mean'), fill='none', size=2) # Distribution of folds
    + scale_fill_cmap_d(mpl_cmap_concat('tab20', 'tab20b', 'tab20c'))
    + coord_flip()
    + guides(fill=guide_legend(reverse=True, ncol=2, byrow=True))
    # + theme(axis_title_y=element_blank(), axis_text_y=element_blank(), axis_ticks_major_y=element_blank())
    + theme(legend_position='bottom', legend_direction='vertical', legend_box_spacing=.4, legend_key_height=8)
    + theme_figsize(width=24, aspect_ratio=1/2)
    + ggtitle(f'Forest depth ({recs_stats})')
)
# Out:
# /Users/danb/miniconda3/envs/bubo-features/lib/python3.6/site-packages/plotnine/layer.py:452: UserWarning: geom_col : Removed 81 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# /Users/danb/miniconda3/envs/bubo-features/lib/python3.6/site-packages/plotnine/layer.py:452: UserWarning: geom_point : Removed 81 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# <ggplot: (396230990)>

# %%
# TODO Revive if insightful
(cv_models
    .pipe(df_reverse_cat, 'params_no_ns')
    .assign(n_species=lambda df: df.params_dict.str['n_species'])
    .pipe(ggplot, aes(x='n_species', y='forest_depth_mean', color='params_no_ns'))
    # + facet_wrap('params_no_ns', ncol=2)
    + geom_point()
    + geom_pointrange(aes(ymin='forest_depth_mean - 2*forest_depth_std', ymax='forest_depth_mean + 2*forest_depth_std'))
    + geom_smooth(method='lm', se=False)  # Disable se because it only knows forest_depth_mean, no measure of spread
    + expand_limits(x=0)
    + scale_color_cmap_d(mpl_cmap_concat('tab20', 'tab20b', 'tab20c'))
    + guides(color=guide_legend(reverse=True))
    + theme(legend_position='bottom', legend_direction='vertical', legend_box_spacing=.4, legend_key_height=8)
    # + theme_figsize(aspect_ratio=1/3)
    + theme_figsize(aspect_ratio=1/3)
    + ggtitle(f'RF depth vs. n_species ({recs_stats})')
)
# Out:
# [skip]

# %%
(cv_models
    .pipe(df_reverse_cat, 'params', 'params_no_ns', 'ns')
    # Manually compute y.mean() per group
    .groupby('params').apply(lambda g: g.assign(mem_rss_spread_mean=lambda df: df.mem_rss_spread.mean()))
    .pipe(ggplot, aes(x='ns', group='params_no_ns'))
    + geom_col(aes(y='mem_rss_spread_mean', fill='params_no_ns'), position=position_dodge()) # Summary per fold
    + geom_point(aes(y='mem_rss_spread'), fill='none', size=2, position=position_dodge(width=.9)) # Distribution of folds
    + coord_flip()
    + scale_fill_cmap_d(mpl_cmap_concat('tab20', 'tab20b', 'tab20c'))
    + scale_y_continuous(labels=labels_bytes(), breaks=breaks_bytes())
    + guides(fill=guide_legend(reverse=True))
    + theme(legend_position='bottom', legend_direction='vertical', legend_box_spacing=.4, legend_key_height=8)
    + theme_figsize(aspect_ratio=1/3*2)
    + ggtitle(f'Mem rss spread ($max-min$) ({recs_stats})')
)
# Out:
# [skip]

# %%
# TODO Might need to stack/geom_area for overlapping runs
(cv_models_proc_stats
    .pipe(ggplot, aes(x='time',
        color='model_id',
        # color='params_no_ns', linetype='ns',
        # color='params_no_ns', size='ns',
    ))
    + geom_line(aes(y='cpu_system'), linetype='dashed', size=.5)
    + geom_line(aes(y='cpu_system + cpu_user'), linetype='solid', size=.5)
    # + geom_line(aes(y='cpu_system + cpu_user'), size=1)
    + expand_limits(y=0)
    + ylab('cpu')
    + scale_x_datetime(date_labels='%H:%M:%S')
    + scale_y_continuous(labels=lambda labels: ['%.3g%%' % x for x in labels])
    # + scale_color_cmap_d(mpl_cmap_concat('tab20', 'tab20b', 'tab20c'))
    + theme(legend_position='bottom', legend_direction='vertical', legend_box_spacing=.4, legend_key_height=8)
    + theme_figsize('inline_short')
    + ggtitle('cpu over time (system + user)')
)
# Out:
# [skip]

# %%
(cv_models_proc_stats
    .pipe(ggplot, aes(x='time', color='model_id'))
    + geom_line(aes(y='mem_rss'), linetype='solid', size=.5)
    + geom_line(aes(y='mem_vms'), linetype='dashed', size=.5)
    + expand_limits(y=0)
    + ylab('mem')
    + scale_x_datetime(date_labels='%H:%M:%S')
    + scale_y_continuous(labels=labels_bytes(), breaks=breaks_bytes(pow=3))
    # + scale_color_cmap_d(mpl_cmap_concat('tab20', 'tab20b', 'tab20c'))
    + theme(legend_position='bottom', legend_direction='vertical', legend_box_spacing=.4, legend_key_height=8)
    + theme_figsize('inline_short')
    + ggtitle('Mem over time (rss, vms)')
)
# Out:
# [skip]

# %%
# Train/test scores
#   - Grain: models x {train,test}
#   - Metrics: score
#   - Dims: group, params
(cv_models
    .pipe(df_reverse_cat, 'params_no_ns')
    .fillna({'c_rf_max_depth': np.inf})
    .pipe(lambda df: pd.melt(
        df,
        id_vars=['ns', 'params_no_ns', 'params', 'fold', 'c_rf_max_depth'],
        value_vars=['train_score', 'test_score'],
        var_name='split',
        value_name='score'),
    )
    .assign(
        split=lambda df: df.split.str.replace('_score', ''),
        group=lambda df: df.params_no_ns.str.cat(df.split, '/'),
    )
    .pipe(df_ordered_cat,
        group=lambda df: reversed(df.group.unique()),
    )
    .pipe(lambda df: (df
        .pipe(ggplot, aes(
            # x='params_no_ns',
            x='factor(c_rf_max_depth)',
            y='score',
            # color='group',  # Ran out of colors
            color='params_no_ns',
        ))
        + facet_wrap('ns', ncol=3)
        + geom_hline(yintercept=-1, color='lightgrey')  # -1 is the max score (1 is the min coverage_error)
        + geom_point(data=df[df.split == 'test'], shape='o', fill='none', size=2)
        + geom_point(data=df[df.split == 'train'], shape='x', size=2)
        # + geom_line(aes(group='str(group) + str(fold)'), alpha=.2)  # Low ROI
        + stat_summary(aes(group='group'), fun_data='mean_cl_boot', random_state=0, geom='errorbar')
        # + stat_summary(aes(group='group'), fun_data='mean_cl_boot', random_state=0, geom='line', size=1)  # Low ROI
        + scale_color_cmap_d(mpl_cmap_concat('tab20', 'tab20b', 'tab20c'))
        + coord_flip(
            ylim=(-30, 0),
        )
        + scale_shape_manual(values=['o', 'x'])
        + guides(color=guide_legend(reverse=True, ncol=2, byrow=True))
        # + theme(axis_title_y=element_blank(), axis_text_y=element_blank(), axis_ticks_major_y=element_blank())
        + theme(legend_position='bottom', legend_direction='vertical', legend_box_spacing=.4, legend_key_height=8)
        + theme_figsize(width=18, aspect_ratio=1/2)
        + ylab('score (-coverage_error)')
        + ggtitle(f'Train/test scores ({recs_stats})')
    ))
)
# Out:
# /Users/danb/miniconda3/envs/bubo-features/lib/python3.6/site-packages/plotnine/guides/guides.py:200: UserWarning: Cannot generate legend for the 'shape' aesthetic. Make sure you have mapped a variable to it
#   "variable to it".format(output))
# <ggplot: (-9223372036544937086)>

# %%
(cv_models
    .pipe(ggplot, aes(x='model_size', y='test_score'))
    + aes(color='params_no_ns') + facet_wrap('ns', ncol=3,
        # scales='free_x',
    )
    + geom_point()
    + geom_hline(yintercept=0, color='grey')
    + scale_x_continuous(labels=labels_bytes(), breaks=breaks_bytes())
    + expand_limits(x=0)
    + ylim(-30, 0)
    + theme(panel_spacing_y=.3)
    + guides(color=guide_legend(reverse=True, ncol=2, byrow=True))
    + theme(legend_position='bottom', legend_direction='vertical', legend_box_spacing=.4, legend_key_height=8)
    + theme_figsize(width=18, aspect_ratio=1/2)
    + ggtitle('test_score ~ model_size (tuned by e.g. max_depth)')
)
# Out:
# /Users/danb/miniconda3/envs/bubo-features/lib/python3.6/site-packages/plotnine/layer.py:452: UserWarning: geom_point : Removed 21 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# <ggplot: (401857975)>

# %%
STOP
# Out:
# Traceback (most recent call last):
#
#   File "<ipython-input-321-ee4decdca3b8>", line 1, in <module>
#     STOP
#
# NameError: name 'STOP' is not defined

# %% [markdown]
# # Model diagnostics: all models, all folds

# %%
print('models:')
print('  params[*/%s]' % len(cv_models.params.cat.categories))
print('  fold[*/%s]' % cv.cv.n_splits)

# %%
# TODO Cache
# Coverage errors: all models, all folds
#   - Subset: all models
#   - Grain: sum(recs[model.test_i] for model)
#   - Dims: model_id, params, fold, y_true, rec_id
#   - Metrics: coverage_error
coverage_errors_all_all = (cv_models
    # .sample(n=5, random_state=0)  # For faster dev
    .pipe(lambda df: DF(
        OrderedDict(
            # **row[['model_id', 'params', 'fold']],  # Slow (in this inner loop), unpack manually instead
            model_id=row.model_id,
            params=row.params,
            params_no_ns=row.params_no_ns,
            ns=row.ns,
            fold=row.fold,
            i=i,
            y_true=y_true,
            coverage_error=coverage_error,
        )
        for row in iter_progress(df_rows(df), n=len(df))
        for i, y_true, coverage_error in zip(
            row.test_evals.i,
            row.test_evals.y,
            row.test_evals.coverage_errors(),
        )
    ))
    .astype(dict(
        model_id=cv_models.model_id.dtype,
        params=cv_models.params.dtype,
        params_no_ns=cv_models.params_no_ns.dtype,
        ns=cv_models.ns.dtype,
    ))
    .pipe(tap, lambda df: display(
        df_summary(df).T,
        df[:10],
    ))
)

# %%
# Facet by params_no_ns, order by median(coverage_error)
#   - Subset: all models
#   - Grain: sum(recs[model.test_i].groupby(params, y_true) for model)
#       - Over: fold, rec_id
#   - Dims: params, y_true
#   - Metrics: coverage_error.median
# in: coverage_errors_all_all, recs
(coverage_errors_all_all
    # .pipe(df_reverse_cat, 'params', 'params_no_ns', 'ns')
    .pipe(df_ordered_cat,
        y_true=lambda df: (
            # Sort species by median(coverage_error) (across all models)
            df.groupby('y_true').agg({'coverage_error': np.median}).reset_index().sort_values('coverage_error').y_true
            # Sort species by taxo (hard to compare across models, unless they're pretty low noise)
            # reversed(recs.species.cat.categories)
        ),
    )
    .pipe(ggplot, aes(x='y_true', y='coverage_error',
        # color='params',
    ))
    # + facet_wrap('params_no_ns', ncol=3)
    + facet_grid('ns ~ params_no_ns')
    # + geom_line(aes(group='params'), stat='summary', fun_y=np.median)  # TODO Bad interpolation with n_species
    + geom_point(aes(group='params'), stat='summary', fun_y=np.median)
    + coord_flip(
        # ylim=(0, min(30, len(np.unique(y)))),  # Restore eventually
    )
    # + geom_hline(yintercept=recs.species.nunique(), color='grey')
    # + scale_color_cmap_d(mpl_cmap_concat('tab20', 'tab20b', 'tab20c'))
    + theme(legend_position='bottom', legend_direction='vertical', legend_box_spacing=.4, legend_key_height=8)
    # + theme_figsize(width=12*2, aspect_ratio=2/3)
    + theme_figsize(width=12, aspect_ratio=1/4)
    + ggtitle(rf'Coverage error over fold $\times$ instance, by params_no_ns $\times$ ns ({recs_stats})')
)

# %%
# TODO Slow, bad for notebook dev loop -- move lower, or disable by default?
# Facet by species
#   - Subset: all models
#   - Grain: sum(recs[model.test_i].groupby(params, y_true) for model)
#       - Over: fold, rec_id
#   - Dims: params, y_true
#   - Metrics: coverage_error.median
# in: coverage_errors_all_all, recs
(coverage_errors_all_all
    # .sample(200, random_state=0)  # Faster dev
    .astype({'y_true': metadata.species.df.shorthand.dtype})
    .pipe(df_reverse_cat, 'params')
    .pipe(ggplot, aes(x='params', y='coverage_error', color='params_no_ns'))
    + facet_wrap('y_true')
    + geom_hline(yintercept=1, color='grey')
    # + geom_hline(yintercept=recs.species.nunique(), color='grey')

    # Percentiles (faster, no overplot)
    # + geom_point(stat='summary', fun_y=np.median)
    # + geom_linerange(stat='summary', fun_ymin=partial(np.percentile, q=25), fun_ymax=partial(np.percentile, q=75))

    # Violin (slow, no overplot)
    # + geom_violin()

    # Boxplot (very slow, no overplot)
    # + geom_boxplot()

    # Points (medium cost, high overplot)
    #   - n (count) instead of prop (proportion)
    #   - scale_size_area() instead of default scale_size(), because it's a count [I don't grok this but it looks good]
    + geom_count(aes(size='..n..'), alpha=.5)
    + scale_size_area()
    + geom_point(stat='summary', fun_y=np.median, alpha=1, color='black', shape='|', size=3, stroke=1)

    + coord_flip()
    + scale_color_cmap_d(mpl_cmap_concat('tab20', 'tab20b', 'tab20c'))
    + theme(axis_text_y=element_text(size=6))
    + theme_figsize('square')  # Faster
    # + theme_figsize('half')
    # + theme_figsize('full')
    # + theme_figsize('full_dense')
    + ggtitle(rf'Coverage error over fold $\times$ instance, by params ({recs_stats})')
)

# %% [markdown]
# # Model diagnostics: one model, all folds

# %%
params_i = 0
params = cv_models.params.cat.categories[params_i]
print("params:\n%s" % '\n'.join('  %s: %r' % (i, x) for i, x in enumerate(cv_models.params.cat.categories)))
print()
print('models:')
print('  params[%s/%s]: %r' % (params_i, len(cv_models.params.cat.categories), params))
print('  fold[*/%s]' % cv.cv.n_splits)

# %%
# Coverage errors: one model, all folds
#   - Subset: models.params == params
#   - Grain: sum(recs[model.test_i] for model)
#   - Dims: model_id, params, fold, y_true, rec_id
#   - Metrics: coverage_error
coverage_errors_one_all = (coverage_errors_all_all
    [lambda df: df.params == params]  # One model, all folds
)
display(
    df_summary(coverage_errors_one_all).T,
    coverage_errors_one_all[:10],
)

# %%
#   - Subset: models.params == params
#   - Grain: sum(recs[model.test_i].groupby(y_true) for model)
#       - Over: fold, rec_id
#   - Dims: y_true
#   - Metrics: count, coverage_error.percentiles
# in: coverage_errors_one_all, recs
(coverage_errors_one_all
    .astype({'y_true': metadata.species.df.shorthand.dtype})
    .pipe(df_reverse_cat, 'y_true')
    .pipe(ggplot, aes(x='y_true', y='coverage_error'))
    + geom_hline(yintercept=1, color='grey')
    + geom_hline(yintercept=recs.species.nunique(), color='grey')
    + geom_count(aes(size='..n..'), alpha=1)  # n (count) instead of prop (proportion)
    + scale_size_area()  # Instead of default scale_size(), because it's a count [I don't grok this but it looks good]
    + geom_point(stat='summary', fun_y=np.median, alpha=1, color='red', shape='|', size=6, stroke=2)
    + coord_flip()
    # + theme_figsize('inline')
    # + theme_figsize('square')
    # + theme_figsize('half')
    + theme_figsize('half_dense')
    # + theme_figsize('full')
    # + theme_figsize('full_dense')
    + ggtitle(rf'Coverage error over fold $\times$ instance ({params}) ({recs_stats})')
)

# %%
# One-model/all-folds confusion matrix
with figsize(
    # 'square',
    # 'full',
    'full_dense',
):
    (cv_models
        [lambda df: df.params == params]
        .pipe(lambda df: plot_confusion_matrix(
            classes=df.iloc[0].test_evals.classes,
            M=np.array([
                row.test_evals.confusion_matrix_prob()
                for row in df_rows(df)
            ]).sum(axis=0),
            # normalize=False,  # For counts
            raw=True, scale=10,  # Faster dev
            format=None,  # Omit numbers, too dense
            title=f'({recs_stats})',
        ))
    )

# %% [markdown]
# # Model diagnostics: one model, one fold

# %%
fold = 0
# params_i = ...  # Comment out to reuse from above
params = cv_models.params.cat.categories[params_i]
[(_, model)] = list(cv_models[lambda df: (df.params == params) & (df.fold == fold)].iterrows())
print("params:\n%s" % '\n'.join('  %s: %r' % (i, x) for i, x in enumerate(cv_models.params.cat.categories)))
print()
print('model:')
print('  params[%s/%s]: %r' % (params_i, len(cv_models.params.cat.categories), model.params))
print('  fold[%s/%s]' % (model.fold, cv.cv.n_splits))
print()
print(model)
# Out:
# [skip]

# %%
# in: model
model_id = model.model_id
params = model.params
fold = model.fold
# train_evals = model.train_evals
test_evals = model.test_evals

# in: model, recs
# train_recs = recs.iloc[train_evals.i]
# train_X = Search.X(recs)[train_evals.i]
# train_y = Search.y(recs)[train_evals.i]
test_recs = recs.iloc[test_evals.i]
test_X = Search.X(recs)[test_evals.i]
test_y = Search.y(recs)[test_evals.i]  # (Don't need to store cv_models.test_evals.y if we have recs -- which sometimes we don't?)

display(
    # len(train_recs),
    len(test_recs),
)
# Out:
# [skip]

# %%
# TODO Restore this plot like 'Coverage error over ...' above, so we can see _one_ model instead of aggregating over n_splits models
# # TODO Update [kill the .merge, then species -> y_true]
# (search.coverage_error_by(test_recs, 'id')
#     [:5]
#     # .merge(test_recs[['id', 'species']], on='id', how='left')
#     # .pipe(ggplot, aes(x='species', y='coverage_error'))
#     # + geom_count(aes(size='..n..'))
#     # + stat_summary(fun_y=np.median, geom='point', color='red', alpha=.5, shape='|', size=6, stroke=1)
#     # + stat_summary(
#     #     fun_ymin=partial(np.percentile, q=25), fun_ymax=partial(np.percentile, q=75),
#     #     geom='linerange', color='red', alpha=.5, size=1,
#     # )
#     # + coord_flip()
#     # + geom_hline(yintercept=len(search.classes_), color='grey')
#     # + scale_x_discrete(limits=list(reversed(test_recs.species.cat.categories)))
#     # + theme_figsize('square')
#     # + ggtitle(rf'Coverage error over instance ({model_id}) ({recs_stats})')
# )
# Out:
# [skip]

# %%
# One-model/one-fold confusion matrix
with figsize(
    'square',
    # 'full',
    # 'full_dense',
):
    plot_confusion_matrix_df(
        confusion_matrix_prob_df(model.test_evals.y, model.test_evals.y_scores, model.test_evals.classes),
        title=model.model_id,
        # normalize=False,  # For counts
        raw=True, scale=10,  # Faster dev
        title=f'({recs_stats})',
    )
# Out:
# [skip]
