# %% [markdown]
# # How to do ACF (autocorrelation function) in R?
# - https://www.rdocumentation.org/packages/stats/versions/3.1.1/topics/acf
# - https://www.rdocumentation.org/packages/forecast/versions/8.1/topics/Acf
# - https://www.rdocumentation.org/packages/forecast/versions/8.1/topics/autoplot.acf

# %%
# %%R
# require(graphics)

# %%
# %%R
# ## Examples from Venables & Ripley
# acf(lh)
# acf(lh, type = "covariance")
# pacf(lh)

# %%
# %%R
# # acf(ldeaths)
# # acf(ldeaths, ci.type = "ma")
# # acf(ts.union(mdeaths, fdeaths))
# # ccf(mdeaths, fdeaths, ylab = "cross-correlation")
# # (just the cross-correlations)
# Out:
# NULL

# %%
# %%R
# presidents # contains missing values
# acf(presidents, na.action = na.pass)
# pacf(presidents, na.action = na.pass)
