# %%
from api.recs import *
from api.server_globals import sg
sg.init(app=None)
# Out:
# /Users/danb/miniconda3/envs/bubo-features/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# 2018-09-05 14:15.06
# init
# 2018-09-05 14:15.08
# init:done

# %%
from notebooks import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext
# autoreload
# The potoo.default_magic_magic extension is already loaded. To reload it, use:
#   %reload_ext
# potoo.default_magic_magic

# %%
# TODO def xc_species(species: str) -> pd.DataFrame:
species = 'SPTO'

# %%
from datasets import xc_meta_to_xc_raw_recs, xc_raw_recs_to_xc_recs
(sg.xc_meta
    [lambda df: df.species == species]
    [lambda df: df.quality.isin(['A', 'B'])]
    .sort_index(ascending=True)
    [:3]
    # TODO Can we make this more lightweight?
    .pipe(xc_meta_to_xc_raw_recs, load=sg.load)
    .pipe(xc_raw_recs_to_xc_recs, projection=sg.projection)
    # What we want
    .pipe(df_assign_first,
        micro=df_cell_spectros(plot_spectro_micro.many, sg.features, wrap_s=10, scale=dict(h=26)),
    )
)
# Out:
# [21:16:31.504] INFO   [2/3 slower] Loading xc.metadata -> xc_raw_recs (.audio, more metadata)...
# [21:16:31.533] INFO   [3/3 slowest] Featurizing xc_raw_recs -> xc_recs (.audio, .feat, .spectro)...
# [21:16:31.537] DEBUG  Load.audio:in
#   len(recs): 3
#   len(recs) per dataset: {xc: 3}
# audio: [
# ] |   0% Completed |  0.0s
# audio: [
# #####################################################################################
# ] | 100% Completed |  0.1s
# [21:16:31.657] DEBUG  Load.audio:out
#   len(audio): 3
# [21:16:31.678] DEBUG  Features.spectros:in
#   len(recs): 3
#   len(recs) per dataset: {xc: 3}
#   sum(duration_h): 0.0546
#   sum(samples_mb): 8.27
#   sum(samples_n): 4334388
# spectro: [
# ] |   0% Completed |  0.0s
# spectro: [
# ###################################################################################
# ] | 100% Completed |  0.1s
# [21:16:31.805] DEBUG  Features.spectros:out
#   (f, sum(t)): [40, 16927]
#                                                             micro dataset species species_com_name species_query  duration_s  samples_mb  samples_n basename       species_longhand                         id                           path  downloaded subspecies         recordist        country                                                  locality     lat      lng  type quality       date   time license_type license_detail                                       license                                url                              download remarks bird_seen playback_used elevation                                                                                                                                            background         volume          speed          pitch         length number_of_notes       variable  channels sampling_rate bitrate_of_mp3               state_only                       place_only                                   state                                                                    place  year  month month_day  hour        background_species  n_background_species                                            place_only_stack                                  state_only_stack                                                                                             place_stack                                                        state_stack                               background_species_stack            remarks_stack                                                                                         audio                                                                                                                                                                                                     feat                                      spectro
# xc_id
# 413996  df_cell_display(value=<IPython.core.display.HTML object>)      xc    SPTO   Spotted Towhee          SPTO     104.430       4.392    2302680    audio  Spotted Towhee - SPTO  xc/data/SPTO/413996/audio  xc/data/SPTO/413996/audio.mp3        True             Thomas G. Graves  United States  Rancho Palos Verdes, California, Portuguese Bend Reserve  33.754 -118.363  song       A 2018-04-28   7:42     by-nc-sa            4.0  //creativecommons.org/licenses/by-nc-sa/4.0/  https://www.xeno-canto.org/413996  //www.xeno-canto.org/413996/download               yes            no     280 m         [Indian Peafowl (Pavo cristatus), Common Yellowthroat (Geothlypis trichas), Northern Raven (Corvus corax), Spotted Towhee (Pipilo maculatus)]  Not specified  Not specified  Not specified  Not specified   Not specified  Not specified  1 (mono)    48000 (Hz)   320000 (bps)  Portuguese Bend Reserve  Rancho Palos Verdes, California  Portuguese Bend Reserve, United States  Rancho Palos Verdes, California, Portuguese Bend Reserve, United States  2018      4     04-28     7  [INPE, COYE, CORA, SPTO]                     4  df_cell_stack(value=['Rancho Palos Verdes', 'California'])  df_cell_stack(value=['Portuguese Bend Reserve'])  df_cell_stack(value=['Rancho Palos Verdes', 'California', 'Portuguese Bend Reserve', 'United States'])  df_cell_stack(value=['Portuguese Bend Reserve', 'United States'])  df_cell_stack(value=['INPE', 'COYE', 'CORA', 'SPTO'])  df_cell_stack(value=[])  box(unbox=xc/data/SPTO/413996/audio: 1 channels, 16 bit, sampled @ 22.05 kHz, 104.430s long)  [0.04258307358434181, -0.04536490749453763, 0.019493329190502656, -0.05121013259465169, -0.09013632157764816, -0.03849159280312274, 0.018081410819483876, 0.014221190896367128, 0.07212147405295197,...  <features.Melspectro object at 0x13dc70eb8>
# 413791  df_cell_display(value=<IPython.core.display.HTML object>)      xc    SPTO   Spotted Towhee          SPTO      32.522       1.368     717120    audio  Spotted Towhee - SPTO  xc/data/SPTO/413791/audio  xc/data/SPTO/413791/audio.mp3        True  megalonyx     Steve Hampton  United States                                          Hidden Hills, CA  34.164 -118.647  song       A 2018-05-05  08:30     by-nc-sa            4.0  //creativecommons.org/licenses/by-nc-sa/4.0/  https://www.xeno-canto.org/413791  //www.xeno-canto.org/413791/download                no            no     280 m                                                                                                                 [Bewick's Wren (Thryomanes bewickii)]  Not specified  Not specified  Not specified  Not specified   Not specified  Not specified  1 (mono)    44100 (Hz)    88712 (bps)                       CA                     Hidden Hills                       CA, United States                                          Hidden Hills, CA, United States  2018      5     05-05     8                    [BEWR]                     1                       df_cell_stack(value=['Hidden Hills'])                       df_cell_stack(value=['CA'])                                            df_cell_stack(value=['Hidden Hills', 'CA', 'United States'])                       df_cell_stack(value=['CA', 'United States'])                          df_cell_stack(value=['BEWR'])  df_cell_stack(value=[])   box(unbox=xc/data/SPTO/413791/audio: 1 channels, 16 bit, sampled @ 22.05 kHz, 32.522s long)  [-0.023570819663425443, 0.022148507774318302, -0.07417874173424731, -0.0728416368560942, -0.029449822397438895, -0.021442868106794754, 0.005492520987350125, -0.11325965405199301, 0.156443566839175...  <features.Melspectro object at 0x14153c3c8>
# 413790  df_cell_display(value=<IPython.core.display.HTML object>)      xc    SPTO   Spotted Towhee          SPTO      59.619       2.507    1314588    audio  Spotted Towhee - SPTO  xc/data/SPTO/413790/audio  xc/data/SPTO/413790/audio.mp3        True  megalonyx     Steve Hampton  United States                                          Hidden Hills, CA  34.164 -118.647  song       A 2018-05-05  09:00     by-nc-sa            4.0  //creativecommons.org/licenses/by-nc-sa/4.0/  https://www.xeno-canto.org/413790  //www.xeno-canto.org/413790/download                no            no     280 m  [House Finch (Haemorhous mexicanus), Cassin's Kingbird (Tyrannus vociferans), Bewick's Wren (Thryomanes bewickii), Mourning Dove (Zenaida macroura)]  Not specified  Not specified  Not specified  Not specified   Not specified  Not specified  1 (mono)    44100 (Hz)    90599 (bps)                       CA                     Hidden Hills                       CA, United States                                          Hidden Hills, CA, United States  2018      5     05-05     9  [HOFI, CAKI, BEWR, MODO]                     4                       df_cell_stack(value=['Hidden Hills'])                       df_cell_stack(value=['CA'])                                            df_cell_stack(value=['Hidden Hills', 'CA', 'United States'])                       df_cell_stack(value=['CA', 'United States'])  df_cell_stack(value=['HOFI', 'CAKI', 'BEWR', 'MODO'])  df_cell_stack(value=[])   box(unbox=xc/data/SPTO/413790/audio: 1 channels, 16 bit, sampled @ 22.05 kHz, 59.619s long)  [0.010582395745784207, 0.04990155478302545, -0.1892398931082032, -0.0633248748777787, -0.028309703064592358, 0.24543011362808895, -0.0018720530197310543, -0.15192491931624816, 0.044969360704747725...  <features.Melspectro object at 0x13dc93dd8>

# %%
xc_species_html(
    species='SPTO',
    limit=8,
)
# Out:
# [21:15:12.097] INFO   [2/3 slower] Loading xc.metadata -> xc_raw_recs (.audio, more metadata)...
# [21:15:12.125] INFO   [3/3 slowest] Featurizing xc_raw_recs -> xc_recs (.audio, .feat, .spectro)...
# [21:15:12.128] DEBUG  Load.audio:in
#   len(recs): 8
#   len(recs) per dataset: {xc: 8}
# audio: [
# ] |   0% Completed |  0.0s
# audio: [
# #####################################################################################
# ] | 100% Completed |  0.1s
# [21:15:12.248] DEBUG  Load.audio:out
#   len(audio): 8
# [21:15:12.274] DEBUG  Features.spectros:in
#   len(recs): 8
#   len(recs) per dataset: {xc: 8}
#   sum(duration_h): 0.167
#   sum(samples_mb): 25.2
#   sum(samples_n): 13216776
# spectro: [
# ] |   0% Completed |  0.0s
# spectro: [
# ###################################################################################
# ] | 100% Completed |  0.1s
# [21:15:12.407] DEBUG  Features.spectros:out
#   (f, sum(t)): [40, 51616]
# plot_thumb.many: [
# ] |   0% Completed |  0.0s
# plot_thumb.many: [
# #########
# ] |  12% Completed |  0.1s
# plot_thumb.many: [
# ############################################################
# ] |  81% Completed |  0.2s
# plot_thumb.many: [
# ###########################################################################
# ] | 100% Completed |  0.3s
# plot_spectro_micro.many: [
# ] |   0% Completed |  0.0s
# plot_spectro_micro.many: [
# ] |   0% Completed |  0.1s
# plot_spectro_micro.many: [
# ###################################################################
# ] | 100% Completed |  0.2s
#                                                       xc_id quality                                                      thumb                                                      micro
# 0  <a href="https://www.xeno-canto.org/413996">XC413996</a>       A  df_cell_display(value=<IPython.core.display.HTML object>)  df_cell_display(value=<IPython.core.display.HTML object>)
# 1  <a href="https://www.xeno-canto.org/413791">XC413791</a>       A  df_cell_display(value=<IPython.core.display.HTML object>)  df_cell_display(value=<IPython.core.display.HTML object>)
# 2  <a href="https://www.xeno-canto.org/413790">XC413790</a>       A  df_cell_display(value=<IPython.core.display.HTML object>)  df_cell_display(value=<IPython.core.display.HTML object>)
# 3  <a href="https://www.xeno-canto.org/413023">XC413023</a>       B  df_cell_display(value=<IPython.core.display.HTML object>)  df_cell_display(value=<IPython.core.display.HTML object>)
# 4  <a href="https://www.xeno-canto.org/413017">XC413017</a>       A  df_cell_display(value=<IPython.core.display.HTML object>)  df_cell_display(value=<IPython.core.display.HTML object>)
# 5  <a href="https://www.xeno-canto.org/413006">XC413006</a>       A  df_cell_display(value=<IPython.core.display.HTML object>)  df_cell_display(value=<IPython.core.display.HTML object>)
# 6  <a href="https://www.xeno-canto.org/412854">XC412854</a>       B  df_cell_display(value=<IPython.core.display.HTML object>)  df_cell_display(value=<IPython.core.display.HTML object>)
# 7  <a href="https://www.xeno-canto.org/412849">XC412849</a>       B  df_cell_display(value=<IPython.core.display.HTML object>)  df_cell_display(value=<IPython.core.display.HTML object>)
