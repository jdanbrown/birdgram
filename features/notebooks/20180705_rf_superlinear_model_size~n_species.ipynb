# %%
from notebooks import *
print_sys_info()
# Out:
# platform:
#   machine: x86_64
#   node: Dan-B.local
#   processor: i386
#   release: 15.6.0
#   system: Darwin
#   version: 'Darwin Kernel Version 15.6.0: Thu Jun 23 18:25:34 PDT 2016; root:xnu-3248.60.10~1/RELEASE_X86_64'
# cpu: 8
# mem: 16g
# swap: 18g

# %%
# Load models
load = Load()
projection = Projection.load('peterson-v0-26bae1c', features=Features(load=load))
# Out:
# [03:44:07.716] DEBUG  Projection.load
#   path: /Users/danb/hack/bubo/features/data/models/projection/peterson-v0-26bae1c.pkl

# %%
# Select recs
#   1. countries: Filter recs to these countries
#   2. com_names: Filter recs to these species
#   3. recs_at_least: Filter species to those with at least this many recs
#   4. num_species: Sample this many of the species
#   5. num_recs: Sample this many recs per species
get_recs_stats = lambda df: dict(sp=df.species.nunique(), recs=len(df))
puts_stats = lambda desc: partial(tap, f=lambda df: print('%-15s %12s (sp/recs)' % (desc, '%(sp)s/%(recs)s' % get_recs_stats(df))))
countries, com_names = countries_na, com_names_ca  # 9.4k/400k -> 1.1k/60k -> 334/35k
# recs_at_least, num_species, num_recs = 100, 100, 100  # ca[334/35k -> 127/25k -> 100/21k -> 100/10k   -> 100/10k]
# recs_at_least, num_species, num_recs =  50, 100, 100  # ca[334/35k -> 224/32k -> 100/16k -> 100/ 9.0k -> 100/ 9.0k]
# recs_at_least, num_species, num_recs =   0, 100, 100  # ca[334/35k -> 334/35k -> 100/12k -> 100/ 6.8k ->  99/ 6.8k]
# recs_at_least, num_species, num_recs =   0, 168, 100  # ca[334/34k -> 334/34k -> 168/18k -> 168/11k   -> 167/11k]    # (old 'all')
# recs_at_least, num_species, num_recs =   0, 168,  20  # ca[334/34k -> 334/35k -> 168/18k -> 168/ 3.2k -> 167/ 3.2k]  # (old 'recs')
recs_at_least, num_species, num_recs =  20, 168,  20    # ca[334/35k -> 296/35k -> 168/20k -> 168/ 3.4k -> 168/ 3.4k]  # (old 'recs')
# recs_at_least, num_species, num_recs =  20, 50,  100  # Faster dev
# recs_at_least, num_species, num_recs =  20, 50,  50   # Faster dev
# recs_at_least, num_species, num_recs =  20, 50,  20   # Faster dev
# recs_at_least, num_species, num_recs =  20, 50,  10   # Faster dev
# recs_at_least, num_species, num_recs =  20, 50,  5    # Faster dev
xcs = (xc.metadata
    .pipe(puts_stats('all'))
    # 1. countries: Filter recs to these countries
    [lambda df: df.country.isin(countries)]
    .pipe(puts_stats('countries'))
    # 2. com_names: Filter recs to these species
    [lambda df: df.com_name.isin(com_names)]
    .pipe(puts_stats('com_names'))
    # Omit not-downloaded recs (should be few within the selected countries)
    [lambda df: df.downloaded]
    .pipe(puts_stats('(downloaded)'))
    # Remove empty cats for perf
    .pipe(df_remove_unused_categories)
    # 3. recs_at_least: Filter species to those with at least this many recs
    [lambda df: df.species.isin(df.species.value_counts()[lambda s: s >= recs_at_least].index)]
    .pipe(puts_stats('recs_at_least'))
    # 4. num_species: Sample this many of the species
    [lambda df: df.species.isin(df.species.drop_duplicates().pipe(lambda s: s.sample(n=min(len(s), num_species), random_state=0)))]
    .pipe(puts_stats('num_species'))
    # 5. num_recs: Sample this many recs per species
    #   - Remove empty cats else .groupby fails on empty groups
    .pipe(df_remove_unused_categories)
    .groupby('species').apply(lambda g: g.sample(n=min(len(g), num_recs), random_state=0))
    .pipe(puts_stats('num_recs'))
    # Drop species with <2 recs, else StratifiedShuffleSplit complains (e.g. 'TUVU')
    [lambda df: df.species.isin(df.species.value_counts()[lambda s: s >= 2].index)]
    .pipe(puts_stats('recs ≥ 2'))
    # Clean up for downstream
    .pipe(df_remove_unused_categories)
)
_recs_stats = get_recs_stats(xcs)
recs_stats = ', '.join(['%s[%s]' % (k, v) for k, v in _recs_stats.items()])
display(
    recs_stats,
    df_summary(xcs).T,
    xcs.sample(n=10, random_state=0).sort_values('species'),
)
# Out:
# all              9442/399859 (sp/recs)
# countries         1148/59713 (sp/recs)
# com_names          334/35236 (sp/recs)
# (downloaded)       334/35232 (sp/recs)
# recs_at_least      296/34846 (sp/recs)
# num_species        168/19640 (sp/recs)
# num_recs            168/3360 (sp/recs)
# recs ≥ 2            168/3360 (sp/recs)
# 'sp[168], recs[3360]'
#                                                                                                                          min                                               25%                                           50%                                                  75%                                        max
#                dtype          sizeof len  count nunique mean        std
# downloaded     bool           94080  3360 3360  1       NaN         NaN                                                 True                                              True                                          True                                                 True                                       True
# species        category       178080 3360 3360  168     NaN         NaN                                                 GWFG                                              GBTE                                          REVI                                                 NOWA                                       AMGO
# id             int64          94080  3360 3360  3360     213283.439 108055.964                                          1133                                            138144                                        193564                                               308285                                     416744
# sci_name       category       227200 3360 3360  168     NaN         NaN                                      Anser albifrons                             Gelochelidon nilotica                               Vireo olivaceus                              Parkesia noveboracensis                             Spinus tristis
# com_name       category       220320 3360 3360  168     NaN         NaN                          Greater White-fronted Goose                                  Gull-billed Tern                                Red-eyed Vireo                                 Northern Waterthrush                         American Goldfinch
# subspecies     object         180915 3360 3360  205     NaN         NaN                                                                                                                                                                                                                                              zaboria
# recordist      object         212323 3360 3360  291     NaN         NaN                                              AJ Knue                                     Frank Lambert                          Matthias Feuersenger                                        Peter Boesman                                   tetiaroa
# country        object         203315 3360 3360  3       NaN         NaN                                               Canada                                     United States                                 United States                                        United States                              United States
# locality       object         321587 3360 3360  1740    NaN         NaN                Bahía la Ventosa, Salina Cruz, Oaxaca  Desert Beeline Highway, Maricopa County, Arizona             May Lake, Yosemite NP, California  Sabine Nature Trail loop, Cameron Parish, Louisiana                          west of Thorp, WA
# lat            float64        80640  3360 3308  1768     37.885     9.895                                               15.6                                              31.9                                          35.8                                                 43.8                                       71.3
# lng            float64        80640  3360 3308  1782    -107.691    19.351                                              -177                                              -118                                          -110                                                  -95                                        -54
# type           object         191757 3360 3360  339     NaN         NaN                                   "chekurrrrrr" call                                              call                                    call, male                                                 song                                   wipe-out
# quality        category       194711 3360 3360  6       NaN         NaN                                                    A                                                 A                                             B                                                    B                                   no score
# date           datetime64[ns] 430080 3360 3360  1569    NaN         NaN                                  1985-06-25 00:00:00                               2011-09-28 00:00:00                           2013-09-18 00:00:00                                  2015-06-12 00:00:00                        2018-05-23 00:00:00
# time           object         181020 3360 3360  896     NaN         NaN                                                    ?                                              0820                                       10:00am                                                 1513                                         am
# license_type   category       191388 3360 3360  3       NaN         NaN                                             by-nc-nd                                          by-nc-nd                                      by-nc-sa                                             by-nc-sa                                      by-sa
# license_detail category       174720 3360 3360  3       NaN         NaN                                                  2.5                                               3.0                                           4.0                                                  4.0                                        4.0
# license        object         313236 3360 3360  7       NaN         NaN         //creativecommons.org/licenses/by-nc-nd/2.5/      //creativecommons.org/licenses/by-nc-nd/4.0/  //creativecommons.org/licenses/by-nc-sa/4.0/         //creativecommons.org/licenses/by-nc-sa/4.0/  //creativecommons.org/licenses/by-sa/4.0/
# url            object         275706 3360 3360  3360    NaN         NaN                    https://www.xeno-canto.org/100121                 https://www.xeno-canto.org/160005             https://www.xeno-canto.org/236694                     https://www.xeno-canto.org/34583           https://www.xeno-canto.org/99812
# download       object         285846 3360 3360  3360    NaN         NaN                 //www.xeno-canto.org/100121/download              //www.xeno-canto.org/160005/download          //www.xeno-canto.org/236694/download                  //www.xeno-canto.org/34583/download        //www.xeno-canto.org/99812/download
#                 downloaded species      id               sci_name                 com_name    subspecies           recordist        country                                                                    locality     lat      lng                           type   quality       date   time license_type license_detail                                       license                                url                              download
# species
# COGA    205189        True    COGA  207451      Gallinula galeata         Common Gallinule  sandvicensis       Ross Gallardy  United States                                             Kailua, Honolulu County, Hawaii  21.391 -157.743                           call         B 2014-12-21  07:30     by-nc-sa            4.0  //creativecommons.org/licenses/by-nc-sa/4.0/  https://www.xeno-canto.org/207451  //www.xeno-canto.org/207451/download
# INDO    18832         True    INDO  398616         Columbina inca                Inca Dove                  Manuel Grosselet         Mexico                                 Lomas de Bezares Miguel Hidalgo Mexico city  19.391  -99.244                           song         B 2018-01-07  08:00     by-nc-sa            4.0  //creativecommons.org/licenses/by-nc-sa/4.0/  https://www.xeno-canto.org/398616  //www.xeno-canto.org/398616/download
# EWPW    223194        True    EWPW  188611  Antrostomus vociferus   Eastern Whip-poor-will                 David Jonas Weber  United States                                 Gravelly Hill Rd., Salem County, New Jersey  39.495  -75.355                           song         C 2014-07-25  05:30     by-nc-sa            4.0  //creativecommons.org/licenses/by-nc-sa/4.0/  https://www.xeno-canto.org/188611  //www.xeno-canto.org/188611/download
# NUWO    113835        True    NUWO  301366     Picoides nuttallii     Nuttall's Woodpecker                      Denise Wight  United States                                     Moraga, Contra Costa County, California  37.832 -122.134  Hawk mobbing call, alarm call         C 2016-01-25  10:00     by-nc-sa            4.0  //creativecommons.org/licenses/by-nc-sa/4.0/  https://www.xeno-canto.org/301366  //www.xeno-canto.org/301366/download
# BBWO    80808         True    BBWO  335436      Picoides arcticus  Black-backed Woodpecker                Lance A. M. Benner  United States                              Blackrock Trailhead, Tulare County, California  36.175 -118.270                 drumming, male  no score 2016-09-17  16:41     by-nc-sa            4.0  //creativecommons.org/licenses/by-nc-sa/4.0/  https://www.xeno-canto.org/335436  //www.xeno-canto.org/335436/download
# HUVI    117936        True    HUVI  297126          Vireo huttoni           Hutton's Vireo                       Paul Marvin  United States                            Kickapoo Cavern State Park, Brackettville, Texas  29.618 -100.451                           song         C 2012-04-08  07:58     by-nc-sa            4.0  //creativecommons.org/licenses/by-nc-sa/4.0/  https://www.xeno-canto.org/297126  //www.xeno-canto.org/297126/download
# MGWA    89731         True    MGWA  326299     Geothlypis tolmiei   MacGillivray's Warbler                Lance A. M. Benner  United States  Buckhorn Campground, San Gabriel Mountains, Los Angeles County, California  34.346 -117.915                     male, song  no score 2016-06-28  10:49     by-nc-sa            4.0  //creativecommons.org/licenses/by-nc-sa/4.0/  https://www.xeno-canto.org/326299  //www.xeno-canto.org/326299/download
# PUFI    159786        True    PUFI  254326   Haemorhous purpureus             Purple Finch                              Iain         Canada                             Algonquin Highlands, Haliburton County, Ontario  45.306  -78.809                           song         C 2015-06-27  11:00     by-nc-sa            4.0  //creativecommons.org/licenses/by-nc-sa/4.0/  https://www.xeno-canto.org/254326  //www.xeno-canto.org/254326/download
# CAFI    46804         True    CAFI  369971    Haemorhous cassinii           Cassin's Finch                      Eric DeFonso  United States          Dunton Rd area, San Juan National Forest, Dolores County, Colorado  37.780 -108.040                           song         A 2016-06-28  15:00     by-nc-sa            4.0  //creativecommons.org/licenses/by-nc-sa/4.0/  https://www.xeno-canto.org/369971  //www.xeno-canto.org/369971/download
# AMGO    256886        True    AMGO  153552         Spinus tristis       American Goldfinch                  Mike Schanbacher  United States                                         Falmouth, Barnstable, Massachusetts  41.522  -70.668                     call, male         B 2013-05-01  12:00     by-nc-sa            3.0  //creativecommons.org/licenses/by-nc-sa/3.0/  https://www.xeno-canto.org/153552  //www.xeno-canto.org/153552/download

# %%
xcs_paths = [
    ('xc', f'{data_dir}/xc/data/{row.species}/{row.id}/audio.mp3')
    for row in df_rows(xcs)
]
joblib.dump(xcs_paths, '/tmp/xcs_paths')  # In case you want to run load.recs in a terminal (it's long and verbose)
display(
    len(xcs_paths),
    # xcs_paths[:2],
)
# Out:
# 3360

# %%
# TODO Restore once:true after debug [but think carefully how once:true interacts with the once:false params above]
recs = load.recs(paths=xcs_paths)
display(
    df_summary(recs).T,
    recs[:5],
)
# Out:
#                                                                                                         min                           25%                           50%                            75%                           max
#                  dtype    sizeof len  count nunique mean      std
# dataset          object   171360 3360 3360  1       NaN       NaN                                        xc                            xc                            xc                             xc                            xc
# species          category 178080 3360 3360  168     NaN       NaN                                      GWFG                          GBTE                          REVI                           NOWA                          AMGO
# species_com_name category 219160 3360 3360  168     NaN       NaN               Greater White-fronted Goose              Gull-billed Tern                Red-eyed Vireo           Northern Waterthrush            American Goldfinch
# species_query    object   178080 3360 3360  168     NaN       NaN                                      ACWO                          CONI                          LASP                           RIRA                          YRWA
# duration_s       float64  80640  3360 3360  3054    5.430e+01 7.031e+01                               0.697                          14.4                          31.8                           65.4                           940
# samples_mb       float64  80640  3360 3360  3055    2.286e+00 2.958e+00                              0.0293                         0.604                          1.34                           2.76                          39.5
# samples_n        int64    94080  3360 3360  3055    1.198e+06 1.551e+06                               15368                        316510                        701190                        1444435                      20731931
# basename         object   181440 3360 3360  1       NaN       NaN                                     audio                         audio                         audio                          audio                         audio
# species_longhand category 242680 3360 3360  168     NaN       NaN        Greater White-fronted Goose - GWFG       Gull-billed Tern - GBTE         Red-eyed Vireo - REVI    Northern Waterthrush - NOWA     American Goldfinch - AMGO
# id               object   248154 3360 3360  3360    NaN       NaN                 xc/data/ACWO/153315/audio      xc/data/CONI/77526/audio      xc/data/LASP/72200/audio      xc/data/RIRA/408562/audio      xc/data/YRWA/78150/audio
# path             object   261594 3360 3360  3360    NaN       NaN             xc/data/ACWO/153315/audio.mp3  xc/data/CONI/77526/audio.mp3  xc/data/LASP/72200/audio.mp3  xc/data/RIRA/408562/audio.mp3  xc/data/YRWA/78150/audio.mp3
#   dataset species             species_com_name species_query  duration_s  samples_mb  samples_n basename                    species_longhand                         id                           path
# 0      xc    GWFG  Greater White-fronted Goose          GWFG      23.712       0.997     522850    audio  Greater White-fronted Goose - GWFG  xc/data/GWFG/149379/audio  xc/data/GWFG/149379/audio.mp3
# 1      xc    GWFG  Greater White-fronted Goose          GWFG      18.312       0.770     403780    audio  Greater White-fronted Goose - GWFG  xc/data/GWFG/276918/audio  xc/data/GWFG/276918/audio.mp3
# 2      xc    GWFG  Greater White-fronted Goose          GWFG      44.957       1.891     991296    audio  Greater White-fronted Goose - GWFG  xc/data/GWFG/210100/audio  xc/data/GWFG/210100/audio.mp3
# 3      xc    GWFG  Greater White-fronted Goose          GWFG      17.554       0.738     387072    audio  Greater White-fronted Goose - GWFG  xc/data/GWFG/323113/audio  xc/data/GWFG/323113/audio.mp3
# 4      xc    GWFG  Greater White-fronted Goose          GWFG      23.952       1.007     528142    audio  Greater White-fronted Goose - GWFG  xc/data/GWFG/276919/audio  xc/data/GWFG/276919/audio.mp3

# %%
# Fast-and-cheap version (<1s) of the plot below (7s)
(recs
    .species_longhand.value_counts().sort_index()
    .reset_index().rename(columns={'index': 'species_longhand', 'species_longhand': 'num_recs'})
    .assign(num_recs=lambda df: df.num_recs.map(lambda n: '%s /%s' % ('•' * int(n / df.num_recs.max() * 60), df.num_recs.max())))
)
# Out:
#                          species_longhand                                                          num_recs
# 0      Greater White-fronted Goose - GWFG  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 1                          Gadwall - GADW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 2                  American Wigeon - AMWI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 3                          Mallard - MALL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 4                Green-winged Teal - GWTE  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 5                 California Quail - CAQU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 6                   Gambel's Quail - GAQU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 7                     Sooty Grouse - SOGR  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 8                      Wild Turkey - WITU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 9                      Common Loon - COLO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 10                Red-necked Grebe - RNGR  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 11          Black-footed Albatross - BFAL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 12        Double-crested Cormorant - DCCO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 13                American Bittern - AMBI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 14                   Least Bittern - LEBI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 15                Great Blue Heron - GBHE  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 16                     Great Egret - GREG  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 17                     Snowy Egret - SNEG  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 18                          Osprey - OSPR  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 19                 Swainson's Hawk - SWHA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 20                 Red-tailed Hawk - RTHA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 21                      Black Rail - BLRA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 22                  Ridgway's Rail - RIRA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 23                Common Gallinule - COGA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 24              Black-necked Stilt - BNST  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 25             Black Oystercatcher - BLOY  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 26             Semipalmated Plover - SEPL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 27                        Whimbrel - WHIM  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 28              Long-billed Curlew - LBCU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 29                  Rock Sandpiper - ROSA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 30                 Least Sandpiper - LESA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 31           Long-billed Dowitcher - LBDO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 32            Red-necked Phalarope - RNPH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 33              Greater Yellowlegs - GRYE  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 34                Bonaparte's Gull - BOGU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 35                   Laughing Gull - LAGU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 36                 Heermann's Gull - HEEG  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 37                Ring-billed Gull - RBGU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 38                    Western Gull - WEGU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 39                 California Gull - CAGU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 40            Glaucous-winged Gull - GWGU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 41                Gull-billed Tern - GBTE  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 42                    Caspian Tern - CATE  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 43                      Black Tern - BLTE  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 44                      Royal Tern - ROYT  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 45              Band-tailed Pigeon - BTPI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 46                       Inca Dove - INDO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 47              Common Ground-Dove - COGD  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 48            Yellow-billed Cuckoo - YBCU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 49                        Barn Owl - BANO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 50                Great Horned Owl - GHOW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 51                         Elf Owl - ELOW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 52                     Spotted Owl - SPOW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 53                Lesser Nighthawk - LENI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 54                Common Nighthawk - CONI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 55                 Common Poorwill - COPO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 56          Eastern Whip-poor-will - EWPW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 57          Mexican Whip-poor-will - MWPW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 58            White-throated Swift - WTSW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 59       Black-chinned Hummingbird - BCHU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 60        Broad-tailed Hummingbird - BTAH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 61                Acorn Woodpecker - ACWO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 62          Williamson's Sapsucker - WISA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 63          Red-breasted Sapsucker - RBSA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 64        Ladder-backed Woodpecker - LBWO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 65            Nuttall's Woodpecker - NUWO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 66                Hairy Woodpecker - HAWO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 67         White-headed Woodpecker - WHWO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 68         Black-backed Woodpecker - BBWO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 69                Northern Flicker - NOFL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 70              Western Wood-Pewee - WEWP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 71                Least Flycatcher - LEFL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 72                 Gray Flycatcher - GRFL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 73                Dusky Flycatcher - DUFL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 74        Pacific-slope Flycatcher - PSFL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 75                  Eastern Phoebe - EAPH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 76                    Say's Phoebe - SAPH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 77            Vermilion Flycatcher - VEFL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 78         Dusky-capped Flycatcher - DCFL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 79               Tropical Kingbird - TRKI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 80                Couch's Kingbird - COKI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 81                  Hutton's Vireo - HUVI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 82                  Warbling Vireo - WAVI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 83                  Red-eyed Vireo - REVI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 84              Yellow-green Vireo - YGVI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 85                        Gray Jay - GRAJ  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 86                      Pinyon Jay - PIJA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 87                   Steller's Jay - STJA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 88            California Scrub-Jay - CASJ  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 89           Woodhouse's Scrub-Jay - WOSJ  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 90              Clark's Nutcracker - CLNU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 91                    Common Raven - CORA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 92   Northern Rough-winged Swallow - NRWS  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 93                   Purple Martin - PUMA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 94            Violet-green Swallow - VGSW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 95                   Cliff Swallow - CLSW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 96              Mountain Chickadee - MOCH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 97       Chestnut-backed Chickadee - CBCH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 98                          Verdin - VERD  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 99                         Bushtit - BUSH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 100          Red-breasted Nuthatch - RBNU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 101                      Rock Wren - ROWR  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 102                    Canyon Wren - CANW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 103                    Winter Wren - WIWR  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 104                     Marsh Wren - MAWR  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 105                  Bewick's Wren - BEWR  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 106                    Cactus Wren - CACW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 107         California Gnatcatcher - CAGN  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 108       Black-tailed Gnatcatcher - BTGN  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 109                American Dipper - AMDI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 110           Ruby-crowned Kinglet - RCKI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 111               Western Bluebird - WEBL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 112              Mountain Bluebird - MOBL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 113           Townsend's Solitaire - TOSO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 114              Swainson's Thrush - SWTH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 115                  Hermit Thrush - HETH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 116                 American Robin - AMRO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 117                   Gray Catbird - GRCA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 118             Bendire's Thrasher - BETH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 119             LeConte's Thrasher - LCTH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 120               Crissal Thrasher - CRTH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 121              European Starling - EUST  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 122                 American Pipit - AMPI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 123                    Phainopepla - PHAI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 124               Lapland Longspur - LALO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 125           Northern Waterthrush - NOWA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 126         Orange-crowned Warbler - OCWA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 127                 Lucy's Warbler - LUWA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 128              Nashville Warbler - NAWA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 129         MacGillivray's Warbler - MGWA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 130            Common Yellowthroat - COYE  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 131                 Hooded Warbler - HOWA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 132                Northern Parula - NOPA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 133         Chestnut-sided Warbler - CSWA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 134          Yellow-rumped Warbler - YRWA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 135                Prairie Warbler - PRAW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 136                Grace's Warbler - GRWA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 137                 Hermit Warbler - HEWA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 138               Cassin's Sparrow - CASP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 139          Black-chinned Sparrow - BCSP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 140         Black-throated Sparrow - BTSP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 141                   Lark Sparrow - LASP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 142                    Fox Sparrow - FOSP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 143          White-crowned Sparrow - WCSP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 144         Golden-crowned Sparrow - GCSP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 145         White-throated Sparrow - WTSP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 146                 Vesper Sparrow - VESP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 147                   Song Sparrow - SOSP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 148              Lincoln's Sparrow - LISP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 149         Rufous-crowned Sparrow - RCSP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 150           Yellow-breasted Chat - YBCH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 151                Western Tanager - WETA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 152              Northern Cardinal - NOCA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 153         Rose-breasted Grosbeak - RBGR  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 154                 Indigo Bunting - INBU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 155        Yellow-headed Blackbird - YHBL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 156                 Scott's Oriole - SCOR  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 157           Red-winged Blackbird - RWBL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 158             Brewer's Blackbird - BRBL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 159           Great-tailed Grackle - GTGR  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 160                  Pine Grosbeak - PIGR  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 161                    House Finch - HOFI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 162                   Purple Finch - PUFI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 163                 Cassin's Finch - CAFI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 164                    Pine Siskin - PISI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 165               Lesser Goldfinch - LEGO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 166           Lawrence's Goldfinch - LAGO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 167             American Goldfinch - AMGO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20

# %%
(recs
    .assign(species=lambda df: df.species_longhand)
    .assign(count=1)
    # 0-fill all (species, dataset) combinations to create empty placeholders for missing bars
    .pipe(lambda df: df.append(
        pd.DataFrame([
            dict(species=species, dataset=dataset, duration_s=0)
            for species in df.species.unique()
            for dataset in df.dataset.unique()
        ])
        .astype({'species': df.species.dtype})
    ))
    .groupby(['dataset', 'species'])[['count', 'duration_s']].sum().reset_index()
    # Order by species by taxo
    .pipe(df_reverse_cat, 'species')
    # Order by species by count
    # .pipe(df_ordered_cat, species=lambda df: df.sort_values('count').species)
    .pipe(pd.melt, id_vars=['dataset', 'species'], value_vars=['count', 'duration_s'])
    .pipe(df_remove_unused_categories)
    .pipe(ggplot, aes(x='species', y='value', fill='dataset', color='dataset'))
    + coord_flip()
    + geom_bar(stat='identity', position=position_dodge(), width=.8)
    + facet_wrap('variable', nrow=1, scales='free')
    + xlab('')
    + ylab('')
    + scale_fill_cmap_d(mpl.cm.tab10)
    + scale_color_cmap_d(mpl.cm.tab10)
    + theme(panel_spacing=2.5)
    + theme_figsize(width=18, aspect_ratio=4/1)
    + ggtitle(f'recs: Total (count, duration_s) per (species, dataset)')
)
# Out:
# [skip]

# %%
# Add .feat
recs = projection.transform(recs)

# %%
# GridSearchCV many models / model params
#   - Order these roughly from most to least expensive, so that training runs fail fast (e.g. oom at the start, not the end)
param_grid = [
    dict(
        classifier=[

            # RandomForest(entropy)
            #   - [SP14] uses entropy
            # 'cls: rf, criterion: entropy, n_estimators: 1000',
            # 'cls: rf, criterion: entropy, n_estimators: 800',
            # 'cls: rf, criterion: entropy, n_estimators: 400',
            # 'cls: rf, criterion: entropy, n_estimators: 200',  # [SP14]
            # 'cls: rf, criterion: entropy, n_estimators: 100',
            # 'cls: rf, criterion: entropy, n_estimators: 50',
            # 'cls: rf, criterion: entropy, n_estimators: 10',

            # lightgbm
            # 'cls: lgbm, n_estimators: 100, learning_rate: .01, min_child_samples: 1',
            # 'cls: lgbm, n_estimators: 50,  learning_rate: .01, min_child_samples: 1',
            # 'cls: lgbm, n_estimators: 10,  learning_rate: .01, min_child_samples: 1',
            # 'cls: lgbm, n_estimators: 100, learning_rate: .1,  min_child_samples: 1',
            # 'cls: lgbm, n_estimators: 50,  learning_rate: .1,  min_child_samples: 1',
            # 'cls: lgbm, n_estimators: 10,  learning_rate: .1,  min_child_samples: 1',
            # 'cls: lgbm, n_estimators: 100, learning_rate: .5,  min_child_samples: 1',
            # 'cls: lgbm, n_estimators: 100, learning_rate: 1.,  min_child_samples: 1',
            # 'cls: lgbm, n_estimators: 50,  learning_rate: 1.,  min_child_samples: 1',
            # 'cls: lgbm, n_estimators: 10,  learning_rate: 1.,  min_child_samples: 1',

            # 'cls: lgbm, n_estimators: 25, learning_rate: .016, min_child_samples: 1',
            # 'cls: lgbm, n_estimators: 25, learning_rate: .032, min_child_samples: 1',
            # 'cls: lgbm, n_estimators: 25, learning_rate: .064, min_child_samples: 1',
            # 'cls: lgbm, n_estimators: 25, learning_rate: .128, min_child_samples: 1',
            # 'cls: lgbm, n_estimators: 25, learning_rate: .256, min_child_samples: 1',
            # 'cls: lgbm, n_estimators: 25, learning_rate: .512, min_child_samples: 1',

            # RandomForest(gini)
            #   - sk uses gini by default

            # WARNING These two are not very mem safe...
            #   - They finish, but they cause OSX to "Not responding" most/all of its apps at ~2-3 different times
            # 'cls: rf, criterion: gini, n_estimators: 2000',
            # 'cls: rf, criterion: gini, n_estimators: 1500',

            # 'cls: rf, criterion: gini, n_estimators: 1000',
            # 'cls: rf, criterion: gini, n_estimators: 800',
            # 'cls: rf, criterion: gini, n_estimators: 600',
            # 'cls: rf, criterion: gini, n_estimators: 400',
            'cls: rf, criterion: gini, n_estimators: 200',
            'cls: rf, criterion: gini, n_estimators: 100',
            # 'cls: rf, criterion: gini, n_estimators: 50',
            # 'cls: rf, criterion: gini, n_estimators: 10',  # [sk default]
            # 'cls: rf, criterion: gini, n_estimators: 1',  # Faster dev

        ],
        n_species=[int(n_species * _recs_stats['sp'])],
        n_recs=[
            # int(n_recs * _recs_stats['recs']),
            n_recs,  # TODO Figure out how to represent this as an n instead of a frac again [TODO interaction with test_size=.2 ...]
        ],
    )
    for (n_species, n_recs) in [
        # Subset for learning curves
        #   - Biggest first, to fail fast
        # (None, None),
        (1.00, 1.00),
        (1.00, 0.50),
        (0.80, 1.00),
        (0.80, 0.50),
        (0.60, 1.00),
        (0.60, 0.50),
        (0.40, 1.00),
        (0.40, 0.50),
        (0.20, 1.00),
        (0.20, 0.50),
    ]
]

# TODO Increase cv to decrease variance in eval metrics (this made Alex extremely squirmy)
cv = GridSearchCVCached(
    estimator=Search(projection=projection),
    param_grid=param_grid,
    refit=False,  # Don't spend time fitting cv.best_estimator_ at the end (default: True)
    # cv=3,  # [SP14] uses two-/three-fold CV [why?]
    # Stratified ensures that all classes have >0 instances in each split, which is statistically maybe fishy but avoids
    # breaking various code that merges the split results back together and assumes all splits' classes are the same
    cv=sk.model_selection.StratifiedShuffleSplit(
        n_splits=1,  # [for ~18/20 miss: ~19m, ~16g disk cache]
        # n_splits=2,
        # n_splits=3,
        # n_splits=5,
        # n_splits=10,
        # n_splits=20,  # Known good [>51m uncached, >25g disk cache]
        # n_splits=100,  # [?m runtime, ?g disk cache]
        test_size=.2,
        random_state=0,
    ),
    return_train_score=True,
    extra_metrics=dict(
        # [How to specify SearchEvals here without creating caching headaches?]
        #   - e.g. defs don't bust cache on code edit
        #   - And avoid thrashing cache every time we refactor SearchEvals
        classes='estimator.classes_',
        train_i='train',
        train_y='y_train',
        train_predict_proba='estimator.classifier_.predict_proba(X_train)',
        test_i='test',
        test_y='y_test',
        test_predict_proba='estimator.classifier_.predict_proba(X_test)',
        model_size='len(joblib_dumps(estimator))',
        proc_stats='proc_stats',
    ),
    # return_estimator=True,  # Verrrry heavy, use extra_metrics instead
    # verbose=100,
    # verbose=10,  # O(models * n_splits) lines of outputs
    verbose=1,  # O(1) lines of outputs
    # Use n_jobs=1
    #   - All classifiers can parallelize .fit/.predict
    #   - Avoid memory contention
    n_jobs=1,  # Required for %prun
    artifacts=dict(
        # Stamp experiment_id once for all calls to _fit_and_score_cached [TODO Re-home this concern]
        experiment_id = '-'.join([datetime.utcnow().strftime('%Y%m%d-%H%M%S'), sha1hex(str(uuid.uuid4()))[:7]]),
        dir=f'{data_dir}/artifacts',  # TODO Iron out syncing across local/gs/remote
        extra=dict(estimator='estimator'),
        save=True,
        # load='20180705-191644-12459af',
    ),
)
with contextlib.ExitStack() as stack:
    # stack.enter_context(cache_control(refresh=True))  # Disk unsafe...
    stack.enter_context(cache_control(enabled=False))  # Disk safe
    # stack.enter_context(joblib.parallel_backend('threading'))  # Default: 'multiprocessing'
    # stack.enter_context(joblib.parallel_backend('sequential'))  # For %prun [FIXME Has no effect; why?]
    stack.enter_context(log.context(level='info'))
    X, y = Search.Xy(recs)
    cv.fit(X, y)
# Out:
# Fitting 1 folds for each of 20 candidates, totalling 20 fits
# [03:44:10.680] INFO   artifacts
#   experiment_id: 20180706-034410-1453b79
#   dir: /Users/danb/hack/bubo/features/data/artifacts
#   extra: {estimator: estimator}
#   save: true
# [03:44:10.686] INFO   _fit_and_score... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200', random_state=0)]
# [03:44:32.573] INFO   _fit_and_score[21.753s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200', random_state=0)]
# [03:44:33.991] INFO   _fit_and_score.save_artifacts... model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200',random_state=0)]
# [03:44:35.885] INFO   _fit_and_score.save_artifacts[1.893s, 701.4 MB]: model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200',random_state=0)]
# [03:44:35.890] INFO   _fit_and_score... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100', random_state=0)]
# [03:44:47.600] INFO   _fit_and_score[11.383s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100', random_state=0)]
# [03:44:48.836] INFO   _fit_and_score.save_artifacts... model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100',random_state=0)]
# [03:44:49.806] INFO   _fit_and_score.save_artifacts[0.970s, 361.7 MB]: model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100',random_state=0)]
# [03:44:49.811] INFO   _fit_and_score... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 200', random_state=0)]
# [03:45:02.378] INFO   _fit_and_score[12.326s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 200', random_state=0)]
# [03:45:03.867] INFO   _fit_and_score.save_artifacts... model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=200',random_state=0)]
# [03:45:04.878] INFO   _fit_and_score.save_artifacts[1.010s, 368.2 MB]: model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=200',random_state=0)]
# [03:45:04.883] INFO   _fit_and_score... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 100', random_state=0)]
# [03:45:11.995] INFO   _fit_and_score[6.878s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 100', random_state=0)]
# [03:45:12.580] INFO   _fit_and_score.save_artifacts... model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=100',random_state=0)]
# [03:45:13.173] INFO   _fit_and_score.save_artifacts[0.592s, 190.4 MB]: model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=100',random_state=0)]
# [03:45:13.179] INFO   _fit_and_score... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=134, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200', random_state=0)]
# [03:45:26.867] INFO   _fit_and_score[13.499s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=134, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200', random_state=0)]
# [03:45:28.224] INFO   _fit_and_score.save_artifacts... model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=134,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200',random_state=0)]
# [03:45:29.487] INFO   _fit_and_score.save_artifacts[1.261s, 441.2 MB]: model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=134,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200',random_state=0)]
# [03:45:29.492] INFO   _fit_and_score... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=134, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100', random_state=0)]
# [03:45:36.969] INFO   _fit_and_score[7.258s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=134, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100', random_state=0)]
# [03:45:38.197] INFO   _fit_and_score.save_artifacts... model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=134,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100',random_state=0)]
# [03:45:38.786] INFO   _fit_and_score.save_artifacts[0.588s, 228.8 MB]: model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=134,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100',random_state=0)]
# [03:45:38.791] INFO   _fit_and_score... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=134, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 200', random_state=0)]
# [03:45:46.892] INFO   _fit_and_score[7.904s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=134, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 200', random_state=0)]
# [03:45:47.660] INFO   _fit_and_score.save_artifacts... model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=134,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=200',random_state=0)]
# [03:45:48.289] INFO   _fit_and_score.save_artifacts[0.628s, 232.7 MB]: model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=134,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=200',random_state=0)]
# [03:45:48.293] INFO   _fit_and_score... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=134, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 100', random_state=0)]
# [03:45:53.195] INFO   _fit_and_score[4.713s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=134, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 100', random_state=0)]
# [03:45:53.874] INFO   _fit_and_score.save_artifacts... model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=134,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=100',random_state=0)]
# [03:45:54.164] INFO   _fit_and_score.save_artifacts[0.289s, 121.2 MB]: model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=134,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=100',random_state=0)]
# [03:45:54.168] INFO   _fit_and_score... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=100, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200', random_state=0)]
# [03:46:02.321] INFO   _fit_and_score[7.979s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=100, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200', random_state=0)]
# [03:46:03.001] INFO   _fit_and_score.save_artifacts... model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=100,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200',random_state=0)]
# [03:46:03.619] INFO   _fit_and_score.save_artifacts[0.618s, 244.5 MB]: model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=100,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200',random_state=0)]
# [03:46:03.625] INFO   _fit_and_score... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=100, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100', random_state=0)]
# [03:46:08.308] INFO   _fit_and_score[4.475s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=100, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100', random_state=0)]
# [03:46:09.233] INFO   _fit_and_score.save_artifacts... model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=100,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100',random_state=0)]
# [03:46:09.590] INFO   _fit_and_score.save_artifacts[0.356s, 128.1 MB]: model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=100,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100',random_state=0)]
# [03:46:09.595] INFO   _fit_and_score... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=100, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 200', random_state=0)]
# [03:46:14.631] INFO   _fit_and_score[4.851s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=100, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 200', random_state=0)]
# [03:46:15.314] INFO   _fit_and_score.save_artifacts... model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=100,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=200',random_state=0)]
# [03:46:15.654] INFO   _fit_and_score.save_artifacts[0.339s, 129.9 MB]: model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=100,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=200',random_state=0)]
# [03:46:15.659] INFO   _fit_and_score... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=100, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 100', random_state=0)]
# [03:46:18.931] INFO   _fit_and_score[3.091s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=100, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 100', random_state=0)]
# [03:46:20.186] INFO   _fit_and_score.save_artifacts... model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=100,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=100',random_state=0)]
# [03:46:20.373] INFO   _fit_and_score.save_artifacts[0.186s, 68.8 MB]: model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=100,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=100',random_state=0)]
# [03:46:20.377] INFO   _fit_and_score... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=67, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200', random_state=0)]
# [03:46:24.793] INFO   _fit_and_score[4.230s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=67, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200', random_state=0)]
# [03:46:25.993] INFO   _fit_and_score.save_artifacts... model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=67,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200',random_state=0)]
# [03:46:26.368] INFO   _fit_and_score.save_artifacts[0.375s, 109.0 MB]: model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=67,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200',random_state=0)]
# [03:46:26.374] INFO   _fit_and_score... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=67, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100', random_state=0)]
# [03:46:29.384] INFO   _fit_and_score[2.828s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=67, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100', random_state=0)]
# [03:46:29.886] INFO   _fit_and_score.save_artifacts... model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=67,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100',random_state=0)]
# [03:46:30.119] INFO   _fit_and_score.save_artifacts[0.233s, 58.6 MB]: model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=67,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100',random_state=0)]
# [03:46:30.128] INFO   _fit_and_score... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=67, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 200', random_state=0)]
# [03:46:33.164] INFO   _fit_and_score[2.865s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=67, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 200', random_state=0)]
# [03:46:33.669] INFO   _fit_and_score.save_artifacts... model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=67,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=200',random_state=0)]
# [03:46:33.861] INFO   _fit_and_score.save_artifacts[0.192s, 58.4 MB]: model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=67,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=200',random_state=0)]
# [03:46:33.865] INFO   _fit_and_score... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=67, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 100', random_state=0)]
# [03:46:36.131] INFO   _fit_and_score[2.080s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=67, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 100', random_state=0)]
# [03:46:37.366] INFO   _fit_and_score.save_artifacts... model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=67,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=100',random_state=0)]
# [03:46:37.499] INFO   _fit_and_score.save_artifacts[0.133s, 31.9 MB]: model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=67,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=100',random_state=0)]
# [03:46:37.504] INFO   _fit_and_score... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=33, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200', random_state=0)]
# [03:46:39.902] INFO   _fit_and_score[2.228s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=33, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200', random_state=0)]
# [03:46:41.028] INFO   _fit_and_score.save_artifacts... model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=33,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200',random_state=0)]
# [03:46:41.166] INFO   _fit_and_score.save_artifacts[0.138s, 27.3 MB]: model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=33,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200',random_state=0)]
# [03:46:41.171] INFO   _fit_and_score... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=33, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100', random_state=0)]
# [03:46:43.129] INFO   _fit_and_score[1.792s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=33, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100', random_state=0)]
# [03:46:43.616] INFO   _fit_and_score.save_artifacts... model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=33,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100',random_state=0)]
# [03:46:43.704] INFO   _fit_and_score.save_artifacts[0.087s, 15.7 MB]: model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=33,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100',random_state=0)]
# [03:46:43.710] INFO   _fit_and_score... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=33, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 200', random_state=0)]
# [03:46:45.709] INFO   _fit_and_score[1.825s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=33, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 200', random_state=0)]
# [03:46:46.198] INFO   _fit_and_score.save_artifacts... model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=33,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=200',random_state=0)]
# [03:46:46.365] INFO   _fit_and_score.save_artifacts[0.167s, 14.7 MB]: model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=33,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=200',random_state=0)]
# [03:46:46.370] INFO   _fit_and_score... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=33, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 100', random_state=0)]
# [03:46:48.103] INFO   _fit_and_score[1.564s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=33, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 100', random_state=0)]
# [03:46:48.820] INFO   _fit_and_score.save_artifacts... model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=33,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=100',random_state=0)]
# [03:46:48.898] INFO   _fit_and_score.save_artifacts[0.078s, 8.6 MB]: model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=33,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=100',random_state=0)]
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:  2.6min finished
# /Users/danb/hack/bubo/features/sk_hack.py:358: RuntimeWarning: invalid value encountered in subtract
#   array_means[:, np.newaxis]) ** 2,

# %%
# Precompute eval metrics + dims for the plots below
#   - Grain: models
#   - Metrics: train_score, test_score, ...
#   - Dims: model_id, params_no_ns, fold, ...
cv_models = (cv_results_splits_df(cv.cv_results_)
    # Slow yaml parsing, compute up front
    .assign(params_dict=lambda df: df.apply(axis=1, func=lambda row: dict(
        **{strip_startswith(k, 'param_'): row[k] for k in df if k.startswith('param_') and k not in ['param_classifier']},
        # HACK 'classifier.foo' -> 'c_foo'
        #   - TODO Refactor Search.classifier to get rid of the yaml strs ('c_cls', 'c_n_estimators', ...)
        **{'c_' + k: v for k, v in yaml.safe_load('{%s}' % row.param_classifier).items()},
        # 'classifier': yaml.safe_load('{%s}' % row.param_classifier),
    )))
    [lambda df: [c for c in df if not c.startswith('param_')]]
    # Dims from params
    .assign(
        # Useful for validation curves (vary params by classifier type)
        # params_no_ns=lambda df: df.params_dict.str['classifier'].apply(lambda x: (
        #     '%s-%s' % (x['cls'], x['criterion']) if x['cls'] == 'rf' else
        #     x['cls']
        # )),
        # Useful for learning curves (vary n_species/n_recs per classifier)
        params_no_ns=lambda df: df.params_dict.apply(lambda d: ', '.join(
            '%s[%s]' % (k, d[k]) for k in d if k not in ['n_species', 'n_recs']
        )),
        ns=lambda df: df.params_dict.apply(lambda d: ', '.join(
            '%s[%s]' % (k, d[k]) for k in ['n_species', 'n_recs']
        )),
    )
    # HACK Convert yaml strs ('x: y') to bracket style ('x[y]'), for visual consistency
    #   - TODO Refactor Search.classifier to get rid of the yaml strs ('c_cls', 'c_n_estimators', ...)
    .applymap(lambda x: x if not isinstance(x, str) else (
        re.sub(r'([^][:, ]+):\s+([^][:,]+)(, )?', r'c_\1[\2]\3',
            re.sub(r'classifier\[([^]]+)\]', r'\1',
                x,
            ),
        )
    ))
    #   - Restore the cats we just destroyed [copied from cv_results_splits_df]
    .pipe(df_ordered_cat,
        model_id=lambda df: df.model_id.unique(),
        params=lambda df: df.params.unique(),
        params_no_ns=lambda df: df.params_no_ns.unique(),
        ns=lambda df: df.ns.unique(),
    )
    # .eval
    .assign(
        train_evals=lambda df: np.vectorize(SearchEvals)(
            i=df.pop('train_i'),
            y=df.pop('train_y'),
            classes=df['classes'],
            y_scores=df.pop('train_predict_proba'),
            drop_missing_classes_for_n_species=True,  # HACK Migrate to sk Pipeline to avoid this
        ),
        test_evals=lambda df: np.vectorize(SearchEvals)(
            i=df.pop('test_i'),
            y=df.pop('test_y'),
            classes=df['classes'],
            y_scores=df.pop('test_predict_proba'),
            drop_missing_classes_for_n_species=True,  # HACK Migrate to sk Pipeline to avoid this
        ),
        # HACK Recompute (train_score, test_score) using SearchEvals.score so it can drop_missing_classes_for_n_species
        #   - Else you'll get scores that are too low (bad) because they include some -np.inf's in the median
        train_score=lambda df: df.train_evals.map(lambda x: x.score()),
        test_score=lambda df: df.test_evals.map(lambda x: x.score()),
    )
    .drop(columns=[
        'classes',
    ])
    # proc_stats
    .assign(
        mem_rss_spread=lambda df: df.proc_stats.map(lambda p: p.df.mem_rss.pipe(lambda s: s.max() - s.min())),
        mem_vms_spread=lambda df: df.proc_stats.map(lambda p: p.df.mem_vms.pipe(lambda s: s.max() - s.min())),
    )
    # Reorder
    .pipe(df_reorder_cols,
        first=['model_id', 'params', 'params_dict', 'params_no_ns', 'ns'],
        last=['train_evals', 'test_evals', 'proc_stats'],
    )
    .pipe(tap, f=lambda df: display(
        df_summary(df).T,
        # df[:5],
        df,
    ))
)
# Out:
#                                                                                                                                                              min                                                                                      25%                                                                                      50%                                                                                     75%                                                                                     max
#                dtype    sizeof   len count nunique mean       std
# model_id       category 2712     20  20    20.0    NaN        NaN        n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], fold[0]  n_species[134], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], fold[0]  n_species[100], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], fold[0]  n_species[67], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[200], fold[0]  n_species[33], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[100], fold[0]
# params         category 2532     20  20    20.0    NaN        NaN                 n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200]           n_species[134], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200]           n_species[100], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100]           n_species[67], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[200]           n_species[33], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[100]
# params_dict    object   4800     20  20    NaN     NaN        NaN                                                                                            NaN                                                                                      NaN                                                                                      NaN                                                                                     NaN                                                                                     NaN
# params_no_ns   category 1960     20  20    2.0     NaN        NaN                                              c_cls[rf], c_criterion[gini], c_n_estimators[200]                                        c_cls[rf], c_criterion[gini], c_n_estimators[200]                                        c_cls[rf], c_criterion[gini], c_n_estimators[200]                                       c_cls[rf], c_criterion[gini], c_n_estimators[100]                                       c_cls[rf], c_criterion[gini], c_n_estimators[100]
# ns             category 1512     20  20    10.0    NaN        NaN                                                                    n_species[168], n_recs[1.0]                                                              n_species[134], n_recs[1.0]                                                              n_species[100], n_recs[1.0]                                                              n_species[67], n_recs[0.5]                                                              n_species[33], n_recs[0.5]
# fold           int64    480      20  20    1.0      0.000e+00 0.000e+00                                                                                        0                                                                                        0                                                                                        0                                                                                       0                                                                                       0
# train_score    float64  480      20  20    1.0     -1.000e+00 0.000e+00                                                                                       -1                                                                                       -1                                                                                       -1                                                                                      -1                                                                                      -1
# test_score     float64  480      20  20    13.0    -7.325e+00 4.546e+00                                                                                      -22                                                                                       -9                                                                                       -7                                                                                      -5                                                                                      -2
# fit_time       float64  480      20  20    20.0     4.983e+00 5.097e+00                                                                                    0.324                                                                                    0.903                                                                                     3.26                                                                                    6.54                                                                                    20.4
# score_time     float64  480      20  20    20.0     3.163e-01 1.267e-02                                                                                    0.303                                                                                    0.306                                                                                    0.313                                                                                   0.319                                                                                   0.357
# model_size     int64    560      20  20    20.0     1.743e+08 1.770e+08                                                                                  7660824                                                                                 29989508                                                                                117546868                                                                               228972080                                                                               696763088
# mem_rss_spread int64    564      20  20    20.0     2.375e+08 2.777e+08                                                                                  1978368                                                                                 42721280                                                                                133677056                                                                               285470720                                                                              1164935168
# mem_vms_spread int64    564      20  20    20.0     2.668e+08 2.901e+08                                                                                  1978368                                                                                 43884544                                                                                176984064                                                                               296890368                                                                              1223598080
# train_evals    object   32612592 20  20    NaN     NaN        NaN                                                                                            NaN                                                                                      NaN                                                                                      NaN                                                                                     NaN                                                                                     NaN
# test_evals     object   8189424  20  20    NaN     NaN        NaN                                                                                            NaN                                                                                      NaN                                                                                      NaN                                                                                     NaN                                                                                     NaN
# proc_stats     object   97588    20  20    NaN     NaN        NaN                                                                                            NaN                                                                                      NaN                                                                                      NaN                                                                                     NaN                                                                                     NaN
#                                                                                    model_id                                                                          params                                                                                     params_dict                                       params_no_ns                           ns  fold  train_score  test_score  fit_time  score_time  model_size  mem_rss_spread  mem_vms_spread                                                                  train_evals                                                                test_evals                          proc_stats
# 0   n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], fold[0]  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200]  {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 200}  c_cls[rf], c_criterion[gini], c_n_estimators[200]  n_species[168], n_recs[1.0]     0         -1.0        -7.0    20.372       0.334   696763088      1164935168      1223598080  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])  ProcStats(interval=1.0, stats[22])
# 1   n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], fold[0]  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100]  {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 100}  c_cls[rf], c_criterion[gini], c_n_estimators[100]  n_species[168], n_recs[1.0]     0         -1.0       -10.0    10.040       0.316   357092388       571551744       632856576  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])  ProcStats(interval=1.0, stats[12])
# 2   n_species[168], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[200], fold[0]  n_species[168], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[200]  {'n_recs': 0.5, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 200}  c_cls[rf], c_criterion[gini], c_n_estimators[200]  n_species[168], n_recs[0.5]     0         -1.0       -12.0    10.974       0.323   363572384       542584832       552275968  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])  ProcStats(interval=1.0, stats[13])
# 3   n_species[168], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[100], fold[0]  n_species[168], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[100]  {'n_recs': 0.5, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 100}  c_cls[rf], c_criterion[gini], c_n_estimators[100]  n_species[168], n_recs[0.5]     0         -1.0       -22.0     5.563       0.305   185769684       285470720       296890368  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])   ProcStats(interval=1.0, stats[7])
# 4   n_species[134], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], fold[0]  n_species[134], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200]  {'n_recs': 1.0, 'n_species': 134, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 200}  c_cls[rf], c_criterion[gini], c_n_estimators[200]  n_species[134], n_recs[1.0]     0         -1.0        -5.0    12.053       0.357   437479872       446926848       499978240  SearchEvals(i[(2688,)], y[(2144,)], classes[(134,)], y_scores[(2144, 134)])  SearchEvals(i[(672,)], y[(536,)], classes[(134,)], y_scores[(536, 134)])  ProcStats(interval=1.0, stats[14])
# 5   n_species[134], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], fold[0]  n_species[134], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100]  {'n_recs': 1.0, 'n_species': 134, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 100}  c_cls[rf], c_criterion[gini], c_n_estimators[100]  n_species[134], n_recs[1.0]     0         -1.0        -7.0     6.045       0.303   225071588       229498880       249290752  SearchEvals(i[(2688,)], y[(2144,)], classes[(134,)], y_scores[(2144, 134)])  SearchEvals(i[(672,)], y[(536,)], classes[(134,)], y_scores[(536, 134)])   ProcStats(interval=1.0, stats[8])
# 6   n_species[134], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[200], fold[0]  n_species[134], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[200]  {'n_recs': 0.5, 'n_species': 134, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 200}  c_cls[rf], c_criterion[gini], c_n_estimators[200]  n_species[134], n_recs[0.5]     0         -1.0        -9.0     6.538       0.306   228972080       223911936       267280384  SearchEvals(i[(2688,)], y[(2144,)], classes[(134,)], y_scores[(2144, 134)])  SearchEvals(i[(672,)], y[(536,)], classes[(134,)], y_scores[(536, 134)])   ProcStats(interval=1.0, stats[8])
# 7   n_species[134], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[100], fold[0]  n_species[134], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[100]  {'n_recs': 0.5, 'n_species': 134, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 100}  c_cls[rf], c_criterion[gini], c_n_estimators[100]  n_species[134], n_recs[0.5]     0         -1.0       -12.0     3.472       0.306   117546868       133677056       163151872  SearchEvals(i[(2688,)], y[(2144,)], classes[(134,)], y_scores[(2144, 134)])  SearchEvals(i[(672,)], y[(536,)], classes[(134,)], y_scores[(536, 134)])   ProcStats(interval=1.0, stats[5])
# 8   n_species[100], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], fold[0]  n_species[100], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200]  {'n_recs': 1.0, 'n_species': 100, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 200}  c_cls[rf], c_criterion[gini], c_n_estimators[200]  n_species[100], n_recs[1.0]     0         -1.0        -5.5     6.615       0.330   241683712       341831680       405454848  SearchEvals(i[(2688,)], y[(1600,)], classes[(100,)], y_scores[(1600, 100)])  SearchEvals(i[(672,)], y[(400,)], classes[(100,)], y_scores[(400, 100)])   ProcStats(interval=1.0, stats[8])
# 9   n_species[100], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], fold[0]  n_species[100], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100]  {'n_recs': 1.0, 'n_species': 100, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 100}  c_cls[rf], c_criterion[gini], c_n_estimators[100]  n_species[100], n_recs[1.0]     0         -1.0        -7.0     3.259       0.313   125368836       173805568       212930560  SearchEvals(i[(2688,)], y[(1600,)], classes[(100,)], y_scores[(1600, 100)])  SearchEvals(i[(672,)], y[(400,)], classes[(100,)], y_scores[(400, 100)])   ProcStats(interval=1.0, stats[5])
# 10  n_species[100], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[200], fold[0]  n_species[100], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[200]  {'n_recs': 0.5, 'n_species': 100, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 200}  c_cls[rf], c_criterion[gini], c_n_estimators[200]  n_species[100], n_recs[0.5]     0         -1.0        -7.5     3.528       0.309   127131712       168599552       201166848  SearchEvals(i[(2688,)], y[(1600,)], classes[(100,)], y_scores[(1600, 100)])  SearchEvals(i[(672,)], y[(400,)], classes[(100,)], y_scores[(400, 100)])   ProcStats(interval=1.0, stats[5])
# 11  n_species[100], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[100], fold[0]  n_species[100], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[100]  {'n_recs': 0.5, 'n_species': 100, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 100}  c_cls[rf], c_criterion[gini], c_n_estimators[100]  n_species[100], n_recs[0.5]     0         -1.0        -9.0     1.817       0.315    66032260        98500608       104091648  SearchEvals(i[(2688,)], y[(1600,)], classes[(100,)], y_scores[(1600, 100)])  SearchEvals(i[(672,)], y[(400,)], classes[(100,)], y_scores[(400, 100)])   ProcStats(interval=1.0, stats[4])
# 12   n_species[67], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], fold[0]   n_species[67], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200]   {'n_recs': 1.0, 'n_species': 67, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 200}  c_cls[rf], c_criterion[gini], c_n_estimators[200]   n_species[67], n_recs[1.0]     0         -1.0        -4.0     2.993       0.306   107131120       124055552       176984064    SearchEvals(i[(2688,)], y[(1072,)], classes[(67,)], y_scores[(1072, 67)])    SearchEvals(i[(672,)], y[(268,)], classes[(67,)], y_scores[(268, 67)])   ProcStats(interval=1.0, stats[5])
# 13   n_species[67], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], fold[0]   n_species[67], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100]   {'n_recs': 1.0, 'n_species': 67, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 100}  c_cls[rf], c_criterion[gini], c_n_estimators[100]   n_species[67], n_recs[1.0]     0         -1.0        -5.0     1.588       0.316    56741348        69537792        97443840    SearchEvals(i[(2688,)], y[(1072,)], classes[(67,)], y_scores[(1072, 67)])    SearchEvals(i[(672,)], y[(268,)], classes[(67,)], y_scores[(268, 67)])   ProcStats(interval=1.0, stats[3])
# 14   n_species[67], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[200], fold[0]   n_species[67], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[200]   {'n_recs': 0.5, 'n_species': 67, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 200}  c_cls[rf], c_criterion[gini], c_n_estimators[200]   n_species[67], n_recs[0.5]     0         -1.0        -6.5     1.631       0.308    56524048        65515520       123449344    SearchEvals(i[(2688,)], y[(1072,)], classes[(67,)], y_scores[(1072, 67)])    SearchEvals(i[(672,)], y[(268,)], classes[(67,)], y_scores[(268, 67)])   ProcStats(interval=1.0, stats[3])
# 15   n_species[67], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[100], fold[0]   n_species[67], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[100]   {'n_recs': 0.5, 'n_species': 67, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 100}  c_cls[rf], c_criterion[gini], c_n_estimators[100]   n_species[67], n_recs[0.5]     0         -1.0        -8.0     0.849       0.314    29989508        42721280        42860544    SearchEvals(i[(2688,)], y[(1072,)], classes[(67,)], y_scores[(1072, 67)])    SearchEvals(i[(672,)], y[(268,)], classes[(67,)], y_scores[(268, 67)])   ProcStats(interval=1.0, stats[3])
# 16   n_species[33], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], fold[0]   n_species[33], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200]   {'n_recs': 1.0, 'n_species': 33, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 200}  c_cls[rf], c_criterion[gini], c_n_estimators[200]   n_species[33], n_recs[1.0]     0         -1.0        -2.0     0.903       0.321    26308528        34971648        43884544      SearchEvals(i[(2688,)], y[(528,)], classes[(33,)], y_scores[(528, 33)])    SearchEvals(i[(672,)], y[(132,)], classes[(33,)], y_scores[(132, 33)])   ProcStats(interval=1.0, stats[3])
# 17   n_species[33], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], fold[0]   n_species[33], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100]   {'n_recs': 1.0, 'n_species': 33, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 100}  c_cls[rf], c_criterion[gini], c_n_estimators[100]   n_species[33], n_recs[1.0]     0         -1.0        -2.0     0.519       0.319    14764868        22605824        22605824      SearchEvals(i[(2688,)], y[(528,)], classes[(33,)], y_scores[(528, 33)])    SearchEvals(i[(672,)], y[(132,)], classes[(33,)], y_scores[(132, 33)])   ProcStats(interval=1.0, stats[2])
# 18   n_species[33], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[200], fold[0]   n_species[33], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[200]   {'n_recs': 0.5, 'n_species': 33, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 200}  c_cls[rf], c_criterion[gini], c_n_estimators[200]   n_species[33], n_recs[0.5]     0         -1.0        -3.0     0.585       0.312    13728344         7540736        18014208      SearchEvals(i[(2688,)], y[(528,)], classes[(33,)], y_scores[(528, 33)])    SearchEvals(i[(672,)], y[(132,)], classes[(33,)], y_scores[(132, 33)])   ProcStats(interval=1.0, stats[2])
# 19   n_species[33], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[100], fold[0]   n_species[33], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[100]   {'n_recs': 0.5, 'n_species': 33, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 100}  c_cls[rf], c_criterion[gini], c_n_estimators[100]   n_species[33], n_recs[0.5]     0         -1.0        -3.0     0.324       0.313     7660824         1978368         1978368      SearchEvals(i[(2688,)], y[(528,)], classes[(33,)], y_scores[(528, 33)])    SearchEvals(i[(672,)], y[(132,)], classes[(33,)], y_scores[(132, 33)])   ProcStats(interval=1.0, stats[2])

# %%
cv_models_proc_stats = (cv_models
    # Enable these as needed (at the cost of mem usage)
    [[
        'model_id',
        'params',
        # 'params_dict',
        'params_no_ns',
        'ns',
        'fold',
        # 'train_score',
        # 'test_score',
        # 'fit_time',
        # 'score_time',
        'mem_rss_spread',
        # 'mem_vms_spread',
        # 'train_evals',
        # 'test_evals',
        'proc_stats',
    ]]
    .pipe(df_flatmap, lambda row: [
        row.append(pd.Series(dict(**stats)))
        for stats in row.proc_stats.stats
    ])
    # Restore the cats we just destroyed [copied from cv_results_splits_df]
    .pipe(df_ordered_cat,
        model_id=lambda df: df.model_id.unique(),
        params=lambda df: df.params.unique(),
    )
    .assign(
        cpu_user=lambda df: df.cpu_user.diff() * 100,
        cpu_system=lambda df: df.cpu_system.diff() * 100,
    )
    .pipe(tap, f=lambda df: display(
        # df_summary(df).T,
        # df[:5],
    ))
)

# %%
(cv_models
    .pipe(df_reverse_cat, 'params', 'params_no_ns', 'ns')
    # Manually compute y.mean() per group
    .groupby('params').apply(lambda g: g.assign(
        fit_time_mean=lambda df: df.fit_time.mean(),
        score_time_mean=lambda df: df.score_time.mean(),
    ))
    .pipe(ggplot, aes(x='ns', group='params_no_ns'))
    # Summary per fold
    + geom_col(aes(y='fit_time_mean + score_time_mean', fill='params_no_ns'), color='black', size=.2, position=position_dodge())
    + geom_col(aes(y='fit_time_mean', fill='params_no_ns'), color='black', size=.2, position=position_dodge())
    # Distribution of folds
    + geom_point(aes(y='fit_time'), size=2, color='gray', fill='none', position=position_dodge(width=.9))
    + geom_point(aes(y='fit_time + score_time'), size=2, color='black', fill='none', position=position_dodge(width=.9))
    + coord_flip()
    + scale_fill_cmap_d(mpl.cm.tab10)
    + guides(fill=guide_legend(reverse=True))
    + theme(legend_position='bottom', legend_direction='vertical', legend_box_spacing=.4, legend_key_height=8)
    + theme_figsize(aspect_ratio=1/3)
    + ylab('fit_time + score_time')
    + ggtitle(f'Train + score times ({recs_stats})')
)
# Out:
# <ggplot: (355241508)>

# %%
(cv_models
    .pipe(df_reverse_cat, 'params', 'params_no_ns', 'ns')
    # Manually compute y.mean() per group
    .groupby('params').apply(lambda g: g.assign(model_size_mean=lambda df: df.model_size.mean()))
    .pipe(ggplot, aes(x='ns', group='params_no_ns'))
    + geom_col(aes(y='model_size_mean', fill='params_no_ns'), position=position_dodge()) # Summary per fold
    + geom_point(aes(y='model_size'), fill='none', size=2, position=position_dodge(width=.9)) # Distribution of folds
    + coord_flip()
    + scale_fill_cmap_d(mpl.cm.tab10)
    + scale_y_continuous(labels=labels_bytes(), breaks=breaks_bytes())
    + guides(fill=guide_legend(reverse=True))
    + theme(legend_position='bottom', legend_direction='vertical', legend_box_spacing=.4, legend_key_height=8)
    + theme_figsize(aspect_ratio=1/3)
    + ggtitle(f'Model size ({recs_stats})')
)
# Out:
# <ggplot: (314436819)>

# %%
(cv_models
    .pipe(df_reverse_cat, 'params', 'params_no_ns', 'ns')
    # Manually compute y.mean() per group
    .groupby('params').apply(lambda g: g.assign(mem_rss_spread_mean=lambda df: df.mem_rss_spread.mean()))
    .pipe(ggplot, aes(x='ns', group='params_no_ns'))
    + geom_col(aes(y='mem_rss_spread_mean', fill='params_no_ns'), position=position_dodge()) # Summary per fold
    + geom_point(aes(y='mem_rss_spread'), fill='none', size=2, position=position_dodge(width=.9)) # Distribution of folds
    + coord_flip()
    + scale_fill_cmap_d(mpl.cm.tab10)
    + scale_y_continuous(labels=labels_bytes(), breaks=breaks_bytes())
    + guides(fill=guide_legend(reverse=True))
    + theme(legend_position='bottom', legend_direction='vertical', legend_box_spacing=.4, legend_key_height=8)
    + theme_figsize(aspect_ratio=1/3)
    + ggtitle(f'Mem rss spread ($max-min$) ({recs_stats})')
)
# Out:
# <ggplot: (314987854)>

# %%
# TODO Might need to stack/geom_area for overlapping runs
(cv_models_proc_stats
    .pipe(ggplot, aes(x='time',
        color='model_id',
        # color='params_no_ns', linetype='ns',
        # color='params_no_ns', size='ns',
    ))
    + geom_line(aes(y='cpu_system'), linetype='dashed', size=.5)
    + geom_line(aes(y='cpu_system + cpu_user'), linetype='solid', size=.5)
    # + geom_line(aes(y='cpu_system + cpu_user'), size=1)
    + expand_limits(y=0)
    + ylab('cpu')
    + scale_x_datetime(date_labels='%H:%M:%S')
    + scale_y_continuous(labels=lambda labels: ['%.3g%%' % x for x in labels])
    # + scale_color_cmap_d(mpl.cm.tab20)
    + theme(legend_position='bottom', legend_direction='vertical', legend_box_spacing=.4, legend_key_height=8)
    + theme_figsize('inline_short')
    + ggtitle('cpu over time (system + user)')
)
# Out:
# /Users/danb/miniconda3/envs/bubo-features/lib/python3.6/site-packages/plotnine/geoms/geom_path.py:76: UserWarning: geom_path: Removed 1 rows containing missing values.
#   warn(msg.format(n1-n2))
# /Users/danb/miniconda3/envs/bubo-features/lib/python3.6/site-packages/plotnine/geoms/geom_path.py:76: UserWarning: geom_path: Removed 1 rows containing missing values.
#   warn(msg.format(n1-n2))
# <ggplot: (319405341)>

# %%
(cv_models_proc_stats
    .pipe(ggplot, aes(x='time', color='model_id'))
    + geom_line(aes(y='mem_rss'), linetype='solid', size=.5)
    + geom_line(aes(y='mem_vms'), linetype='dashed', size=.5)
    + expand_limits(y=0)
    + ylab('mem')
    + scale_x_datetime(date_labels='%H:%M:%S')
    + scale_y_continuous(labels=labels_bytes(), breaks=breaks_bytes(pow=3))
    # + scale_color_cmap_d(mpl.cm.tab20)
    + theme(legend_position='bottom', legend_direction='vertical', legend_box_spacing=.4, legend_key_height=8)
    + theme_figsize('inline_short')
    + ggtitle('Mem over time (rss, vms)')
)
# Out:
# <ggplot: (325600867)>

# %%
# Train/test scores
#   - Grain: models x {train,test}
#   - Metrics: score
#   - Dims: group, params
(cv_models
    .pipe(df_reverse_cat, 'params_no_ns')
    .pipe(lambda df: pd.melt(
        df,
        id_vars=['ns', 'params_no_ns', 'params', 'fold'],
        value_vars=['train_score', 'test_score'],
        var_name='split',
        value_name='score'),
    )
    .assign(
        split=lambda df: df.split.str.replace('_score', ''),
        group=lambda df: df.params_no_ns.str.cat(df.split, '/'),
    )
    .pipe(df_ordered_cat,
        group=lambda df: reversed(df.group.unique()),
    )
    .pipe(ggplot, aes(
        x='params_no_ns',
        y='score',
        # color='group',  # Ran out of colors
        color='params_no_ns',
    ))
    + facet_wrap('ns', ncol=1)
    + geom_hline(yintercept=-1, color='lightgrey')  # -1 is the max score (1 is the min coverage_error)
    + geom_point(fill='none', size=2)
    # + geom_line(aes(group='str(group) + str(fold)'), alpha=.2)  # More trouble than it's worth
    + stat_summary(aes(group='group'), fun_data='mean_cl_boot', random_state=0, geom='errorbar')
    # + stat_summary(aes(group='group'), fun_data='mean_cl_boot', random_state=0, geom='line', size=1)  # More trouble than it's worth
    + scale_color_cmap_d(mpl.cm.tab10)
    + coord_flip(
        # ylim=(-40, 0),
    )
    + theme(legend_position='none')
    + theme_figsize(width=10, aspect_ratio=1/10)
    + ylab('score (-coverage_error)')
    + ggtitle(f'Train/test scores ({recs_stats})')
)
# Out:
# <ggplot: (-9223372036527386301)>

# %% [markdown]
# # Model diagnostics: all models, all folds

# %%
print('models:')
print('  params[*/%s]' % len(cv_models.params.cat.categories))
print('  fold[*/%s]' % cv.cv.n_splits)
# Out:
# models:
#   params[*/20]
#   fold[*/1]

# %%
# TODO Cache
# Coverage errors: all models, all folds
#   - Subset: all models
#   - Grain: sum(recs[model.test_i] for model)
#   - Dims: model_id, params, fold, y_true, rec_id
#   - Metrics: coverage_error
coverage_errors_all_all = (cv_models
    # .sample(n=5, random_state=0)  # For faster dev
    .pipe(lambda df: DF(
        OrderedDict(
            # **row[['model_id', 'params', 'fold']],  # Slow (in this inner loop), unpack manually instead
            model_id=row.model_id,
            params=row.params,
            params_no_ns=row.params_no_ns,
            ns=row.ns,
            fold=row.fold,
            i=i,
            y_true=y_true,
            coverage_error=coverage_error,
        )
        for row in iter_progress(df_rows(df), n=len(df))
        for i, y_true, coverage_error in zip(
            row.test_evals.i,
            row.test_evals.y,
            row.test_evals.coverage_errors(),
        )
    ))
    .astype(dict(
        model_id=cv_models.model_id.dtype,
        params=cv_models.params.dtype,
        params_no_ns=cv_models.params_no_ns.dtype,
        ns=cv_models.ns.dtype,
    ))
    .pipe(tap, lambda df: display(
        df_summary(df).T,
        df[:10],
    ))
)
# Out:
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   5%|████▏                                                                              | 1/20 [00:00<00:04,  4.21it/s]
#  10%|████████▎                                                                          | 2/20 [00:00<00:04,  4.21it/s]
#  15%|████████████▍                                                                      | 3/20 [00:00<00:04,  4.25it/s]
#  20%|████████████████▌                                                                  | 4/20 [00:00<00:03,  4.25it/s]
#  25%|████████████████████▊                                                              | 5/20 [00:01<00:03,  4.41it/s]
#  30%|████████████████████████▉                                                          | 6/20 [00:01<00:03,  4.56it/s]
#  35%|█████████████████████████████                                                      | 7/20 [00:01<00:02,  4.66it/s]
#  40%|█████████████████████████████████▏                                                 | 8/20 [00:01<00:02,  4.72it/s]
#  45%|█████████████████████████████████████▎                                             | 9/20 [00:01<00:02,  4.92it/s]
#  50%|█████████████████████████████████████████                                         | 10/20 [00:01<00:01,  5.08it/s]
#  55%|█████████████████████████████████████████████                                     | 11/20 [00:02<00:01,  5.21it/s]
#  60%|█████████████████████████████████████████████████▏                                | 12/20 [00:02<00:01,  5.33it/s]
#  70%|█████████████████████████████████████████████████████████▍                        | 14/20 [00:02<00:01,  5.76it/s]
#  80%|█████████████████████████████████████████████████████████████████▌                | 16/20 [00:02<00:00,  6.11it/s]
#  95%|█████████████████████████████████████████████████████████████████████████████▉    | 19/20 [00:02<00:00,  6.90it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [00:02<00:00,  7.15it/s]
#                                                                                                                                                          min                                                                                      25%                                                                                      50%                                                                                      75%                                                                                     max
#                dtype    sizeof  len  count nunique mean     std
# model_id       category 3911616 8032 8032  20      NaN      NaN      n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], fold[0]  n_species[168], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[200], fold[0]  n_species[134], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[200], fold[0]  n_species[100], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[200], fold[0]  n_species[33], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[100], fold[0]
# params         category 1018464 8032 8032  20      NaN      NaN               n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200]           n_species[168], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[200]           n_species[134], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[200]           n_species[100], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[200]           n_species[33], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[100]
# params_no_ns   category 2393536 8032 8032  2       NaN      NaN                                            c_cls[rf], c_criterion[gini], c_n_estimators[200]                                        c_cls[rf], c_criterion[gini], c_n_estimators[200]                                        c_cls[rf], c_criterion[gini], c_n_estimators[200]                                        c_cls[rf], c_criterion[gini], c_n_estimators[100]                                       c_cls[rf], c_criterion[gini], c_n_estimators[100]
# ns             category 1502016 8032 8032  10      NaN      NaN                                                                  n_species[168], n_recs[1.0]                                                              n_species[168], n_recs[0.5]                                                              n_species[134], n_recs[0.5]                                                              n_species[100], n_recs[0.5]                                                              n_species[33], n_recs[0.5]
# fold           int64    192768  8032 8032  1       0.000    0.000                                                                                          0                                                                                        0                                                                                        0                                                                                        0                                                                                       0
# i              int64    224848  8032 8032  672     1680.378 964.454                                                                                        0                                                                                      837                                                                                     1683                                                                                     2501                                                                                    3348
# y_true         object   682720  8032 8032  168     NaN      NaN                                                                                         ACWO                                                                                     CRTH                                                                                     LEBI                                                                                     RIRA                                                                                    YRWA
# coverage_error float64  192768  8032 8032  106     28.007   43.494                                                                                         1                                                                                        2                                                                                        7                                                                                       32                                                                                     168
#                                                                                   model_id                                                                          params                                       params_no_ns                           ns  fold     i y_true  coverage_error
# 0  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], fold[0]  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200]  c_cls[rf], c_criterion[gini], c_n_estimators[200]  n_species[168], n_recs[1.0]     0  1765   CASJ             2.0
# 1  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], fold[0]  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200]  c_cls[rf], c_criterion[gini], c_n_estimators[200]  n_species[168], n_recs[1.0]     0  1551   VEFL             1.0
# 2  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], fold[0]  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200]  c_cls[rf], c_criterion[gini], c_n_estimators[200]  n_species[168], n_recs[1.0]     0  2967   LISP            11.0
# 3  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], fold[0]  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200]  c_cls[rf], c_criterion[gini], c_n_estimators[200]  n_species[168], n_recs[1.0]     0   578   LBCU             2.0
# 4  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], fold[0]  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200]  c_cls[rf], c_criterion[gini], c_n_estimators[200]  n_species[168], n_recs[1.0]     0   684   BOGU            27.0
# 5  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], fold[0]  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200]  c_cls[rf], c_criterion[gini], c_n_estimators[200]  n_species[168], n_recs[1.0]     0  1209   BTAH             1.0
# 6  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], fold[0]  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200]  c_cls[rf], c_criterion[gini], c_n_estimators[200]  n_species[168], n_recs[1.0]     0  2372   BETH             1.0
# 7  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], fold[0]  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200]  c_cls[rf], c_criterion[gini], c_n_estimators[200]  n_species[168], n_recs[1.0]     0  2874   WCSP           168.0
# 8  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], fold[0]  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200]  c_cls[rf], c_criterion[gini], c_n_estimators[200]  n_species[168], n_recs[1.0]     0  1424   LEFL            11.0
# 9  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], fold[0]  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200]  c_cls[rf], c_criterion[gini], c_n_estimators[200]  n_species[168], n_recs[1.0]     0  2115   BEWR            15.0

# %%
# Facet by params_no_ns, order by median(coverage_error)
#   - Subset: all models
#   - Grain: sum(recs[model.test_i].groupby(params, y_true) for model)
#       - Over: fold, rec_id
#   - Dims: params, y_true
#   - Metrics: coverage_error.median
# in: coverage_errors_all_all, recs
(coverage_errors_all_all
    # .pipe(df_reverse_cat, 'params', 'params_no_ns', 'ns')
    .pipe(df_ordered_cat,
        y_true=lambda df: (
            # Sort species by median(coverage_error) (across all models)
            df.groupby('y_true').agg({'coverage_error': np.median}).reset_index().sort_values('coverage_error').y_true
            # Sort species by taxo (hard to compare across models, unless they're pretty low noise)
            # reversed(recs.species.cat.categories)
        ),
    )
    .pipe(ggplot, aes(x='y_true', y='coverage_error',
        # color='params',
    ))
    # + facet_wrap('params_no_ns', ncol=3)
    + facet_grid('ns ~ params_no_ns')
    # + geom_line(aes(group='params'), stat='summary', fun_y=np.median)  # TODO Bad interpolation with n_species
    + geom_point(aes(group='params'), stat='summary', fun_y=np.median)
    + coord_flip(
        # ylim=(0, min(30, len(np.unique(y)))),  # Restore eventually
    )
    + geom_hline(yintercept=recs.species.nunique(), color='grey')
    # + scale_color_cmap_d(mpl.cm.tab20)
    + theme(legend_position='bottom', legend_direction='vertical', legend_box_spacing=.4, legend_key_height=8)
    + theme_figsize(width=12*2, aspect_ratio=1/4)
    + ggtitle(rf'Coverage error over fold $\times$ instance, by params_no_ns $\times$ ns ({recs_stats})')
)
# Out:
# <ggplot: (312377243)>

# %%
# TODO Slow, bad for notebook dev loop -- move lower, or disable by default?
# Facet by species
#   - Subset: all models
#   - Grain: sum(recs[model.test_i].groupby(params, y_true) for model)
#       - Over: fold, rec_id
#   - Dims: params, y_true
#   - Metrics: coverage_error.median
# in: coverage_errors_all_all, recs
(coverage_errors_all_all
    # .sample(200, random_state=0)  # Faster dev
    .astype({'y_true': metadata.species.df.shorthand.dtype})
    .pipe(df_reverse_cat, 'params')
    .pipe(ggplot, aes(x='params', y='coverage_error', color='params_no_ns'))
    + facet_wrap('y_true')
    + geom_hline(yintercept=1, color='grey')
    + geom_hline(yintercept=recs.species.nunique(), color='grey')

    # Percentiles (faster, no overplot)
    # + geom_point(stat='summary', fun_y=np.median)
    # + geom_linerange(stat='summary', fun_ymin=partial(np.percentile, q=25), fun_ymax=partial(np.percentile, q=75))

    # Violin (slow, no overplot)
    # + geom_violin()

    # Boxplot (very slow, no overplot)
    # + geom_boxplot()

    # Points (medium cost, high overplot)
    #   - n (count) instead of prop (proportion)
    #   - scale_size_area() instead of default scale_size(), because it's a count [I don't grok this but it looks good]
    + geom_count(aes(size='..n..'), alpha=.5)
    + scale_size_area()
    + geom_point(stat='summary', fun_y=np.median, alpha=1, color='black', shape='|', size=3, stroke=1)

    + coord_flip()
    + scale_color_cmap_d(mpl.cm.tab20)
    + theme(axis_text_y=element_text(size=6))
    + theme_figsize('square')  # Faster
    # + theme_figsize('half')
    # + theme_figsize('full')
    # + theme_figsize('full_dense')
    + ggtitle(rf'Coverage error over fold $\times$ instance, by params ({recs_stats})')
)
# Out:
# [skip]

# %% [markdown]
# # Model diagnostics: one model, all folds

# %%
params_i = 0
params = cv_models.params.cat.categories[params_i]
print("params:\n%s" % '\n'.join('  %s: %r' % (i, x) for i, x in enumerate(cv_models.params.cat.categories)))
print()
print('models:')
print('  params[%s/%s]: %r' % (params_i, len(cv_models.params.cat.categories), params))
print('  fold[*/%s]' % cv.cv.n_splits)
# Out:
# params:
#   0: 'n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200]'
#   1: 'n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100]'
#   2: 'n_species[168], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[200]'
#   3: 'n_species[168], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[100]'
#   4: 'n_species[134], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200]'
#   5: 'n_species[134], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100]'
#   6: 'n_species[134], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[200]'
#   7: 'n_species[134], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[100]'
#   8: 'n_species[100], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200]'
#   9: 'n_species[100], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100]'
#   10: 'n_species[100], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[200]'
#   11: 'n_species[100], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[100]'
#   12: 'n_species[67], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200]'
#   13: 'n_species[67], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100]'
#   14: 'n_species[67], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[200]'
#   15: 'n_species[67], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[100]'
#   16: 'n_species[33], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200]'
#   17: 'n_species[33], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100]'
#   18: 'n_species[33], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[200]'
#   19: 'n_species[33], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[100]'
#
# models:
#   params[0/20]: 'n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200]'
#   fold[*/1]

# %%
# Coverage errors: one model, all folds
#   - Subset: models.params == params
#   - Grain: sum(recs[model.test_i] for model)
#   - Dims: model_id, params, fold, y_true, rec_id
#   - Metrics: coverage_error
coverage_errors_one_all = (coverage_errors_all_all
    [lambda df: df.params == params]  # One model, all folds
)
display(
    df_summary(coverage_errors_one_all).T,
    coverage_errors_one_all[:10],
)
# Out:
#                                                                                                                                                        min                                                                                      25%                                                                                      50%                                                                                      75%                                                                                      max
#                dtype    sizeof len count nunique mean     std
# model_id       category 327936 672 672   1       NaN      NaN      n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], fold[0]  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], fold[0]  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], fold[0]  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], fold[0]  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], fold[0]
# params         category 85344  672 672   1       NaN      NaN               n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200]           n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200]           n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200]           n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200]           n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200]
# params_no_ns   category 200256 672 672   1       NaN      NaN                                            c_cls[rf], c_criterion[gini], c_n_estimators[200]                                        c_cls[rf], c_criterion[gini], c_n_estimators[200]                                        c_cls[rf], c_criterion[gini], c_n_estimators[200]                                        c_cls[rf], c_criterion[gini], c_n_estimators[200]                                        c_cls[rf], c_criterion[gini], c_n_estimators[200]
# ns             category 126336 672 672   1       NaN      NaN                                                                  n_species[168], n_recs[1.0]                                                              n_species[168], n_recs[1.0]                                                              n_species[168], n_recs[1.0]                                                              n_species[168], n_recs[1.0]                                                              n_species[168], n_recs[1.0]
# fold           int64    16128  672 672   1       0.000    0.000                                                                                          0                                                                                        0                                                                                        0                                                                                        0                                                                                        0
# i              int64    18812  672 672   672     1679.338 970.784                                                                                        0                                                                                      837                                                                                     1677                                                                                     2517                                                                                     3348
# y_true         object   60500  672 672   168     NaN      NaN                                                                                         ACWO                                                                                     CONI                                                                                     LASP                                                                                     RIRA                                                                                     YRWA
# coverage_error float64  16128  672 672   86      30.759   48.234                                                                                         1                                                                                        1                                                                                        7                                                                                       37                                                                                      168
#                                                                                   model_id                                                                          params                                       params_no_ns                           ns  fold     i y_true  coverage_error
# 0  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], fold[0]  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200]  c_cls[rf], c_criterion[gini], c_n_estimators[200]  n_species[168], n_recs[1.0]     0  1765   CASJ             2.0
# 1  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], fold[0]  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200]  c_cls[rf], c_criterion[gini], c_n_estimators[200]  n_species[168], n_recs[1.0]     0  1551   VEFL             1.0
# 2  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], fold[0]  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200]  c_cls[rf], c_criterion[gini], c_n_estimators[200]  n_species[168], n_recs[1.0]     0  2967   LISP            11.0
# 3  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], fold[0]  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200]  c_cls[rf], c_criterion[gini], c_n_estimators[200]  n_species[168], n_recs[1.0]     0   578   LBCU             2.0
# 4  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], fold[0]  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200]  c_cls[rf], c_criterion[gini], c_n_estimators[200]  n_species[168], n_recs[1.0]     0   684   BOGU            27.0
# 5  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], fold[0]  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200]  c_cls[rf], c_criterion[gini], c_n_estimators[200]  n_species[168], n_recs[1.0]     0  1209   BTAH             1.0
# 6  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], fold[0]  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200]  c_cls[rf], c_criterion[gini], c_n_estimators[200]  n_species[168], n_recs[1.0]     0  2372   BETH             1.0
# 7  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], fold[0]  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200]  c_cls[rf], c_criterion[gini], c_n_estimators[200]  n_species[168], n_recs[1.0]     0  2874   WCSP           168.0
# 8  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], fold[0]  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200]  c_cls[rf], c_criterion[gini], c_n_estimators[200]  n_species[168], n_recs[1.0]     0  1424   LEFL            11.0
# 9  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], fold[0]  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200]  c_cls[rf], c_criterion[gini], c_n_estimators[200]  n_species[168], n_recs[1.0]     0  2115   BEWR            15.0

# %%
#   - Subset: models.params == params
#   - Grain: sum(recs[model.test_i].groupby(y_true) for model)
#       - Over: fold, rec_id
#   - Dims: y_true
#   - Metrics: count, coverage_error.percentiles
# in: coverage_errors_one_all, recs
(coverage_errors_one_all
    .astype({'y_true': metadata.species.df.shorthand.dtype})
    .pipe(df_reverse_cat, 'y_true')
    .pipe(ggplot, aes(x='y_true', y='coverage_error'))
    + geom_hline(yintercept=1, color='grey')
    + geom_hline(yintercept=recs.species.nunique(), color='grey')
    + geom_count(aes(size='..n..'), alpha=1)  # n (count) instead of prop (proportion)
    + scale_size_area()  # Instead of default scale_size(), because it's a count [I don't grok this but it looks good]
    + geom_point(stat='summary', fun_y=np.median, alpha=1, color='red', shape='|', size=6, stroke=2)
    + coord_flip()
    # + theme_figsize('inline')
    # + theme_figsize('square')
    # + theme_figsize('half')
    + theme_figsize('half_dense')
    # + theme_figsize('full')
    # + theme_figsize('full_dense')
    + ggtitle(rf'Coverage error over fold $\times$ instance ({params}) ({recs_stats})')
)
# Out:
# <ggplot: (325547875)>

# %%
# One-model/all-folds confusion matrix
with figsize(
    # 'square',
    # 'full',
    'full_dense',
):
    (cv_models
        [lambda df: df.params == params]
        .pipe(lambda df: plot_confusion_matrix(
            classes=df.iloc[0].test_evals.classes,
            M=np.array([
                row.test_evals.confusion_matrix_prob()
                for row in df_rows(df)
            ]).sum(axis=0),
            # normalize=False,  # For counts
            raw=True, scale=10,  # Faster dev
            format=None,  # Omit numbers, too dense
            title=f'({recs_stats})',
        ))
    )
# Out:
# <PIL.Image.Image image mode=RGBA size=1680x1680 at 0x130B96400>

# %% [markdown]
# # Model diagnostics: one model, one fold

# %%
fold = 0
# params_i = ...  # Comment out to reuse from above
params = cv_models.params.cat.categories[params_i]
[(_, model)] = list(cv_models[lambda df: (df.params == params) & (df.fold == fold)].iterrows())
print("params:\n%s" % '\n'.join('  %s: %r' % (i, x) for i, x in enumerate(cv_models.params.cat.categories)))
print()
print('model:')
print('  params[%s/%s]: %r' % (params_i, len(cv_models.params.cat.categories), model.params))
print('  fold[%s/%s]' % (model.fold, cv.cv.n_splits))
print()
print(model)
# Out:
# [skip]

# %%
# in: model
model_id = model.model_id
params = model.params
fold = model.fold
# train_evals = model.train_evals
test_evals = model.test_evals

# in: model, recs
# train_recs = recs.iloc[train_evals.i]
# train_X = Search.X(recs)[train_evals.i]
# train_y = Search.y(recs)[train_evals.i]
test_recs = recs.iloc[test_evals.i]
test_X = Search.X(recs)[test_evals.i]
test_y = Search.y(recs)[test_evals.i]  # (Don't need to store cv_models.test_evals.y if we have recs -- which sometimes we don't?)

display(
    # len(train_recs),
    len(test_recs),
)
# Out:
# [skip]

# %%
# TODO Restore this plot like 'Coverage error over ...' above, so we can see _one_ model instead of aggregating over n_splits models
# # TODO Update [kill the .merge, then species -> y_true]
# (search.coverage_error_by(test_recs, 'id')
#     [:5]
#     # .merge(test_recs[['id', 'species']], on='id', how='left')
#     # .pipe(ggplot, aes(x='species', y='coverage_error'))
#     # + geom_count(aes(size='..n..'))
#     # + stat_summary(fun_y=np.median, geom='point', color='red', alpha=.5, shape='|', size=6, stroke=1)
#     # + stat_summary(
#     #     fun_ymin=partial(np.percentile, q=25), fun_ymax=partial(np.percentile, q=75),
#     #     geom='linerange', color='red', alpha=.5, size=1,
#     # )
#     # + coord_flip()
#     # + geom_hline(yintercept=len(search.classes_), color='grey')
#     # + scale_x_discrete(limits=list(reversed(test_recs.species.cat.categories)))
#     # + theme_figsize('square')
#     # + ggtitle(rf'Coverage error over instance ({model_id}) ({recs_stats})')
# )
# Out:
# [skip]

# %%
# One-model/one-fold confusion matrix
with figsize(
    'square',
    # 'full',
    # 'full_dense',
):
    plot_confusion_matrix_df(
        confusion_matrix_prob_df(model.test_evals.y, model.test_evals.y_scores, model.test_evals.classes),
        title=model.model_id,
        # normalize=False,  # For counts
        raw=True, scale=10,  # Faster dev
        title=f'({recs_stats})',
    )
# Out:
# [skip]
