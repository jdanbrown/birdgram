# %%
import glob

from potoo.plot import *
from potoo.util import *
import sklearn

from cache import *
from datasets import *
from features import *
from load import *
from sp14.model import *
from util import *

figsize('inline_short');

# %%
glob.glob(f'{data_dir}/mlsp-2013/*')
# Out:
# [
#   '/Users/danb/hack/bubo/data/mlsp-2013/light_data',
#   '/Users/danb/hack/bubo/data/mlsp-2013/mlsp13birdchallenge_documentation.pdf',
#   '/Users/danb/hack/bubo/data/mlsp-2013/mlsp_contest_dataset',
#   '/Users/danb/hack/bubo/data/mlsp-2013/README.txt',
# ]

# %%
glob.glob(f'{data_dir}/mlsp-2013/light_data/*')
# Out:
# [
#   '/Users/danb/hack/bubo/data/mlsp-2013/light_data/CVfolds_2.txt',
#   '/Users/danb/hack/bubo/data/mlsp-2013/light_data/histogram_of_segments.txt',
#   '/Users/danb/hack/bubo/data/mlsp-2013/light_data/rec_id2filename.txt',
#   '/Users/danb/hack/bubo/data/mlsp-2013/light_data/rec_labels_test_hidden.txt',
#   '/Users/danb/hack/bubo/data/mlsp-2013/light_data/sample_submission.csv',
#   '/Users/danb/hack/bubo/data/mlsp-2013/light_data/segment_features.txt',
#   '/Users/danb/hack/bubo/data/mlsp-2013/light_data/species_list.txt',
# ]

# %%
glob.glob(f'{data_dir}/mlsp-2013/mlsp_contest_dataset/essential_data/*')
# Out:
# [
#   '/Users/danb/hack/bubo/data/mlsp-2013/mlsp_contest_dataset/essential_data/CVfolds_2.txt',
#   '/Users/danb/hack/bubo/data/mlsp-2013/mlsp_contest_dataset/essential_data/rec_id2filename.txt',
#   '/Users/danb/hack/bubo/data/mlsp-2013/mlsp_contest_dataset/essential_data/rec_labels_test_hidden.txt',
#   '/Users/danb/hack/bubo/data/mlsp-2013/mlsp_contest_dataset/essential_data/sample_submission.csv',
#   '/Users/danb/hack/bubo/data/mlsp-2013/mlsp_contest_dataset/essential_data/species_list.txt',
#   '/Users/danb/hack/bubo/data/mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs',
# ]

# %%
# Boring
# pd.read_csv(f'{data_dir}/mlsp-2013/mlsp_contest_dataset/essential_data/CVfolds_2.txt')[:50]

# Interesting
rec_id_to_filename_df = pd.read_csv(f'{data_dir}/mlsp-2013/mlsp_contest_dataset/essential_data/rec_id2filename.txt')
sample_submission_df = pd.read_csv(f'{data_dir}/mlsp-2013/mlsp_contest_dataset/essential_data/sample_submission.csv')
species_df = pd.read_csv(f'{data_dir}/mlsp-2013/mlsp_contest_dataset/essential_data/species_list.txt')

# This one has variable numbers of columns, so parse it manually
with open(f'{data_dir}/mlsp-2013/mlsp_contest_dataset/essential_data/rec_labels_test_hidden.txt') as f:
    rec_labels_test_hidden_df = (
        pd.DataFrame(line.rstrip().split(',', 1) for line in f.readlines())
        .T.set_index(0).T  # Pull first row into df col names
    )

# %%
display(
    species_df.shape,
    species_df,
)
# Out:
# (19, 3)
#     class_id  code                    species
# 0          0  BRCR              Brown Creeper
# 1          1  PAWR               Pacific Wren
# 2          2  PSFL   Pacific-slope Flycatcher
# 3          3  RBNU      Red-breasted Nuthatch
# 4          4  DEJU            Dark-eyed Junco
# 5          5  OSFL     Olive-sided Flycatcher
# 6          6  HETH              Hermit Thrush
# 7          7  CBCH  Chestnut-backed Chickadee
# 8          8  VATH              Varied Thrush
# 9          9  HEWA             Hermit Warbler
# 10        10  SWTH          Swainson's Thrush
# 11        11  HAFL       Hammond's Flycatcher
# 12        12  WETA            Western Tanager
# 13        13  BHGB      Black-headed Grosbeak
# 14        14  GCKI     Golden Crowned Kinglet
# 15        15  WAVI             Warbling Vireo
# 16        16  MGWA     MacGillivray's Warbler
# 17        17  STJA              Stellar's Jay
# 18        18  CONI           Common Nighthawk

# %%
display(
    rec_id_to_filename_df.shape,
    rec_id_to_filename_df[:10],
)
# Out:
# (645, 2)
#    rec_id                  filename
# 0       0  PC1_20090513_050000_0010
# 1       1  PC1_20090513_070000_0010
# 2       2  PC1_20090606_050012_0010
# 3       3  PC1_20090606_070012_0010
# 4       4  PC1_20090705_050000_0010
# 5       5  PC1_20090705_070000_0010
# 6       6  PC1_20090804_050011_0010
# 7       7  PC1_20090804_070012_0010
# 8       8  PC1_20100513_043000_0010
# 9       9  PC1_20100513_043000_0720

# %%
display(
    sample_submission_df.shape,
    sample_submission_df[:10],
)
# Out:
# (6137, 3)
#    rec_id  species  probability
# 0       0        0            0
# 1       0        1            0
# 2       0        2            0
# 3       0        3            0
# 4       0        4            0
# 5       0        5            0
# 6       0        6            0
# 7       0        7            0
# 8       0        8            0
# 9       0        9            0

# %%
# Test examples are '[labels]' = '?'
display(
    rec_labels_test_hidden_df.shape,
    rec_labels_test_hidden_df[:10],
)
# Out:
# (645, 2)
# 0  rec_id [labels]
# 1       0        ?
# 2       1        ?
# 3       2    11,12
# 4       3     None
# 5       4        ?
# 6       5       10
# 7       6        ?
# 8       7        ?
# 9       8     None
# 10      9     None

# %%
# Split train vs. test
train_labels_df = rec_labels_test_hidden_df[lambda df: df['[labels]'] != '?']
test_labels_df = rec_labels_test_hidden_df[lambda df: df['[labels]'] == '?']

# %%
display(
    test_labels_df.shape,
    test_labels_df[:10],
)
# Out:
# (323, 2)
# 0  rec_id [labels]
# 1       0        ?
# 2       1        ?
# 5       4        ?
# 7       6        ?
# 8       7        ?
# 11     10        ?
# 13     12        ?
# 18     17        ?
# 23     22        ?
# 28     27        ?

# %%
display(
    train_labels_df.shape,
    train_labels_df[:10],
)
# Out:
# (322, 2)
# 0  rec_id [labels]
# 3       2    11,12
# 4       3     None
# 6       5       10
# 9       8     None
# 10      9     None
# 12     11     None
# 14     13    15,17
# 15     14     None
# 16     15     None
# 17     16     None

# %%
# How many train vs. test recordings?
(rec_labels_test_hidden_df
    .assign(group=lambda df: df['[labels]'].map(lambda x: 'test' if x == '?' else 'train'))
    .assign(n=1).groupby('group')['n'].count()
)
# Out:
# group
# test     323
# train    322
# Name: n, dtype: int64

# %%
(train_labels_df
    ['[labels]']
    .fillna('')
    .map(lambda s: [int(x) for x in s.split(',') if x != ''])
    .map(lambda class_ids: len(class_ids))
    .pipe(gghist)
    + xlab('num species in same recording')
    + ylab('num recordings')
    + ggtitle('How many species per training recording?')
)
# Out:
# <ggplot: (304652527)>

# %%
(train_labels_df
    .fillna({'[labels]': '-1'})
    .astype({'rec_id': 'int'})
    .set_index('rec_id')['[labels]']
    .fillna('')
    .map(lambda s: [int(x) for x in s.split(',') if x != ''])
    .apply(pd.Series).unstack()  # flatmap
    .reset_index(level=0, drop=True)  # Drop 'level' index
    .sort_index().reset_index()  # Sort and reset 'rec_id' index
    .rename(columns={0: 'class_id'})
    .dropna()
    .merge(species_df, how='left', on='class_id').drop(columns=['class_id'])
    .fillna({'code': 'none', 'species': 'none'})
    .pipe(ggplot, aes(x='code'))
    + geom_bar()
    + coord_flip()
    + xlab('species')
    + ylab('num recordings')
    + ggtitle('How many training recordings per species? (multiple species per recording)')
)
# Out:
# <ggplot: (-9223372036547378158)>

# %%
recs_paths = load_recs_paths(['mlsp-2013'])
display(
    recs_paths.shape,
    recs_paths.groupby('dataset').head(5),
    recs_paths.dataset.value_counts(),
)
# Out:
# (645, 2)
#      dataset                                                                                  path
# 0  mlsp-2013  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20090513_054500_0010.wav
# 1  mlsp-2013  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20090513_054500_0020.wav
# 2  mlsp-2013  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20090513_054500_0030.wav
# 3  mlsp-2013  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20090513_054500_0040.wav
# 4  mlsp-2013  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20090513_070000_0010.wav
# mlsp-2013    645
# Name: dataset, dtype: int64

# %%
recs = load_recs_data(
    (recs_paths
        # .sample(1000)  # For faster dev
    ),
    # FIXME pickling AudioSegment's across processes makes this (1) slow and (2) super-linearly slow
    #   - TODO We want 'processes' par for converting audio to std .wav format and 'threads' par for loading from std
    #     .wav, so split the convert (metadata_only=True) + load (metadata_only=False) steps to separate these concerns
    # metadata_only=True, dask_opts=dict(scheduler='processes'),
    metadata_only=False, dask_opts=dict(scheduler='threads'),
)
display(
    recs.shape,
    recs[:20],
    recs[:1].T,
)
# Out:
# [                                                                                          ] | 0% Completed |  0.0s
# [                                                                                          ] | 0% Completed |  0.1s
# [##################                                                                        ] | 21% Completed |  0.2s
# [##################                                                                        ] | 21% Completed |  0.3s
# [#####################################                                                     ] | 42% Completed |  0.4s
# [#####################################                                                     ] | 42% Completed |  0.5s
# [########################################################                                  ] | 63% Completed |  0.7s
# [########################################################                                  ] | 63% Completed |  0.8s
# [###########################################################################               ] | 84% Completed |  0.9s
# [##########################################################################################] | 100% Completed |  1.0s
# (645, 10)
#       dataset                                                                              name         species species_query                   basename  duration_s  samples_mb  samples_n                                                                                                                                                                                                  samples                                                                                                                                    audio
# 0   mlsp-2013  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20090513_054500_0010            XXXX          None  PC10_20090513_054500_0010        10.0       0.421     220500  [-72, -48, -7, -40, -97, -108, -105, -114, -102, -76, -91, -111, -89, -65, -58, -48, -58, -80, -40, -2, -50, -73, -21, -45, -130, -123, -60, -44, -44, -33, -17, -5, -46, -104, -113, -145, -200, -1...  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20090513_054500_0010: 1 channels, 16 bit, sampled @ 22.05 kHz, 10.000s long
# 1   mlsp-2013  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20090513_054500_0020            none          None  PC10_20090513_054500_0020        10.0       0.421     220500  [90, 67, 42, 71, 80, 101, 167, 183, 171, 193, 195, 174, 147, 71, 12, 20, 8, -18, 10, 46, 83, 129, 125, 93, 82, 53, 24, 39, 49, 52, 63, 22, -19, 5, 5, -23, 6, 50, 75, 115, 102, 32, 5, 10, 19, 37, 1...  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20090513
mlsp-2013  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20090705_044500_0030            XXXX          None  PC10_20090705_044500_0030        10.0       0.421     220500  [25, -2, -9, 15, 12, 11, 6, -42, -56, -31, -39, -18, 23, -7, -22, 19, 15, -6, 7, 4, 7, 21, -7, -21, 5, 20, 36, 43, 29, 42, 47, 13, 1, -4, -22, 9, 56, 51, 26, 27, 57, 60, -7, -53, -25, 12, 37, 59, ...  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20090705_044500_0030: 1 channels, 16 bit, sampled @ 22.05 kHz, 10.000s long
# 19  mlsp-2013  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20090705_044500_0040            none          None  PC10_20090705_044500_0040        10.0       0.421     220500  [4, -1, 51, 74, 58, 101, 138, 96, 68, 66, 36, 19, 27, 31, 52, 73, 67, 33, -8, 4, 41, 12, -12, 34, 49, 25, 33, 38, 42, 71, 81, 96, 123, 75, -4, 3, 36, 30, 27, 31, 15, 6, 12, -2, -22, -1, 27, 12, 25...  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20090705_044500_0040: 1 channels, 16 bit, sampled @ 22.05 kHz, 10.000s long
#                                                                                                                                                                                                                      0
# dataset                                                                                                                                                                                                      mlsp-2013
# name                                                                                                                                  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20090513_054500_0010
# species                                                                                                                                                                                                           XXXX
# species_query                                                                                                                                                                                                     None
# basename                                                                                                                                                                                     PC10_20090513_054500_0010
# duration_s                                                                                                                                                                                                          10
# samples_mb                                                                                                                                                                                                       0.421
# samples_n                                                                                                                                                                                                       220500
# samples        [-72, -48, -7, -40, -97, -108, -105, -114, -102, -76, -91, -111, -89, -65, -58, -48, -58, -80, -40, -2, -50, -73, -21, -45, -130, -123, -60, -44, -44, -33, -17, -5, -46, -104, -113, -145, -200, -1...
# audio                                                                          mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20090513_054500_0010: 1 channels, 16 bit, sampled @ 22.05 kHz, 10.000s long

# %%
# Stats
(recs
    .fillna('')
    .assign(
        n=1,
        duration_h=lambda df: df.duration_s / 3600,
        samples_gb=lambda df: df.samples_mb / 1024,
    )
    .groupby([
        'dataset',
        'species',
    ])
    [['n', 'duration_h', 'samples_gb', 'samples_n']]
    .sum()
)
# Out:
#                                            n  duration_h  samples_gb  samples_n
# dataset   species
# mlsp-2013 BHGB                             1       0.003   4.107e-04     220500
#           BHGB,CONI,HEWA,SWTH              1       0.003   4.107e-04     220500
#           BHGB,GCKI                        2       0.006   8.214e-04     441000
#           BHGB,GCKI,MGWA                   1       0.003   4.107e-04     220500
#           BHGB,GCKI,SWTH                   1       0.003   4.107e-04     220500
#           BRCR                             2       0.006   8.214e-04     441000
#           BRCR,CBCH,VATH                   1       0.003   4.107e-04     220500
#           BRCR,HEWA                        1       0.003   4.107e-04     220500
#           BRCR,OSFL                        1       0.003   4.107e-04     220500
#           BRCR,PSFL                        2       0.006   8.214e-04     441000
#           CBCH                             4       0.011   1.643e-03     882000
#           CBCH,CONI                        1       0.003   4.107e-04     220500
#           CBCH,CONI,HEWA,SWTH              1       0.003   4.107e-04     220500
#           CBCH,DEJU                        1       0.003   4.107e-04     220500
#           CBCH,DEJU,HETH,HEWA,PSFL,SWTH    1       0.003   4.107e-04     220500
#           CBCH,DEJU,HETH,HEWA,SWTH         1       0.003   4.107e-04     220500
#           CBCH,HAFL,PAWR,WETA              1       0.003   4.107e-04     220500
#           CBCH,HETH,SWTH                   1       0.003   4.107e-04     220500
#           CBCH,OSFL,RBNU,VATH              1       0.003   4.107e-04     220500
#           CBCH,PAWR,PSFL,WETA              1       0.003   4.107e-04     220500
#           CBCH,PAWR,SWTH                   1       0.003   4.107e-04     220500
#           CBCH,PAWR,WETA                   1       0.003   4.107e-04     220500
#           PAWR,SWTH,VATH                   1       0.003   4.107e-04     220500
#           PAWR,SWTH,WETA                   1       0.003   4.107e-04     220500
#           PAWR,WETA                        2       0.006   8.214e-04     441000
#           PSFL                             2       0.006   8.214e-04     441000
#           PSFL,RBNU                        1       0.003   4.107e-04     220500
#           PSFL,SWTH                        2       0.006   8.214e-04     441000
#           RBNU                             1       0.003   4.107e-04     220500
#           STJA                             4       0.011   1.643e-03     882000
#           STJA,WAVI                        1       0.003   4.107e-04     220500
#           SWTH                            12       0.033   4.929e-03    2646000
#           SWTH,VATH                        1       0.003   4.107e-04     220500
#           SWTH,WAVI                        1       0.003   4.107e-04     220500
#           SWTH,WETA                        1       0.003   4.107e-04     220500
#           VATH                             7       0.019   2.875e-03    1543500
#           WAVI                             1       0.003   4.107e-04     220500
#           WETA                             2       0.006   8.214e-04     441000
#           XXXX                           323       0.897   1.327e-01   71221500
#           none                           143       0.397   5.873e-02   31531500

# %%
# TODO What did 'XXXX' vs. 'none' mean here? [see datasets.metadata_from_audio]

# %%
recs_multi = (recs
    .pipe(df_flatmap_list_col, 'species', lambda s: s.str.split(','))
)
display(
    recs_multi.shape,
    recs_multi[:20]
)
# Out:
# (807, 10)
#       dataset                                                                              name species species_query                   basename  duration_s  samples_mb  samples_n                                                                                                                                                                                                  samples                                                                                                                                    audio
# 0   mlsp-2013  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20090513_054500_0010    XXXX          None  PC10_20090513_054500_0010        10.0       0.421     220500  [-72, -48, -7, -40, -97, -108, -105, -114, -102, -76, -91, -111, -89, -65, -58, -48, -58, -80, -40, -2, -50, -73, -21, -45, -130, -123, -60, -44, -44, -33, -17, -5, -46, -104, -113, -145, -200, -1...  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20090513_054500_0010: 1 channels, 16 bit, sampled @ 22.05 kHz, 10.000s long
# 1   mlsp-2013  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20090513_054500_0020    none          None  PC10_20090513_054500_0020        10.0       0.421     220500  [90, 67, 42, 71, 80, 101, 167, 183, 171, 193, 195, 174, 147, 71, 12, 20, 8, -18, 10, 46, 83, 129, 125, 93, 82, 53, 24, 39, 49, 52, 63, 22, -19, 5, 5, -23, 6, 50, 75, 115, 102, 32, 5, 10, 19, 37, 1...  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20090513_054500_0020: 1 channels, 16 bit, sampled @ 22.05 kHz, 10.000s long
# 2   mlsp-2013  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20090513_054500_0030    none          None  PC10_20090513_054500_0030        10.0       0.421     220500  [45, -21, -74, -43, -28, -30, 8, 14, -19, -33, -51, -84, -103, -120, -125, -84, -46, -56, -96, -130, -142, -133, -111, -78, -38, 10, 36, 6, -23, 19, 51, 33, 35, 22, -52, -109, -115, -113, -109, -1...  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20090513_054500_0030: 1 channels, 16 bit, sampled @ 22.05 kHz, 10.000s long
# 3   mlsp-2013  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20090513_054500_0040    none          None  PC10_20090513_054500_0040        10.0       0.421     220500  [4, -28, -10, 26, 1, -39, -35, -15, -15, -18, -15, -4, 12, 26, 23, 16, 7, -29, -60, -33, -11, -51, -62, -14, 5, -12, -9, -30, -73, -57, -6, 4, 4, 38, 72, 75, 58, 46, 65, 87, 68, 21, -20, -54, -64,...  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20090513_054500_0040: 1 channels, 16 bit, sampled @ 22.05 kHz, 10.000s long
# 4   mlsp-2013  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20090513_070000_0010    none          None  PC10_20090513_070000_0010        10.0       0.421     220500  [9, 11, -36, -41, -5, -26, -54, -26, -35, -69, -50, -23, -28, -34, -33, -14, -4, -35, -39, 11, 27, 28, 78, 98, 33, -13, 9, 21, -9, -25, -27, -58, -77, -48, -38, -65, -69, -63, -91, -101, -56, -11,...  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20090513
mlsp-2013  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20090606_054500_0040    VATH          None  PC10_20090606_054500_0040        10.0       0.421     220500  [111, 100, 85, 114, 100, 69, 81, 72, 23, -8, -22, -33, -37, -45, -29, 18, 48, 85, 138, 134, 98, 101, 99, 79, 67, 33, 12, 52, 80, 63, 52, 25, -12, -5, 11, 5, -3, -27, -47, -24, 0, -7, -33, -63, -72...  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20090606_054500_0040: 1 channels, 16 bit, sampled @ 22.05 kHz, 10.000s long
# 14  mlsp-2013  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20090606_074500_0010    BRCR          None  PC10_20090606_074500_0010        10.0       0.421     220500  [-8, -51, -101, -108, -58, -39, -90, -101, -63, -71, -100, -92, -69, -48, -48, -78, -78, -34, 14, 27, -18, -53, -32, -39, -67, -63, -93, -115, -36, 12, -33, -40, -17, -9, 30, 52, 21, 16, 50, 85, 7...  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20090606_074500_0010: 1 channels, 16 bit, sampled @ 22.05 kHz, 10.000s long
# 15  mlsp-2013  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20090606_074500_0010    PSFL          None  PC10_20090606_074500_0010        10.0       0.421     220500  [-8, -51, -101, -108, -58, -39, -90, -101, -63, -71, -100, -92, -69, -48, -48, -78, -78, -34, 14, 27, -18, -53, -32, -39, -67, -63, -93, -115, -36, 12, -33, -40, -17, -9, 30, 52, 21, 16, 50, 85, 7...  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20090606_074500_0010: 1 channels, 16 bit, sampled @ 22.05 kHz, 10.000s long
# 16  mlsp-2013  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20090606_074500_0020    XXXX          None  PC10_20090606_074500_0020        10.0       0.421     220500  [131, 146, 112, 90, 58, 55, 85, 80, 92, 143, 131, 103, 127, 114, 80, 82, 66, 63, 100, 70, 11, 17, -7, -49, -4, 40, 36, 78, 120, 107, 113, 116, 55, 4, 29, 80, 83, 36, 12, 24, 15, 19, 73, 108, 95, 7...  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20090606_074500_0020: 1 channels, 16 bit, sampled @ 22.05 kHz, 10.000s long
# 17  mlsp-2013  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20090606_074500_0030    BRCR          None  PC10_20090606_074500_0030        10.0       0.421     220500  [46, 93, 104, 88, 67, 29, 0, 6, 17, 10, -9, -19, 9, 58, 79, 73, 62, 69, 105, 121, 89, 47, 22, 15, 20, 18, 28, 72, 102, 103, 102, 88, 83, 114, 143, 143, 131, 111, 85, 13, -99, -108, -22, 0, -13, 28...  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20090606_074500_0030: 1 channels, 16 bit, sampled @ 22.05 kHz, 10.000s long
# 18  mlsp-2013  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20090606_074500_0030    PSFL          None  PC10_20090606_074500_0030        10.0       0.421     220500  [46, 93, 104, 88, 67, 29, 0, 6, 17, 10, -9, -19, 9, 58, 79, 73, 62, 69, 105, 121, 89, 47, 22, 15, 20, 18, 28, 72, 102, 103, 102, 88, 83, 114, 143, 143, 131, 111, 85, 13, -99, -108, -22, 0, -13, 28...  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20090606_074500_0030: 1 channels, 16 bit, sampled @ 22.05 kHz, 10.000s long
# 19  mlsp-2013  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20090606_074500_0040    XXXX          None  PC10_20090606_074500_0040        10.0       0.421     220500  [43, 82, 66, 78, 112, 83, 73, 80, -26, -83, 22, 40, -10, 58, 86, 58, 117, 60, -83, -1, 77, -49, -39, 102, 88, 90, 192, 146, 50, 97, 133, 90, 55, -1, -45, -4, 6, -57, -41, 15, -10, -6, 49, 38, 28, ...  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20090606_074500_0040: 1 channels, 16 bit, sampled @ 22.05 kHz, 10.000s long

# %%
# Stats
(recs_multi
    .fillna('')
    .assign(
        n=1,
        duration_h=lambda df: df.duration_s / 3600,
        samples_gb=lambda df: df.samples_mb / 1024,
    )
    .groupby([
        'dataset',
        'species',
    ])
    [['n', 'duration_h', 'samples_gb', 'samples_n']]
    .sum()
)
# Out:
#                      n  duration_h  samples_gb  samples_n
# dataset   species
# mlsp-2013 BHGB       6       0.017       0.002    1323000
#           BRCR       7       0.019       0.003    1543500
#           CBCH      22       0.061       0.009    4851000
#           CONI      16       0.044       0.007    3528000
#           DEJU      13       0.036       0.005    2866500
#           GCKI      18       0.050       0.007    3969000
#           HAFL      12       0.033       0.005    2646000
#           HETH      25       0.069       0.010    5512500
#           HEWA      25       0.069       0.010    5512500
#           MGWA       4       0.011       0.002     882000
#           OSFL       8       0.022       0.003    1764000
#           PAWR      35       0.097       0.014    7717500
#           PSFL      21       0.058       0.009    4630500
#           RBNU       4       0.011       0.002     882000
#           STJA       6       0.017       0.002    1323000
#           SWTH      64       0.178       0.026   14112000
#           VATH      29       0.081       0.012    6394500
#           WAVI       8       0.022       0.003    1764000
#           WETA      18       0.050       0.007    3969000
#           XXXX     323       0.897       0.133   71221500
#           none     143       0.397       0.059   31531500

# %%
# TODO
#   - [ ] Inspect random spectros: how much non-bird time? how much noise?

# %%
recs_test = (recs
    [lambda df: ~df.species.isin(['XXXX', 'none'])]
    [lambda df: df.species.str.split(',').str.len() == 1]
)
display(
    recs_test.shape,
    recs_test[:10],
    (recs_test
        .assign(n=1)
        .groupby(['dataset', 'species'])
        ['n'].sum()
    ),
)
# Out:
# (82, 10)
#       dataset                                                                              name species species_query                   basename  duration_s  samples_mb  samples_n                                                                                                                                                                                                  samples                                                                                                                                    audio
# 23  mlsp-2013  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20090705_071500_0040    PAWR          None  PC10_20090705_071500_0040        10.0       0.421     220500  [-16, -14, -30, -38, -36, -45, -39, -13, -12, -32, -40, -25, -15, -33, -46, -38, -60, -78, -37, -22, -63, -40, 11, -24, -55, -12, 1, -37, -37, -5, 11, 20, 16, 10, 25, 38, 40, 48, 24, -17, -13, 4, ...  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20090705_071500_0040: 1 channels, 16 bit, sampled @ 22.05 kHz, 10.000s long
# 43  mlsp-2013  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20100606_070000_0010    PAWR          None  PC10_20100606_070000_0010        10.0       0.421     220500  [75, 62, 56, 66, 23, -24, -5, 30, 27, 20, 67, 120, 71, -19, 30, 148, 113, 24, 109, 189, 49, -45, 116, 249, 109, -98, -90, 61, 43, -125, -100, 84, 71, -62, 8, 185, 163, -6, -15, 150, 133, -97, -120...  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20100606_070000_0010: 1 channels, 16 bit, sampled @ 22.05 kHz, 10.000s long
# 49  mlsp-2013  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20100705_050000_0030    VATH          None  PC10_20100705_050000_0030        10.0       0.421     220500  [33, 40, 49, 70, 53, 0, -30, -28, -22, -23, -30, -9, 24, 11, -8, 9, 4, -40, -65, -74, -80, -54, -26, -28, -30, -24, -31, -36, -40, -60, -74, -62, -46, -50, -73, -97, -105, -95, -69, -48, -52, -65,...  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20100705_050000_0030: 1 channels, 16 bit, sampled @ 22.05 kHz, 10.000s long
# 53  mlsp-2013  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20100705_070000_0030    HEWA          None  PC10_20100705_070000_0030        10.0       0.421     220500  [-18, -5, 5, 2, 13, 29, 18, 15, 47, 72, 60, 34, 7, -23, -32, -34, -46, -24, 28, 43, 36, 55, 71, 56, 44, 52, 60, 43, 11, 6, 12, -5, -14, 12, 33, 38, 41, 35, 21, 11, 1, -13, -19, -14, -21, -40, -31,...  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20100705_070000_0030: 1 channels, 16 bit, sampled @ 22.05 kHz, 10.000s long
# 60  mlsp-2013  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20100804_070000_0020    SWTH          None  PC10_20100804_070000_0020        10.0       0.421     220500  [8, -2, 29, 56, 43, 38, 28, 7, 12, 1, -47, -44, -14, -25, -28, -1, 30, 67, 67, 13, -7, 10, 2, -7, -11, -51, -82, -69, -58, -60, -38, -4, 15, 14, 1, 2, 24, 24, 5, 16, 33, 21, 22, 45, 44, 20, -5, -2...  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC10_20100804_070000_0020: 1 channels, 16 bit, sampled @ 22.05 kHz, 10.000s long
# 73  mlsp-2013  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC11_20090606_050000_0030    BHGB          None  PC11_20090606_050000_0030        10.0       0.421     220500  [23, 23, 20, 43, 73, 35, -36, -33, -17, -48, -3, 82, 43, -42, -30, 39, 87, 68, -4, -35, -15, 25, 94, 131, 98, 81, 70, 32, 75, 160, 108, -8, -40, -39, -15, 56, 75, 15, -27, -27, -7, 28, 30, -13, -6...  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC11_20090606_050000_0030: 1 channels, 16 bit, sampled @ 22.05 kHz, 10.000s long
# 74  mlsp-2013  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC11_20090606_050000_0040    WETA          None  PC11_20090606_050000_0040        10.0       0.421     220500  [36, 21, -13, -4, 21, 35, 48, 45, 38, 22, -32, -50, 11, 27, -18, -8, 6, -65, -141, -153, -154, -173, -130, -24, 5, -46, -53, -55, -120, -124, -71, -63, -31, 36, 6, -60, -61, -52, -45, -33, -63, -9...  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC11_20090606_050000_0040: 1 channels, 16 bit, sampled @ 22.05 kHz, 10.000s long
# 77  mlsp-2013  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC11_20090606_070000_0030    WAVI          None  PC11_20090606_070000_0030        10.0       0.421     220500  [-10, -12, -22, -42, -50, -68, -117, -111, -47, -57, -107, -49, 32, -19, -98, -100, -83, -76, -49, -11, 41, 72, 40, 28, 77, 81, 69, 134, 159, 123, 169, 220, 180, 158, 159, 118, 110, 143, 139, 151,...  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC11_20090606_070000_0030: 1 channels, 16 bit, sampled @ 22.05 kHz, 10.000s long
# 84  mlsp-2013  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC11_20090705_070000_0030    HETH          None  PC11_20090705_070000_0030        10.0       0.421     220500  [-7, 18, 5, -13, 14, 24, -24, -51, -16, 16, 4, -8, 1, -6, -10, 23, 37, 3, -21, 4, 39, 33, 2, -8, -8, -18, -19, -29, -58, -54, -18, -6, -16, -21, -29, -31, -15, 3, 0, -12, 2, 40, 43, 25, 43, 71, 66...  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC11_20090705_070000_0030: 1 channels, 16 bit, sampled @ 22.05 kHz, 10.000s long
# 92  mlsp-2013  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC11_20100513_043000_0750    DEJU          None  PC11_20100513_043000_0750        10.0       0.421     220500  [81, 104, 105, 92, 31, -7, 34, 45, -32, -73, -12, 62, 71, 53, 46, 12, -47, -38, 40, 70, 29, -6, -15, 10, 56, 42, -10, -4, -2, -44, -30, 8, -14, -19, 11, 10, 33, 72, 32, -11, 21, 38, 23, 61, 114, 8...  mlsp-2013/mlsp_contest_dataset/essential_data/src_wavs/PC11_20100513_043000_0750: 1 channels, 16 bit, sampled @ 22.05 kHz, 10.000s long
# dataset    species
# mlsp-2013  BHGB        1
#            BRCR        2
#            CBCH        4
#            CONI        8
#            DEJU        1
#            GCKI        3
#            HAFL        3
#            HETH        9
#            HEWA       10
#            MGWA        2
#            PAWR       10
#            PSFL        2
#            RBNU        1
#            STJA        4
#            SWTH       12
#            VATH        7
#            WAVI        1
#            WETA        2
# Name: n, dtype: int64

# %%
# Spectros
model = Model(verbose_config=False)
display(dict(model.config))
spectros = Model._spectros(df_rows(recs_test), **model.config.patch_config.spectro_config)
display(len(spectros))
# Out:
# {
#   'agg_config': {'funs': ['mean', 'std', 'max']},
#   'class_knn_config': {'n_neighbors': 3},
#   'patch_config': {
#     'patch_length': 4,
#     'spectro_config': {
#       'f_bins': 40,
#       'f_min': 1000,
#       'frame_length': 512,
#       'frame_window': 'hann',
#       'hop_length': 256,
#       'sample_rate': 22050,
#     },
#   },
#   'proj_skm_config': {'k': 500, 'variance_explained': 0.99},
#   'verbose_config': False,
# }
# [Memory]164.6s, 2.7min  : Loading _spectros from /Users/danb/hack/bubo/data/cache/joblib/sp14/model/_spectros/0f288051d402481552af9bfdfa0dd598
# ____________________________________________spectros cache loaded - 0.2s, 0.0min
# 82

# %%
with with_figsize(width=24, aspect_ratio=1/16):
    for spectro in spectros[:10]:
        spectro.plot(show_audio=False, fancy=False)
        plt.show()

# %%
# %%time
from sp14.model import *
for i, config in enumerate([
    # AttrDict(n=None, proj_skm_config=dict(k=40, normalize=False, standardize=False, pca_whiten=True, do_pca=True)),  # Full (slow)
    AttrDict(n=50, proj_skm_config=dict(k=40, normalize=False, standardize=False, pca_whiten=True, do_pca=True)),  # Defaults
    AttrDict(n=50, proj_skm_config=dict(k=40, normalize=False, standardize=False, pca_whiten=False, do_pca=False)),
    AttrDict(n=50, proj_skm_config=dict(k=40, normalize=True, standardize=False, pca_whiten=False, do_pca=False)),
    AttrDict(n=50, proj_skm_config=dict(k=40, normalize=False, standardize=True, pca_whiten=False, do_pca=False)),
    AttrDict(n=50, proj_skm_config=dict(k=40, normalize=True, standardize=True, pca_whiten=False, do_pca=False)),
    AttrDict(n=50, proj_skm_config=dict(k=40, normalize=True, standardize=True, pca_whiten=True, do_pca=True)),
]):
    print(f'\n\ni[{i}] config[{config}]\n\n')
    model = Model(
        verbose_config=False,
        proj_skm_config=config.proj_skm_config,
    )
    # model.proj_skm_.args  # [Can't run until after model.fit_proj, below]

    # %%
    recs_test_n = (recs_test
        .pipe(sklearn.utils.shuffle, random_state=0)
        [:config.n]
    )

    # %%time
    # One skm example per rec (not one per recs_multi)
    #   - recs: 248s, 645 recs, 552765 patches
    #   - recs[:100]: 30s, 100 recs, 85700 patches
    #   - recs[:10]: (fast), 10 recs, 8570 patches
    model.fit_proj(recs_test_n)

    # %%
    # # TODO
    # #   - [ ] Inspect learned centroid patches: do they look plausible?

    # %%
    # # skm.transform(X)
    # # = (skm._pca_transform(X).T @ skm.D).T
    # # = (skm.pca.transform(X.T) @ skm.D).T
    # # = (X.T @ skm.pca.components_.T @ skm.D).T
    # # = skm.D.T @ skm.pca.components_ @ X
    # #
    # # skm.transform
    # # = skm.D.T @ skm.pca.components_

    # %%
    skm = model.proj_skm_
    skm_transform = (skm.D.T @ skm.pca.components_).T
    # display(
    #     skm.D.shape,
    #     skm.D,
    #     skm.pca.components_.shape,
    #     skm.pca.components_,
    #     skm_transform.shape,
    #     skm_transform,
    # )

    # %%
    # plt.imshow(skm.D, origin='lower')

    # %%
    # plt.imshow(skm_transform, origin='lower')

    # %%
    (fp, k) = skm_transform.shape
    p = 4
    f = fp // p
    x = np.array([
        skm_transform[i*f:(i+1)*f, j]
        for i in range(p)
        for j in range(k)
    ]).T
    # display(skm_transform.shape)
    # display(x.shape)
    plt.pcolormesh(x[:, :160])
    plt.show()

    # # %%
    # model.fit_class(recs_test_n)
    # display(
    #     model.test(recs_test_n, 'classes'),
    #     model.test(recs_test_n, 'kneighbors'),
    # )
