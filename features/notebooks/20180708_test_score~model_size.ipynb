# %%
from notebooks import *
print_sys_info()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The potoo.default_magic_magic extension is already loaded. To reload it, use:
#   %reload_ext potoo.default_magic_magic
# platform:
#   machine: x86_64
#   node: Dan-B.local
#   processor: i386
#   release: 15.6.0
#   system: Darwin
#   version: 'Darwin Kernel Version 15.6.0: Thu Jun 23 18:25:34 PDT 2016; root:xnu-3248.60.10~1/RELEASE_X86_64'
# cpu: 8
# mem: 16g
# swap: 18g

# %%
# Load models
load = Load()
projection = Projection.load('peterson-v0-26bae1c', features=Features(load=load))
# Out:
# [04:46:23.989] DEBUG  Projection.load
#   path: /Users/danb/hack/bubo/features/data/models/projection/peterson-v0-26bae1c.pkl

# %%
# Select recs
#   1. countries: Filter recs to these countries
#   2. com_names: Filter recs to these species
#   3. recs_at_least: Filter species to those with at least this many recs
#   4. num_species: Sample this many of the species
#   5. num_recs: Sample this many recs per species
get_recs_stats = lambda df: dict(sp=df.species.nunique(), recs=len(df))
puts_stats = lambda desc: partial(tap, f=lambda df: print('%-15s %12s (sp/recs)' % (desc, '%(sp)s/%(recs)s' % get_recs_stats(df))))
countries, com_names = countries_na, com_names_ca  # 400k/9.4k -> 60k/1.1k -> 35k/334
# recs_at_least, num_species, num_recs = 100, 100, 100  # ca[334/35k -> 127/25k -> 100/21k -> 100/10k   -> 100/10k]
# recs_at_least, num_species, num_recs =  50, 100, 100  # ca[334/35k -> 224/32k -> 100/16k -> 100/ 9.0k -> 100/ 9.0k]
# recs_at_least, num_species, num_recs =   0, 100, 100  # ca[334/35k -> 334/35k -> 100/12k -> 100/ 6.8k ->  99/ 6.8k]
# recs_at_least, num_species, num_recs =   0, 168, 100  # ca[334/34k -> 334/34k -> 168/18k -> 168/11k   -> 167/11k]    # (old 'all')
# recs_at_least, num_species, num_recs =   0, 168,  20  # ca[334/34k -> 334/35k -> 168/18k -> 168/ 3.2k -> 167/ 3.2k]  # (old 'recs')
recs_at_least, num_species, num_recs =  20, 168,  20    # ca[334/35k -> 296/35k -> 168/20k -> 168/ 3.4k -> 168/ 3.4k]  # (old 'recs')
# recs_at_least, num_species, num_recs =  20, 50,  100  # Faster dev
# recs_at_least, num_species, num_recs =  20, 50,  50   # Faster dev
# recs_at_least, num_species, num_recs =  20, 50,  20   # Faster dev
# recs_at_least, num_species, num_recs =  20, 50,  10   # Faster dev
# recs_at_least, num_species, num_recs =  20, 50,  5    # Faster dev
xcs = (xc.metadata
    .pipe(puts_stats('all'))
    # 1. countries: Filter recs to these countries
    [lambda df: df.country.isin(countries)]
    .pipe(puts_stats('countries'))
    # 2. com_names: Filter recs to these species
    [lambda df: df.com_name.isin(com_names)]
    .pipe(puts_stats('com_names'))
    # Omit not-downloaded recs (should be few within the selected countries)
    [lambda df: df.downloaded]
    .pipe(puts_stats('(downloaded)'))
    # Remove empty cats for perf
    .pipe(df_remove_unused_categories)
    # 3. recs_at_least: Filter species to those with at least this many recs
    [lambda df: df.species.isin(df.species.value_counts()[lambda s: s >= recs_at_least].index)]
    .pipe(puts_stats('recs_at_least'))
    # 4. num_species: Sample this many of the species
    [lambda df: df.species.isin(df.species.drop_duplicates().pipe(lambda s: s.sample(n=min(len(s), num_species), random_state=0)))]
    .pipe(puts_stats('num_species'))
    # 5. num_recs: Sample this many recs per species
    #   - Remove empty cats else .groupby fails on empty groups
    .pipe(df_remove_unused_categories)
    .groupby('species').apply(lambda g: g.sample(n=min(len(g), num_recs), random_state=0))
    .pipe(puts_stats('num_recs'))
    # Drop species with <2 recs, else StratifiedShuffleSplit complains (e.g. 'TUVU')
    [lambda df: df.species.isin(df.species.value_counts()[lambda s: s >= 2].index)]
    .pipe(puts_stats('recs ≥ 2'))
    # Clean up for downstream
    .pipe(df_remove_unused_categories)
)
_recs_stats = get_recs_stats(xcs)
recs_stats = ', '.join(['%s[%s]' % (k, v) for k, v in _recs_stats.items()])
display(
    recs_stats,
    df_summary(xcs).T,
    xcs.sample(n=10, random_state=0).sort_values('species'),
)
# Out:
# all              9442/399859 (sp/recs)
# countries         1148/59713 (sp/recs)
# com_names          334/35236 (sp/recs)
# (downloaded)       334/35232 (sp/recs)
# recs_at_least      296/34846 (sp/recs)
# num_species        168/19640 (sp/recs)
# num_recs            168/3360 (sp/recs)
# recs ≥ 2            168/3360 (sp/recs)
# 'sp[168], recs[3360]'
#                                                                                                                          min                                               25%                                           50%                                                  75%                                        max
#                dtype          sizeof len  count nunique mean        std
# downloaded     bool           94080  3360 3360  1       NaN         NaN                                                 True                                              True                                          True                                                 True                                       True
# species        category       178080 3360 3360  168     NaN         NaN                                                 GWFG                                              GBTE                                          REVI                                                 NOWA                                       AMGO
# id             int64          94080  3360 3360  3360     213283.439 108055.964                                          1133                                            138144                                        193564                                               308285                                     416744
# sci_name       category       227200 3360 3360  168     NaN         NaN                                      Anser albifrons                             Gelochelidon nilotica                               Vireo olivaceus                              Parkesia noveboracensis                             Spinus tristis
# com_name       category       220320 3360 3360  168     NaN         NaN                          Greater White-fronted Goose                                  Gull-billed Tern                                Red-eyed Vireo                                 Northern Waterthrush                         American Goldfinch
# subspecies     object         169603 3360 3360  205     NaN         NaN                                                                                                                                                                                                                                              zaboria
# recordist      object         211728 3360 3360  291     NaN         NaN                                              AJ Knue                                     Frank Lambert                          Matthias Feuersenger                                        Peter Boesman                                   tetiaroa
# country        object         203063 3360 3360  3       NaN         NaN                                               Canada                                     United States                                 United States                                        United States                              United States
# locality       object         316516 3360 3360  1740    NaN         NaN                Bahía la Ventosa, Salina Cruz, Oaxaca  Desert Beeline Highway, Maricopa County, Arizona             May Lake, Yosemite NP, California  Sabine Nature Trail loop, Cameron Parish, Louisiana                          west of Thorp, WA
# lat            float64        80640  3360 3308  1768     37.885     9.895                                               15.6                                              31.9                                          35.8                                                 43.8                                       71.3
# lng            float64        80640  3360 3308  1782    -107.691    19.351                                              -177                                              -118                                          -110                                                  -95                                        -54
# type           object         191561 3360 3360  339     NaN         NaN                                   "chekurrrrrr" call                                              call                                    call, male                                                 song                                   wipe-out
# quality        category       194711 3360 3360  6       NaN         NaN                                                    A                                                 A                                             B                                                    B                                   no score
# date           datetime64[ns] 430080 3360 3360  1569    NaN         NaN                                  1985-06-25 00:00:00                               2011-09-28 00:00:00                           2013-09-18 00:00:00                                  2015-06-12 00:00:00                        2018-05-23 00:00:00
# time           object         180924 3360 3360  896     NaN         NaN                                                    ?                                              0820                                       10:00am                                                 1513                                         am
# license_type   category       191388 3360 3360  3       NaN         NaN                                             by-nc-nd                                          by-nc-nd                                      by-nc-sa                                             by-nc-sa                                      by-sa
# license_detail category       174720 3360 3360  3       NaN         NaN                                                  2.5                                               3.0                                           4.0                                                  4.0                                        4.0
# license        object         312348 3360 3360  7       NaN         NaN         //creativecommons.org/licenses/by-nc-nd/2.5/      //creativecommons.org/licenses/by-nc-nd/4.0/  //creativecommons.org/licenses/by-nc-sa/4.0/         //creativecommons.org/licenses/by-nc-sa/4.0/  //creativecommons.org/licenses/by-sa/4.0/
# url            object         275034 3360 3360  3360    NaN         NaN                    https://www.xeno-canto.org/100121                 https://www.xeno-canto.org/160005             https://www.xeno-canto.org/236694                     https://www.xeno-canto.org/34583           https://www.xeno-canto.org/99812
# download       object         285114 3360 3360  3360    NaN         NaN                 //www.xeno-canto.org/100121/download              //www.xeno-canto.org/160005/download          //www.xeno-canto.org/236694/download                  //www.xeno-canto.org/34583/download        //www.xeno-canto.org/99812/download
#                 downloaded species      id               sci_name                 com_name    subspecies           recordist        country                                                                    locality     lat      lng                           type   quality       date   time license_type license_detail                                       license                                url                              download
# species
# COGA    205189        True    COGA  207451      Gallinula galeata         Common Gallinule  sandvicensis       Ross Gallardy  United States                                             Kailua, Honolulu County, Hawaii  21.391 -157.743                           call         B 2014-12-21  07:30     by-nc-sa            4.0  //creativecommons.org/licenses/by-nc-sa/4.0/  https://www.xeno-canto.org/207451  //www.xeno-canto.org/207451/download
# INDO    18832         True    INDO  398616         Columbina inca                Inca Dove                  Manuel Grosselet         Mexico                                 Lomas de Bezares Miguel Hidalgo Mexico city  19.391  -99.244                           song         B 2018-01-07  08:00     by-nc-sa            4.0  //creativecommons.org/licenses/by-nc-sa/4.0/  https://www.xeno-canto.org/398616  //www.xeno-canto.org/398616/download
# EWPW    223194        True    EWPW  188611  Antrostomus vociferus   Eastern Whip-poor-will                 David Jonas Weber  United States                                 Gravelly Hill Rd., Salem County, New Jersey  39.495  -75.355                           song         C 2014-07-25  05:30     by-nc-sa            4.0  //creativecommons.org/licenses/by-nc-sa/4.0/  https://www.xeno-canto.org/188611  //www.xeno-canto.org/188611/download
# NUWO    113835        True    NUWO  301366     Picoides nuttallii     Nuttall's Woodpecker                      Denise Wight  United States                                     Moraga, Contra Costa County, California  37.832 -122.134  Hawk mobbing call, alarm call         C 2016-01-25  10:00     by-nc-sa            4.0  //creativecommons.org/licenses/by-nc-sa/4.0/  https://www.xeno-canto.org/301366  //www.xeno-canto.org/301366/download
# BBWO    80808         True    BBWO  335436      Picoides arcticus  Black-backed Woodpecker                Lance A. M. Benner  United States                              Blackrock Trailhead, Tulare County, California  36.175 -118.270                 drumming, male  no score 2016-09-17  16:41     by-nc-sa            4.0  //creativecommons.org/licenses/by-nc-sa/4.0/  https://www.xeno-canto.org/335436  //www.xeno-canto.org/335436/download
# HUVI    117936        True    HUVI  297126          Vireo huttoni           Hutton's Vireo                       Paul Marvin  United States                            Kickapoo Cavern State Park, Brackettville, Texas  29.618 -100.451                           song         C 2012-04-08  07:58     by-nc-sa            4.0  //creativecommons.org/licenses/by-nc-sa/4.0/  https://www.xeno-canto.org/297126  //www.xeno-canto.org/297126/download
# MGWA    89731         True    MGWA  326299     Geothlypis tolmiei   MacGillivray's Warbler                Lance A. M. Benner  United States  Buckhorn Campground, San Gabriel Mountains, Los Angeles County, California  34.346 -117.915                     male, song  no score 2016-06-28  10:49     by-nc-sa            4.0  //creativecommons.org/licenses/by-nc-sa/4.0/  https://www.xeno-canto.org/326299  //www.xeno-canto.org/326299/download
# PUFI    159786        True    PUFI  254326   Haemorhous purpureus             Purple Finch                              Iain         Canada                             Algonquin Highlands, Haliburton County, Ontario  45.306  -78.809                           song         C 2015-06-27  11:00     by-nc-sa            4.0  //creativecommons.org/licenses/by-nc-sa/4.0/  https://www.xeno-canto.org/254326  //www.xeno-canto.org/254326/download
# CAFI    46804         True    CAFI  369971    Haemorhous cassinii           Cassin's Finch                      Eric DeFonso  United States          Dunton Rd area, San Juan National Forest, Dolores County, Colorado  37.780 -108.040                           song         A 2016-06-28  15:00     by-nc-sa            4.0  //creativecommons.org/licenses/by-nc-sa/4.0/  https://www.xeno-canto.org/369971  //www.xeno-canto.org/369971/download
# AMGO    256886        True    AMGO  153552         Spinus tristis       American Goldfinch                  Mike Schanbacher  United States                                         Falmouth, Barnstable, Massachusetts  41.522  -70.668                     call, male         B 2013-05-01  12:00     by-nc-sa            3.0  //creativecommons.org/licenses/by-nc-sa/3.0/  https://www.xeno-canto.org/153552  //www.xeno-canto.org/153552/download

# %%
xcs_paths = [
    ('xc', f'{data_dir}/xc/data/{row.species}/{row.id}/audio.mp3')
    for row in df_rows(xcs)
]
joblib.dump(xcs_paths, '/tmp/xcs_paths')  # In case you want to run load.recs in a terminal (it's long and verbose)
display(
    len(xcs_paths),
    # xcs_paths[:2],
)
# Out:
# 3360

# %%
# TODO Restore once:true after debug [but think carefully how once:true interacts with the once:false params above]
recs = load.recs(paths=xcs_paths)
display(
    df_summary(recs).T,
    recs[:5],
)
# Out:
#                                                                                                         min                           25%                           50%                            75%                           max
#                  dtype    sizeof len  count nunique mean      std
# dataset          object   171360 3360 3360  1       NaN       NaN                                        xc                            xc                            xc                             xc                            xc
# species          category 178080 3360 3360  168     NaN       NaN                                      GWFG                          GBTE                          REVI                           NOWA                          AMGO
# species_com_name category 219160 3360 3360  168     NaN       NaN               Greater White-fronted Goose              Gull-billed Tern                Red-eyed Vireo           Northern Waterthrush            American Goldfinch
# species_query    object   178080 3360 3360  168     NaN       NaN                                      ACWO                          CONI                          LASP                           RIRA                          YRWA
# duration_s       float64  80640  3360 3360  3054    5.430e+01 7.031e+01                               0.697                          14.4                          31.8                           65.4                           940
# samples_mb       float64  80640  3360 3360  3055    2.286e+00 2.958e+00                              0.0293                         0.604                          1.34                           2.76                          39.5
# samples_n        int64    94080  3360 3360  3055    1.198e+06 1.551e+06                               15368                        316510                        701190                        1444435                      20731931
# basename         object   181440 3360 3360  1       NaN       NaN                                     audio                         audio                         audio                          audio                         audio
# species_longhand category 242680 3360 3360  168     NaN       NaN        Greater White-fronted Goose - GWFG       Gull-billed Tern - GBTE         Red-eyed Vireo - REVI    Northern Waterthrush - NOWA     American Goldfinch - AMGO
# id               object   248154 3360 3360  3360    NaN       NaN                 xc/data/ACWO/153315/audio      xc/data/CONI/77526/audio      xc/data/LASP/72200/audio      xc/data/RIRA/408562/audio      xc/data/YRWA/78150/audio
# path             object   261594 3360 3360  3360    NaN       NaN             xc/data/ACWO/153315/audio.mp3  xc/data/CONI/77526/audio.mp3  xc/data/LASP/72200/audio.mp3  xc/data/RIRA/408562/audio.mp3  xc/data/YRWA/78150/audio.mp3
#   dataset species             species_com_name species_query  duration_s  samples_mb  samples_n basename                    species_longhand                         id                           path
# 0      xc    GWFG  Greater White-fronted Goose          GWFG      23.712       0.997     522850    audio  Greater White-fronted Goose - GWFG  xc/data/GWFG/149379/audio  xc/data/GWFG/149379/audio.mp3
# 1      xc    GWFG  Greater White-fronted Goose          GWFG      18.312       0.770     403780    audio  Greater White-fronted Goose - GWFG  xc/data/GWFG/276918/audio  xc/data/GWFG/276918/audio.mp3
# 2      xc    GWFG  Greater White-fronted Goose          GWFG      44.957       1.891     991296    audio  Greater White-fronted Goose - GWFG  xc/data/GWFG/210100/audio  xc/data/GWFG/210100/audio.mp3
# 3      xc    GWFG  Greater White-fronted Goose          GWFG      17.554       0.738     387072    audio  Greater White-fronted Goose - GWFG  xc/data/GWFG/323113/audio  xc/data/GWFG/323113/audio.mp3
# 4      xc    GWFG  Greater White-fronted Goose          GWFG      23.952       1.007     528142    audio  Greater White-fronted Goose - GWFG  xc/data/GWFG/276919/audio  xc/data/GWFG/276919/audio.mp3

# %%
# Fast-and-cheap version (<1s) of the plot below (7s)
(recs
    .species_longhand.value_counts().sort_index()
    .reset_index().rename(columns={'index': 'species_longhand', 'species_longhand': 'num_recs'})
    .assign(num_recs=lambda df: df.num_recs.map(lambda n: '%s /%s' % ('•' * int(n / df.num_recs.max() * 60), df.num_recs.max())))
)
# Out:
#                          species_longhand                                                          num_recs
# 0      Greater White-fronted Goose - GWFG  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 1                          Gadwall - GADW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 2                  American Wigeon - AMWI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 3                          Mallard - MALL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 4                Green-winged Teal - GWTE  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 5                 California Quail - CAQU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 6                   Gambel's Quail - GAQU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 7                     Sooty Grouse - SOGR  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 8                      Wild Turkey - WITU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 9                      Common Loon - COLO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 10                Red-necked Grebe - RNGR  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 11          Black-footed Albatross - BFAL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 12        Double-crested Cormorant - DCCO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 13                American Bittern - AMBI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 14                   Least Bittern - LEBI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 15                Great Blue Heron - GBHE  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 16                     Great Egret - GREG  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 17                     Snowy Egret - SNEG  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 18                          Osprey - OSPR  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 19                 Swainson's Hawk - SWHA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 20                 Red-tailed Hawk - RTHA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 21                      Black Rail - BLRA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 22                  Ridgway's Rail - RIRA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 23                Common Gallinule - COGA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 24              Black-necked Stilt - BNST  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 25             Black Oystercatcher - BLOY  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 26             Semipalmated Plover - SEPL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 27                        Whimbrel - WHIM  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 28              Long-billed Curlew - LBCU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 29                  Rock Sandpiper - ROSA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 30                 Least Sandpiper - LESA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 31           Long-billed Dowitcher - LBDO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 32            Red-necked Phalarope - RNPH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 33              Greater Yellowlegs - GRYE  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 34                Bonaparte's Gull - BOGU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 35                   Laughing Gull - LAGU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 36                 Heermann's Gull - HEEG  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 37                Ring-billed Gull - RBGU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 38                    Western Gull - WEGU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 39                 California Gull - CAGU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 40            Glaucous-winged Gull - GWGU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 41                Gull-billed Tern - GBTE  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 42                    Caspian Tern - CATE  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 43                      Black Tern - BLTE  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 44                      Royal Tern - ROYT  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 45              Band-tailed Pigeon - BTPI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 46                       Inca Dove - INDO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 47              Common Ground-Dove - COGD  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 48            Yellow-billed Cuckoo - YBCU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 49                        Barn Owl - BANO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 50                Great Horned Owl - GHOW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 51                         Elf Owl - ELOW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 52                     Spotted Owl - SPOW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 53                Lesser Nighthawk - LENI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 54                Common Nighthawk - CONI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 55                 Common Poorwill - COPO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 56          Eastern Whip-poor-will - EWPW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 57          Mexican Whip-poor-will - MWPW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 58            White-throated Swift - WTSW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 59       Black-chinned Hummingbird - BCHU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 60        Broad-tailed Hummingbird - BTAH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 61                Acorn Woodpecker - ACWO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 62          Williamson's Sapsucker - WISA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 63          Red-breasted Sapsucker - RBSA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 64        Ladder-backed Woodpecker - LBWO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 65            Nuttall's Woodpecker - NUWO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 66                Hairy Woodpecker - HAWO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 67         White-headed Woodpecker - WHWO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 68         Black-backed Woodpecker - BBWO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 69                Northern Flicker - NOFL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 70              Western Wood-Pewee - WEWP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 71                Least Flycatcher - LEFL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 72                 Gray Flycatcher - GRFL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 73                Dusky Flycatcher - DUFL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 74        Pacific-slope Flycatcher - PSFL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 75                  Eastern Phoebe - EAPH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 76                    Say's Phoebe - SAPH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 77            Vermilion Flycatcher - VEFL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 78         Dusky-capped Flycatcher - DCFL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 79               Tropical Kingbird - TRKI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 80                Couch's Kingbird - COKI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 81                  Hutton's Vireo - HUVI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 82                  Warbling Vireo - WAVI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 83                  Red-eyed Vireo - REVI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 84              Yellow-green Vireo - YGVI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 85                        Gray Jay - GRAJ  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 86                      Pinyon Jay - PIJA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 87                   Steller's Jay - STJA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 88            California Scrub-Jay - CASJ  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 89           Woodhouse's Scrub-Jay - WOSJ  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 90              Clark's Nutcracker - CLNU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 91                    Common Raven - CORA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 92   Northern Rough-winged Swallow - NRWS  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 93                   Purple Martin - PUMA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 94            Violet-green Swallow - VGSW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 95                   Cliff Swallow - CLSW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 96              Mountain Chickadee - MOCH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 97       Chestnut-backed Chickadee - CBCH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 98                          Verdin - VERD  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 99                         Bushtit - BUSH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 100          Red-breasted Nuthatch - RBNU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 101                      Rock Wren - ROWR  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 102                    Canyon Wren - CANW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 103                    Winter Wren - WIWR  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 104                     Marsh Wren - MAWR  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 105                  Bewick's Wren - BEWR  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 106                    Cactus Wren - CACW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 107         California Gnatcatcher - CAGN  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 108       Black-tailed Gnatcatcher - BTGN  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 109                American Dipper - AMDI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 110           Ruby-crowned Kinglet - RCKI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 111               Western Bluebird - WEBL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 112              Mountain Bluebird - MOBL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 113           Townsend's Solitaire - TOSO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 114              Swainson's Thrush - SWTH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 115                  Hermit Thrush - HETH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 116                 American Robin - AMRO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 117                   Gray Catbird - GRCA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 118             Bendire's Thrasher - BETH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 119             LeConte's Thrasher - LCTH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 120               Crissal Thrasher - CRTH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 121              European Starling - EUST  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 122                 American Pipit - AMPI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 123                    Phainopepla - PHAI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 124               Lapland Longspur - LALO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 125           Northern Waterthrush - NOWA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 126         Orange-crowned Warbler - OCWA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 127                 Lucy's Warbler - LUWA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 128              Nashville Warbler - NAWA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 129         MacGillivray's Warbler - MGWA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 130            Common Yellowthroat - COYE  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 131                 Hooded Warbler - HOWA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 132                Northern Parula - NOPA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 133         Chestnut-sided Warbler - CSWA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 134          Yellow-rumped Warbler - YRWA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 135                Prairie Warbler - PRAW  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 136                Grace's Warbler - GRWA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 137                 Hermit Warbler - HEWA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 138               Cassin's Sparrow - CASP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 139          Black-chinned Sparrow - BCSP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 140         Black-throated Sparrow - BTSP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 141                   Lark Sparrow - LASP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 142                    Fox Sparrow - FOSP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 143          White-crowned Sparrow - WCSP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 144         Golden-crowned Sparrow - GCSP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 145         White-throated Sparrow - WTSP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 146                 Vesper Sparrow - VESP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 147                   Song Sparrow - SOSP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 148              Lincoln's Sparrow - LISP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 149         Rufous-crowned Sparrow - RCSP  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 150           Yellow-breasted Chat - YBCH  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 151                Western Tanager - WETA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 152              Northern Cardinal - NOCA  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 153         Rose-breasted Grosbeak - RBGR  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 154                 Indigo Bunting - INBU  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 155        Yellow-headed Blackbird - YHBL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 156                 Scott's Oriole - SCOR  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 157           Red-winged Blackbird - RWBL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 158             Brewer's Blackbird - BRBL  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 159           Great-tailed Grackle - GTGR  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 160                  Pine Grosbeak - PIGR  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 161                    House Finch - HOFI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 162                   Purple Finch - PUFI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 163                 Cassin's Finch - CAFI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 164                    Pine Siskin - PISI  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 165               Lesser Goldfinch - LEGO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 166           Lawrence's Goldfinch - LAGO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20
# 167             American Goldfinch - AMGO  •••••••••••••••••••••••••••••••••••••••••••••••••••••••••••• /20

# %%
(recs
    .assign(species=lambda df: df.species_longhand)
    .assign(count=1)
    # 0-fill all (species, dataset) combinations to create empty placeholders for missing bars
    .pipe(lambda df: df.append(
        pd.DataFrame([
            dict(species=species, dataset=dataset, duration_s=0)
            for species in df.species.unique()
            for dataset in df.dataset.unique()
        ])
        .astype({'species': df.species.dtype})
    ))
    .groupby(['dataset', 'species'])[['count', 'duration_s']].sum().reset_index()
    # Order by species by taxo
    .pipe(df_reverse_cat, 'species')
    # Order by species by count
    # .pipe(df_ordered_cat, species=lambda df: df.sort_values('count').species)
    .pipe(pd.melt, id_vars=['dataset', 'species'], value_vars=['count', 'duration_s'])
    .pipe(df_remove_unused_categories)
    .pipe(ggplot, aes(x='species', y='value', fill='dataset', color='dataset'))
    + coord_flip()
    + geom_bar(stat='identity', position=position_dodge(), width=.8)
    + facet_wrap('variable', nrow=1, scales='free')
    + xlab('')
    + ylab('')
    + scale_fill_cmap_d(mpl.cm.tab10)
    + scale_color_cmap_d(mpl.cm.tab10)
    + theme(panel_spacing=2.5)
    + theme_figsize(width=18, aspect_ratio=4/1)
    + ggtitle(f'recs: Total (count, duration_s) per (species, dataset)')
)
# Out:
# [skip]

# %%
# Add .feat
recs = projection.transform(recs)

# %%
# GridSearchCV many models / model params
#   - Order these roughly from most to least expensive, so that training runs fail fast (e.g. oom at the start, not the end)
param_grid = [
    dict(
        classifier=[

            # RandomForest(entropy)
            #   - 'gini' tends has better accuracy
            # 'cls: rf, criterion: entropy, n_estimators: 200',  # [SP14]

            # RandomForest(gini)
            #
            # WARNING These two are not very mem safe...
            #   - They finish, but they cause OSX to "Not responding" most/all of its apps at ~2-3 different times
            # 'cls: rf, criterion: gini, n_estimators: 2000',
            # 'cls: rf, criterion: gini, n_estimators: 1500',
            #
            # 'cls: rf, criterion: gini, n_estimators: 1000',
            # 'cls: rf, criterion: gini, n_estimators: 800',
            # 'cls: rf, criterion: gini, n_estimators: 600',
            # 'cls: rf, criterion: gini, n_estimators: 400',
            f'cls: rf, criterion: gini, n_estimators: 200, max_depth: {max_depth}',
            f'cls: rf, criterion: gini, n_estimators: 100, max_depth: {max_depth}',
            # 'cls: rf, criterion: gini, n_estimators: 50',
            # 'cls: rf, criterion: gini, n_estimators: 10',
            # 'cls: rf, criterion: gini, n_estimators: 1',

        ],
        n_species=[n_species if isinstance(n_species, int) else int(n_species * _recs_stats['sp'])],
        n_recs=[
            # n_recs if isinstance(n_recs, int) else int(n_recs * _recs_stats['recs']),
            # TODO Figure out how to represent this as an n instead of a frac again [TODO interaction with test_size=.2 ...]
            #   - TODO Also make clear in the plot descs when e.g. (recs[3360], n_species[33], n_recs[1.0]) -> n_recs[33*20 < 3360]
            n_recs,
        ],
    )
    for (n_species, n_recs) in [
        # Subset for learning curves
        #   - Biggest first, to fail fast

        # (None, None),

        (1.00, 1.00),
        (1.00, 0.50),
        # (0.75, 1.00),
        # (0.75, 0.50),
        (0.50, 1.00),
        # (0.50, 0.50),
        # (0.25, 1.00),
        # (0.25, 0.50),

        # (1.00, 1.00),
        # (1.00, 0.80),
        # (1.00, 0.60),
        # (1.00, 0.40),
        # (1.00, 0.20),

    ]
    # TODO TODO model_size ~ forest_depth
    for mean_depth_at_168_sp in [93.5]
    for max_depth in [
        'null',
        int(mean_depth_at_168_sp * n_species * 1),
        int(mean_depth_at_168_sp * n_species * 1/2),
        int(mean_depth_at_168_sp * n_species * 1/4),
        int(mean_depth_at_168_sp * n_species * 1/8),
        int(mean_depth_at_168_sp * n_species * 1/16),
    ]
]

# TODO Increase cv to decrease variance in eval metrics (this made Alex extremely squirmy)
cv = GridSearchCVCached(
    estimator=Search(projection=projection),
    param_grid=param_grid,
    refit=False,  # Don't spend time fitting cv.best_estimator_ at the end (default: True)
    # cv=3,  # [SP14] uses two-/three-fold CV [why?]
    # Stratified ensures that all classes have >0 instances in each split, which is statistically maybe fishy but avoids
    # breaking various code that merges the split results back together and assumes all splits' classes are the same
    cv=sk.model_selection.StratifiedShuffleSplit(
        # n_splits=1,  # [for ~18/20 miss: ~19m, ~16g disk cache]
        # n_splits=2,
        n_splits=3,
        # n_splits=5,
        # n_splits=10,
        # n_splits=20,  # Known good [>51m uncached, >25g disk cache]
        # n_splits=100,  # [?m runtime, ?g disk cache]
        test_size=.2,
        random_state=0,
    ),
    return_train_score=True,
    extra_metrics=dict(
        # [How to specify SearchEvals here without creating caching headaches?]
        #   - e.g. defs don't bust cache on code edit
        #   - And avoid thrashing cache every time we refactor SearchEvals
        classes='estimator.classes_',
        train_i='train',
        train_y='y_train',
        train_predict_proba='estimator.classifier_.predict_proba(X_train)',
        test_i='test',
        test_y='y_test',
        test_predict_proba='estimator.classifier_.predict_proba(X_test)',
        model_size='len(joblib_dumps(estimator))',
        model_stats='model_stats(estimator)',
        proc_stats='proc_stats',
    ),
    # return_estimator=True,  # Verrrry heavy, use extra_metrics instead
    # verbose=100,
    # verbose=10,  # O(models * n_splits) lines of outputs
    verbose=1,  # O(1) lines of outputs
    # Use n_jobs=1
    #   - All classifiers can parallelize .fit/.predict
    #   - Avoid memory contention
    n_jobs=1,  # Required for %prun
    artifacts=dict(
        # Stamp experiment_id once for all calls to _fit_and_score_cached [TODO Re-home this concern]
        experiment_id = '-'.join([datetime.utcnow().strftime('%Y%m%d-%H%M%S'), sha1hex(str(uuid.uuid4()))[:7]]),
        dir=f'{data_dir}/artifacts',  # TODO Iron out syncing across local/gs/remote
        extra=dict(estimator='estimator'),
        save=True,
        # load='20180705-033522-b6889a7',
    ),
)
with contextlib.ExitStack() as stack:
    # stack.enter_context(cache_control(refresh=True))  # Disk unsafe...
    stack.enter_context(cache_control(enabled=False))  # Disk safe
    # stack.enter_context(joblib.parallel_backend('threading'))  # Default: 'multiprocessing'
    # stack.enter_context(joblib.parallel_backend('sequential'))  # For %prun [FIXME Has no effect; why?]
    stack.enter_context(log.context(level='info'))
    # stack.enter_context(log.context(level='debug'))
    X, y = Search.Xy(recs)
    cv.fit(X, y)
# Out:
# Fitting 3 folds for each of 36 candidates, totalling 108 fits
# [04:46:29.739] INFO   artifacts
#   experiment_id: 20180708-044629-793bdc9
#   dir: /Users/danb/hack/bubo/features/data/artifacts
#   extra: {estimator: estimator}
#   save: true
# [04:46:29.751] INFO   _fit_and_score... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: null', random_state=0)]
# [04:46:52.825] INFO   _fit_and_score[22.966s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: null', random_state=0)]
# [04:46:55.036] INFO   _fit_and_score.save_artifacts... model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=null',random_state=0)]
# [04:46:56.430] INFO   _fit_and_score.save_artifacts[1.394s, 701.4 MB]: model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=null',random_state=0)]
# [04:46:56.436] INFO   _fit_and_score... split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: null', random_state=0)]
# [04:47:18.358] INFO   _fit_and_score[21.596s]: split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: null', random_state=0)]
# [04:47:20.707] INFO   _fit_and_score.save_artifacts... model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=null',random_state=0)]
# [04:47:22.176] INFO   _fit_and_score.save_artifacts[1.469s, 700.8 MB]: model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=null',random_state=0)]
# [04:47:22.180] INFO   _fit_and_score... split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: null', random_state=0)]
# [04:47:44.244] INFO   _fit_and_score[21.751s]: split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: null', random_state=0)]
# [04:47:46.420] INFO   _fit_and_score.save_artifacts... model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=null',random_state=0)]
# [04:47:48.117] INFO   _fit_and_score.save_artifacts[1.697s, 704.7 MB]: model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=null',random_state=0)]
# [04:47:48.120] INFO   _fit_and_score... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: null', random_state=0)]
# [04:47:59.536] INFO   _fit_and_score[11.113s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: null', random_state=0)]
# [04:48:01.444] INFO   _fit_and_score.save_artifacts... model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=null',random_state=0)]
# [04:48:02.359] INFO   _fit_and_score.save_artifacts[0.915s, 361.7 MB]: model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=null',random_state=0)]
# [04:48:02.364] INFO   _fit_and_score... split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: null', random_state=0)]
# [04:48:13.818] INFO   _fit_and_score[11.223s]: split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: null', random_state=0)]
# [04:48:15.657] INFO   _fit_and_score.save_artifacts... model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=null',random_state=0)]
# [04:48:16.495] INFO   _fit_and_score.save_artifacts[0.838s, 361.1 MB]: model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=null',random_state=0)]
# [04:48:16.499] INFO   _fit_and_score... split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: null', random_state=0)]
# [04:48:28.254] INFO   _fit_and_score[11.516s]: split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: null', random_state=0)]
# [04:48:29.764] INFO   _fit_and_score.save_artifacts... model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=null',random_state=0)]
# [04:48:30.681] INFO   _fit_and_score.save_artifacts[0.917s, 362.4 MB]: model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=null',random_state=0)]
# [04:48:30.686] INFO   _fit_and_score... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 93', random_state=0)]
# [04:48:53.210] INFO   _fit_and_score[22.296s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 93', random_state=0)]
# [04:48:55.770] INFO   _fit_and_score.save_artifacts... model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=93',random_state=0)]
# [04:48:57.565] INFO   _fit_and_score.save_artifacts[1.795s, 697.9 MB]: model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=93',random_state=0)]
# [04:48:57.569] INFO   _fit_and_score... split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 93', random_state=0)]
# [04:49:19.668] INFO   _fit_and_score[21.802s]: split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 93', random_state=0)]
# [04:49:21.809] INFO   _fit_and_score.save_artifacts... model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=93',random_state=0)]
# [04:49:23.580] INFO   _fit_and_score.save_artifacts[1.770s, 697.2 MB]: model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=93',random_state=0)]
# [04:49:23.584] INFO   _fit_and_score... split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 93', random_state=0)]
# [04:49:46.345] INFO   _fit_and_score[22.453s]: split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 93', random_state=0)]
# [04:49:48.811] INFO   _fit_and_score.save_artifacts... model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=93',random_state=0)]
# [04:49:50.600] INFO   _fit_and_score.save_artifacts[1.789s, 700.8 MB]: model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=93',random_state=0)]
# [04:49:50.605] INFO   _fit_and_score... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 93', random_state=0)]
# [04:50:02.132] INFO   _fit_and_score[11.225s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 93', random_state=0)]
# [04:50:03.946] INFO   _fit_and_score.save_artifacts... model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=93',random_state=0)]
# [04:50:04.873] INFO   _fit_and_score.save_artifacts[0.927s, 360.2 MB]: model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=93',random_state=0)]
# [04:50:04.877] INFO   _fit_and_score... split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 93', random_state=0)]
# [04:50:16.619] INFO   _fit_and_score[11.506s]: split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 93', random_state=0)]
# [04:50:18.134] INFO   _fit_and_score.save_artifacts... model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=93',random_state=0)]
# [04:50:19.049] INFO   _fit_and_score.save_artifacts[0.915s, 359.0 MB]: model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=93',random_state=0)]
# [04:50:19.052] INFO   _fit_and_score... split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 93', random_state=0)]
# [04:50:30.962] INFO   _fit_and_score[11.678s]: split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 93', random_state=0)]
# [04:50:32.351] INFO   _fit_and_score.save_artifacts... model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=93',random_state=0)]
# [04:50:33.261] INFO   _fit_and_score.save_artifacts[0.910s, 360.3 MB]: model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=93',random_state=0)]
# [04:50:33.266] INFO   _fit_and_score... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 46', random_state=0)]
# [04:50:53.716] INFO   _fit_and_score[20.218s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 46', random_state=0)]
# [04:50:56.095] INFO   _fit_and_score.save_artifacts... model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=46',random_state=0)]
# [04:50:57.529] INFO   _fit_and_score.save_artifacts[1.434s, 563.7 MB]: model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=46',random_state=0)]
# [04:50:57.533] INFO   _fit_and_score... split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 46', random_state=0)]
# [04:51:18.022] INFO   _fit_and_score[20.228s]: split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 46', random_state=0)]
# [04:51:20.387] INFO   _fit_and_score.save_artifacts... model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=46',random_state=0)]
# [04:51:21.843] INFO   _fit_and_score.save_artifacts[1.456s, 571.3 MB]: model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=46',random_state=0)]
# [04:51:21.846] INFO   _fit_and_score... split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 46', random_state=0)]
# [04:51:42.373] INFO   _fit_and_score[20.283s]: split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 46', random_state=0)]
# [04:51:44.728] INFO   _fit_and_score.save_artifacts... model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=46',random_state=0)]
# [04:51:46.164] INFO   _fit_and_score.save_artifacts[1.436s, 564.4 MB]: model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=46',random_state=0)]
# [04:51:46.168] INFO   _fit_and_score... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 46', random_state=0)]
# [04:51:56.982] INFO   _fit_and_score[10.569s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 46', random_state=0)]
# [04:51:58.312] INFO   _fit_and_score.save_artifacts... model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=46',random_state=0)]
# [04:51:59.072] INFO   _fit_and_score.save_artifacts[0.760s, 293.8 MB]: model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=46',random_state=0)]
# [04:51:59.075] INFO   _fit_and_score... split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 46', random_state=0)]
# [04:52:09.984] INFO   _fit_and_score[10.689s]: split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 46', random_state=0)]
# [04:52:11.200] INFO   _fit_and_score.save_artifacts... model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=46',random_state=0)]
# [04:52:11.947] INFO   _fit_and_score.save_artifacts[0.747s, 297.7 MB]: model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=46',random_state=0)]
# [04:52:11.950] INFO   _fit_and_score... split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 46', random_state=0)]
# [04:52:22.994] INFO   _fit_and_score[10.833s]: split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 46', random_state=0)]
# [04:52:24.043] INFO   _fit_and_score.save_artifacts... model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=46',random_state=0)]
# [04:52:24.799] INFO   _fit_and_score.save_artifacts[0.756s, 289.8 MB]: model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=46',random_state=0)]
# [04:52:24.803] INFO   _fit_and_score... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 23', random_state=0)]
# [04:52:39.892] INFO   _fit_and_score[14.891s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 23', random_state=0)]
# [04:52:41.078] INFO   _fit_and_score.save_artifacts... model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=23',random_state=0)]
# [04:52:41.791] INFO   _fit_and_score.save_artifacts[0.713s, 275.9 MB]: model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=23',random_state=0)]
# [04:52:41.794] INFO   _fit_and_score... split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 23', random_state=0)]
# [04:52:56.883] INFO   _fit_and_score[14.890s]: split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 23', random_state=0)]
# [04:52:58.058] INFO   _fit_and_score.save_artifacts... model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=23',random_state=0)]
# [04:52:58.789] INFO   _fit_and_score.save_artifacts[0.731s, 281.0 MB]: model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=23',random_state=0)]
# [04:52:58.793] INFO   _fit_and_score... split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 23', random_state=0)]
# [04:53:13.776] INFO   _fit_and_score[14.781s]: split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 23', random_state=0)]
# [04:53:15.068] INFO   _fit_and_score.save_artifacts... model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=23',random_state=0)]
# [04:53:15.783] INFO   _fit_and_score.save_artifacts[0.715s, 280.8 MB]: model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=23',random_state=0)]
# [04:53:15.787] INFO   _fit_and_score... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 23', random_state=0)]
# [04:53:23.858] INFO   _fit_and_score[7.866s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 23', random_state=0)]
# [04:53:24.593] INFO   _fit_and_score.save_artifacts... model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=23',random_state=0)]
# [04:53:24.981] INFO   _fit_and_score.save_artifacts[0.388s, 148.9 MB]: model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=23',random_state=0)]
# [04:53:24.986] INFO   _fit_and_score... split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 23', random_state=0)]
# [04:53:33.339] INFO   _fit_and_score[8.166s]: split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 23', random_state=0)]
# [04:53:34.800] INFO   _fit_and_score.save_artifacts... model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=23',random_state=0)]
# [04:53:35.203] INFO   _fit_and_score.save_artifacts[0.404s, 150.6 MB]: model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=23',random_state=0)]
# [04:53:35.206] INFO   _fit_and_score... split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 23', random_state=0)]
# [04:53:43.323] INFO   _fit_and_score[7.924s]: split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 23', random_state=0)]
# [04:53:44.016] INFO   _fit_and_score.save_artifacts... model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=23',random_state=0)]
# [04:53:44.420] INFO   _fit_and_score.save_artifacts[0.404s, 149.1 MB]: model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=23',random_state=0)]
# [04:53:44.423] INFO   _fit_and_score... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 11', random_state=0)]
# [04:53:53.505] INFO   _fit_and_score[8.898s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 11', random_state=0)]
# [04:53:54.235] INFO   _fit_and_score.save_artifacts... model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=11',random_state=0)]
# [04:53:54.464] INFO   _fit_and_score.save_artifacts[0.229s, 81.6 MB]: model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=11',random_state=0)]
# [04:53:54.468] INFO   _fit_and_score... split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 11', random_state=0)]
# [04:54:03.513] INFO   _fit_and_score[8.859s]: split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 11', random_state=0)]
# [04:54:04.274] INFO   _fit_and_score.save_artifacts... model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=11',random_state=0)]
# [04:54:04.492] INFO   _fit_and_score.save_artifacts[0.217s, 81.2 MB]: model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=11',random_state=0)]
# [04:54:04.497] INFO   _fit_and_score... split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 11', random_state=0)]
# [04:54:13.543] INFO   _fit_and_score[8.866s]: split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 11', random_state=0)]
# [04:54:14.315] INFO   _fit_and_score.save_artifacts... model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=11',random_state=0)]
# [04:54:14.548] INFO   _fit_and_score.save_artifacts[0.233s, 84.8 MB]: model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=11',random_state=0)]
# [04:54:14.552] INFO   _fit_and_score... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 11', random_state=0)]
# [04:54:19.717] INFO   _fit_and_score[4.989s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 11', random_state=0)]
# [04:54:20.112] INFO   _fit_and_score.save_artifacts... model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=11',random_state=0)]
# [04:54:20.254] INFO   _fit_and_score.save_artifacts[0.142s, 50.7 MB]: model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=11',random_state=0)]
# [04:54:20.257] INFO   _fit_and_score... split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 11', random_state=0)]
# [04:54:25.540] INFO   _fit_and_score[5.110s]: split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 11', random_state=0)]
# [04:54:26.823] INFO   _fit_and_score.save_artifacts... model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=11',random_state=0)]
# [04:54:26.961] INFO   _fit_and_score.save_artifacts[0.138s, 50.2 MB]: model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=11',random_state=0)]
# [04:54:26.964] INFO   _fit_and_score... split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 11', random_state=0)]
# [04:54:32.090] INFO   _fit_and_score[4.954s]: split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 11', random_state=0)]
# [04:54:32.516] INFO   _fit_and_score.save_artifacts... model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=11',random_state=0)]
# [04:54:32.665] INFO   _fit_and_score.save_artifacts[0.149s, 52.4 MB]: model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=11',random_state=0)]
# [04:54:32.668] INFO   _fit_and_score... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 5', random_state=0)]
# [04:54:37.784] INFO   _fit_and_score[4.940s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 5', random_state=0)]
# [04:54:38.321] INFO   _fit_and_score.save_artifacts... model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=5',random_state=0)]
# [04:54:38.468] INFO   _fit_and_score.save_artifacts[0.147s, 31.5 MB]: model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=5',random_state=0)]
# [04:54:38.472] INFO   _fit_and_score... split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 5', random_state=0)]
# [04:54:43.552] INFO   _fit_and_score[4.917s]: split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 5', random_state=0)]
# [04:54:44.117] INFO   _fit_and_score.save_artifacts... model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=5',random_state=0)]
# [04:54:44.264] INFO   _fit_and_score.save_artifacts[0.147s, 31.7 MB]: model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=5',random_state=0)]
# [04:54:44.267] INFO   _fit_and_score... split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 5', random_state=0)]
# [04:54:49.399] INFO   _fit_and_score[4.939s]: split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 5', random_state=0)]
# [04:54:49.928] INFO   _fit_and_score.save_artifacts... model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=5',random_state=0)]
# [04:54:50.071] INFO   _fit_and_score.save_artifacts[0.143s, 31.9 MB]: model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=5',random_state=0)]
# [04:54:50.076] INFO   _fit_and_score... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 5', random_state=0)]
# [04:54:53.322] INFO   _fit_and_score[3.075s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 5', random_state=0)]
# [04:54:54.582] INFO   _fit_and_score.save_artifacts... model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=5',random_state=0)]
# [04:54:54.677] INFO   _fit_and_score.save_artifacts[0.095s, 26.2 MB]: model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=5',random_state=0)]
# [04:54:54.681] INFO   _fit_and_score... split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 5', random_state=0)]
# [04:54:57.959] INFO   _fit_and_score[3.102s]: split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 5', random_state=0)]
# [04:54:59.200] INFO   _fit_and_score.save_artifacts... model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=5',random_state=0)]
# [04:54:59.305] INFO   _fit_and_score.save_artifacts[0.105s, 26.2 MB]: model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=5',random_state=0)]
# [04:54:59.309] INFO   _fit_and_score... split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 5', random_state=0)]
# [04:55:02.601] INFO   _fit_and_score[3.104s]: split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 5', random_state=0)]
# [04:55:03.824] INFO   _fit_and_score.save_artifacts... model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=5',random_state=0)]
# [04:55:03.922] INFO   _fit_and_score.save_artifacts[0.097s, 26.2 MB]: model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=5',random_state=0)]
# [04:55:03.925] INFO   _fit_and_score... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: null', random_state=0)]
# [04:55:16.734] INFO   _fit_and_score[12.643s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: null', random_state=0)]
# [04:55:18.308] INFO   _fit_and_score.save_artifacts... model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=null',random_state=0)]
# [04:55:19.302] INFO   _fit_and_score.save_artifacts[0.994s, 368.2 MB]: model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=null',random_state=0)]
# [04:55:19.306] INFO   _fit_and_score... split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: null', random_state=0)]
# [04:55:32.781] INFO   _fit_and_score[13.248s]: split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: null', random_state=0)]
# [04:55:34.763] INFO   _fit_and_score.save_artifacts... model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=null',random_state=0)]
# [04:55:35.718] INFO   _fit_and_score.save_artifacts[0.954s, 368.4 MB]: model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=null',random_state=0)]
# [04:55:35.721] INFO   _fit_and_score... split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: null', random_state=0)]
# [04:55:48.602] INFO   _fit_and_score[12.657s]: split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: null', random_state=0)]
# [04:55:50.185] INFO   _fit_and_score.save_artifacts... model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=null',random_state=0)]
# [04:55:51.150] INFO   _fit_and_score.save_artifacts[0.964s, 368.0 MB]: model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=null',random_state=0)]
# [04:55:51.154] INFO   _fit_and_score... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: null', random_state=0)]
# [04:55:58.227] INFO   _fit_and_score[6.846s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: null', random_state=0)]
# [04:55:59.052] INFO   _fit_and_score.save_artifacts... model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=null',random_state=0)]
# [04:55:59.551] INFO   _fit_and_score.save_artifacts[0.499s, 190.4 MB]: model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=null',random_state=0)]
# [04:55:59.555] INFO   _fit_and_score... split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: null', random_state=0)]
# [04:56:06.996] INFO   _fit_and_score[7.246s]: split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: null', random_state=0)]
# [04:56:08.436] INFO   _fit_and_score.save_artifacts... model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=null',random_state=0)]
# [04:56:08.973] INFO   _fit_and_score.save_artifacts[0.537s, 190.4 MB]: model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=null',random_state=0)]
# [04:56:08.977] INFO   _fit_and_score... split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: null', random_state=0)]
# [04:56:15.969] INFO   _fit_and_score[6.792s]: split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: null', random_state=0)]
# [04:56:16.857] INFO   _fit_and_score.save_artifacts... model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=null',random_state=0)]
# [04:56:17.450] INFO   _fit_and_score.save_artifacts[0.592s, 190.5 MB]: model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=null',random_state=0)]
# [04:56:17.453] INFO   _fit_and_score... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 93', random_state=0)]
# [04:56:30.412] INFO   _fit_and_score[12.756s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 93', random_state=0)]
# [04:56:31.870] INFO   _fit_and_score.save_artifacts... model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=93',random_state=0)]
# [04:56:32.894] INFO   _fit_and_score.save_artifacts[1.023s, 365.4 MB]: model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=93',random_state=0)]
# [04:56:32.897] INFO   _fit_and_score... split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 93', random_state=0)]
# [04:56:46.418] INFO   _fit_and_score[13.281s]: split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 93', random_state=0)]
# [04:56:48.351] INFO   _fit_and_score.save_artifacts... model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=93',random_state=0)]
# [04:56:49.562] INFO   _fit_and_score.save_artifacts[1.211s, 363.6 MB]: model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=93',random_state=0)]
# [04:56:49.566] INFO   _fit_and_score... split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 93', random_state=0)]
# [04:57:02.470] INFO   _fit_and_score[12.670s]: split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 93', random_state=0)]
# [04:57:04.014] INFO   _fit_and_score.save_artifacts... model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=93',random_state=0)]
# [04:57:05.071] INFO   _fit_and_score.save_artifacts[1.057s, 365.1 MB]: model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=93',random_state=0)]
# [04:57:05.076] INFO   _fit_and_score... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 93', random_state=0)]
# [04:57:12.078] INFO   _fit_and_score[6.776s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 93', random_state=0)]
# [04:57:12.973] INFO   _fit_and_score.save_artifacts... model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=93',random_state=0)]
# [04:57:13.570] INFO   _fit_and_score.save_artifacts[0.596s, 188.9 MB]: model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=93',random_state=0)]
# [04:57:13.574] INFO   _fit_and_score... split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 93', random_state=0)]
# [04:57:21.051] INFO   _fit_and_score[7.279s]: split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 93', random_state=0)]
# [04:57:22.456] INFO   _fit_and_score.save_artifacts... model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=93',random_state=0)]
# [04:57:23.059] INFO   _fit_and_score.save_artifacts[0.602s, 188.3 MB]: model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=93',random_state=0)]
# [04:57:23.062] INFO   _fit_and_score... split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 93', random_state=0)]
# [04:57:30.170] INFO   _fit_and_score[6.895s]: split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 93', random_state=0)]
# [04:57:30.966] INFO   _fit_and_score.save_artifacts... model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=93',random_state=0)]
# [04:57:31.559] INFO   _fit_and_score.save_artifacts[0.592s, 188.7 MB]: model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=93',random_state=0)]
# [04:57:31.563] INFO   _fit_and_score... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 46', random_state=0)]
# [04:57:43.316] INFO   _fit_and_score[11.554s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 46', random_state=0)]
# [04:57:44.803] INFO   _fit_and_score.save_artifacts... model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=46',random_state=0)]
# [04:57:45.736] INFO   _fit_and_score.save_artifacts[0.933s, 282.0 MB]: model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=46',random_state=0)]
# [04:57:45.740] INFO   _fit_and_score... split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 46', random_state=0)]
# [04:57:57.790] INFO   _fit_and_score[11.849s]: split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 46', random_state=0)]
# [04:57:58.972] INFO   _fit_and_score.save_artifacts... model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=46',random_state=0)]
# [04:57:59.734] INFO   _fit_and_score.save_artifacts[0.762s, 265.5 MB]: model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=46',random_state=0)]
# [04:57:59.738] INFO   _fit_and_score... split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 46', random_state=0)]
# [04:58:11.467] INFO   _fit_and_score[11.531s]: split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=168, n_recs=0.5, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 46', random_state=0)]
# [04:58:12.988] INFO   _fit_and_score.save_artifacts... model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=46',random_state=0)]
# [04:58:13.737] INFO   _fit_and_score.save_artifacts[0.749s, 278.4 MB]: model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=168,n_recs=0-5,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=46',random_state=0)]
# ...
# [05:02:22.469] INFO   _fit_and_score... split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 11', random_state=0)]
# [05:02:26.397] INFO   _fit_and_score[3.736s]: split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 11', random_state=0)]
# [05:02:27.127] INFO   _fit_and_score.save_artifacts... model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=11',random_state=0)]
# [05:02:27.297] INFO   _fit_and_score.save_artifacts[0.169s, 43.3 MB]: model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=11',random_state=0)]
# [05:02:27.300] INFO   _fit_and_score... split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 11', random_state=0)]
# [05:02:31.173] INFO   _fit_and_score[3.707s]: split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 11', random_state=0)]
# [05:02:31.900] INFO   _fit_and_score.save_artifacts... model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=11',random_state=0)]
# [05:02:32.060] INFO   _fit_and_score.save_artifacts[0.160s, 42.5 MB]: model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=11',random_state=0)]
# [05:02:32.064] INFO   _fit_and_score... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 11', random_state=0)]
# [05:02:34.752] INFO   _fit_and_score[2.504s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 11', random_state=0)]
# [05:02:35.597] INFO   _fit_and_score.save_artifacts... model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=11',random_state=0)]
# [05:02:35.699] INFO   _fit_and_score.save_artifacts[0.102s, 26.5 MB]: model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=11',random_state=0)]
# [05:02:35.703] INFO   _fit_and_score... split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 11', random_state=0)]
# [05:02:38.378] INFO   _fit_and_score[2.500s]: split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 11', random_state=0)]
# [05:02:39.229] INFO   _fit_and_score.save_artifacts... model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=11',random_state=0)]
# [05:02:39.331] INFO   _fit_and_score.save_artifacts[0.102s, 26.3 MB]: model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=11',random_state=0)]
# [05:02:39.335] INFO   _fit_and_score... split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 11', random_state=0)]
# [05:02:41.996] INFO   _fit_and_score[2.498s]: split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 11', random_state=0)]
# [05:02:42.849] INFO   _fit_and_score.save_artifacts... model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=11',random_state=0)]
# [05:02:42.952] INFO   _fit_and_score.save_artifacts[0.103s, 26.7 MB]: model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=11',random_state=0)]
# [05:02:42.956] INFO   _fit_and_score... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 5', random_state=0)]
# [05:02:45.739] INFO   _fit_and_score[2.593s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 5', random_state=0)]
# [05:02:46.498] INFO   _fit_and_score.save_artifacts... model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=5',random_state=0)]
# [05:02:46.638] INFO   _fit_and_score.save_artifacts[0.139s, 16.3 MB]: model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=5',random_state=0)]
# [05:02:46.642] INFO   _fit_and_score... split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 5', random_state=0)]
# [05:02:49.399] INFO   _fit_and_score[2.583s]: split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 5', random_state=0)]
# [05:02:50.171] INFO   _fit_and_score.save_artifacts... model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=5',random_state=0)]
# [05:02:50.315] INFO   _fit_and_score.save_artifacts[0.143s, 16.2 MB]: model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=5',random_state=0)]
# [05:02:50.319] INFO   _fit_and_score... split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 5', random_state=0)]
# [05:02:53.088] INFO   _fit_and_score[2.594s]: split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 5', random_state=0)]
# [05:02:53.858] INFO   _fit_and_score.save_artifacts... model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=5',random_state=0)]
# [05:02:53.999] INFO   _fit_and_score.save_artifacts[0.140s, 16.0 MB]: model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=5',random_state=0)]
# [05:02:54.003] INFO   _fit_and_score... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 5', random_state=0)]
# [05:02:56.147] INFO   _fit_and_score[1.977s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 5', random_state=0)]
# [05:02:56.474] INFO   _fit_and_score.save_artifacts... model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=5',random_state=0)]
# [05:02:56.573] INFO   _fit_and_score.save_artifacts[0.099s, 13.3 MB]: model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=5',random_state=0)]
# [05:02:56.576] INFO   _fit_and_score... split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 5', random_state=0)]
# [05:02:58.748] INFO   _fit_and_score[1.986s]: split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 5', random_state=0)]
# [05:02:59.062] INFO   _fit_and_score.save_artifacts... model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=5',random_state=0)]
# [05:02:59.156] INFO   _fit_and_score.save_artifacts[0.094s, 13.2 MB]: model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=5',random_state=0)]
# [05:02:59.159] INFO   _fit_and_score... split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 5', random_state=0)]
# [05:03:01.329] INFO   _fit_and_score[2.005s]: split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 5', random_state=0)]
# [05:03:01.619] INFO   _fit_and_score.save_artifacts... model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=5',random_state=0)]
# [05:03:01.714] INFO   _fit_and_score.save_artifacts[0.094s, 13.2 MB]: model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=5',random_state=0)]
# [05:03:01.717] INFO   _fit_and_score... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 2', random_state=0)]
# [05:03:03.846] INFO   _fit_and_score[1.962s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 2', random_state=0)]
# [05:03:04.216] INFO   _fit_and_score.save_artifacts... model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=2',random_state=0)]
# [05:03:04.351] INFO   _fit_and_score.save_artifacts[0.135s, 11.7 MB]: model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=2',random_state=0)]
# [05:03:04.355] INFO   _fit_and_score... split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 2', random_state=0)]
# [05:03:06.469] INFO   _fit_and_score[1.939s]: split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 2', random_state=0)]
# [05:03:06.864] INFO   _fit_and_score.save_artifacts... model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=2',random_state=0)]
# [05:03:06.991] INFO   _fit_and_score.save_artifacts[0.126s, 11.7 MB]: model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=2',random_state=0)]
# [05:03:06.994] INFO   _fit_and_score... split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 2', random_state=0)]
# [05:03:09.168] INFO   _fit_and_score[2.002s]: split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 200, max_depth: 2', random_state=0)]
# [05:03:09.499] INFO   _fit_and_score.save_artifacts... model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=2',random_state=0)]
# [05:03:09.684] INFO   _fit_and_score.save_artifacts[0.184s, 11.7 MB]: model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=200,max_depth=2',random_state=0)]
# [05:03:09.688] INFO   _fit_and_score... split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 2', random_state=0)]
# [05:03:11.544] INFO   _fit_and_score[1.692s]: split_i[0], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 2', random_state=0)]
# [05:03:12.142] INFO   _fit_and_score.save_artifacts... model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=2',random_state=0)]
# [05:03:12.225] INFO   _fit_and_score.save_artifacts[0.083s, 11.1 MB]: model_desc[split_i=0,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=2',random_state=0)]
# [05:03:12.229] INFO   _fit_and_score... split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 2', random_state=0)]
# [05:03:14.064] INFO   _fit_and_score[1.674s]: split_i[1], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 2', random_state=0)]
# [05:03:14.686] INFO   _fit_and_score.save_artifacts... model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=2',random_state=0)]
# [05:03:14.770] INFO   _fit_and_score.save_artifacts[0.084s, 11.0 MB]: model_desc[split_i=1,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=2',random_state=0)]
# [05:03:14.775] INFO   _fit_and_score... split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 2', random_state=0)]
# [05:03:16.675] INFO   _fit_and_score[1.715s]: split_i[2], train[2688], test[672], classes[168], estimator[Search(n_species=84, n_recs=1.0, classifier='cls: rf, criterion: gini, n_estimators: 100, max_depth: 2', random_state=0)]
# [05:03:17.252] INFO   _fit_and_score.save_artifacts... model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=2',random_state=0)]
# [05:03:17.340] INFO   _fit_and_score.save_artifacts[0.087s, 11.1 MB]: model_desc[split_i=2,train=2688,test=672,classes=168,estimator=Search(n_species=84,n_recs=1-0,classifier='cls=rf,criterion=gini,n_estimators=100,max_depth=2',random_state=0)]
# [Parallel(n_jobs=1)]: Done 108 out of 108 | elapsed: 16.8min finished
# /Users/danb/hack/bubo/features/sk_hack.py:358: RuntimeWarning: invalid value encountered in subtract
#   array_means[:, np.newaxis]) ** 2,

# %%
# Precompute eval metrics + dims for the plots below
#   - Grain: models
#   - Metrics: train_score, test_score, ...
#   - Dims: model_id, params_no_ns, fold, ...
ns = [
    'n_species', 'n_recs',
    'c_n_estimators',  # TODO TODO Pivot plots for model_size ~ max_depth
]
cv_models = (cv_results_splits_df(cv.cv_results_)
    # Slow yaml parsing, compute up front
    .assign(params_dict=lambda df: df.apply(axis=1, func=lambda row: dict(
        **{strip_startswith(k, 'param_'): row[k] for k in df if k.startswith('param_') and k not in ['param_classifier']},
        # HACK 'classifier.foo' -> 'c_foo'
        #   - TODO Refactor Search.classifier to get rid of the yaml strs ('c_cls', 'c_n_estimators', ...)
        **{'c_' + k: v for k, v in yaml.safe_load('{%s}' % row.param_classifier).items()},
        # 'classifier': yaml.safe_load('{%s}' % row.param_classifier),
    )))
    [lambda df: [c for c in df if not c.startswith('param_')]]
    # Dims from params
    .assign(
        # Useful for validation curves (vary params by classifier type)
        # params_no_ns=lambda df: df.params_dict.str['classifier'].apply(lambda x: (
        #     '%s-%s' % (x['cls'], x['criterion']) if x['cls'] == 'rf' else
        #     x['cls']
        # )),
        # Useful for learning curves (vary n_species/n_recs per classifier)
        params_no_ns=lambda df: df.params_dict.apply(lambda d: ', '.join(
            '%s[%s]' % (k, d[k]) for k in d if k not in ns
        )),
        ns=lambda df: df.params_dict.apply(lambda d: ', '.join(
            '%s[%s]' % (k, d[k]) for k in ns
        )),
    )
    # HACK Convert yaml strs ('x: y') to bracket style ('x[y]'), for visual consistency
    #   - TODO Refactor Search.classifier to get rid of the yaml strs ('c_cls', 'c_n_estimators', ...)
    .applymap(lambda x: x if not isinstance(x, str) else (
        re.sub(r'([^][:, ]+):\s+([^][:,]+)(, )?', r'c_\1[\2]\3',
            re.sub(r'classifier\[([^]]+)\]', r'\1',
                x,
            ),
        )
    ))
    #   - Restore the cats we just destroyed [copied from cv_results_splits_df]
    .pipe(df_ordered_cat,
        model_id=lambda df: df.model_id.unique(),
        params=lambda df: df.params.unique(),
        params_no_ns=lambda df: df.params_no_ns.unique(),
        ns=lambda df: df.ns.unique(),
    )
    # .eval
    .assign(
        train_evals=lambda df: np.vectorize(SearchEvals)(
            i=df.pop('train_i'),
            y=df.pop('train_y'),
            classes=df['classes'],
            y_scores=df.pop('train_predict_proba'),
            drop_missing_classes_for_n_species=True,  # HACK Migrate to sk Pipeline to avoid this
        ),
        test_evals=lambda df: np.vectorize(SearchEvals)(
            i=df.pop('test_i'),
            y=df.pop('test_y'),
            classes=df['classes'],
            y_scores=df.pop('test_predict_proba'),
            drop_missing_classes_for_n_species=True,  # HACK Migrate to sk Pipeline to avoid this
        ),
        # HACK Recompute (train_score, test_score) using SearchEvals.score so it can drop_missing_classes_for_n_species
        #   - Else you'll get scores that are too low (bad) because they include some -np.inf's in the median
        train_score=lambda df: df.train_evals.map(lambda x: x.score()),
        test_score=lambda df: df.test_evals.map(lambda x: x.score()),
    )
    .drop(columns=[
        'classes',
    ])
    # proc_stats
    .assign(
        mem_rss_spread=lambda df: df.proc_stats.map(lambda p: p.df.mem_rss.pipe(lambda s: s.max() - s.min())),
        mem_vms_spread=lambda df: df.proc_stats.map(lambda p: p.df.mem_vms.pipe(lambda s: s.max() - s.min())),
    )
    # Reorder
    .pipe(df_reorder_cols,
        first=['model_id', 'params', 'params_dict', 'params_no_ns', 'ns'],
        last=['train_evals', 'test_evals', 'proc_stats', 'model_stats', 'model'],
    )
    .pipe(tap, f=lambda df: display(
        df_summary(df).T,
        # df[:5],
        df,
    ))
)
# Out:
#                                                                                                                                                                                  min                                                                                                       25%                                                                                                       50%                                                                                                      75%                                                                                                     max
#                dtype    sizeof    len count nunique mean       std
# model_id       category 16500     108 108   108.0   NaN        NaN        n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[null], fold[0]  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[11], fold[2]  n_species[168], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[46], fold[2]  n_species[84], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[46], fold[2]  n_species[84], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[2], fold[2]
# params         category 15528     108 108   36.0    NaN        NaN                 n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[null]           n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[11]           n_species[168], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[46]           n_species[84], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[46]           n_species[84], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[2]
# params_dict    object   39744     108 108   NaN     NaN        NaN                                                                                                               NaN                                                                                                       NaN                                                                                                       NaN                                                                                                      NaN                                                                                                     NaN
# params_no_ns   category 10164     108 108   7.0     NaN        NaN                                                                   c_cls[rf], c_criterion[gini], c_max_depth[None]                                                             c_cls[rf], c_criterion[gini], c_max_depth[93]                                                             c_cls[rf], c_criterion[gini], c_max_depth[23]                                                            c_cls[rf], c_criterion[gini], c_max_depth[11]                                                            c_cls[rf], c_criterion[gini], c_max_depth[2]
# ns             category 10440     108 108   6.0     NaN        NaN                                                                  n_species[168], n_recs[1.0], c_n_estimators[200]                                                          n_species[168], n_recs[1.0], c_n_estimators[100]                                                          n_species[168], n_recs[0.5], c_n_estimators[200]                                                          n_species[84], n_recs[1.0], c_n_estimators[200]                                                         n_species[84], n_recs[1.0], c_n_estimators[100]
# fold           int64    2880      108 108   3.0      1.000e+00 8.203e-01                                                                                                           0                                                                                                         0                                                                                                         1                                                                                                        2                                                                                                       2
# train_score    float64  2592      108 108   10.0    -1.806e+00 2.129e+00                                                                                                         -13                                                                                                        -1                                                                                                        -1                                                                                                       -1                                                                                                      -1
# test_score     float64  2592      108 108   32.0    -1.071e+01 5.689e+00                                                                                                         -28                                                                                                       -14                                                                                                      -9.5                                                                                                       -6                                                                                                      -4
# fit_time       float64  2592      108 108   108.0    6.132e+00 5.441e+00                                                                                                       0.448                                                                                                      1.99                                                                                                      3.91                                                                                                      9.4                                                                                                    21.4
# score_time     float64  2592      108 108   108.0    3.248e-01 1.850e-02                                                                                                         0.3                                                                                                     0.309                                                                                                     0.318                                                                                                     0.34                                                                                                   0.369
# model_size     int64    3024      108 108   108.0    1.697e+08 1.852e+08                                                                                                     8685739                                                                                                  24345092                                                                                                  88965413                                                                                                273740200                                                                                               700019505
# mem_rss_spread int64    3048      108 108   103.0    2.523e+08 2.824e+08                                                                                                      454656                                                                                                  60219392                                                                                                 146649088                                                                                                341340160                                                                                              1231839232
# mem_vms_spread int64    3048      108 108   94.0     2.858e+08 2.900e+08                                                                                                      454656                                                                                                  87797760                                                                                                 175357952                                                                                                371462144                                                                                              1268686848
# train_evals    object   299149200 108 108   NaN     NaN        NaN                                                                                                               NaN                                                                                                       NaN                                                                                                       NaN                                                                                                      NaN                                                                                                     NaN
# test_evals     object   75034512  108 108   NaN     NaN        NaN                                                                                                               NaN                                                                                                       NaN                                                                                                       NaN                                                                                                      NaN                                                                                                     NaN
# proc_stats     object   612636    108 108   NaN     NaN        NaN                                                                                                               NaN                                                                                                       NaN                                                                                                       NaN                                                                                                      NaN                                                                                                     NaN
# model_stats    object   3032640   108 108   NaN     NaN        NaN                                                                                                               NaN                                                                                                       NaN                                                                                                       NaN                                                                                                      NaN                                                                                                     NaN
# model          float64  2592      108 0     0.0     NaN        NaN                                                                                                               NaN                                                                                                       NaN                                                                                                       NaN                                                                                                      NaN                                                                                                     NaN
#                                                                                                        model_id                                                                                             params                                                                                                          params_dict                                     params_no_ns                                                ns  fold  train_score  test_score  fit_time  score_time  model_size  mem_rss_spread  mem_vms_spread                                                                  train_evals                                                                test_evals                          proc_stats                                                                                                                                                                                              model_stats  model
# 0    n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[null], fold[0]  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[null]  {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 200, 'c_max_depth': None}  c_cls[rf], c_criterion[gini], c_max_depth[None]  n_species[168], n_recs[1.0], c_n_estimators[200]     0         -1.0        -7.0    21.356       0.334   696763105      1231839232      1268686848  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])  ProcStats(interval=1.0, stats[23])       capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0        2455     81        1227        1228         81            168        1500...    NaN
# 1    n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[null], fold[1]  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[null]  {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 200, 'c_max_depth': None}  c_cls[rf], c_criterion[gini], c_max_depth[None]  n_species[168], n_recs[1.0], c_n_estimators[200]     1         -1.0        -7.0    20.200       0.334   696110705      1114812416      1193603072  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])  ProcStats(interval=1.0, stats[22])       capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0        2491     93        1245        1246         93            168        1500...    NaN
# 2    n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[null], fold[2]  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[null]  {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 200, 'c_max_depth': None}  c_cls[rf], c_criterion[gini], c_max_depth[None]  n_species[168], n_recs[1.0], c_n_estimators[200]     2         -1.0        -6.0    20.203       0.343   700019505      1115033600      1195515904  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])  ProcStats(interval=1.0, stats[22])       capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0        2475    100        1237        1238        100            168        1500...    NaN
# 3    n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[null], fold[0]  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[null]  {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 100, 'c_max_depth': None}  c_cls[rf], c_criterion[gini], c_max_depth[None]  n_species[168], n_recs[1.0], c_n_estimators[100]     0         -1.0       -10.0     9.889       0.315   357092405       554303488       574726144  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])  ProcStats(interval=1.0, stats[12])      capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0       2455     81        1227        1228         81            168        1500  ...    NaN
# 4    n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[null], fold[1]  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[null]  {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 100, 'c_max_depth': None}  c_cls[rf], c_criterion[gini], c_max_depth[None]  n_species[168], n_recs[1.0], c_n_estimators[100]     1         -1.0       -10.5     9.895       0.318   356456805       553742336       574529536  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])  ProcStats(interval=1.0, stats[12])      capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0       2491     93        1245        1246         93            168        1500  ...    NaN
# 5    n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[null], fold[2]  n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[null]  {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 100, 'c_max_depth': None}  c_cls[rf], c_criterion[gini], c_max_depth[None]  n_species[168], n_recs[1.0], c_n_estimators[100]     2         -1.0        -8.0    10.130       0.336   357761605       560570368       580435968  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])  ProcStats(interval=1.0, stats[12])      capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0       2475    100        1237        1238        100            168        1500  ...    NaN
# 6      n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[93], fold[0]    n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[93]    {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 200, 'c_max_depth': 93}    c_cls[rf], c_criterion[gini], c_max_depth[93]  n_species[168], n_recs[1.0], c_n_estimators[200]     0         -1.0        -6.5    20.802       0.340   693282904      1107132416      1222725632  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])  ProcStats(interval=1.0, stats[23])       capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0        2455     81        1227        1228         81            168        1500...    NaN
# 7      n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[93], fold[1]    n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[93]    {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 200, 'c_max_depth': 93}    c_cls[rf], c_criterion[gini], c_max_depth[93]  n_species[168], n_recs[1.0], c_n_estimators[200]     1         -1.0        -7.0    20.292       0.346   692507304      1102848000      1180139520  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])  ProcStats(interval=1.0, stats[22])       capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0        2491     93        1245        1246         93            168        1500...    NaN
# 8      n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[93], fold[2]    n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[93]    {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 200, 'c_max_depth': 93}    c_cls[rf], c_criterion[gini], c_max_depth[93]  n_species[168], n_recs[1.0], c_n_estimators[200]     2         -1.0        -6.0    20.957       0.343   696158504      1107996672      1149751296  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])  ProcStats(interval=1.0, stats[23])       capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0        2441     93        1220        1221         93            168        1500...    NaN
# 9      n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[93], fold[0]    n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[93]    {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 100, 'c_max_depth': 93}    c_cls[rf], c_criterion[gini], c_max_depth[93]  n_species[168], n_recs[1.0], c_n_estimators[100]     0         -1.0       -10.0     9.916       0.337   355594504       553553920       574205952  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])  ProcStats(interval=1.0, stats[12])      capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0       2455     81        1227        1228         81            168        1500  ...    NaN
# 10     n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[93], fold[1]    n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[93]    {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 100, 'c_max_depth': 93}    c_cls[rf], c_criterion[gini], c_max_depth[93]  n_species[168], n_recs[1.0], c_n_estimators[100]     1         -1.0       -11.0    10.124       0.333   354376504       554397696       575537152  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])  ProcStats(interval=1.0, stats[12])      capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0       2491     93        1245        1246         93            168        1500  ...    NaN
# 11     n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[93], fold[2]    n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[93]    {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 100, 'c_max_depth': 93}    c_cls[rf], c_criterion[gini], c_max_depth[93]  n_species[168], n_recs[1.0], c_n_estimators[100]     2         -1.0        -9.0    10.212       0.353   355714904       565854208       610357248  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])  ProcStats(interval=1.0, stats[12])      capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0       2441     93        1220        1221         93            168        1500  ...    NaN
# 12     n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[46], fold[0]    n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[46]    {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 200, 'c_max_depth': 46}    c_cls[rf], c_criterion[gini], c_max_depth[46]  n_species[168], n_recs[1.0], c_n_estimators[200]     0         -1.0        -6.0    18.696       0.341   559022904       673906688       747450368  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])  ProcStats(interval=1.0, stats[21])       capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0        2009     46        1004        1005         46            168        1500...    NaN
# 13     n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[46], fold[1]    n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[46]    {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 200, 'c_max_depth': 46}    c_cls[rf], c_criterion[gini], c_max_depth[46]  n_species[168], n_recs[1.0], c_n_estimators[200]     1         -1.0        -6.5    18.654       0.357   566638904       675110912       755101696  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])  ProcStats(interval=1.0, stats[21])       capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0        1933     46         966         967         46            168        1500...    NaN
# 14     n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[46], fold[2]    n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[46]    {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 200, 'c_max_depth': 46}    c_cls[rf], c_criterion[gini], c_max_depth[46]  n_species[168], n_recs[1.0], c_n_estimators[200]     2         -1.0        -5.0    18.763       0.345   559742504       671596544       753782784  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])  ProcStats(interval=1.0, stats[21])       capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0        1667     46         833         834         46            168        1500...    NaN
# 15     n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[46], fold[0]    n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[46]    {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 100, 'c_max_depth': 46}    c_cls[rf], c_criterion[gini], c_max_depth[46]  n_species[168], n_recs[1.0], c_n_estimators[100]     0         -1.0        -8.0     9.176       0.333   289167304       345415680       383369216  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])  ProcStats(interval=1.0, stats[11])      capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0       2009     46        1004        1005         46            168        1500  ...    NaN
# 16     n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[46], fold[1]    n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[46]    {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 100, 'c_max_depth': 46}    c_cls[rf], c_criterion[gini], c_max_depth[46]  n_species[168], n_recs[1.0], c_n_estimators[100]     1         -1.0        -8.0     9.245       0.348   293059304       353579008       393244672  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])  ProcStats(interval=1.0, stats[11])      capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0       1933     46         966         967         46            168        1500  ...    NaN
# 17     n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[46], fold[2]    n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[46]    {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 100, 'c_max_depth': 46}    c_cls[rf], c_criterion[gini], c_max_depth[46]  n_species[168], n_recs[1.0], c_n_estimators[100]     2         -1.0        -6.0     9.396       0.354   285152104       341340160       369160192  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])  ProcStats(interval=1.0, stats[11])      capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0       1667     46         833         834         46            168        1500  ...    NaN
# 18     n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[23], fold[0]    n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[23]    {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 200, 'c_max_depth': 23}    c_cls[rf], c_criterion[gini], c_max_depth[23]  n_species[168], n_recs[1.0], c_n_estimators[200]     0         -1.0        -7.0    13.460       0.346   271224904       341225472       369143808  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])  ProcStats(interval=1.0, stats[15])       capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0         893     23         446         447         23            168        1500...    NaN
# 19     n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[23], fold[1]    n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[23]    {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 200, 'c_max_depth': 23}    c_cls[rf], c_criterion[gini], c_max_depth[23]  n_species[168], n_recs[1.0], c_n_estimators[200]     1         -1.0        -6.0    13.341       0.351   276385304       363106304       393646080  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])  ProcStats(interval=1.0, stats[15])       capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0        1187     23         593         594         23            168        1500...    NaN
# 20     n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[23], fold[2]    n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[23]    {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 200, 'c_max_depth': 23}    c_cls[rf], c_criterion[gini], c_max_depth[23]  n_species[168], n_recs[1.0], c_n_estimators[200]     2         -1.0        -6.0    13.365       0.340   276138904       351481856       384528384  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])  ProcStats(interval=1.0, stats[15])       capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0         985     23         492         493         23            168        1500...    NaN
# 21     n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[23], fold[0]    n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[23]    {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 100, 'c_max_depth': 23}    c_cls[rf], c_criterion[gini], c_max_depth[23]  n_species[168], n_recs[1.0], c_n_estimators[100]     0         -1.0        -9.5     6.587       0.326   144247704       195829760       210432000  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])   ProcStats(interval=1.0, stats[8])      capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0        893     23         446         447         23            168        1500  ...    NaN
# 22     n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[23], fold[1]    n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[23]    {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 100, 'c_max_depth': 23}    c_cls[rf], c_criterion[gini], c_max_depth[23]  n_species[168], n_recs[1.0], c_n_estimators[100]     1         -1.0        -9.0     6.705       0.352   145933304       199872512       212324352  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])   ProcStats(interval=1.0, stats[9])      capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0       1187     23         593         594         23            168        1500  ...    NaN
# 23     n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[23], fold[2]    n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[23]    {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 100, 'c_max_depth': 23}    c_cls[rf], c_criterion[gini], c_max_depth[23]  n_species[168], n_recs[1.0], c_n_estimators[100]     2         -1.0        -7.0     6.614       0.339   144432504       188416000       204410880  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])   ProcStats(interval=1.0, stats[8])      capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0        985     23         492         493         23            168        1500  ...    NaN
# 24     n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[11], fold[0]    n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[11]    {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 200, 'c_max_depth': 11}    c_cls[rf], c_criterion[gini], c_max_depth[11]  n_species[168], n_recs[1.0], c_n_estimators[200]     0         -1.0       -11.0     7.418       0.358    76996860       122433536       162836480  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])   ProcStats(interval=1.0, stats[9])       capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0         169     11          84          85         11            168        1500...    NaN
# 25     n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[11], fold[1]    n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[11]    {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 200, 'c_max_depth': 11}    c_cls[rf], c_criterion[gini], c_max_depth[11]  n_species[168], n_recs[1.0], c_n_estimators[200]     1         -1.0       -10.0     7.394       0.354    76599230       129212416       162861056  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])   ProcStats(interval=1.0, stats[9])       capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0         219     11         109         110         11            168        1500...    NaN
# 26     n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[11], fold[2]    n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[11]    {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 200, 'c_max_depth': 11}    c_cls[rf], c_criterion[gini], c_max_depth[11]  n_species[168], n_recs[1.0], c_n_estimators[200]     2         -1.0        -9.0     7.403       0.352    80174896       136916992       171802624  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])   ProcStats(interval=1.0, stats[9])       capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0         227     11         113         114         11            168        1500...    NaN
# 27     n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[11], fold[0]    n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[11]    {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 100, 'c_max_depth': 11}    c_cls[rf], c_criterion[gini], c_max_depth[11]  n_species[168], n_recs[1.0], c_n_estimators[100]     0         -1.0       -13.0     3.729       0.326    46121476        70352896       117075968  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])   ProcStats(interval=1.0, stats[5])      capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0        169     11          84          85         11            168        1500  ...    NaN
# 28     n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[11], fold[1]    n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[11]    {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 100, 'c_max_depth': 11}    c_cls[rf], c_criterion[gini], c_max_depth[11]  n_species[168], n_recs[1.0], c_n_estimators[100]     1         -1.0       -11.5     3.845       0.331    45544655        87564288       118202368  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])   ProcStats(interval=1.0, stats[6])      capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0        219     11         109         110         11            168        1500  ...    NaN
# 29     n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[11], fold[2]    n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[11]    {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 100, 'c_max_depth': 11}    c_cls[rf], c_criterion[gini], c_max_depth[11]  n_species[168], n_recs[1.0], c_n_estimators[100]     2         -1.0       -11.0     3.742       0.315    47818300        74276864       122773504  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])   ProcStats(interval=1.0, stats[5])      capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0        227     11         113         114         11            168        1500  ...    NaN
# 30      n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[5], fold[0]     n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[5]     {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 200, 'c_max_depth': 5}     c_cls[rf], c_criterion[gini], c_max_depth[5]  n_species[168], n_recs[1.0], c_n_estimators[200]     0         -2.0       -18.0     3.620       0.309    26899103        69033984       126599168  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])   ProcStats(interval=1.0, stats[5])       capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0          29      5          14          15          5            168        1500...    NaN
# 31      n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[5], fold[1]     n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[5]     {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 200, 'c_max_depth': 5}     c_cls[rf], c_criterion[gini], c_max_depth[5]  n_species[168], n_recs[1.0], c_n_estimators[200]     1         -2.0       -15.0     3.586       0.317    27092303        30949376        87613440  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])   ProcStats(interval=1.0, stats[5])       capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0          37      5          18          19          5            168        1500...    NaN
# 32      n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[5], fold[2]     n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[5]     {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 200, 'c_max_depth': 5}     c_cls[rf], c_criterion[gini], c_max_depth[5]  n_species[168], n_recs[1.0], c_n_estimators[200]     2         -2.0       -13.0     3.625       0.315    27240703        30953472        87613440  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])   ProcStats(interval=1.0, stats[5])       capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0          31      5          15          16          5            168        1500...    NaN
# 33      n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[5], fold[0]     n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[5]     {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 100, 'c_max_depth': 5}     c_cls[rf], c_criterion[gini], c_max_depth[5]  n_species[168], n_recs[1.0], c_n_estimators[100]     0         -3.0       -20.0     1.874       0.310    21537403        15056896        72146944  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])   ProcStats(interval=1.0, stats[4])      capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0         29      5          14          15          5            168        1500  ...    NaN
# 34      n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[5], fold[1]     n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[5]     {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 100, 'c_max_depth': 5}     c_cls[rf], c_criterion[gini], c_max_depth[5]  n_species[168], n_recs[1.0], c_n_estimators[100]     1         -3.0       -17.5     1.894       0.304    21540203        10584064        69861376  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])   ProcStats(interval=1.0, stats[4])      capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0         37      5          18          19          5            168        1500  ...    NaN
# 35      n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[5], fold[2]     n_species[168], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[5]     {'n_recs': 1.0, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 100, 'c_max_depth': 5}     c_cls[rf], c_criterion[gini], c_max_depth[5]  n_species[168], n_recs[1.0], c_n_estimators[100]     2         -4.0       -15.0     1.890       0.314    21554203        17809408        75243520  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])   ProcStats(interval=1.0, stats[4])      capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0         31      5          15          16          5            168        1500  ...    NaN
# 36   n_species[168], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[null], fold[0]  n_species[168], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[null]  {'n_recs': 0.5, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 200, 'c_max_depth': None}  c_cls[rf], c_criterion[gini], c_max_depth[None]  n_species[168], n_recs[0.5], c_n_estimators[200]     0         -1.0       -12.0    11.094       0.349   363572401       537649152       530042880  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])  ProcStats(interval=1.0, stats[13])       capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0        1239     81         619         620         81            168        1500...    NaN
# 37   n_species[168], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[null], fold[1]  n_species[168], n_recs[0.5], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[null]  {'n_recs': 0.5, 'n_species': 168, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 200, 'c_max_depth': None}  c_cls[rf], c_criterion[gini], c_max_depth[None]  n_species[168], n_recs[0.5], c_n_estimators[200]     1         -1.0       -13.0    11.788       0.355   363799201       546967552       563662848  SearchEvals(i[(2688,)], y[(2688,)], classes[(168,)], y_scores[(2688, 168)])  SearchEvals(i[(672,)], y[(672,)], classes[(168,)], y_scores[(672, 168)])  ProcStats(interval=1.0, stats[14])       capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0        1261     89         630         631         89            168        1500...    NaN
# ...
# 0         191     11          95          96         11             84        1500...    NaN
# 91      n_species[84], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[11], fold[1]     n_species[84], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[11]     {'n_recs': 1.0, 'n_species': 84, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 200, 'c_max_depth': 11}    c_cls[rf], c_criterion[gini], c_max_depth[11]   n_species[84], n_recs[1.0], c_n_estimators[200]     1         -1.0        -5.0     2.472       0.318    40962422        66592768       104828928    SearchEvals(i[(2688,)], y[(1344,)], classes[(84,)], y_scores[(1344, 84)])    SearchEvals(i[(672,)], y[(336,)], classes[(84,)], y_scores[(336, 84)])   ProcStats(interval=1.0, stats[4])       capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0         209     11         104         105         11             84        1500...    NaN
# 92      n_species[84], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[11], fold[2]     n_species[84], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[11]     {'n_recs': 1.0, 'n_species': 84, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 200, 'c_max_depth': 11}    c_cls[rf], c_criterion[gini], c_max_depth[11]   n_species[84], n_recs[1.0], c_n_estimators[200]     2         -1.0        -5.0     2.487       0.309    40071341        66076672       104095744    SearchEvals(i[(2688,)], y[(1344,)], classes[(84,)], y_scores[(1344, 84)])    SearchEvals(i[(672,)], y[(336,)], classes[(84,)], y_scores[(336, 84)])   ProcStats(interval=1.0, stats[4])       capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0         229     11         114         115         11             84        1500...    NaN
# 93      n_species[84], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[11], fold[0]     n_species[84], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[11]     {'n_recs': 1.0, 'n_species': 84, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 100, 'c_max_depth': 11}    c_cls[rf], c_criterion[gini], c_max_depth[11]   n_species[84], n_recs[1.0], c_n_estimators[100]     0         -1.0        -6.0     1.276       0.314    24133987        46120960        87797760    SearchEvals(i[(2688,)], y[(1344,)], classes[(84,)], y_scores[(1344, 84)])    SearchEvals(i[(672,)], y[(336,)], classes[(84,)], y_scores[(336, 84)])   ProcStats(interval=1.0, stats[3])      capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0        191     11          95          96         11             84        1500  ...    NaN
# 94      n_species[84], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[11], fold[1]     n_species[84], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[11]     {'n_recs': 1.0, 'n_species': 84, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 100, 'c_max_depth': 11}    c_cls[rf], c_criterion[gini], c_max_depth[11]   n_species[84], n_recs[1.0], c_n_estimators[100]     1         -1.0        -6.0     1.274       0.320    23949051        44929024        86077440    SearchEvals(i[(2688,)], y[(1344,)], classes[(84,)], y_scores[(1344, 84)])    SearchEvals(i[(672,)], y[(336,)], classes[(84,)], y_scores[(336, 84)])   ProcStats(interval=1.0, stats[3])      capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0        209     11         104         105         11             84        1500  ...    NaN
# 95      n_species[84], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[11], fold[2]     n_species[84], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[11]     {'n_recs': 1.0, 'n_species': 84, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 100, 'c_max_depth': 11}    c_cls[rf], c_criterion[gini], c_max_depth[11]   n_species[84], n_recs[1.0], c_n_estimators[100]     2         -1.0        -5.0     1.275       0.304    24345092        45871104        87797760    SearchEvals(i[(2688,)], y[(1344,)], classes[(84,)], y_scores[(1344, 84)])    SearchEvals(i[(672,)], y[(336,)], classes[(84,)], y_scores[(336, 84)])   ProcStats(interval=1.0, stats[3])      capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0        229     11         114         115         11             84        1500  ...    NaN
# 96       n_species[84], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[5], fold[0]      n_species[84], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[5]      {'n_recs': 1.0, 'n_species': 84, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 200, 'c_max_depth': 5}     c_cls[rf], c_criterion[gini], c_max_depth[5]   n_species[84], n_recs[1.0], c_n_estimators[200]     0         -1.0        -9.0     1.363       0.318    13905423        24862720        73936896    SearchEvals(i[(2688,)], y[(1344,)], classes[(84,)], y_scores[(1344, 84)])    SearchEvals(i[(672,)], y[(336,)], classes[(84,)], y_scores[(336, 84)])   ProcStats(interval=1.0, stats[3])       capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0          45      5          22          23          5             84        1500...    NaN
# 97       n_species[84], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[5], fold[1]      n_species[84], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[5]      {'n_recs': 1.0, 'n_species': 84, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 200, 'c_max_depth': 5}     c_cls[rf], c_criterion[gini], c_max_depth[5]   n_species[84], n_recs[1.0], c_n_estimators[200]     1         -1.0        -7.0     1.355       0.315    13786031         9756672        67956736    SearchEvals(i[(2688,)], y[(1344,)], classes[(84,)], y_scores[(1344, 84)])    SearchEvals(i[(672,)], y[(336,)], classes[(84,)], y_scores[(336, 84)])   ProcStats(interval=1.0, stats[3])       capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0          27      5          13          14          5             84        1500...    NaN
# 98       n_species[84], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[5], fold[2]      n_species[84], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[5]      {'n_recs': 1.0, 'n_species': 84, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 200, 'c_max_depth': 5}     c_cls[rf], c_criterion[gini], c_max_depth[5]   n_species[84], n_recs[1.0], c_n_estimators[200]     2         -1.0        -7.0     1.357       0.312    13620047         9637888        67993600    SearchEvals(i[(2688,)], y[(1344,)], classes[(84,)], y_scores[(1344, 84)])    SearchEvals(i[(672,)], y[(336,)], classes[(84,)], y_scores[(336, 84)])   ProcStats(interval=1.0, stats[3])       capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0          55      5          27          28          5             84        1500...    NaN
# 99       n_species[84], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[5], fold[0]      n_species[84], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[5]      {'n_recs': 1.0, 'n_species': 84, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 100, 'c_max_depth': 5}     c_cls[rf], c_criterion[gini], c_max_depth[5]   n_species[84], n_recs[1.0], c_n_estimators[100]     0         -1.0        -9.0     0.760       0.313    10960011          454656          454656    SearchEvals(i[(2688,)], y[(1344,)], classes[(84,)], y_scores[(1344, 84)])    SearchEvals(i[(672,)], y[(336,)], classes[(84,)], y_scores[(336, 84)])   ProcStats(interval=1.0, stats[2])      capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0         45      5          22          23          5             84        1500  ...    NaN
# 100      n_species[84], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[5], fold[1]      n_species[84], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[5]      {'n_recs': 1.0, 'n_species': 84, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 100, 'c_max_depth': 5}     c_cls[rf], c_criterion[gini], c_max_depth[5]   n_species[84], n_recs[1.0], c_n_estimators[100]     1         -1.0        -8.0     0.760       0.320    10818779          454656          454656    SearchEvals(i[(2688,)], y[(1344,)], classes[(84,)], y_scores[(1344, 84)])    SearchEvals(i[(672,)], y[(336,)], classes[(84,)], y_scores[(336, 84)])   ProcStats(interval=1.0, stats[2])      capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0         27      5          13          14          5             84        1500  ...    NaN
# 101      n_species[84], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[5], fold[2]      n_species[84], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[5]      {'n_recs': 1.0, 'n_species': 84, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 100, 'c_max_depth': 5}     c_cls[rf], c_criterion[gini], c_max_depth[5]   n_species[84], n_recs[1.0], c_n_estimators[100]     2         -1.0        -7.0     0.763       0.319    10861003          454656          454656    SearchEvals(i[(2688,)], y[(1344,)], classes[(84,)], y_scores[(1344, 84)])    SearchEvals(i[(672,)], y[(336,)], classes[(84,)], y_scores[(336, 84)])   ProcStats(interval=1.0, stats[2])      capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0         55      5          27          28          5             84        1500  ...    NaN
# 102      n_species[84], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[2], fold[0]      n_species[84], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[2]      {'n_recs': 1.0, 'n_species': 84, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 200, 'c_max_depth': 2}     c_cls[rf], c_criterion[gini], c_max_depth[2]   n_species[84], n_recs[1.0], c_n_estimators[200]     0         -4.0       -13.0     0.737       0.312     9298639          466944          454656    SearchEvals(i[(2688,)], y[(1344,)], classes[(84,)], y_scores[(1344, 84)])    SearchEvals(i[(672,)], y[(336,)], classes[(84,)], y_scores[(336, 84)])   ProcStats(interval=1.0, stats[2])       capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0           7      2           3           4          2             84        1500...    NaN
# 103      n_species[84], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[2], fold[1]      n_species[84], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[2]      {'n_recs': 1.0, 'n_species': 84, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 200, 'c_max_depth': 2}     c_cls[rf], c_criterion[gini], c_max_depth[2]   n_species[84], n_recs[1.0], c_n_estimators[200]     1         -4.0       -11.0     0.716       0.313     9281167          462848          454656    SearchEvals(i[(2688,)], y[(1344,)], classes[(84,)], y_scores[(1344, 84)])    SearchEvals(i[(672,)], y[(336,)], classes[(84,)], y_scores[(336, 84)])   ProcStats(interval=1.0, stats[2])       capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0           7      2           3           4          2             84        1500...    NaN
# 104      n_species[84], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[2], fold[2]      n_species[84], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[200], c_max_depth[2]      {'n_recs': 1.0, 'n_species': 84, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 200, 'c_max_depth': 2}     c_cls[rf], c_criterion[gini], c_max_depth[2]   n_species[84], n_recs[1.0], c_n_estimators[200]     2         -5.0       -10.0     0.753       0.322     9288447          462848          454656    SearchEvals(i[(2688,)], y[(1344,)], classes[(84,)], y_scores[(1344, 84)])    SearchEvals(i[(672,)], y[(336,)], classes[(84,)], y_scores[(336, 84)])   ProcStats(interval=1.0, stats[2])       capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0           7      2           3           4          2             84        1500...    NaN
# 105      n_species[84], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[2], fold[0]      n_species[84], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[2]      {'n_recs': 1.0, 'n_species': 84, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 100, 'c_max_depth': 2}     c_cls[rf], c_criterion[gini], c_max_depth[2]   n_species[84], n_recs[1.0], c_n_estimators[100]     0         -5.0       -13.0     0.454       0.309     8694475         4866048         5783552    SearchEvals(i[(2688,)], y[(1344,)], classes[(84,)], y_scores[(1344, 84)])    SearchEvals(i[(672,)], y[(336,)], classes[(84,)], y_scores[(336, 84)])   ProcStats(interval=1.0, stats[2])      capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0          7      2           3           4          2             84        1500  ...    NaN
# 106      n_species[84], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[2], fold[1]      n_species[84], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[2]      {'n_recs': 1.0, 'n_species': 84, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 100, 'c_max_depth': 2}     c_cls[rf], c_criterion[gini], c_max_depth[2]   n_species[84], n_recs[1.0], c_n_estimators[100]     1         -5.0       -11.0     0.448       0.309     8685739         5926912         6303744    SearchEvals(i[(2688,)], y[(1344,)], classes[(84,)], y_scores[(1344, 84)])    SearchEvals(i[(672,)], y[(336,)], classes[(84,)], y_scores[(336, 84)])   ProcStats(interval=1.0, stats[2])      capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0          7      2           3           4          2             84        1500  ...    NaN
# 107      n_species[84], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[2], fold[2]      n_species[84], n_recs[1.0], c_cls[rf], c_criterion[gini], c_n_estimators[100], c_max_depth[2]      {'n_recs': 1.0, 'n_species': 84, 'c_cls': 'rf', 'c_criterion': 'gini', 'c_n_estimators': 100, 'c_max_depth': 2}     c_cls[rf], c_criterion[gini], c_max_depth[2]   n_species[84], n_recs[1.0], c_n_estimators[100]     2         -5.0       -11.0     0.459       0.323     8693019         5918720         6303744    SearchEvals(i[(2688,)], y[(1344,)], classes[(84,)], y_scores[(1344, 84)])    SearchEvals(i[(672,)], y[(336,)], classes[(84,)], y_scores[(336, 84)])   ProcStats(interval=1.0, stats[2])      capacity  depth  fork_count  leaf_count  max_depth  max_n_classes  n_features  n_outputs  node_count    type
# 0          7      2           3           4          2             84        1500  ...    NaN

# %%
cv_models_proc_stats = (cv_models
    # Enable these as needed (at the cost of mem usage)
    [[
        'model_id',
        'params',
        # 'params_dict',
        'params_no_ns',
        'ns',
        'fold',
        # 'train_score',
        # 'test_score',
        # 'fit_time',
        # 'score_time',
        'mem_rss_spread',
        # 'mem_vms_spread',
        # 'train_evals',
        # 'test_evals',
        'proc_stats',
    ]]
    .pipe(df_flatmap, lambda row: [
        row.append(pd.Series(dict(**stats)))
        for stats in row.proc_stats.stats
    ])
    # Restore the cats we just destroyed [copied from cv_results_splits_df]
    .pipe(df_ordered_cat,
        model_id=lambda df: df.model_id.unique(),
        params=lambda df: df.params.unique(),
    )
    .assign(
        cpu_user=lambda df: df.cpu_user.diff() * 100,
        cpu_system=lambda df: df.cpu_system.diff() * 100,
    )
    .pipe(tap, f=lambda df: display(
        # df_summary(df).T,
        # df[:5],
    ))
)

# %%
(cv_models
    .pipe(df_reverse_cat, 'params', 'params_no_ns', 'ns')
    # Manually compute y.mean() per group
    .groupby('params').apply(lambda g: g.assign(
        fit_time_mean=lambda df: df.fit_time.mean(),
        score_time_mean=lambda df: df.score_time.mean(),
    ))
    .pipe(ggplot, aes(x='ns', group='params_no_ns'))
    # Summary per fold
    + geom_col(aes(y='fit_time_mean + score_time_mean', fill='params_no_ns'), color='black', size=.2, position=position_dodge())
    + geom_col(aes(y='fit_time_mean', fill='params_no_ns'), color='black', size=.2, position=position_dodge())
    # Distribution of folds
    + geom_point(aes(y='fit_time'), size=2, color='gray', fill='none', position=position_dodge(width=.9))
    + geom_point(aes(y='fit_time + score_time'), size=2, color='black', fill='none', position=position_dodge(width=.9))
    + coord_flip()
    # + scale_fill_cmap_d(mpl.cm.tab10)
    + scale_fill_cmap_d(mpl.cm.tab20)
    + guides(fill=guide_legend(reverse=True))
    + theme(legend_position='bottom', legend_direction='vertical', legend_box_spacing=.4, legend_key_height=8)
    + theme_figsize(aspect_ratio=1/3*2)
    + ylab('fit_time + score_time')
    + ggtitle(f'Train + score times ({recs_stats})')
)
# Out:
# <ggplot: (315945536)>

# %%
# TODO TODO Grok forest depth so we can tune max_depth, to see how it reduces model_size
cv_models = (cv_models
    .assign(
        # TODO Generalize this for models other than rf (e.g. having a df is probably specific to ensembles)
        forest_depth_mean=lambda df: df.model_stats.map(lambda stats: or_else(None, lambda: stats.depth.mean())),
        forest_depth_std=lambda df: df.model_stats.map(lambda stats: or_else(None, lambda: stats.depth.std())),
    )
)
display(
    # cv_models[['model_id', 'forest_depth_mean', 'forest_depth_std']],
)

# %%
(cv_models
    .pipe(df_reverse_cat, 'params_no_ns')
    .assign(n_species=lambda df: df.params_dict.str['n_species'])
    .pipe(ggplot, aes(x='n_species', y='forest_depth_mean', color='params_no_ns'))
    # + facet_wrap('params_no_ns', ncol=2)
    + geom_point()
    + geom_pointrange(aes(ymin='forest_depth_mean - 2*forest_depth_std', ymax='forest_depth_mean + 2*forest_depth_std'))
    + geom_smooth(method='lm', se=False)  # Disable se because it only knows forest_depth_mean, no measure of spread
    # + scale_color_cmap_d(mpl.cm.tab10)
    + scale_color_cmap_d(mpl.cm.tab20)
    + guides(color=guide_legend(reverse=True))
    + theme(legend_position='bottom', legend_direction='vertical', legend_box_spacing=.4, legend_key_height=8)
    # + theme_figsize(aspect_ratio=1/3)
    + theme_figsize(aspect_ratio=1/3)
    + ggtitle(f'RF depth vs. n_species ({recs_stats})')
)
# Out:
# <ggplot: (-9223372036535499688)>

# %%
(cv_models
    .pipe(df_reverse_cat, 'params', 'params_no_ns', 'ns')
    # Manually compute y.mean() per group
    .groupby('params').apply(lambda g: g.assign(model_size_mean=lambda df: df.model_size.mean()))
    .pipe(ggplot, aes(x='ns', group='params_no_ns'))
    + geom_col(aes(y='model_size_mean', fill='params_no_ns'), position=position_dodge()) # Summary per fold
    + geom_point(aes(y='model_size'), fill='none', size=2, position=position_dodge(width=.9)) # Distribution of folds
    # TODO TODO XXX
    + geom_point(aes(y='forest_depth_mean * 1e6'), color='red', size=3, position=position_dodge(width=.9))
    + geom_text(aes(label='forest_depth_mean.astype(int)', y='-15 * 1e6'), color='red', position=position_dodge(width=.9))
    # TODO TODO XXX
    + coord_flip()
    # + scale_fill_cmap_d(mpl.cm.tab10)
    + scale_fill_cmap_d(mpl.cm.tab20)
    + scale_y_continuous(labels=labels_bytes(), breaks=breaks_bytes())
    + guides(fill=guide_legend(reverse=True))
    + theme(legend_position='bottom', legend_direction='vertical', legend_box_spacing=.4, legend_key_height=8)
    + theme_figsize(aspect_ratio=1/3*2)
    + ggtitle(f'[Forest depth and] Model size ({recs_stats})')
)
# Out:
# <ggplot: (304382205)>

# %%
(cv_models
    .pipe(df_reverse_cat, 'params', 'params_no_ns', 'ns')
    # Manually compute y.mean() per group
    .groupby('params').apply(lambda g: g.assign(mem_rss_spread_mean=lambda df: df.mem_rss_spread.mean()))
    .pipe(ggplot, aes(x='ns', group='params_no_ns'))
    + geom_col(aes(y='mem_rss_spread_mean', fill='params_no_ns'), position=position_dodge()) # Summary per fold
    + geom_point(aes(y='mem_rss_spread'), fill='none', size=2, position=position_dodge(width=.9)) # Distribution of folds
    + coord_flip()
    # + scale_fill_cmap_d(mpl.cm.tab10)
    + scale_fill_cmap_d(mpl.cm.tab20)
    + scale_y_continuous(labels=labels_bytes(), breaks=breaks_bytes())
    + guides(fill=guide_legend(reverse=True))
    + theme(legend_position='bottom', legend_direction='vertical', legend_box_spacing=.4, legend_key_height=8)
    + theme_figsize(aspect_ratio=1/3*2)
    + ggtitle(f'Mem rss spread ($max-min$) ({recs_stats})')
)
# Out:
# [skip]

# %%
# TODO Might need to stack/geom_area for overlapping runs
(cv_models_proc_stats
    .pipe(ggplot, aes(x='time',
        color='model_id',
        # color='params_no_ns', linetype='ns',
        # color='params_no_ns', size='ns',
    ))
    + geom_line(aes(y='cpu_system'), linetype='dashed', size=.5)
    + geom_line(aes(y='cpu_system + cpu_user'), linetype='solid', size=.5)
    # + geom_line(aes(y='cpu_system + cpu_user'), size=1)
    + expand_limits(y=0)
    + ylab('cpu')
    + scale_x_datetime(date_labels='%H:%M:%S')
    + scale_y_continuous(labels=lambda labels: ['%.3g%%' % x for x in labels])
    # + scale_color_cmap_d(mpl.cm.tab20)
    + theme(legend_position='bottom', legend_direction='vertical', legend_box_spacing=.4, legend_key_height=8)
    + theme_figsize('inline_short')
    + ggtitle('cpu over time (system + user)')
)
# Out:
# [skip]

# %%
(cv_models_proc_stats
    .pipe(ggplot, aes(x='time', color='model_id'))
    + geom_line(aes(y='mem_rss'), linetype='solid', size=.5)
    + geom_line(aes(y='mem_vms'), linetype='dashed', size=.5)
    + expand_limits(y=0)
    + ylab('mem')
    + scale_x_datetime(date_labels='%H:%M:%S')
    + scale_y_continuous(labels=labels_bytes(), breaks=breaks_bytes(pow=3))
    # + scale_color_cmap_d(mpl.cm.tab20)
    + theme(legend_position='bottom', legend_direction='vertical', legend_box_spacing=.4, legend_key_height=8)
    + theme_figsize('inline_short')
    + ggtitle('Mem over time (rss, vms)')
)
# Out:
# [skip]

# %%
# Train/test scores
#   - Grain: models x {train,test}
#   - Metrics: score
#   - Dims: group, params
(cv_models
    .pipe(df_reverse_cat, 'params_no_ns')
    .pipe(lambda df: pd.melt(
        df,
        id_vars=['ns', 'params_no_ns', 'params', 'fold'],
        value_vars=['train_score', 'test_score'],
        var_name='split',
        value_name='score'),
    )
    .assign(
        split=lambda df: df.split.str.replace('_score', ''),
        group=lambda df: df.params_no_ns.str.cat(df.split, '/'),
    )
    .pipe(df_ordered_cat,
        group=lambda df: reversed(df.group.unique()),
    )
    .pipe(ggplot, aes(
        x='params_no_ns',
        y='score',
        # color='group',  # Ran out of colors
        color='params_no_ns',
    ))
    + facet_wrap('ns', ncol=1)
    + geom_hline(yintercept=-1, color='lightgrey')  # -1 is the max score (1 is the min coverage_error)
    + geom_point(aes(shape='split'), fill='none', size=2)
    # + geom_line(aes(group='str(group) + str(fold)'), alpha=.2)  # More trouble than it's worth
    + stat_summary(aes(group='group'), fun_data='mean_cl_boot', random_state=0, geom='errorbar')
    # + stat_summary(aes(group='group'), fun_data='mean_cl_boot', random_state=0, geom='line', size=1)  # More trouble than it's worth
    # + scale_color_cmap_d(mpl.cm.tab10)
    + scale_color_cmap_d(mpl.cm.tab20)
    + coord_flip(
        # ylim=(-40, 0),
    )
    + theme(legend_position='none')
    + theme_figsize(width=12, aspect_ratio=1/10*1)
    + ylab('score (-coverage_error)')
    + ggtitle(f'Train/test scores ({recs_stats})')
)
# Out:
# <ggplot: (350073208)>

# %%
# TODO TODO Oh snap! -- model sizes look very chewy
(cv_models
    .pipe(ggplot, aes(x='model_size', y='test_score'))
    + aes(color='params_no_ns') + facet_wrap('ns', ncol=2)  # Useful facet
    # + aes(color='ns') + facet_wrap('params_no_ns', ncol=3)  # XXX Not useful facet
    + geom_point()
    + geom_hline(yintercept=0, color='grey')
    + scale_x_continuous(labels=labels_bytes(), breaks=breaks_bytes())
    + guides(fill=guide_legend(reverse=True))
    + theme(legend_position='bottom', legend_direction='vertical', legend_box_spacing=.4, legend_key_height=8)
    + theme_figsize(aspect_ratio=1/2)
    + ggtitle('test_score ~ model_size (tuned by e.g. max_depth)')
)
# Out:
# <ggplot: (-9223372036470782681)>

# %%
STOP
# Out:
# Traceback (most recent call last):
#
#   File "<ipython-input-19-ee4decdca3b8>", line 1, in <module>
#     STOP
#
# NameError: name 'STOP' is not defined

# %% [markdown]
# # Model diagnostics: all models, all folds

# %%
print('models:')
print('  params[*/%s]' % len(cv_models.params.cat.categories))
print('  fold[*/%s]' % cv.cv.n_splits)

# %%
# TODO Cache
# Coverage errors: all models, all folds
#   - Subset: all models
#   - Grain: sum(recs[model.test_i] for model)
#   - Dims: model_id, params, fold, y_true, rec_id
#   - Metrics: coverage_error
coverage_errors_all_all = (cv_models
    # .sample(n=5, random_state=0)  # For faster dev
    .pipe(lambda df: DF(
        OrderedDict(
            # **row[['model_id', 'params', 'fold']],  # Slow (in this inner loop), unpack manually instead
            model_id=row.model_id,
            params=row.params,
            params_no_ns=row.params_no_ns,
            ns=row.ns,
            fold=row.fold,
            i=i,
            y_true=y_true,
            coverage_error=coverage_error,
        )
        for row in iter_progress(df_rows(df), n=len(df))
        for i, y_true, coverage_error in zip(
            row.test_evals.i,
            row.test_evals.y,
            row.test_evals.coverage_errors(),
        )
    ))
    .astype(dict(
        model_id=cv_models.model_id.dtype,
        params=cv_models.params.dtype,
        params_no_ns=cv_models.params_no_ns.dtype,
        ns=cv_models.ns.dtype,
    ))
    .pipe(tap, lambda df: display(
        df_summary(df).T,
        df[:10],
    ))
)

# %%
# Facet by params_no_ns, order by median(coverage_error)
#   - Subset: all models
#   - Grain: sum(recs[model.test_i].groupby(params, y_true) for model)
#       - Over: fold, rec_id
#   - Dims: params, y_true
#   - Metrics: coverage_error.median
# in: coverage_errors_all_all, recs
(coverage_errors_all_all
    # .pipe(df_reverse_cat, 'params', 'params_no_ns', 'ns')
    .pipe(df_ordered_cat,
        y_true=lambda df: (
            # Sort species by median(coverage_error) (across all models)
            df.groupby('y_true').agg({'coverage_error': np.median}).reset_index().sort_values('coverage_error').y_true
            # Sort species by taxo (hard to compare across models, unless they're pretty low noise)
            # reversed(recs.species.cat.categories)
        ),
    )
    .pipe(ggplot, aes(x='y_true', y='coverage_error',
        # color='params',
    ))
    # + facet_wrap('params_no_ns', ncol=3)
    + facet_grid('ns ~ params_no_ns')
    # + geom_line(aes(group='params'), stat='summary', fun_y=np.median)  # TODO Bad interpolation with n_species
    + geom_point(aes(group='params'), stat='summary', fun_y=np.median)
    + coord_flip(
        # ylim=(0, min(30, len(np.unique(y)))),  # Restore eventually
    )
    # + geom_hline(yintercept=recs.species.nunique(), color='grey')
    # + scale_color_cmap_d(mpl.cm.tab20)
    + theme(legend_position='bottom', legend_direction='vertical', legend_box_spacing=.4, legend_key_height=8)
    # + theme_figsize(width=12*2, aspect_ratio=2/3)
    + theme_figsize(width=12, aspect_ratio=1/4)
    + ggtitle(rf'Coverage error over fold $\times$ instance, by params_no_ns $\times$ ns ({recs_stats})')
)

# %%
# TODO Slow, bad for notebook dev loop -- move lower, or disable by default?
# Facet by species
#   - Subset: all models
#   - Grain: sum(recs[model.test_i].groupby(params, y_true) for model)
#       - Over: fold, rec_id
#   - Dims: params, y_true
#   - Metrics: coverage_error.median
# in: coverage_errors_all_all, recs
(coverage_errors_all_all
    # .sample(200, random_state=0)  # Faster dev
    .astype({'y_true': metadata.species.df.shorthand.dtype})
    .pipe(df_reverse_cat, 'params')
    .pipe(ggplot, aes(x='params', y='coverage_error', color='params_no_ns'))
    + facet_wrap('y_true')
    + geom_hline(yintercept=1, color='grey')
    # + geom_hline(yintercept=recs.species.nunique(), color='grey')

    # Percentiles (faster, no overplot)
    # + geom_point(stat='summary', fun_y=np.median)
    # + geom_linerange(stat='summary', fun_ymin=partial(np.percentile, q=25), fun_ymax=partial(np.percentile, q=75))

    # Violin (slow, no overplot)
    # + geom_violin()

    # Boxplot (very slow, no overplot)
    # + geom_boxplot()

    # Points (medium cost, high overplot)
    #   - n (count) instead of prop (proportion)
    #   - scale_size_area() instead of default scale_size(), because it's a count [I don't grok this but it looks good]
    + geom_count(aes(size='..n..'), alpha=.5)
    + scale_size_area()
    + geom_point(stat='summary', fun_y=np.median, alpha=1, color='black', shape='|', size=3, stroke=1)

    + coord_flip()
    + scale_color_cmap_d(mpl.cm.tab20)
    + theme(axis_text_y=element_text(size=6))
    + theme_figsize('square')  # Faster
    # + theme_figsize('half')
    # + theme_figsize('full')
    # + theme_figsize('full_dense')
    + ggtitle(rf'Coverage error over fold $\times$ instance, by params ({recs_stats})')
)

# %% [markdown]
# # Model diagnostics: one model, all folds

# %%
params_i = 0
params = cv_models.params.cat.categories[params_i]
print("params:\n%s" % '\n'.join('  %s: %r' % (i, x) for i, x in enumerate(cv_models.params.cat.categories)))
print()
print('models:')
print('  params[%s/%s]: %r' % (params_i, len(cv_models.params.cat.categories), params))
print('  fold[*/%s]' % cv.cv.n_splits)

# %%
# Coverage errors: one model, all folds
#   - Subset: models.params == params
#   - Grain: sum(recs[model.test_i] for model)
#   - Dims: model_id, params, fold, y_true, rec_id
#   - Metrics: coverage_error
coverage_errors_one_all = (coverage_errors_all_all
    [lambda df: df.params == params]  # One model, all folds
)
display(
    df_summary(coverage_errors_one_all).T,
    coverage_errors_one_all[:10],
)

# %%
#   - Subset: models.params == params
#   - Grain: sum(recs[model.test_i].groupby(y_true) for model)
#       - Over: fold, rec_id
#   - Dims: y_true
#   - Metrics: count, coverage_error.percentiles
# in: coverage_errors_one_all, recs
(coverage_errors_one_all
    .astype({'y_true': metadata.species.df.shorthand.dtype})
    .pipe(df_reverse_cat, 'y_true')
    .pipe(ggplot, aes(x='y_true', y='coverage_error'))
    + geom_hline(yintercept=1, color='grey')
    + geom_hline(yintercept=recs.species.nunique(), color='grey')
    + geom_count(aes(size='..n..'), alpha=1)  # n (count) instead of prop (proportion)
    + scale_size_area()  # Instead of default scale_size(), because it's a count [I don't grok this but it looks good]
    + geom_point(stat='summary', fun_y=np.median, alpha=1, color='red', shape='|', size=6, stroke=2)
    + coord_flip()
    # + theme_figsize('inline')
    # + theme_figsize('square')
    # + theme_figsize('half')
    + theme_figsize('half_dense')
    # + theme_figsize('full')
    # + theme_figsize('full_dense')
    + ggtitle(rf'Coverage error over fold $\times$ instance ({params}) ({recs_stats})')
)

# %%
# One-model/all-folds confusion matrix
with figsize(
    # 'square',
    # 'full',
    'full_dense',
):
    (cv_models
        [lambda df: df.params == params]
        .pipe(lambda df: plot_confusion_matrix(
            classes=df.iloc[0].test_evals.classes,
            M=np.array([
                row.test_evals.confusion_matrix_prob()
                for row in df_rows(df)
            ]).sum(axis=0),
            # normalize=False,  # For counts
            raw=True, scale=10,  # Faster dev
            format=None,  # Omit numbers, too dense
            title=f'({recs_stats})',
        ))
    )

# %% [markdown]
# # Model diagnostics: one model, one fold

# %%
fold = 0
# params_i = ...  # Comment out to reuse from above
params = cv_models.params.cat.categories[params_i]
[(_, model)] = list(cv_models[lambda df: (df.params == params) & (df.fold == fold)].iterrows())
print("params:\n%s" % '\n'.join('  %s: %r' % (i, x) for i, x in enumerate(cv_models.params.cat.categories)))
print()
print('model:')
print('  params[%s/%s]: %r' % (params_i, len(cv_models.params.cat.categories), model.params))
print('  fold[%s/%s]' % (model.fold, cv.cv.n_splits))
print()
print(model)
# Out:
# [skip]

# %%
# in: model
model_id = model.model_id
params = model.params
fold = model.fold
# train_evals = model.train_evals
test_evals = model.test_evals

# in: model, recs
# train_recs = recs.iloc[train_evals.i]
# train_X = Search.X(recs)[train_evals.i]
# train_y = Search.y(recs)[train_evals.i]
test_recs = recs.iloc[test_evals.i]
test_X = Search.X(recs)[test_evals.i]
test_y = Search.y(recs)[test_evals.i]  # (Don't need to store cv_models.test_evals.y if we have recs -- which sometimes we don't?)

display(
    # len(train_recs),
    len(test_recs),
)
# Out:
# [skip]

# %%
# TODO Restore this plot like 'Coverage error over ...' above, so we can see _one_ model instead of aggregating over n_splits models
# # TODO Update [kill the .merge, then species -> y_true]
# (search.coverage_error_by(test_recs, 'id')
#     [:5]
#     # .merge(test_recs[['id', 'species']], on='id', how='left')
#     # .pipe(ggplot, aes(x='species', y='coverage_error'))
#     # + geom_count(aes(size='..n..'))
#     # + stat_summary(fun_y=np.median, geom='point', color='red', alpha=.5, shape='|', size=6, stroke=1)
#     # + stat_summary(
#     #     fun_ymin=partial(np.percentile, q=25), fun_ymax=partial(np.percentile, q=75),
#     #     geom='linerange', color='red', alpha=.5, size=1,
#     # )
#     # + coord_flip()
#     # + geom_hline(yintercept=len(search.classes_), color='grey')
#     # + scale_x_discrete(limits=list(reversed(test_recs.species.cat.categories)))
#     # + theme_figsize('square')
#     # + ggtitle(rf'Coverage error over instance ({model_id}) ({recs_stats})')
# )
# Out:
# [skip]

# %%
# One-model/one-fold confusion matrix
with figsize(
    'square',
    # 'full',
    # 'full_dense',
):
    plot_confusion_matrix_df(
        confusion_matrix_prob_df(model.test_evals.y, model.test_evals.y_scores, model.test_evals.classes),
        title=model.model_id,
        # normalize=False,  # For counts
        raw=True, scale=10,  # Faster dev
        title=f'({recs_stats})',
    )
# Out:
# [skip]
